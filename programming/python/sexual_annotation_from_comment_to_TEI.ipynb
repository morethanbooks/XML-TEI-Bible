# %%
import parse_sexual_anotation

# %%
wdir_str = "../../sexual-annotation/"
file_str = "GEN.xml"

book_name_str = file_str[0:3]

# %%
book_str = parse_sexual_anotation.open_book(wdir_str, file_str)
book_str[0:1000]
# Out:
# [&#39;../../sexual-annotation/GEN.xml&#39;]
# GEN
# &lt;class &#39;str&#39;&gt;
# &#39;&lt;?xml version=&quot;1.0&quot; encoding=&quot;UTF-8&quot;?&gt;\n\n\n\n&lt;?xml-model href=&quot;http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng&quot; type=&quot;application/xml&quot;\n\tschematypens=&quot;http://purl.oclc.org/dsdl/schematron&quot;?&gt;\n&lt;?xml-model href=&quot;https://raw.githubusercontent.com/morethanbooks/XML-TEI-Bible/master/scheme/tei_lite.rng&quot; type=&quot;application/xml&quot; schematypens=&quot;http://relaxng.org/ns/structure/1.0&quot;?&gt;\n\n\n\n&lt;?xml-stylesheet type=&quot;text/css&quot; href=&quot;../styles/styles.css&quot; rel=&quot;stylesheet&quot; title=&quot;Classic&quot;?&gt;\n&lt;?xml-stylesheet type=&quot;text/css&quot; href=&quot;../styles/word2pix-reference.css&quot; rel=&quot;stylesheet&quot; title=&quot;Word2Pix References&quot;?&gt;\n&lt;?xml-stylesheet type=&quot;text/css&quot; href=&quot;styles/word2pix-quotes.css&quot; rel=&quot;stylesheet&quot; title=&quot;Word2Pix Quotations&quot;?&gt;\n&lt;?xml-stylesheet type=&quot;text/css&quot; href=&quot;styles/word2pix-level-q.css&quot; rel=&quot;stylesheet&quot; title=&quot;Word2Pix Level Quotation&quot;?&gt;\n\n&lt;TEI xmlns=&quot;http://www.tei-c.org/ns/1.0&quot;&gt;\n\t&lt;teiHeader&gt;\n\t\t&lt;fileDesc&gt;\n\t\t\t&lt;titleStmt&gt;\n\t\t\t\t&lt;title&gt;Génesis&lt;/title&gt;\n\t\t\t\t&lt;title type=&quot;idno&quot;&gt;\n\t\t\t\t\t&lt;idno type=&quot;s&#39;

# %%
taxonomy_file_str = "taxonomy.xml"

# %%
taxonomy_el = parse_sexual_anotation.open_taxonomy(wdir_str, taxonomy_file_str)
# Out:
# &lt;class &#39;lxml.etree._Element&#39;&gt;

# %%
namespaces_dict = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
categories_id_lt = parse_sexual_anotation.get_list_categories(taxonomy_el, namespaces = namespaces_dict)

print(categories_id_lt)
# Out:
# [&#39;relations&#39;, &#39;monogamy&#39;, &#39;poligamy&#39;, &#39;marriage&#39;, &#39;second-marriage&#39;, &#39;second-marriage-divorce&#39;, &#39;second-marriage-widow&#39;, &#39;interfaith-marriage&#39;, &#39;interfaith-relation&#39;, &#39;non-marital-relation&#39;, &#39;marital-relation-political-family&#39;, &#39;lord-servant-relation&#39;, &#39;marital-relation-direct-family&#39;, &#39;arranged-marriage&#39;, &#39;divorce&#39;, &#39;engaged&#39;, &#39;love&#39;, &#39;jealousy&#39;, &#39;ascendant-descendant&#39;, &#39;indirect-ascendant-descendant&#39;, &#39;acts&#39;, &#39;social-related-act&#39;, &#39;wedding&#39;, &#39;body-related-act&#39;, &#39;massage&#39;, &#39;kiss&#39;, &#39;hug&#39;, &#39;dance&#39;, &#39;abortion&#39;, &#39;circumcision&#39;, &#39;breast-feeding&#39;, &#39;sexual-act&#39;, &#39;sexual-act-stage&#39;, &#39;erotic-time&#39;, &#39;initation-sexual-act&#39;, &#39;orgasm&#39;, &#39;ejaculation&#39;, &#39;time-after-sex&#39;, &#39;sexual-act-type&#39;, &#39;coitus&#39;, &#39;first-sexual-act&#39;, &#39;coitus-interruptus&#39;, &#39;self-masturbation&#39;, &#39;masturbation&#39;, &#39;oral-sex&#39;, &#39;anal-sex&#39;, &#39;non-penetrative-sex&#39;, &#39;female-rape&#39;, &#39;male-rape&#39;, &#39;sexual-assault&#39;, &#39;female-sexual-assault&#39;, &#39;male-sexual-assault&#39;, &#39;sexual-deception&#39;, &#39;sexual-drive&#39;, &#39;sexual-desire&#39;, &#39;sex-for-goods&#39;, &#39;other-sexual-act&#39;, &#39;sexual-act-situation&#39;, &#39;sex-in-marriage&#39;, &#39;sex-before-marriage&#39;, &#39;sex-outside-marriage&#39;, &#39;sex-outside&#39;, &#39;sexual-act-participants&#39;, &#39;heterosexual-sex&#39;, &#39;homosexual-sex&#39;, &#39;gay-sex&#39;, &#39;lesbian-sex&#39;, &#39;prostitution-sex&#39;, &#39;religous-sex&#39;, &#39;parents-children-sex&#39;, &#39;sibling-sex&#39;, &#39;greater-family-sex&#39;, &#39;angel-human-sex&#39;, &#39;animal-human-sex&#39;, &#39;animal-sex&#39;, &#39;groupal-sex&#39;, &#39;lord-servant-sex&#39;, &#39;states&#39;, &#39;virginity&#39;, &#39;celibacy&#39;, &#39;infertility&#39;, &#39;nudity&#39;, &#39;semi-nudity&#39;, &#39;pregnancy&#39;, &#39;beauty&#39;, &#39;dishonor&#39;, &#39;body&#39;, &#39;body-by-gender&#39;, &#39;female-body&#39;, &#39;male-body&#39;, &#39;body-part&#39;, &#39;genitalia&#39;, &#39;female-genitalia&#39;, &#39;male-genitalia&#39;, &#39;prepuce&#39;, &#39;gluteus-anus&#39;, &#39;female-breast&#39;, &#39;male-chest&#39;, &#39;ovaries&#39;, &#39;semen&#39;, &#39;head&#39;, &#39;eye&#39;, &#39;nose&#39;, &#39;cheek&#39;, &#39;mouth&#39;, &#39;lips&#39;, &#39;tongue&#39;, &#39;tooth&#39;, &#39;hair&#39;, &#39;thigh&#39;, &#39;neck&#39;, &#39;hand&#39;, &#39;skin&#39;, &#39;foot&#39;, &#39;waist&#39;, &#39;heart&#39;, &#39;navel&#39;, &#39;belly&#39;, &#39;leg&#39;, &#39;arm&#39;, &#39;rib&#39;, &#39;lubrication&#39;, &#39;face&#39;, &#39;body-function&#39;, &#39;birth&#39;, &#39;fertilization&#39;, &#39;misscarriage&#39;, &#39;erection&#39;, &#39;menstruation&#39;, &#39;sleep&#39;, &#39;diseases&#39;, &#39;menstrual-disorder&#39;, &#39;senses&#39;, &#39;smell&#39;, &#39;things&#39;, &#39;clothes&#39;, &#39;belt&#39;, &#39;veil&#39;, &#39;perfume&#39;, &#39;juwels&#39;, &#39;earrings&#39;, &#39;piercing&#39;, &#39;collar&#39;, &#39;bracelet&#39;, &#39;food-and-related&#39;, &#39;drink&#39;, &#39;water&#39;, &#39;milk&#39;, &#39;wine&#39;, &#39;glass&#39;, &#39;spices&#39;, &#39;wheat&#39;, &#39;honey&#39;, &#39;fruits&#39;, &#39;pomegranate&#39;, &#39;grapes&#39;, &#39;raisin&#39;, &#39;apples&#39;, &#39;figs&#39;, &#39;carriage&#39;, &#39;weapons&#39;, &#39;sword&#39;, &#39;shield&#39;, &#39;money&#39;, &#39;metal&#39;, &#39;silver&#39;, &#39;gold&#39;, &#39;fountain&#39;, &#39;well&#39;, &#39;pitcher&#39;, &#39;environment&#39;, &#39;moon&#39;, &#39;sun&#39;, &#39;rain&#39;, &#39;wind&#39;, &#39;places&#39;, &#39;interior-spaces&#39;, &#39;bedroom&#39;, &#39;bed&#39;, &#39;door&#39;, &#39;wall&#39;, &#39;house&#39;, &#39;tower&#39;, &#39; ...

# %%
sexual_annotations_from_comments_lt = parse_sexual_anotation.parse_sexual_annotations_from_comments(book_str)
# Out:
# [(&#39;b.GEN.2.7&#39;, &#39;metaphorically birth; blessed-aspect&#39;), (&#39;b.GEN.2.21&#39;, &#39;metaphorically birth; blessed-aspect; rips; sleep&#39;), (&#39;b.GEN.2.22&#39;, &#39;metaphorically birth; blessed-aspect; rips; sleep&#39;), (&#39;b.GEN.2.23&#39;, &#39;body; women; men; blessed-aspect&#39;), (&#39;b.GEN.2.24&#39;, &#39;wedding cert=&quot;medium&quot;; sexual-act cert=&quot;medium&quot;|coitus cert=&quot;medium&quot;; women; men; blessed-aspect&#39;), (&#39;b.GEN.2.25&#39;, &#39;nudity; blessed-aspect&#39;), (&#39;b.GEN.3.7&#39;, &#39;nudity; negative; cloth&#39;), (&#39;b.GEN.3.10&#39;, &#39;nudity; negative&#39;), (&#39;b.GEN.3.11&#39;, &#39;nudity; neutral&#39;), (&#39;b.GEN.3.16&#39;, &#39;birth; negative; women; men&#39;), (&#39;b.GEN.3.21&#39;, &#39;nudity; neutral; cloths&#39;), (&#39;b.GEN.4.1&#39;, &#39;coitus; heterosexual-sex; neutral; conception; birth; descendant&#39;), (&#39;b.GEN.4.2&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.4.17&#39;, &#39;coitus; heterosexual-sex; neutral; conception; birth; descendant&#39;), (&#39;b.GEN.4.18&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.4.19&#39;, &#39;poligamy; neutral&#39;), (&#39;b.GEN.4.20&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.4.22&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.4.25&#39;, &#39;coitus; heterosexual-sex; neutral; birth; descendant&#39;), (&#39;b.GEN.4.26&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.5.3&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.7&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.10&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.12&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.13&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.15&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.16&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.18&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.19&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.21&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.22&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.25&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.26&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.28&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.30&#39;, &#39;descendant&#39;), (&#39;b.GEN.5.32&#39;, &#39;descendant&#39;), (&#39;b.GEN.6.1&#39;, &#39;descendant&#39;), (&#39;b.GEN.6.2&#39;, &#39;beauty; women; men; marriage cert=&quot;medium&quot;&#39;), (&#39;b.GEN.6.4&#39;, &#39;birth; marriage cert=&quot;medium&quot;|coitus cert=&quot;medium&quot;&#39;), (&#39;b.GEN.6.10&#39;, &#39;descendant&#39;), (&#39;b.GEN.9.1&#39;, &#39;fertilization; blessed-aspect&#39;), (&#39;b.GEN.9.7&#39;, &#39;fertilization; blessed-aspect&#39;), (&#39;b.GEN.9.21&#39;, &#39;nudity; negative&#39;), (&#39;b.GEN.9.22&#39;, &#39;nudity; negative&#39;), (&#39;b.GEN.9.23&#39;, &#39;nudity; negative&#39;), (&#39;b.GEN.10.1&#39;, &#39;birth; descendant&#39;), (&#39;b.GEN.10.2&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.3&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.4&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.6&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.7&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.8&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.10&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.13&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.14&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.15&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.16&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.17&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.18&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.20&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.21&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.22&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.23&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.24&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.25&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.26&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.27&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.28&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.29&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.31&#39;, &#39;descendant&#39;), (&#39;b.GEN.10.32&#39;, &#39;descendant&#39;), (&#39;b.GEN.11.10&#39;, &#39;descendant&#39;), (&#39;b.GEN.1 ...

# %%
error_lt, standOff_str = parse_sexual_anotation.parse_each_sexual_annotation_as_comment(sexual_annotations_from_comments_lt, categories_id_lt, "GEN")
# Out:
# b.GEN.2.7
# metaphorically birth
# &lt;class &#39;str&#39;&gt;
# metaphorically
# ERROR!! metaphorically
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.2.21
# metaphorically birth
# &lt;class &#39;str&#39;&gt;
# metaphorically
# ERROR!! metaphorically
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  rips
# &lt;class &#39;str&#39;&gt;
# rips
# ERROR!! rips
#  sleep
# &lt;class &#39;str&#39;&gt;
# sleep
# b.GEN.2.22
# metaphorically birth
# &lt;class &#39;str&#39;&gt;
# metaphorically
# ERROR!! metaphorically
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  rips
# &lt;class &#39;str&#39;&gt;
# rips
# ERROR!! rips
#  sleep
# &lt;class &#39;str&#39;&gt;
# sleep
# b.GEN.2.23
# body
# &lt;class &#39;str&#39;&gt;
# body
#  women
# &lt;class &#39;str&#39;&gt;
# women
#  men
# &lt;class &#39;str&#39;&gt;
# men
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.2.24
# wedding cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# wedding
#  sexual-act cert=&quot;medium&quot;|coitus cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-act
# &lt;class &#39;str&#39;&gt;
# coitus
#  women
# &lt;class &#39;str&#39;&gt;
# women
#  men
# &lt;class &#39;str&#39;&gt;
# men
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.2.25
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.3.7
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  cloth
# &lt;class &#39;str&#39;&gt;
# cloth
# ERROR!! cloth
# b.GEN.3.10
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.3.11
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.3.16
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  women
# &lt;class &#39;str&#39;&gt;
# women
#  men
# &lt;class &#39;str&#39;&gt;
# men
# b.GEN.3.21
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  cloths
# &lt;class &#39;str&#39;&gt;
# cloths
# ERROR!! cloths
# b.GEN.4.1
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.2
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.17
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.18
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.19
# poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.4.20
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.22
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.25
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.4.26
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.7
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.18
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.19
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.25
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.26
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.28
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.30
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.5.32
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.6.1
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.6.2
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  women
# &lt;class &#39;str&#39;&gt;
# women
#  men
# &lt;class &#39;str&#39;&gt;
# men
#  marriage cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# marriage
# b.GEN.6.4
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  marriage cert=&quot;medium&quot;|coitus cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# marriage
# &lt;class &#39;str&#39;&gt;
# coitus
# b.GEN.6.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.9.1
# fertilization
# &lt;class &#39;str&#39;&gt;
# fertilization
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.9.7
# fertilization
# &lt;class &#39;str&#39;&gt;
# fertilization
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.9.21
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.9.22
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.9.23
# nudity
# &lt;class &#39;str&#39;&gt;
# nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.10.1
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.2
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.6
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.7
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.8
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.17
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.18
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.20
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.24
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.25
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.26
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.27
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.28
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.29
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.31
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.10.32
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.11
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.17
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.18
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.19
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.20
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.24
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.25
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.26
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.27
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.29
# monogamy
# &lt;class &#39;str&#39;&gt;
# monogamy
#  marriage
# &lt;class &#39;str&#39;&gt;
# marriage
# b.GEN.11.30
# infertility
# &lt;class &#39;str&#39;&gt;
# infertility
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.11.31
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.12.2
# ascendant-descendant
# &lt;class &#39;str&#39;&gt;
# ascendant-descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.12.11
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.12.12
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  sexual-desire cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.12.13
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  sexual-desire cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  condemned cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.12.14
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  condemned cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.12.15
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  condemned cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.12.17
# condemned cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.12.18
# condemnde cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemnde
# ERROR!! condemnde
# b.GEN.12.19
# non-marital-relation
# &lt;class &#39;str&#39;&gt;
# non-marital-relation
#  condemnde cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# condemnde
# ERROR!! condemnde
# b.GEN.13.13
# condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  sexual-act cert=&quot;low&quot;| gay-sex cert=&quot;low&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-act
# &lt;class &#39;str&#39;&gt;
# gay-sex
# b.GEN.13.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.13.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.15.2
# infertility cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# infertility
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.15.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  indirect-ascendant-descendant
# &lt;class &#39;str&#39;&gt;
# indirect-ascendant-descendant
# b.GEN.15.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#   indirect-ascendant-descendant
# &lt;class &#39;str&#39;&gt;
# indirect-ascendant-descendant
# b.GEN.15.5
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#   blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.15.6
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#   blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.16.1
# infertility
# &lt;class &#39;str&#39;&gt;
# infertility
# b.GEN.16.2
# infertility
# &lt;class &#39;str&#39;&gt;
# infertility
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  sex-outside
# &lt;class &#39;str&#39;&gt;
# sex-outside
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  lord-servant-sex
# &lt;class &#39;str&#39;&gt;
# lord-servant-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.16.3
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  sex-outside
# &lt;class &#39;str&#39;&gt;
# sex-outside
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  lord-servant-sex
# &lt;class &#39;str&#39;&gt;
# lord-servant-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.16.4
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  sex-outside
# &lt;class &#39;str&#39;&gt;
# sex-outside
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  lord-servant-sex
# &lt;class &#39;str&#39;&gt;
# lord-servant-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  fertilization
# &lt;class &#39;str&#39;&gt;
# fertilization
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.16.5
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
#  jelocy
# &lt;class &#39;str&#39;&gt;
# jelocy
# ERROR!! jelocy
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.16.11
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
#  fertilization
# &lt;class &#39;str&#39;&gt;
# fertilization
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.16.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.16.15
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.16.16
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.17.2
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.5
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.6
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.7
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.8
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.9
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.17.11
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  circumcised
# &lt;class &#39;str&#39;&gt;
# circumcised
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#   blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  circumcised
# &lt;class &#39;str&#39;&gt;
# circumcised
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  body
# &lt;class &#39;str&#39;&gt;
# body
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.14
# uncircuncised
# &lt;class &#39;str&#39;&gt;
# uncircuncised
# ERROR!! uncircuncised
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
# b.GEN.17.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.17
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  fertilization
# &lt;class &#39;str&#39;&gt;
# fertilization
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.17.19
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.20
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  circuncised
# &lt;class &#39;str&#39;&gt;
# circuncised
# ERROR!! circuncised
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.24
# prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.25
# prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.17.26
# prepuce
# &lt;class &#39;str&#39;&gt;
# prepuce
#  circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.17.27
# circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  circuncised
# &lt;class &#39;str&#39;&gt;
# circuncised
# ERROR!! circuncised
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.18.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.18.11
# menstruation
# &lt;class &#39;str&#39;&gt;
# menstruation
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.18.12
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.18.13
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
# b.GEN.18.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.18.20
# condemned-aspect cert=&quot;low&quot;
# &lt;class &#39;str&#39;&gt;
# condemned-aspect
#  sexual-act cert=&quot;medium&quot;| gay-sex cert=&quot;low&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-act
# &lt;class &#39;str&#39;&gt;
# gay-sex
# b.GEN.19.4
# sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
# b.GEN.19.5
# sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  gay-sex
# &lt;class &#39;str&#39;&gt;
# gay-sex
#  angel-human-sex
# &lt;class &#39;str&#39;&gt;
# angel-human-sex
#  sexual-assault
# &lt;class &#39;str&#39;&gt;
# sexual-assault
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
# b.GEN.19.7
# gay-sex
# &lt;class &#39;str&#39;&gt;
# gay-sex
#  angel-human-sex
# &lt;class &#39;str&#39;&gt;
# angel-human-sex
#  sexual-assault
# &lt;class &#39;str&#39;&gt;
# sexual-assault
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
# b.GEN.19.8
# heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  virginity
# &lt;class &#39;str&#39;&gt;
# virginity
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
# b.GEN.19.9
# sexual-assault
# &lt;class &#39;str&#39;&gt;
# sexual-assault
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.19.10
# sexual-assault
# &lt;class &#39;str&#39;&gt;
# sexual-assault
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.19.11
# sexual-assault
# &lt;class &#39;str&#39;&gt;
# sexual-assault
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.19.31
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  parents-children-sex
# &lt;class &#39;str&#39;&gt;
# parents-children-sex
# b.GEN.19.32
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  parents-children-sex
# &lt;class &#39;str&#39;&gt;
# parents-children-sex
#  male-rape
# &lt;class &#39;str&#39;&gt;
# male-rape
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.19.33
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  parents-children-sex
# &lt;class &#39;str&#39;&gt;
# parents-children-sex
#  male-rape
# &lt;class &#39;str&#39;&gt;
# male-rape
# b.GEN.19.34
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  parents-children-sex
# &lt;class &#39;str&#39;&gt;
# parents-children-sex
#  male-rape
# &lt;class &#39;str&#39;&gt;
# male-rape
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.19.35
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  parents-children-sex
# &lt;class &#39;str&#39;&gt;
# parents-children-sex
#  male-rape
# &lt;class &#39;str&#39;&gt;
# male-rape
# b.GEN.19.36
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
# b.GEN.19.37
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.19.38
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.20.2
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  sexual-act cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-act
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.3
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  sexual-act cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sexual-act
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.4
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
# b.GEN.20.5
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.6
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.9
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.10
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.20.12
# marriage
# &lt;class &#39;str&#39;&gt;
# marriage
# b.GEN.20.17
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.20.18
# infertility
# &lt;class &#39;str&#39;&gt;
# infertility
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.21.1
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
# b.GEN.21.2
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.21.4
# circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
# b.GEN.21.5
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.21.6
# conception cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
# b.GEN.21.7
# breast-feeding
# &lt;class &#39;str&#39;&gt;
# breast-feeding
# b.GEN.21.8
# breast-feeding
# &lt;class &#39;str&#39;&gt;
# breast-feeding
# b.GEN.21.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.22.20
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.22.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.22.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.22.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.22.24
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  concubina
# &lt;class &#39;str&#39;&gt;
# concubina
# ERROR!! concubina
# b.GEN.24.2
# thigh
# &lt;class &#39;str&#39;&gt;
# thigh
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.3
# interfaith-marriage
# &lt;class &#39;str&#39;&gt;
# interfaith-marriage
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.24.4
# marriage
# &lt;class &#39;str&#39;&gt;
# marriage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.5
# marriage
# &lt;class &#39;str&#39;&gt;
# marriage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.9
# thigh
# &lt;class &#39;str&#39;&gt;
# thigh
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.14
# fountain
# &lt;class &#39;str&#39;&gt;
# fountain
#  water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
# b.GEN.24.15
# water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
# b.GEN.24.16
# beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  virginity
# &lt;class &#39;str&#39;&gt;
# virginity
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  fountain
# &lt;class &#39;str&#39;&gt;
# fountain
# b.GEN.24.17
# water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  fountain
# &lt;class &#39;str&#39;&gt;
# fountain
# b.GEN.24.18
# water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
# b.GEN.24.19
# water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  camel
# &lt;class &#39;str&#39;&gt;
# camel
# b.GEN.24.20
# water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  camel
# &lt;class &#39;str&#39;&gt;
# camel
# b.GEN.24.22
# earrings
# &lt;class &#39;str&#39;&gt;
# earrings
#  bracelete
# &lt;class &#39;str&#39;&gt;
# bracelete
# ERROR!! bracelete
# camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
# b.GEN.24.25
# sleep
# &lt;class &#39;str&#39;&gt;
# sleep
# b.GEN.24.29
# fountain
# &lt;class &#39;str&#39;&gt;
# fountain
# b.GEN.24.30
# earrings
# &lt;class &#39;str&#39;&gt;
# earrings
#  braceletes
# &lt;class &#39;str&#39;&gt;
# braceletes
# ERROR!! braceletes
#  camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  fountain
# &lt;class &#39;str&#39;&gt;
# fountain
# b.GEN.24.32
# camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  water
# &lt;class &#39;str&#39;&gt;
# water
#  feet
# &lt;class &#39;str&#39;&gt;
# feet
# ERROR!! feet
# b.GEN.24.33
# food
# &lt;class &#39;str&#39;&gt;
# food
# ERROR!! food
# b.GEN.24.35
# sheep
# &lt;class &#39;str&#39;&gt;
# sheep
#  cow
# &lt;class &#39;str&#39;&gt;
# cow
#  silver
# &lt;class &#39;str&#39;&gt;
# silver
#  gold
# &lt;class &#39;str&#39;&gt;
# gold
#  camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  donkeys
# &lt;class &#39;str&#39;&gt;
# donkeys
# ERROR!! donkeys
# b.GEN.24.36
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.37
# engaged
# &lt;class &#39;str&#39;&gt;
# engaged
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.38
# engaged
# &lt;class &#39;str&#39;&gt;
# engaged
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.39
# engaged
# &lt;class &#39;str&#39;&gt;
# engaged
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.40
# engaged
# &lt;class &#39;str&#39;&gt;
# engaged
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.42
# fountain
# &lt;class &#39;str&#39;&gt;
# fountain
# b.GEN.24.43
# fountain
# &lt;class &#39;str&#39;&gt;
# fountain
#  water
# &lt;class &#39;str&#39;&gt;
# water
#  pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
# b.GEN.24.44
# water
# &lt;class &#39;str&#39;&gt;
# water
#  camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  engaged
# &lt;class &#39;str&#39;&gt;
# engaged
# b.GEN.24.45
# pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  fountain
# &lt;class &#39;str&#39;&gt;
# fountain
#  water
# &lt;class &#39;str&#39;&gt;
# water
# b.GEN.24.46
# pitcher
# &lt;class &#39;str&#39;&gt;
# pitcher
#  water
# &lt;class &#39;str&#39;&gt;
# water
#  camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
# b.GEN.24.47
# piercing
# &lt;class &#39;str&#39;&gt;
# piercing
#  nose
# &lt;class &#39;str&#39;&gt;
# nose
#  braceletes
# &lt;class &#39;str&#39;&gt;
# braceletes
# ERROR!! braceletes
#  arm
# &lt;class &#39;str&#39;&gt;
# arm
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.24.48
# engaged
# &lt;class &#39;str&#39;&gt;
# engaged
# b.GEN.24.54
# food
# &lt;class &#39;str&#39;&gt;
# food
# ERROR!! food
#  drink
# &lt;class &#39;str&#39;&gt;
# drink
# b.GEN.24.60
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.24.62
# well
# &lt;class &#39;str&#39;&gt;
# well
# b.GEN.24.63
# camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  eyes
# &lt;class &#39;str&#39;&gt;
# eyes
# ERROR!! eyes
# b.GEN.24.64
# camell
# &lt;class &#39;str&#39;&gt;
# camell
# ERROR!! camell
#  eyes
# &lt;class &#39;str&#39;&gt;
# eyes
# ERROR!! eyes
# b.GEN.24.65
# velo
# &lt;class &#39;str&#39;&gt;
# velo
# ERROR!! velo
# b.GEN.24.67
# love cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# love
# coitus cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# coitus
#  first-sexual-act  cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# first-sexual-act
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  sex-in-marriage cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# sex-in-marriage
#  heterosexual-sex cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
# b.GEN.25.1
# poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.25.2
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.25.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.6
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.25.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
# b.GEN.25.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.19
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.20
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
# b.GEN.25.21
# marriage
# &lt;class &#39;str&#39;&gt;
# marriage
#  esterility
# &lt;class &#39;str&#39;&gt;
# esterility
# ERROR!! esterility
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
# b.GEN.25.22
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
# b.GEN.25.23
# pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.24
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  pregnancy
# &lt;class &#39;str&#39;&gt;
# pregnancy
# b.GEN.25.25
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.25.26
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.26.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.26.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.26.7
# sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.26.8
# erotic-time cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# erotic-time
# b.GEN.26.9
# sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.26.10
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.26.11
# sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.26.24
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.26.34
# poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.26.35
# poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.27.26
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.27.27
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.28.1
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  interfaith-marriage
# &lt;class &#39;str&#39;&gt;
# interfaith-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.28.2
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.28.3
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.28.4
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.28.8
# interfaith-marriage
# &lt;class &#39;str&#39;&gt;
# interfaith-marriage
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
# b.GEN.28.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
# b.GEN.29.11
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.13
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
#  hug
# &lt;class &#39;str&#39;&gt;
# hug
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.17
# eyes
# &lt;class &#39;str&#39;&gt;
# eyes
# ERROR!! eyes
#  beauty
# &lt;class &#39;str&#39;&gt;
# beauty
#  face
# &lt;class &#39;str&#39;&gt;
# face
# b.GEN.29.18
# love
# &lt;class &#39;str&#39;&gt;
# love
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
# b.GEN.29.19
# arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.20
# love
# &lt;class &#39;str&#39;&gt;
# love
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.21
# wedding
# &lt;class &#39;str&#39;&gt;
# wedding
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
# b.GEN.29.22
# wedding
# &lt;class &#39;str&#39;&gt;
# wedding
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.23
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  first-sexual-act
# &lt;class &#39;str&#39;&gt;
# first-sexual-act
#  sex-in-marriage
# &lt;class &#39;str&#39;&gt;
# sex-in-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.29.24
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.29.25
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
# b.GEN.29.26
# arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.29.27
# arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.29.28
# arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  marriage
# &lt;class &#39;str&#39;&gt;
# marriage
# b.GEN.29.29
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.29.30
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  first-sexual-act
# &lt;class &#39;str&#39;&gt;
# first-sexual-act
#  sex-in-marriage
# &lt;class &#39;str&#39;&gt;
# sex-in-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.31
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  sterility
# &lt;class &#39;str&#39;&gt;
# sterility
# ERROR!! sterility
# b.GEN.29.32
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.33
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.34
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.29.35
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  sterility
# &lt;class &#39;str&#39;&gt;
# sterility
# ERROR!! sterility
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.1
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  sterility
# &lt;class &#39;str&#39;&gt;
# sterility
# ERROR!! sterility
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.30.2
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  sterility
# &lt;class &#39;str&#39;&gt;
# sterility
# ERROR!! sterility
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.30.3
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  lord-sevant-sex
# &lt;class &#39;str&#39;&gt;
# lord-sevant-sex
# ERROR!! lord-sevant-sex
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.30.4
# lord-sevant-sex
# &lt;class &#39;str&#39;&gt;
# lord-sevant-sex
# ERROR!! lord-sevant-sex
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.30.5
# lord-sevant-relation
# &lt;class &#39;str&#39;&gt;
# lord-sevant-relation
# ERROR!! lord-sevant-relation
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.6
# descedant
# &lt;class &#39;str&#39;&gt;
# descedant
# ERROR!! descedant
# b.GEN.30.7
# lord-sevant-relation
# &lt;class &#39;str&#39;&gt;
# lord-sevant-relation
# ERROR!! lord-sevant-relation
#  conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.8
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.9
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  sterility
# &lt;class &#39;str&#39;&gt;
# sterility
# ERROR!! sterility
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.30.10
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  lord-servant-sex
# &lt;class &#39;str&#39;&gt;
# lord-servant-sex
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.11
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.12
# lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.13
# descedant
# &lt;class &#39;str&#39;&gt;
# descedant
# ERROR!! descedant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.15
# jealousy
# &lt;class &#39;str&#39;&gt;
# jealousy
#  poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  sex-for-goods
# &lt;class &#39;str&#39;&gt;
# sex-for-goods
# b.GEN.30.16
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  sex-for-goods
# &lt;class &#39;str&#39;&gt;
# sex-for-goods
#  poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
# b.GEN.30.17
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.30.18
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.19
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.20
# jealousy
# &lt;class &#39;str&#39;&gt;
# jealousy
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  poligamy
# &lt;class &#39;str&#39;&gt;
# poligamy
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.21
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.22
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  blessed-aspect
# &lt;class &#39;str&#39;&gt;
# blessed-aspect
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.30.23
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.30.24
# conception
# &lt;class &#39;str&#39;&gt;
# conception
# ERROR!! conception
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.30.25
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.31.28
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.31.35
# menstruation
# &lt;class &#39;str&#39;&gt;
# menstruation
# b.GEN.31.55
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.32.25
# thigh
# &lt;class &#39;str&#39;&gt;
# thigh
# b.GEN.32.32
# thigh
# &lt;class &#39;str&#39;&gt;
# thigh
# b.GEN.33.4
# hug
# &lt;class &#39;str&#39;&gt;
# hug
#  kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.34.1
# birth
# &lt;class &#39;str&#39;&gt;
# birth
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.34.2
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  female-rape cert=&quot;medium&quot;
# &lt;class &#39;str&#39;&gt;
# female-rape
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  deshonra
# &lt;class &#39;str&#39;&gt;
# deshonra
# ERROR!! deshonra
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.34.3
# love
# &lt;class &#39;str&#39;&gt;
# love
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.34.5
# deshonra
# &lt;class &#39;str&#39;&gt;
# deshonra
# ERROR!! deshonra
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.34.7
# deshonra
# &lt;class &#39;str&#39;&gt;
# deshonra
# ERROR!! deshonra
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.34.8
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  love
# &lt;class &#39;str&#39;&gt;
# love
#  arranged-married
# &lt;class &#39;str&#39;&gt;
# arranged-married
# ERROR!! arranged-married
# b.GEN.34.9
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  arranged-married
# &lt;class &#39;str&#39;&gt;
# arranged-married
# ERROR!! arranged-married
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.34.12
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  arranged-married
# &lt;class &#39;str&#39;&gt;
# arranged-married
# ERROR!! arranged-married
# b.GEN.34.13
# deshonra
# &lt;class &#39;str&#39;&gt;
# deshonra
# ERROR!! deshonra
# b.GEN.34.14
# uncircuncised
# &lt;class &#39;str&#39;&gt;
# uncircuncised
# ERROR!! uncircuncised
#  condemned
# &lt;class &#39;str&#39;&gt;
# condemned
# ERROR!! condemned
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
# b.GEN.34.15
# circumcision
# &lt;class &#39;str&#39;&gt;
# circumcision
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.34.16
# engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
# ...
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
# b.GEN.39.8
# celibacy
# &lt;class &#39;str&#39;&gt;
# celibacy
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.39.9
# celibacy
# &lt;class &#39;str&#39;&gt;
# celibacy
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.39.10
# sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
# b.GEN.39.12
# male-sexual-assault
# &lt;class &#39;str&#39;&gt;
# male-sexual-assault
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  celibacy
# &lt;class &#39;str&#39;&gt;
# celibacy
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
# b.GEN.39.13
# celibacy
# &lt;class &#39;str&#39;&gt;
# celibacy
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
#  neutral
# &lt;class &#39;str&#39;&gt;
# neutral
# ERROR!! neutral
# b.GEN.39.14
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
# b.GEN.39.15
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
# b.GEN.39.16
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.39.17
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
# b.GEN.39.18
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
#  celibacy
# &lt;class &#39;str&#39;&gt;
# celibacy
#  semi-nudity
# &lt;class &#39;str&#39;&gt;
# semi-nudity
# b.GEN.39.19
# sexual-deception
# &lt;class &#39;str&#39;&gt;
# sexual-deception
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
#  female-sexual-assault
# &lt;class &#39;str&#39;&gt;
# female-sexual-assault
#  sexual-desire
# &lt;class &#39;str&#39;&gt;
# sexual-desire
# b.GEN.41.45
# arranged-marriage
# &lt;class &#39;str&#39;&gt;
# arranged-marriage
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
#  engage
# &lt;class &#39;str&#39;&gt;
# engage
# ERROR!! engage
#  intra-faith
# &lt;class &#39;str&#39;&gt;
# intra-faith
# ERROR!! intra-faith
# b.GEN.45.15
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.46.7
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.8
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.9
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.10
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.11
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.12
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.13
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.14
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.15
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  birth
# &lt;class &#39;str&#39;&gt;
# birth
# b.GEN.46.16
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.17
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.18
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
#  descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.19
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.20
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  interfaith-relation
# &lt;class &#39;str&#39;&gt;
# interfaith-relation
# b.GEN.46.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.24
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.25
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  lord-servant-relation
# &lt;class &#39;str&#39;&gt;
# lord-servant-relation
# b.GEN.46.26
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
#  marriage
# &lt;class &#39;str&#39;&gt;
# marriage
# b.GEN.46.27
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.46.29
# hug
# &lt;class &#39;str&#39;&gt;
# hug
#  positive
# &lt;class &#39;str&#39;&gt;
# positive
# ERROR!! positive
# b.GEN.47.29
# thigh
# &lt;class &#39;str&#39;&gt;
# thigh
# b.GEN.48.9
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.48.10
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
#  hug
# &lt;class &#39;str&#39;&gt;
# hug
# b.GEN.48.11
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.49.4
# coitus
# &lt;class &#39;str&#39;&gt;
# coitus
#  heterosexual-sex
# &lt;class &#39;str&#39;&gt;
# heterosexual-sex
#  sex-outside-marriage
# &lt;class &#39;str&#39;&gt;
# sex-outside-marriage
#  great-family-sex
# &lt;class &#39;str&#39;&gt;
# great-family-sex
# ERROR!! great-family-sex
#  lord-servant-sex
# &lt;class &#39;str&#39;&gt;
# lord-servant-sex
#  negative
# &lt;class &#39;str&#39;&gt;
# negative
# ERROR!! negative
# b.GEN.49.21
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.49.22
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# b.GEN.50.1
# kiss
# &lt;class &#39;str&#39;&gt;
# kiss
# b.GEN.50.23
# descendant
# &lt;class &#39;str&#39;&gt;
# descendant
# ERROR!! descendant
# errors [[&#39;b.GEN.2.7&#39;, &#39;metaphorically&#39;], [&#39;b.GEN.2.21&#39;, &#39;metaphorically&#39;], [&#39;b.GEN.2.21&#39;, &#39;rips&#39;], [&#39;b.GEN.2.22&#39;, &#39;metaphorically&#39;], [&#39;b.GEN.2.22&#39;, &#39;rips&#39;], [&#39;b.GEN.3.7&#39;, &#39;negative&#39;], [&#39;b.GEN.3.7&#39;, &#39;cloth&#39;], [&#39;b.GEN.3.10&#39;, &#39;negative&#39;], [&#39;b.GEN.3.11&#39;, &#39;neutral&#39;], [&#39;b.GEN.3.16&#39;, &#39;negative&#39;], [&#39;b.GEN.3.21&#39;, &#39;neutral&#39;], [&#39;b.GEN.3.21&#39;, &#39;cloths&#39;], [&#39;b.GEN.4.1&#39;, &#39;neutral&#39;], [&#39;b.GEN.4.1&#39;, &#39;conception&#39;], [&#39;b.GEN.4.1&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.2&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.17&#39;, &#39;neutral&#39;], [&#39;b.GEN.4.17&#39;, &#39;conception&#39;], [&#39;b.GEN.4.17&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.18&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.19&#39;, &#39;neutral&#39;], [&#39;b.GEN.4.20&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.22&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.25&#39;, &#39;neutral&#39;], [&#39;b.GEN.4.25&#39;, &#39;descendant&#39;], [&#39;b.GEN.4.26&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.3&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.7&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.10&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.12&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.13&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.15&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.16&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.18&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.19&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.21&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.22&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.25&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.26&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.28&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.30&#39;, &#39;descendant&#39;], [&#39;b.GEN.5.32&#39;, &#39;descendant&#39;], [&#39;b.GEN.6.1&#39;, &#39;descendant&#39;], [&#39;b.GEN.6.10&#39;, &#39;descendant&#39;], [&#39;b.GEN.9.21&#39;, &#39;negative&#39;], [&#39;b.GEN.9.22&#39;, &#39;negative&#39;], [&#39;b.GEN.9.23&#39;, &#39;negative&#39;], [&#39;b.GEN.10.1&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.2&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.3&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.4&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.6&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.7&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.8&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.10&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.13&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.14&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.15&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.16&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.17&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.18&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.20&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.21&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.22&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.23&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.24&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.25&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.26&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.27&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.28&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.29&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.31&#39;, &#39;descendant&#39;], [&#39;b.GEN.10.32&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.10&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.11&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.12&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.13&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.14&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.15&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.16&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.17&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.18&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.19&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.20&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.21&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.22&#39;, &#39;descendant&#39;], [&#39;b.GEN.11.23&#39;, &#39;descendant&#39;], [&#39; ...
# [(&#39;descendant&#39;, 229), (&#39;positive&#39;, 52), (&#39;negative&#39;, 46), (&#39;neutral&#39;, 43), (&#39;conception&#39;, 27), (&#39;condemned&#39;, 23), (&#39;engage&#39;, 12), (&#39;camell&#39;, 8), (&#39;sterility&#39;, 5), (&#39;deshonra&#39;, 5), (&#39;great-family-sex&#39;, 5), (&#39;female-prostitute&#39;, 4), (&#39;metaphorically&#39;, 3), (&#39;eyes&#39;, 3), (&#39;arranged-married&#39;, 3), (&#39;rips&#39;, 2), (&#39;condemnde&#39;, 2), (&#39;uncircuncised&#39;, 2), (&#39;circuncised&#39;, 2), (&#39;braceletes&#39;, 2), (&#39;food&#39;, 2), (&#39;lord-sevant-sex&#39;, 2), (&#39;lord-sevant-relation&#39;, 2), (&#39;descedant&#39;, 2), (&#39;arrianged-marriage&#39;, 2), (&#39;great-family-relation&#39;, 2), (&#39;cloth&#39;, 1), (&#39;cloths&#39;, 1), (&#39;jelocy&#39;, 1), (&#39;concubina&#39;, 1), (&#39;bracelete&#39;, 1), (&#39;feet&#39;, 1), (&#39;donkeys&#39;, 1), (&#39;velo&#39;, 1), (&#39;esterility&#39;, 1), (&#39;first-time&#39;, 1), (&#39;inter-faith-relation&#39;, 1), (&#39;intra-faith&#39;, 1)]
#
#
# Consider substitue inter-faith-relation with interfaith-relation . Levenshtein ratio:0.97
# Replacement accepted
#
#
# Consider substitue esterility with infertility . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue cloth with clothes . Levenshtein ratio:0.83
# Replacement accepted
#
#
# Consider substitue jelocy with jealousy . Levenshtein ratio:0.71
# Replacement accepted
#
#
# Consider substitue conception with concubine . Levenshtein ratio:0.63
# Replacement modified with fertilization
#
#
# Consider substitue arranged-married with arranged-marriage . Levenshtein ratio:0.91
# Replacement accepted
#
#
# Consider substitue donkeys with donkey . Levenshtein ratio:0.92
# Replacement accepted
#
#
# Consider substitue circuncised with circumcised . Levenshtein ratio:0.91
# Replacement accepted
#
#
# Consider substitue braceletes with bracelet . Levenshtein ratio:0.89
# Replacement accepted
#
#
# Consider substitue neutral with metal . Levenshtein ratio:0.67
# Replacement modified with neutral-aspect
#
#
# Consider substitue condemnde with condemned-aspect . Levenshtein ratio:0.72
# Replacement accepted
#
#
# Consider substitue uncircuncised with uncircumcised . Levenshtein ratio:0.92
# Replacement accepted
#
#
# Consider substitue concubina with concubine . Levenshtein ratio:0.89
# Replacement accepted
#
#
# Consider substitue cloths with clothes . Levenshtein ratio:0.92
# Replacement accepted
#
#
# Consider substitue arrianged-marriage with arranged-marriage . Levenshtein ratio:0.97
# Replacement accepted
#
#
# Consider substitue condemned with condemned-aspect . Levenshtein ratio:0.72
# Replacement accepted
#
#
# Consider substitue engage with engaged . Levenshtein ratio:0.92
# Replacement accepted
#
#
# Consider substitue sterility with infertility . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue feet with desert . Levenshtein ratio:0.6
# Replacement modified with foot
#
#
# Consider substitue metaphorically with metal . Levenshtein ratio:0.53
# Replacement rejected. No change.
#
#
# Consider substitue eyes with eye . Levenshtein ratio:0.86
# Replacement accepted
#
#
# Consider substitue lord-sevant-relation with lord-servant-relation . Levenshtein ratio:0.98
# Replacement accepted
#
#
# Consider substitue descendant with ascendant-descendant . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue camell with camel . Levenshtein ratio:0.91
# Replacement accepted
#
#
# Consider substitue descedant with desert . Levenshtein ratio:0.67
# Replacement modified with ascendant-descendant
#
#
# Consider substitue first-time with erotic-time . Levenshtein ratio:0.67
# Replacement modified with first-sexual-act
#
#
# Consider substitue rips with lips . Levenshtein ratio:0.75
# Replacement modified with ribs
#
#
# Consider substitue velo with veil . Levenshtein ratio:0.75
# Replacement accepted
#
#
# Consider substitue bracelete with bracelet . Levenshtein ratio:0.94
# Replacement accepted
#
#
# Consider substitue great-family-relation with greater-family-sex . Levenshtein ratio:0.72
# Replacement accepted
#
#
# Consider substitue food with foot . Levenshtein ratio:0.75
# Replacement modified with food-and-related
#
#
# Consider substitue deshonra with dishonor . Levenshtein ratio:0.75
# Replacement accepted
#
#
# Consider substitue negative with negative-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue female-prostitute with female-prostitutes . Levenshtein ratio:0.97
# Replacement accepted
#
#
# Consider substitue positive with positive-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue great-family-sex with greater-family-sex . Levenshtein ratio:0.94
# Replacement accepted
#
#
# Consider substitue intra-faith with interfaith-marriage . Levenshtein ratio:0.6
# Replacement accepted
#
#
# Consider substitue lord-sevant-sex with lord-servant-sex . Levenshtein ratio:0.97
# Replacement accepted

# %%
standOff_str[0:100000]
# Out:
# &#39;&lt;standOff xml:id=&quot;b.GEN.sexualThemes&quot;&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.7&quot;&gt;\n\t&lt;span ana=&quot;#metaphorically&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.7&quot;&gt;\n\t&lt;span ana=&quot;#blessed-aspect&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.21&quot;&gt;\n\t&lt;span ana=&quot;#metaphorically&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.21&quot;&gt;\n\t&lt;span ana=&quot;#blessed-aspect&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.21&quot;&gt;\n\t&lt;span ana=&quot;#ribs&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.21&quot;&gt;\n\t&lt;span ana=&quot;#sleep&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.22&quot;&gt;\n\t&lt;span ana=&quot;#metaphorically&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.22&quot;&gt;\n\t&lt;span ana=&quot;#blessed-aspect&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.22&quot;&gt;\n\t&lt;span ana=&quot;#ribs&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.22&quot;&gt;\n\t&lt;span ana=&quot;#sleep&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.23&quot;&gt;\n\t&lt;span ana=&quot;#body&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.23&quot;&gt;\n\t&lt;span ana=&quot;#women&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.23&quot;&gt;\n\t&lt;span ana=&quot;#men&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.23&quot;&gt;\n\t&lt;span ana=&quot;#blessed-aspect&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;high&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp&gt;\n&lt;spanGrp type=&quot;theme&quot; inst=&quot;#b.GEN.2.24&quot;&gt;\n\t&lt;span ana=&quot;#wedding&quot;&gt;\n\t\t&lt;certainty match=&quot;@ana&quot; locus=&quot;value&quot; cert=&quot;medium&quot; given=&quot;text&quot;/&gt;\n\t&lt;/span&gt;\n&lt;/spanGrp ...

# %%
import pandas as pd
pd.DataFrame([["a", 1],["b", 5],["c", 0],["d", 2],], columns=["label", "value"]).sort_values(by="value", ascending=False).iloc[0]
# Out:
# label    b
# value    5
# Name: 1, dtype: object

# %%
from collections import Counter
Counter([error_id[1] for  error_id in error_lt]).most_common()
# Out:
# [(&#39;descendant&#39;, 229),
#  (&#39;positive&#39;, 52),
#  (&#39;negative&#39;, 46),
#  (&#39;neutral&#39;, 43),
#  (&#39;conception&#39;, 27),
#  (&#39;condemned&#39;, 23),
#  (&#39;engage&#39;, 12),
#  (&#39;camell&#39;, 8),
#  (&#39;sterility&#39;, 5),
#  (&#39;deshonra&#39;, 5),
#  (&#39;great-family-sex&#39;, 5),
#  (&#39;female-prostitute&#39;, 4),
#  (&#39;metaphorically&#39;, 3),
#  (&#39;eyes&#39;, 3),
#  (&#39;arranged-married&#39;, 3),
#  (&#39;rips&#39;, 2),
#  (&#39;condemnde&#39;, 2),
#  (&#39;uncircuncised&#39;, 2),
#  (&#39;circuncised&#39;, 2),
#  (&#39;braceletes&#39;, 2),
#  (&#39;food&#39;, 2),
#  (&#39;lord-sevant-sex&#39;, 2),
#  (&#39;lord-sevant-relation&#39;, 2),
#  (&#39;descedant&#39;, 2),
#  (&#39;arrianged-marriage&#39;, 2),
#  (&#39;great-family-relation&#39;, 2),
#  (&#39;cloth&#39;, 1),
#  (&#39;cloths&#39;, 1),
#  (&#39;jelocy&#39;, 1),
#  (&#39;concubina&#39;, 1),
#  (&#39;bracelete&#39;, 1),
#  (&#39;feet&#39;, 1),
#  (&#39;donkeys&#39;, 1),
#  (&#39;velo&#39;, 1),
#  (&#39;esterility&#39;, 1),
#  (&#39;first-time&#39;, 1),
#  (&#39;inter-faith-relation&#39;, 1),
#  (&#39;intra-faith&#39;, 1)]

# %%
parse_sexual_anotation.save_book_with_standOff_element(book_str, standOff_str, "GEN")
