# %%
from lxml import etree
import pandas as pd
from collections import Counter
import os
import glob
import re
import matplotlib.pyplot as plt
import numpy as np

wdir = "/home/jose/Dropbox/biblia/tb/"
file = "TEIBible" # "*.xml"
outdir = "/home/jose/Dropbox/biblia/tb/resulting data/"

columns = ["len_chapters", "len_verses","len_chars","am_refs","am_1lev_quotes"]
#,"am_diff_people","am_diff_groups","am_diff_places",

# %%
parser = etree.XMLParser(encoding='utf-8')

# %%
documento_xml = etree.parse(wdir+file+".xml", parser)

# %%
documento_root = documento_xml.getroot()

# %%
namespaces_concretos = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
books_names = [title for book in documento_root.xpath('//tei:TEI', namespaces=namespaces_concretos, with_tail=True) for title in book.xpath('.//tei:title[1]/text()', namespaces=namespaces_concretos, with_tail=True) ]

# %%
for book in documento_root.xpath('//tei:TEI', namespaces=namespaces_concretos, with_tail=True):
    print("title:", book.xpath('.//tei:title[1]/text()', namespaces=namespaces_concretos, with_tail=True))
    print("viaf:", book.xpath('.//tei:title/tei:idno[@type="viaf"]/text()', namespaces=namespaces_concretos, with_tail=True))
    print("code:", book.xpath('.//tei:title/tei:idno[@type="string"]/text()', namespaces=namespaces_concretos, with_tail=True))
    print("references:", len(book.xpath('.//tei:rs', namespaces=namespaces_concretos, with_tail=True)))
    print("quotations:", len(book.xpath('.//tei:q', namespaces=namespaces_concretos, with_tail=True)))
    print("verses:", len(book.xpath('.//tei:ab[@type="verse"]', namespaces=namespaces_concretos, with_tail=True)))
    print("chapters:", len(book.xpath('.//tei:div[@type="chapter"]', namespaces=namespaces_concretos, with_tail=True)))
    print("pericopes:", len(book.xpath('.//tei:div[@type="pericope"]', namespaces=namespaces_concretos, with_tail=True)))
    print("references to God:", len(book.xpath('.//tei:rs[@key="#per14"]', namespaces=namespaces_concretos, with_tail=True)))
    print("references to Jesus:", len(book.xpath('.//tei:rs[@key="#per1"]', namespaces=namespaces_concretos, with_tail=True)))
    print("amount of different entities refered:", len(set([item   for group_item in (book.xpath('.//tei:rs/@key', namespaces=namespaces_concretos, with_tail=True)) for item in group_item.split(" ")])))
    print("\n")
# Out:
# title: ['Génesis']
# viaf: ['174582712']
# code: ['GEN']
# rs's: 5017
# q's: 940
# verses: 1533
# chapters: 50
# pericopes: 79
# references to God: 419
# references to Jesus: 1
# amount of different entities refered: 497
#
#
# title: ['Éxodo']
# viaf: ['265859281']
# code: ['EXO']
# rs's: 3037
# q's: 1064
# verses: 1213
# chapters: 40
# pericopes: 87
# references to God: 553
# references to Jesus: 0
# amount of different entities refered: 165
#
#
# title: ['1 Samuel']
# viaf: ['183486306']
# code: ['1SA']
# rs's: 3466
# q's: 590
# verses: 810
# chapters: 31
# pericopes: 36
# references to God: 421
# references to Jesus: 0
# amount of different entities refered: 234
#
#
# title: ['2 Samuel']
# viaf: ['179039927']
# code: ['2SA']
# rs's: 3251
# q's: 508
# verses: 695
# chapters: 24
# pericopes: 41
# references to God: 231
# references to Jesus: 4
# amount of different entities refered: 299
#
#
# title: ['Nehemías']
# viaf: ['314805700']
# code: ['NEH']
# rs's: 1706
# q's: 144
# verses: 406
# chapters: 13
# pericopes: 19
# references to God: 94
# references to Jesus: 0
# amount of different entities refered: 412
#
#
# title: ['Job']
# viaf: ['186698577']
# code: ['JOB']
# rs's: 912
# q's: 1095
# verses: 1070
# chapters: 42
# pericopes: 44
# references to God: 209
# references to Jesus: 0
# amount of different entities refered: 56
#
#
# title: ['Salmos']
# viaf: ['60146153112905251951']
# code: ['PSA']
# rs's: 1712
# q's: 856
# verses: 1143
# chapters: 75
# pericopes: 73
# references to God: 757
# references to Jesus: 4
# amount of different entities refered: 79
#
#
# title: ['Eclesiastés']
# viaf: ['224729743']
# code: ['ECC']
# rs's: 260
# q's: 18
# verses: 222
# chapters: 12
# pericopes: 17
# references to God: 42
# references to Jesus: 0
# amount of different entities refered: 22
#
#
# title: ['Josué']
# viaf: ['181443388']
# code: ['JOS']
# rs's: 3301
# q's: 272
# verses: 658
# chapters: 24
# pericopes: 35
# references to God: 298
# references to Jesus: 0
# amount of different entities refered: 514
#
#
# title: ['Jueces']
# viaf: ['183962727']
# code: ['JDG']
# rs's: 2652
# q's: 377
# verses: 618
# chapters: 21
# pericopes: 36
# references to God: 227
# references to Jesus: 0
# amount of different entities refered: 295
#
#
# title: ['Rut']
# viaf: ['179825447']
# code: ['Rut']
# rs's: 309
# q's: 68
# verses: 85
# chapters: 4
# pericopes: 4
# references to God: 23
# references to Jesus: 0
# amount of different entities refered: 37
#
#
# title: ['Ezekiel']
# viaf: ['176193843']
# code: ['EZE']
# rs's: 3061
# q's: 2610
# verses: 1273
# chapters: 48
# pericopes: 68
# references to God: 696
# references to Jesus: 1
# amount of different entities refered: 214
#
#
# title: ['Daniel']
# viaf: ['174158777']
# code: ['DAN']
# rs's: 1018
# q's: 428
# verses: 357
# chapters: 12
# pericopes: 14
# references to God: 90
# references to Jesus: 6
# amount of different entities refered: 84
#
#
# title: ['Oseas']
# viaf: ['1146030422535861055']
# code: ['HOS']
# rs's: 510
# q's: 308
# verses: 197
# chapters: 14
# pericopes: 15
# references to God: 104
# references to Jesus: 0
# amount of different entities refered: 88
#
#
# title: ['Joel']
# viaf: ['176216021']
# code: ['JOE']
# rs's: 198
# q's: 220
# verses: 73
# chapters: 3
# pericopes: 3
# references to God: 46
# references to Jesus: 0
# amount of different entities refered: 40
#
#
# title: ['Abdías']
# viaf: ['181846225']
# code: ['OBA']
# rs's: 82
# q's: 19
# verses: 21
# chapters: 1
# pericopes: 1
# references to God: 8
# references to Jesus: 0
# amount of different entities refered: 31
#
#
# title: ['Jonás']
# viaf: ['183065974']
# code: ['JON']
# rs's: 115
# q's: 34
# verses: 48
# chapters: 4
# pericopes: 0
# references to God: 38
# references to Jesus: 0
# amount of different entities refered: 14
#
#
# title: ['Miqueas']
# viaf: ['180230104']
# code: ['MIC']
# rs's: 308
# q's: 283
# verses: 105
# chapters: 7
# pericopes: 10
# references to God: 57
# references to Jesus: 3
# amount of different entities refered: 68
#
#
# title: ['Nahúm']
# viaf: ['183065974']
# code: ['NAH']
# rs's: 79
# q's: 140
# verses: 47
# chapters: 3
# pericopes: 3
# references to God: 14
# references to Jesus: 0
# amount of different entities refered: 31
#
#
# title: ['Habacuc']
# viaf: ['87146462592927770973']
# code: ['HAB']
# rs's: 90
# q's: 93
# verses: 56
# chapters: 3
# pericopes: 3
# references to God: 20
# references to Jesus: 0
# amount of different entities refered: 26
#
#
# title: ['Sofonías']
# viaf: ['316744693']
# code: ['ZEP']
# rs's: 184
# q's: 163
# verses: 53
# chapters: 3
# pericopes: 3
# references to God: 39
# references to Jesus: 1
# amount of different entities refered: 53
#
#
# title: ['Hageo']
# viaf: ['185495533']
# code: ['HAG']
# rs's: 144
# q's: 64
# verses: 38
# chapters: 2
# pericopes: 2
# references to God: 38
# references to Jesus: 1
# amount of different entities refered: 18
#
#
# title: ['Zacarías']
# viaf: ['186702507']
# code: ['ZEC']
# rs's: 646
# q's: 569
# verses: 211
# chapters: 14
# pericopes: 20
# references to God: 155
# references to Jesus: 7
# amount of different entities refered: 110
#
#
# title: ['Malaquías']
# viaf: ['192637637']
# code: ['MAL']
# rs's: 165
# q's: 116
# verses: 55
# chapters: 4
# pericopes: 4
# references to God: 63
# references to Jesus: 3
# amount of different entities refered: 36
#
#
# title: ['Evangelio de Mateo']
# viaf: ['186698679']
# code: ['MAT']
# rs's: 1520
# q's: 975
# verses: 1071
# chapters: 28
# pericopes: 150
# references to God: 127
# references to Jesus: 301
# amount of different entities refered: 184
#
#
# title: ['Evangelio de Marcos']
# viaf: ['179823714']
# code: ['MAR']
# rs's: 1128
# q's: 456
# verses: 678
# chapters: 16
# pericopes: 91
# references to God: 75
# references to Jesus: 198
# amount of different entities refered: 134
#
#
# title: ['Lucas']
# viaf: ['175769882']
# code: ['LUK']
# rs's: 322
# q's: 68
# verses: 132
# chapters: 2
# pericopes: 11
# references to God: 50
# references to Jesus: 32
# amount of different entities refered: 62
#
#
# title: ['Evangelio de Juan']
# viaf: ['186698679']
# code: ['JOH']
# rs's: 1521
# q's: 729
# verses: 879
# chapters: 21
# pericopes: 82
# references to God: 218
# references to Jesus: 467
# amount of different entities refered: 101
#
#
# title: ['Hechos']
# viaf: ['174983206']
# code: ['ACT']
# rs's: 2674
# q's: 628
# verses: 1007
# chapters: 28
# pericopes: 79
# references to God: 209
# references to Jesus: 185
# amount of different entities refered: 311
#
#
# title: ['Romans']
# viaf: ['181440270']
# code: ['ROM']
# rs's: 819
# q's: 88
# verses: 433
# chapters: 16
# pericopes: 36
# references to God: 189
# references to Jesus: 117
# amount of different entities refered: 98
#
#
# title: ['1 Corintios']
# viaf: ['179420235']
# code: ['1CO']
# rs's: 764
# q's: 30
# verses: 437
# chapters: 16
# pericopes: 29
# references to God: 123
# references to Jesus: 151
# amount of different entities refered: 67
#
#
# title: ['2 Corintios']
# viaf: ['181845414']
# code: ['2CO']
# rs's: 364
# q's: 11
# verses: 257
# chapters: 13
# pericopes: 26
# references to God: 89
# references to Jesus: 86
# amount of different entities refered: 42
#
#
# title: ['Filemón']
# viaf: ['179022987']
# code: ['PHM']
# rs's: 50
# q's: 0
# verses: 25
# chapters: 1
# pericopes: 4
# references to God: 6
# references to Jesus: 13
# amount of different entities refered: 15
#
#
# title: ['Santiago']
# viaf: ['182251478']
# code: ['JAM']
# rs's: 91
# q's: 9
# verses: 71
# chapters: 3
# pericopes: 8
# references to God: 16
# references to Jesus: 5
# amount of different entities refered: 17
#
#
# title: ['1 Pedro']
# viaf: ['198582656']
# code: ['1PE']
# rs's: 185
# q's: 8
# verses: 105
# chapters: 5
# pericopes: 14
# references to God: 48
# references to Jesus: 34
# amount of different entities refered: 37
#
#
# title: ['2 Pedro']
# viaf: ['4320148523903720970004']
# code: ['2PE']
# rs's: 114
# q's: 3
# verses: 61
# chapters: 3
# pericopes: 5
# references to God: 14
# references to Jesus: 24
# amount of different entities refered: 32
#
#
# title: ['1 epístola de Juan']
# viaf: ['180630929']
# code: ['1JO']
# rs's: 250
# q's: 3
# verses: 105
# chapters: 5
# pericopes: 11
# references to God: 83
# references to Jesus: 45
# amount of different entities refered: 18
#
#
# title: ['2 epístola de Juan']
# viaf: ['180630929']
# code: ['2JO']
# rs's: 26
# q's: 2
# verses: 13
# chapters: 1
# pericopes: 3
# references to God: 6
# references to Jesus: 7
# amount of different entities refered: 8
#
#
# title: ['3 epístola de Juan']
# viaf: ['180630929']
# code: ['3JO']
# rs's: 21
# q's: 0
# verses: 14
# chapters: 1
# pericopes: 5
# references to God: 3
# references to Jesus: 0
# amount of different entities refered: 8
#
#
# title: ['Epístola de Judas']
# viaf: ['181851752']
# code: ['JUD']
# rs's: 68
# q's: 4
# verses: 25
# chapters: 1
# pericopes: 4
# references to God: 12
# references to Jesus: 8
# amount of different entities refered: 25
#
#
# title: ['Apocalipsis']
# viaf: ['181843323']
# code: ['REV']
# rs's: 740
# q's: 258
# verses: 404
# chapters: 22
# pericopes: 39
# references to God: 153
# references to Jesus: 101
# amount of different entities refered: 85

# %%
books_names[0:3]
# Out:
# ['Génesis', 'Éxodo', '1 Samuel']

# %%
metadata_bible = pd.DataFrame(index = books_names, columns = columns).fillna(0)

# %%
metadata_bible
# Out:
#                      len_chapters  len_verses  len_chars  am_refs  \
# Génesis                         0           0          0        0
# Éxodo                           0           0          0        0
# 1 Samuel                        0           0          0        0
# 2 Samuel                        0           0          0        0
# Nehemías                        0           0          0        0
# Job                             0           0          0        0
# Salmos                          0           0          0        0
# Eclesiastés                     0           0          0        0
# Josué                           0           0          0        0
# Jueces                          0           0          0        0
# Rut                             0           0          0        0
# Ezekiel                         0           0          0        0
# Daniel                          0           0          0        0
# Oseas                           0           0          0        0
# Joel                            0           0          0        0
# Abdías                          0           0          0        0
# Jonás                           0           0          0        0
# Miqueas                         0           0          0        0
# Nahúm                           0           0          0        0
# Habacuc                         0           0          0        0
# Sofonías                        0           0          0        0
# Hageo                           0           0          0        0
# Zacarías                        0           0          0        0
# Malaquías                       0           0          0        0
# Evangelio de Mateo              0           0          0        0
# Evangelio de Marcos             0           0          0        0
# Lucas                           0           0          0        0
# Evangelio de Juan               0           0          0        0
# Hechos                          0           0          0        0
# Romans                          0           0          0        0
# 1 Corintios                     0           0          0        0
# 2 Corintios                     0           0          0        0
# Filemón                         0           0          0        0
# Santiago                        0           0          0        0
# 1 Pedro                         0           0          0        0
# 2 Pedro                         0           0          0        0
# 1 epístola de Juan              0           0          0        0
# 2 epístola de Juan              0           0          0        0
# 3 epístola de Juan              0           0          0        0
# Epístola de Judas               0           0          0        0
# Apocalipsis                     0           0          0        0
#
#                      am_1lev_quotes
# Génesis                           0
# Éxodo                             0
# 1 Samuel                          0
# 2 Samuel                          0
# Nehemías                          0
# Job                               0
# Salmos                            0
# Eclesiastés                       0
# Josué                             0
# Jueces                            0
# Rut                               0
# Ezekiel                           0
# Daniel                            0
# Oseas                             0
# Joel                              0
# Abdías                            0
# Jonás                             0
# Miqueas                           0
# Nahúm                             0
# Habacuc                           0
# Sofonías                          0
# Hageo                             0
# Zacarías                          0
# Malaquías                         0
# Evangelio de Mateo                0
# Evangelio de Marcos               0
# Lucas                             0
# Evangelio de Juan                 0
# Hechos                            0
# Romans                            0
# 1 Corintios                       0
# 2 Corintios                       0
# Filemón                           0
# Santiago                          0
# 1 Pedro                           0
# 2 Pedro                           0
# 1 epístola de Juan                0
# 2 epístola de Juan                0
# 3 epístola de Juan                0
# Epístola de Judas                 0
# Apocalipsis                       0
