# %%
import pandas as pd

# %%
wdir = "/home/jose/Dropbox/biblia/tb/"

# %%
xls = pd.ExcelFile(wdir+"catalogue_references.xls",  index_col=0)
entities = xls.parse('Sheet1').fillna("")

# %%
entities
# Out:
#           id          NormalizedName-sp      aclaration            variants  \
# 0      #per0        persona no definida
# 1      #per1                      Jesús
# 2      #per2                    Abraham                               Abram
# 3      #per3                      Isaac
# 4      #per4                      Jacob                              Israel
# 5      #per5                       Judá
# 6      #per6                      Tamar
# 7      #per7                      Fares
# 8      #per8                      Zéraj
# 9      #per9                     Hesrón
# 10    #per10                    Herodes
# 11    #per11                      María  madre de Jesús
# 12    #per12                       José  padre de Jesús
# 13    #per13                      Elías
# 14    #per14                       Dios
# 15    #per15                   Jeremías
# 16    #per16                     Raquel
# 17    #per17             Espíritu Santo
# 18    #per18           Juan el Bautista
# ...

# %%
references = pd.read_csv(wdir+"documentation/cet_high_places.csv", sep="\t")

# %%
references.head()
# Out:
#         id   latitude  longitude
# 0  #pla110  31.941600  35.222734
# 1  #pla112  30.714086  34.875748
# 2  #pla115  31.532569  35.099826
# 3   #pla11  32.880330  35.573307
# 4   #pla12  32.793239  35.117095

# %%
entities = pd.merge(entities,references,on="id", how="outer").fillna("")

# %%
entities
# Out:
#           id          NormalizedName-sp      aclaration            variants  \
# 0      #per0        persona no definida
# 1      #per1                      Jesús
# 2      #per2                    Abraham                               Abram
# 3      #per3                      Isaac
# 4      #per4                      Jacob                              Israel
# 5      #per5                       Judá
# 6      #per6                      Tamar
# 7      #per7                      Fares
# 8      #per8                      Zéraj
# 9      #per9                     Hesrón
# 10    #per10                    Herodes
# 11    #per11                      María  madre de Jesús
# 12    #per12                       José  padre de Jesús
# 13    #per13                      Elías
# 14    #per14                       Dios
# 15    #per15                   Jeremías
# 16    #per16                     Raquel
# 17    #per17             Espíritu Santo
# 18    #per18           Juan el Bautista
# ...

# %%
entities.loc[entities["type"] == "place"]
# Out:
#            id    NormalizedName-sp    aclaration       variants  \
# 2061    #pla1                Belén
# 2062    #pla2                Judea                         Judá
# 2063    #pla3            Jerusalén
# 2064    #pla4               Israel
# 2065    #pla5               Egipto                          Cam
# 2066    #pla6                 Ramá
# 2067    #pla7              Galilea
# 2068    #pla8              Nazaret
# 2069    #pla9               Jordán
# 2070   #pla10
# 2071   #pla11            Capernaúm
# 2072   #pla12              Zabulón
# 2073   #pla13              Neftalí
# 2074   #pla14                Siria
# 2075   #pla15             infierno                   Seol, seol
# 2076   #pla16               Sodoma
# 2077   #pla17              Gomorra
# 2078   #pla18               cielos
# 2079   #pla19  reino de los cielos                reino de Dios
# 2080   #pla20               Nínive
# 2081   #pla21            Genesaret
# 2082   #pla22                 Tiro
# ...

# %%
entities["geo_cert"] = ""

# %%
entities.loc[entities["latitude"] != "", "geo_cert"]  = "high"

# %%
writer = pd.ExcelWriter(wdir+"catalogue_references.xls")
entities.to_excel(writer,'Sheet1')
writer.save()
