# %%
import pandas as pd
from lxml import etree
import requests
import os
import time

# %%
sys.path.append(os.path.abspath("./../scripts/"))

# %%
import parse_sexual_anotation

# %%
book_name = "GAL"

# %%
wdir_str = "./../../../sexual-annotation/"
file_str = book_name + ".xml"

book_name_str = file_str[0:3]

# %%
book_str = parse_sexual_anotation.open_book(wdir_str, file_str)
book_str[0:1000]
# Out:
# ['./../../../sexual-annotation/GAL.xml']
# GAL
# <class 'str'>
# '<?xml version="1.0" encoding="UTF-8"?>\n<?xml-model href="https://raw.githubusercontent.com/morethanbooks/XML-TEI-Bible/master/scheme/tei_lite.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-quotes.css" rel="stylesheet" title="Word2Pix Quotations"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-reference.css" rel="stylesheet" title="Word2Pix References"?>\n<?xml-stylesheet type="text/css" href="styles/styles.css" rel="stylesheet" title="Classic"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-level-q.css" rel="stylesheet" title="Word2Pix Level Quotation"?>\n\n<TEI xmlns="http://www.tei-c.org/ns/1.0">\n\t<teiHeader>\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title>Gálatas</title>\n\t\t\t\t<title type="idno">\n\t\t\t\t\t<idno type="string">GAL</idno>\n\t\t\t\t\t<idno type="viaf">183875648</idno>\n\t\t\t\t</title>\n\t\t\t\t<author>\n\t\t\t\t\t<name type="short"></name>\n\t\t\t\t\t<name type="full"></name>\n\t\t\t\t\t<idno type="viaf"></idno>\n\t\t'

# %%
taxonomy_file_str = "taxonomy.xml"

# %%
taxonomy_el = parse_sexual_anotation.open_taxonomy(wdir_str, taxonomy_file_str)
# Out:
# <class 'lxml.etree._Element'>

# %%
namespaces_dict = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
categories_id_lt = parse_sexual_anotation.get_list_categories(taxonomy_el, namespaces = namespaces_dict)

print(categories_id_lt)
# Out:
# ['relations', 'monogamy', 'poligamy', 'marriage', 'second-marriage', 'second-marriage-divorce', 'second-marriage-widow', 'interfaith-marriage', 'interfaith-relation', 'non-marital-relation', 'relation-greater-family', 'marital-relation-political-family', 'lord-servant-relation', 'marital-relation-direct-family', 'arranged-marriage', 'divorce', 'engaged', 'love', 'jealousy', 'ascendant-descendant', 'primogeniture', 'indirect-ascendant-descendant', 'homosexual-relation', 'acts', 'social-related-act', 'wedding', 'deception', 'body-related-act', 'massage', 'kiss', 'hug', 'dance', 'abortion', 'circumcision', 'breast-feeding', 'bath', 'sexual-act', 'sexual-act-stage', 'seduction', 'rejection', 'erotic-time', 'initation-sexual-act', 'orgasm', 'ejaculation', 'time-after-sex', 'sexual-act-type', 'coitus', 'first-sexual-act', 'coitus-interruptus', 'self-masturbation', 'masturbation', 'oral-sex', 'anal-sex', 'non-penetrative-sex', 'rape', 'female-rape', 'male-rape', 'sexual-
# Out:
# [('b.GAL.001.001', 'ascending; positive; negative'), ('b.GAL.001.003', 'ascending; positive; blessed'), ('b.GAL.001.004', 'ascending; positive; blessed'), ('b.GAL.001.014', 'ascending; positive; negative'), ('b.GAL.001.015', 'birth; positive; blessed'), ('b.GAL.001.016', 'ascending; positive; flesh'), ('b.GAL.002.003', 'positive; negative; circumcision'), ('b.GAL.002.007', 'positive; negative; circumcision; incircumcision'), ('b.GAL.002.008', 'positive; circumcision'), ('b.GAL.002.009', 'positive; circumcision'), ('b.GAL.002.012', 'negative; positive; circumcision'), ('b.GAL.002.020', 'flesh; love; condemned; blessed'), ('b.GAL.003.007', 'sacending; positive'), ('b.GAL.003.016', 'ascending; positive; blessed'), ('b.GAL.003.026', 'ascending; blessed'), ('b.GAL.003.028', 'men; women; positive'), ('b.GAL.003.029', 'ascending; blessed'), ('b.GAL.004.002', 'ascending; positive; neutral'), ('b.GAL.004.004', 'birth; ascending; neutral; positive'), ('b.GAL.004.005', 'ascending; neutral; blessed'), ('b.GAL.004.006', 'ascending;  blessed'), ('b.GAL.004.007', 'ascending;  blessed; condemned'), ('b.GAL.004.014', 'body;  neutral; negative; blessed'), ('b.GAL.004.019', 'ascending; birth; negative; blessed'), ('b.GAL.004.022', 'ascending; negative; positive'), ('b.GAL.004.023', 'ascending; negative; positive; flesh'), ('b.GAL.004.024', 'women; ascending; negative; positive'), ('b.GAL.004.025', 'women; ascending; negative; neutral'), ('b.GAL.004.026', 'ascending; neutral; positive'), ('b.GAL.004.027', 'estirility; birth;ascending; positive; negative'), ('b.GAL.004.028', 'ascending; positive; neutral'), ('b.GAL.004.029', 'birth; flesh; negative; neutral'), ('b.GAL.004.030', 'ascending; negative; positive'), ('b.GAL.004.031', 'ascending; negative; positive'), ('b.GAL.005.002', 'circumcision; negative; neutral'), ('b.GAL.005.003', 'circumcision; negative; neutral'), ('b.GAL.005.006', 'circumcision; incircumcision; neutral; positive; love'), ('b.GAL.005.011', 'circumcision; negative; neutral'), ('b.GAL.005.012', 'circumcision; negative'), ('b.GAL.005.013', 'flesh; love; positive; negative'), ('b.GAL.005.014', 'love; positive; blessed'), ('b.GAL.005.016', 'flesh; negative; positive'), ('b.GAL.005.017', 'flesh; negative; positive'), ('b.GAL.005.019', 'flesh; condemned; adultery; fornication; sexual-drive cert="medium"; lust'), ('b.GAL.005.021', 'condemned; positive; sex-in-group'), ('b.GAL.005.024', 'flesh; blessed; condemened'), ('b.GAL.006.008', 'flesh; condemned; blessed'), ('b.GAL.006.012', 'flesh; circumcision; negative; positive'), ('b.GAL.006.013', 'circumcision; flesh; negative; neutral'), ('b.GAL.006.015', 'circumcision; uncircumcision; blessed; positive')]

# %%
error_lt, standOff_str = parse_sexual_anotation.parse_each_sexual_annotation_as_comment(sexual_annotations_from_comments_lt, categories_id_lt, book_name)
# Out:
# b.GAL.001.001
# ascending
# <class 'str'>
# ascending
# ERROR!! ascending
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#
002', 'neutral'], ['b.GAL.005.003', 'negative'], ['b.GAL.005.003', 'neutral'], ['b.GAL.005.006', 'incircumcision'], ['b.GAL.005.006', 'neutral'], ['b.GAL.005.006', 'positive'], ['b.GAL.005.011', 'negative'], ['b.GAL.005.011', 'neutral'], ['b.GAL.005.012', 'negative'], ['b.GAL.005.013', 'positive'], ['b.GAL.005.013', 'negative'], ['b.GAL.005.014', 'positive'], ['b.GAL.005.014', 'blessed'], ['b.GAL.005.016', 'negative'], ['b.GAL.005.016', 'positive'], ['b.GAL.005.017', 'negative'], ['b.GAL.005.017', 'positive'], ['b.GAL.005.019', 'condemned'], ['b.GAL.005.019', 'adultery'], ['b.GAL.005.019', 'fornication'], ['b.GAL.005.019', 'lust'], ['b.GAL.005.021', 'condemned'], ['b.GAL.005.021', 'positive'], ['b.GAL.005.021', 'sex-in-group'], ['b.GAL.005.024', 'blessed'], ['b.GAL.005.024', 'condemened'], ['b.GAL.006.008', 'condemned'], ['b.GAL.006.008', 'blessed'], ['b.GAL.006.012', 'negative'], ['b.GAL.006.012', 'positive'], ['b.GAL.006.013', 'negative'], ['b.GAL.006.013', 'neutral'], ['b.GAL.006.015', 'uncircumcision'], ['b.GAL.006.015', 'blessed'], ['b.GAL.006.015', 'positive']]
# [('positive', 32), ('negative', 24), ('ascending', 23), ('blessed', 16), ('neutral', 13), ('condemned', 5), ('incircumcision', 2), ('sacending', 1), ('estirility', 1), ('adultery', 1), ('fornication', 1), ('lust', 1), ('sex-in-group', 1), ('condemened', 1), ('uncircumcision', 1)]
#
#
# Consider substitue adultery with water . Levenshtein ratio:0.62
# Replacement modified with sex-before-marriage
#
#
# Consider substitue blessed with blessed-aspect . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue incircumcision with circumcision . Levenshtein ratio:0.92
# Replacement modified with uncircumcised
#
#
# Consider substitue lust with jealousy . Levenshtein ratio:0.5
# Replacement modified with sexual-drive
#
#
# Consider substitue uncircumcision with circumcision . Levenshtein ratio:0.92
# Replacement modified with uncircumcised
#
#
# Consider substitue ascending with wedding . Levenshtein ratio:0.62
# Replacement modified with ascendant-descendant
#
#
# Consider substitue condemened with condemned-aspect . Levenshtein ratio:0.69
# Replacement accepted
#
#
# Consider substitue estirility with infertility . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue sacending with wedding . Levenshtein ratio:0.62
# Replacement modified with ascendant-descendant
#
#
# Consider substitue neutral with metal . Levenshtein ratio:0.67
# Replacement modified with neutral-aspect
#
#
# Consider substitue fornication with lubrication . Levenshtein ratio:0.73
# Replacement modified with sex-outside-marriage
#
#
# Consider substitue sex-in-group with third-sexual-group . Levenshtein ratio:0.6
# Replacement modified with groupal-sex
#
#
# Consider substitue negative with negative-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue positive with positive-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue condemned with condemned-aspect . Levenshtein ratio:0.72
# Replacement accepted

# %%
error_lt
# Out:
# [['b.2SA.1.11', 'negative'],
#  ['b.2SA.1.20', 'incircunciso'],
#  ['b.2SA.1.20', 'negative'],
#  ['b.2SA.1.20', 'positive'],
#  ['b.2SA.1.23', 'positive'],
#  ['b.2SA.1.23', 'negative'],
#  ['b.2SA.1.26', 'positive'],
#  ['b.2SA.1.26', 'negative'],
#  ['b.2SA.2.2', 'multiple-marriage'],
#  ['b.2SA.2.2', 'neutral'],
#  ['b.2SA.2.8', 'ascendant'],
#  ['b.2SA.2.8', 'neutral'],
#  ['b.2SA.2.12', 'descendant'],
#  ['b.2SA.2.12', 'neutral'],
#  ['b.2SA.2.18', 'descendant'],
#  ['b.2SA.2.18', 'neutral'],
#  ['b.2SA.3.2', 'ascendant'],
#  ['b.2SA.3.2', 'positive'],
#  ['b.2SA.3.2', 'multiple-marriage'],
#  ['b.2SA.3.3', 'ascendant'],
#  ['b.2SA.3.3', 'positive'],
#  ['b.2SA.3.3', 'multiple-marriage'],
#  ['b.2SA.3.4', 'ascendant'],
#  ['b.2SA.3.4', 'positive'],
#  ['b.2SA.3.4', 'multiple-marriage'],
#  ['b.2SA.3.5', 'ascendant'],
#  ['b.2SA.3.5', 'positive'],
#  ['b.2SA.3.5', 'multiple-marriage'],
#  ['b.2SA.3.7', 'sex-great-family'],
#  ['b.2SA.3.7', 'multiple-marriage'],
#  ['b.2SA.3.7', 'negative'],
#  ['b.2SA.3.8', 'sex-great-family'],
#  ['b.2SA.3.8', 'multiple-marriage'],
#  ['b.2SA.3.8', 'negative'],
#  ['b.2SA.3.13', 'multiple-marriage'],
#  ['b.2SA.3.13', 'positive'],
#  ['b.2SA.3.14', 'multiple-marriage'],
#  ['b.2SA.3.14', 'positive'],
#  ['b.2SA.3.14', 'prepucios'],
#  ['b.2SA.3.15', 'forced-divorced'],
#  ['b.2SA.3.15', 'multiple-marriage'],
#  ['b.2SA.3.15', 'neutral'],
#  ['b.2SA.3.16', 'forced-divorced'],
#  ['b.2SA.3.16', 'negative'],
#  ['b.2SA.3.23', 'ascending'],
#  ['b.2SA.3.23', 'neutral'],
#  ['b.2SA.3.31', 'neutral'],
#  ['b.2SA.3.39', 'ascending'],
#  ['b.2SA.3.39', 'negative'],
#  ['b.2SA.3.39', 'neutral'],
#  ['b.2SA.4.2', 'ascending'],
#  ['b.2SA.4.2', 'neutral'],
#  ['b.2SA.4.2', 'negative'],
#  ['b.2SA.4.4', 'ascending'],
#  ['b.2SA.4.4', 'neutral'],
#  ['b.2SA.4.4', 'negative'],
#  ['b.2SA.5.1', 'positive'],
#  ['b.2SA.5.14', 'ascendant'],
#  ['b.2SA.5.14', 'positive'],
#  ['b.2SA.5.15', 'ascendant'],
#  ['b.2SA.5.15', 'positive'],
#  ['b.2SA.5.16', 'ascendant'],
#  ['b.2SA.5.16', 'positive'],
#  ['b.2SA.6.3', 'ascending'],
#  ['b.2SA.6.3', 'positive'],
#  ['b.2SA.6.3', 'neutral'],
#  ['b.2SA.6.16', 'ascending'],
#  ['b.2SA.6.16', 'positive'],
#  ['b.2SA.6.16', 'negative'],
#  ['b.2SA.6.20', 'jelous'],
#  ['b.2SA.6.20', 'marital-relation'],
#  ['b.2SA.6.20', 'negative'],
#  ['b.2SA.6.23', 'ascending'],
#  ['b.2SA.6.23', 'neutral'],
#  ['b.2SA.6.23', 'negative'],
#  ['b.2SA.7.12', 'ascending'],
#  ['b.2SA.7.12', 'blessed'],
#  ['b.2SA.7.12', 'testicles'],
#  ['b.2SA.7.14', 'ascending'],
#  ['b.2SA.7.14', 'blessed'],
#  ['b.2SA.7.14', 'negative'],
#  ['b.2SA.7.18', 'ascending'],
#  ['b.2SA.7.18', 'positive'],
#  ['b.2SA.7.19', 'ascending'],
#  ['b.2SA.7.19', 'positive'],
#  ['b.2SA.7.29', 'ascending'],
#  ['b.2SA.7.29', 'blessed'],
#  ['b.2SA.8.3', 'ascending'],
#  ['b.2SA.8.3', 'neutral'],
#  ['b.2SA.8.10', 'ascending'],
#  ['b.2SA.8.10', 'positive'],
#  ['b.2SA.8.10', 'negative'],
#  ['b.2SA.8.12', 'ascending'],
#  ['b.2SA.8.12', 'neutral'],
#  ['b.2SA.8.16', 'ascending'],
#  ['b.2SA.8.16', 'neutral'],
#  ['b.2SA.8.17', 'ascending'],
#  ['b.2SA.8.17', 'neutral'],
#  ['b.2SA.8.17', 'positive'],
#  ['b.2SA.8.18', 'ascending'],
#  ['b.2SA.8.18', 'neutral'],
#  ['b.2SA.9.1', 'positive'],
#  ['b.2SA.9.3', 'ascending'],
#  ['b.2SA.9.3', 'neutral'],
#  ['b.2SA.9.3', 'negative'],
#  ['b.2SA.9.4', 'ascending'],
#  ['b.2SA.9.4', 'negative'],
#  ['b.2SA.9.5', 'ascending'],
#  ['b.2SA.9.5', 'negative'],
#  ['b.2SA.9.6', 'ascending'],
#  ['b.2SA.9.6', 'neutral'],
#  ['b.2SA.9.7', 'ascending'],
#  ['b.2SA.9.7', 'positive'],
#  ['b.2SA.9.9', 'ascending'],
#  ['b.2SA.9.9', 'positive'],
#  ['b.2SA.9.10', 'ascending'],
#  ['b.2SA.9.10', 'neutral'],
#  ['b.2SA.9.11', 'ascending'],
#  ['b.2SA.9.11', 'positive'],
#  ['b.2SA.9.12', 'ascending'],
#  ['b.2SA.9.12', 'neutral'],
#  ['b.2SA.10.1', 'ascending'],
#  ['b.2SA.10.1', 'negative'],
#  ['b.2SA.10.1', 'neutral'],
#  ['b.2SA.10.2', 'ascending'],
#  ['b.2SA.10.2', 'positive'],
#  ['b.2SA.10.2', 'neutral'],
#  ['b.2SA.10.3', 'ascending'],
#  ['b.2SA.10.3', 'neutral'],
#  ['b.2SA.10.3', 'negative'],
#  ['b.2SA.10.8', 'ascending'],
#  ['b.2SA.10.8', 'neutral'],
#  ['b.2SA.10.11', 'ascending'],
#  ['b.2SA.10.11', 'negative'],
#  ['b.2SA.10.11', 'positive'],
#  ['b.2SA.10.14', 'ascending'],
#  ['b.2SA.10.14', 'neutral'],
#  ['b.2SA.10.19', 'ascending'],
#  ['b.2SA.10.19', 'neutral'],
#  ['b.2SA.10.19', 'negative'],
#  ['b.2SA.11.2', 'woman'],
#  ['b.2SA.11.2', 'voyerism'],
#  ['b.2SA.11.2', 'bath'],
#  ['b.2SA.11.2', 'positive'],
#  ['b.2SA.11.3', 'positive'],
#  ['b.2SA.11.3', 'ascending'],
#  ['b.2SA.11.4', 'negative'],
#  ['b.2SA.11.5', 'pregnant'],
#  ['b.2SA.11.5', 'negative'],
#  ['b.2SA.11.6', 'negative'],
#  ['b.2SA.11.7', 'negative'],
#  ['b.2SA.11.8', 'negative'],
#  ['b.2SA.11.10', 'negative'],
#  ['b.2SA.11.11', 'sex-in-marraige'],
#  ['b.2SA.11.11', 'positive'],
#  ['b.2SA.11.11', 'negative'],
#  ['b.2SA.11.12', 'negative'],
#  ['b.2SA.11.13', 'negative'],
#  ['b.2SA.11.14', 'negative'],
#  ['b.2SA.11.15', 'negative'],
#  ['b.2SA.11.16', 'negative'],
#  ['b.2SA.11.17', 'negative'],
#  ['b.2SA.11.21', 'ascending'],
#  ['b.2SA.11.21', 'negative'],
#  ['b.2SA.11.21', 'neutral'],
#  ['b.2SA.11.26', 'positive'],
#  ['b.2SA.11.26', 'negative'],
#  ['b.2SA.11.27', 'ascending'],
#  ['b.2SA.11.27', 'condemned'],
#  ['b.2SA.12.2', 'multi-marriage'],
#  ['b.2SA.12.2', 'neutral'],
#  ['b.2SA.12.2', 'positive'],
#  ['b.2SA.12.3', 'positive'],
#  ['b.2SA.12.4', 'poli-marriage'],
#  ['b.2SA.12.4', 'negative'],
#  ['b.2SA.12.4', 'neutral'],
#  ['b.2SA.12.8', 'poli-marraige'],
#  ['b.2SA.12.8', 'blessed'],
#  ['b.2SA.12.9', 'lie'],
#  ['b.2SA.12.9', 'condemned'],
#  ['b.2SA.12.9', 'neutral'],
#  ['b.2SA.12.10', 'condemned'],
#  ['b.2SA.12.10', 'neutral'],
#  ['b.2SA.12.11', 'condemned'],
#  ['b.2SA.12.11', 'sexo'],
#  ['b.2SA.12.11', 'poli-marriage'],
#  ['b.2SA.12.11', 'neutral'],
#  ['b.2SA.12.12', 'condemned'],
#  ['b.2SA.12.12', 'sexo'],
#  ['b.2SA.12.12', 'neutral'],
#  ['b.2SA.12.13', 'lie'],
#  ['b.2SA.12.13', 'condemned'],
#  ['b.2SA.12.13', 'positive'],
#  ['b.2SA.12.14', 'ascendant'],
#  ['b.2SA.12.14', 'condemned'],
#  ['b.2SA.12.15', 'ascendant'],
#  ['b.2SA.12.15', 'condemned'],
#  ['b.2SA.12.16', 'ascendant'],
#  ['b.2SA.12.16', 'negative'],
#  ['b.2SA.12.18', 'ascendant'],
#  ['b.2SA.12.18', 'negative'],
#  ['b.2SA.12.19', 'ascendant'],
#  ['b.2SA.12.19', 'negative'],
#  ['b.2SA.12.21', 'ascendant'],
#  ['b.2SA.12.21', 'negative'],
#  ['b.2SA.12.24', 'positive'],
#  ['b.2SA.12.24', 'conception'],
#  ['b.2SA.12.24', 'ascendant'],
#  ['b.2SA.13.1', 'ascending'],
#  ['b.2SA.13.1', 'neutral'],
#  ['b.2SA.13.2', 'negative'],
#  ['b.2SA.13.2', 'positive'],
#  ['b.2SA.13.3', 'ascending'],
#  ['b.2SA.13.3', 'positive'],
#  ['b.2SA.13.3', 'neutral'],
#  ['b.2SA.13.3', 'negative'],
#  ['b.2SA.13.4', 'ascending'],
#  ['b.2SA.13.4', 'negative'],
#  ['b.2SA.13.4', 'neutral'],
#  ['b.2SA.13.5', 'food'],
#  ['b.2SA.13.5', 'sickness'],
#  ['b.2SA.13.5', 'neutral'],
#  ['b.2SA.13.5', 'negative'],
#  ['b.2SA.13.6', 'food'],
#  ['b.2SA.13.6', 'sickness'],
#  ['b.2SA.13.6', 'neutral'],
#  ['b.2SA.13.6', 'negative'],
#  ['b.2SA.13.7', 'ascending'],
#  ['b.2SA.13.7', 'food'],
#  ['b.2SA.13.7', 'neutral'],
#  ['b.2SA.13.7', 'negative'],
#  ['b.2SA.13.8', 'food'],
#  ['b.2SA.13.8', 'sickness'],
#  ['b.2SA.13.8', 'positive'],
#  ['b.2SA.13.8', 'neutral'],
#  ['b.2SA.13.9', 'food'],
#  ['b.2SA.13.9', 'negative'],
#  ['b.2SA.13.9', 'neutral'],
#  ['b.2SA.13.10', 'food'],
#  ['b.2SA.13.10', 'hands'],
#  ['b.2SA.13.10', 'positive'],
#  ['b.2SA.13.10', 'neutral'],
#  ['b.2SA.13.11', 'food'],
#  ['b.2SA.13.11', 'negative'],
#  ['b.2SA.13.11', 'positive'],
#  ['b.2SA.13.12', 'negative'],
#  ['b.2SA.13.13', 'condemned'],
#  ['b.2SA.13.14', 'negative'],
#  ['b.2SA.13.15', 'condemned'],
#  ['b.2SA.13.16', 'condemned'],
#  ['b.2SA.13.18', 'dress'],
#  ['b.2SA.13.18', 'positive'],
#  ['b.2SA.13.18', 'negative'],
#  ['b.2SA.13.20', 'negative'],
#  ['b.2SA.13.21', 'condemned'],
#  ['b.2SA.13.22', 'condemned'],
#  ['b.2SA.13.23', 'ascending'],
#  ['b.2SA.13.23', 'neutral'],
#  ['b.2SA.13.25', 'ascending'],
#  ['b.2SA.13.25', 'negative'],
#  ['b.2SA.13.25', 'positive'],
#  ['b.2SA.13.27', 'ascending'],
#  ['b.2SA.13.27', 'neutral'],
#  ['b.2SA.13.29', 'ascending'],
#  ['b.2SA.13.29', 'negative'],
#  ['b.2SA.13.29', 'neutral'],
#  ['b.2SA.13.30', 'ascending'],
#  ['b.2SA.13.30', 'negative'],
#  ['b.2SA.13.32', 'ascending'],
#  ['b.2SA.13.32', 'neutral'],
#  ['b.2SA.13.32', 'negative'],
#  ['b.2SA.13.33', 'ascending'],
#  ['b.2SA.13.33', 'negative'],
#  ['b.2SA.13.33', 'neutral'],
#  ['b.2SA.13.35', 'ascending'],
#  ['b.2SA.13.35', 'positive'],
#  ['b.2SA.13.36', 'ascending'],
#  ['b.2SA.13.36', 'positive'],
#  ['b.2SA.13.37', 'ascending'],
#  ['b.2SA.13.37', 'negative'],
#  ['b.2SA.13.37', 'neutral'],
#  ['b.2SA.13.39', 'ascending'],
#  ['b.2SA.13.39', 'negative'],
#  ['b.2SA.13.39', 'positive'],
#  ['b.2SA.14.1', 'asending'],
#  ['b.2SA.14.1', 'neutral'],
#  ['b.2SA.14.1', 'positive'],
#  ['b.2SA.14.5', 'neutral'],
#  ['b.2SA.14.5', 'negative'],
#  ['b.2SA.14.6', 'ascending'],
#  ['b.2SA.14.6', 'negative'],
#  ['b.2SA.14.6', 'neutral'],
#  ['b.2SA.14.7', 'ascending'],
#  ['b.2SA.14.7', 'negative'],
#  ['b.2SA.14.7', 'neutral'],
#  ['b.2SA.14.11', 'ascending'],
#  ['b.2SA.14.11', 'negative'],
#  ['b.2SA.14.11', 'positive'],
#  ['b.2SA.14.16', 'ascending'],
#  ['b.2SA.14.16', 'negative'],
#  ['b.2SA.14.16', 'positive'],
#  ['b.2SA.14.27', 'ascending'],
#  ['b.2SA.14.27', 'positive'],
#  ['b.2SA.14.33', 'positive'],
#  ['b.2SA.15.5', 'positive'],
#  ['b.2SA.15.16', 'female-prostitute'],
#  ['b.2SA.15.16', 'neutral'],
#  ['b.2SA.15.20', 'neutral'],
#  ['b.2SA.15.20', 'positive'],
#  ['b.2SA.15.27', 'ascending'],
#  ['b.2SA.15.27', 'neutral'],
#  ['b.2SA.15.32', 'neutral'],
#  ['b.2SA.15.32', 'negative'],
#  ['b.2SA.15.36', 'ascending'],
#  ['b.2SA.15.36', 'neural'],
#  ['b.2SA.16.3', 'ascending'],
#  ['b.2SA.16.3', 'neutral'],
#  ['b.2SA.16.3', 'negative'],
#  ['b.2SA.16.5', 'ascending'],
#  ['b.2SA.16.5', 'neutral'],
#  ['b.2SA.16.5', 'negative'],
#  ['b.2SA.16.8', 'ascending'],
#  ['b.2SA.16.8', 'neutral'],
#  ['b.2SA.16.8', 'negative'],
#  ['b.2SA.16.9', 'ascending'],
#  ['b.2SA.16.9', 'negative'],
#  ['b.2SA.16.9', 'neutral'],
#  ['b.2SA.16.10', 'ascending'],
#  ['b.2SA.16.10', 'negative'],
#  ['b.2SA.16.10', 'neutral'],
#  ['b.2SA.16.11', 'ascending'],
#  ['b.2SA.16.11', 'negative'],
#  ['b.2SA.16.11', 'neutral'],
#  ['b.2SA.16.19', 'ascending'],
#  ['b.2SA.16.19', 'neutral'],
#  ['b.2SA.16.19', 'positive'],
#  ['b.2SA.16.21', 'sex-with-prostitutes'],
#  ['b.2SA.16.21', 'neutral'],
#  ['b.2SA.16.21', 'negative'],
#  ['b.2SA.16.21', 'ascending'],
#  ['b.2SA.16.22', 'sex-with-prostitutes'],
#  ['b.2SA.16.22', 'neutral'],
#  ['b.2SA.16.22', 'negative'],
#  ['b.2SA.16.22', 'ascending'],
#  ['b.2SA.17.8', 'ascending'],
#  ['b.2SA.17.8', 'neutral'],
#  ['b.2SA.17.8', 'negative'],
#  ['b.2SA.17.25', 'matrimony'],
#  ['b.2SA.17.25', 'ascending'],
#  ['b.2SA.17.25', 'neutral'],
#  ['b.2SA.17.25', 'positive'],
#  ['b.2SA.17.27', 'ascending'],
#  ['b.2SA.17.27', 'neutral'],
#  ['b.2SA.18.2', 'ascending'],
#  ['b.2SA.18.2', 'neutral'],
#  ['b.2SA.18.5', 'neutral'],
#  ['b.2SA.18.5', 'positive'],
#  ['b.2SA.18.5', 'ascending'],
#  ['b.2SA.18.12', 'ascending'],
#  ['b.2SA.18.12', 'positive'],
#  ['b.2SA.18.12', 'negative'],
#  ['b.2SA.18.18', 'ascending'],
#  ['b.2SA.18.18', 'positive'],
#  ['b.2SA.18.18', 'negative'],
#  ['b.2SA.18.20', 'ascending'],
#  ['b.2SA.18.20', 'neutral'],
#  ['b.2SA.18.20', 'negative'],
#  ['b.2SA.18.22', 'ascending'],
#  ['b.2SA.18.22', 'positive'],
#  ['b.2SA.18.22', 'negative'],
#  ['b.2SA.18.27', 'ascending'],
#  ['b.2SA.18.27', 'neutral'],
#  ['b.2SA.18.27', 'positive'],
#  ['b.2SA.18.32', 'ascending'],
#  ['b.2SA.18.32', 'negative'],
#  ['b.2SA.18.32', 'positive'],
#  ['b.2SA.18.33', 'ascending'],
#  ['b.2SA.18.33', 'negative'],
#  ['b.2SA.18.33', 'positive'],
#  ['b.2SA.19.2', 'ascending'],
#  ['b.2SA.19.2', 'negative'],
#  ['b.2SA.19.2', 'positive'],
#  ['b.2SA.19.4', 'ascending'],
#  ['b.2SA.19.4', 'negative'],
#  ['b.2SA.19.4', 'positive'],
#  ['b.2SA.19.5', 'ascending'],
#  ['b.2SA.19.5', 'wife'],
#  ['b.2SA.19.5', 'positive'],
#  ['b.2SA.19.5', 'negative'],
#  ['b.2SA.19.6', 'positive'],
#  ['b.2SA.19.6', 'negative'],
#  ['b.2SA.19.12', 'positive'],
#  ['b.2SA.19.12', 'negative'],
#  ['b.2SA.19.13', 'positive'],
#  ['b.2SA.19.13', 'negative'],
#  ['b.2SA.19.16', 'ascending'],
#  ['b.2SA.19.16', 'positive'],
#  ['b.2SA.19.16', 'neutral'],
#  ['b.2SA.19.18', 'ascending'],
#  ['b.2SA.19.18', 'positive'],
#  ['b.2SA.19.18', 'neutral'],
#  ['b.2SA.19.21', 'ascending'],
#  ['b.2SA.19.21', 'negative'],
#  ['b.2SA.19.21', 'positive'],
#  ['b.2SA.19.21', 'neutral'],
#  ['b.2SA.19.22', 'ascending'],
#  ['b.2SA.19.22', 'negative'],
#  ['b.2SA.19.22', 'neutral'],
#  ['b.2SA.19.22', 'positive'],
#  ['b.2SA.19.24', 'ascending'],
#  ['b.2SA.19.24', 'neutral'],
#  ['b.2SA.19.24', 'negative'],
#  ['b.2SA.19.37', 'ascending'],
#  ['b.2SA.19.37', 'negative'],
#  ['b.2SA.19.37', 'neutral'],
#  ['b.2SA.19.39', 'positive'],
#  ['b.2SA.19.39', 'neutral'],
#  ['b.2SA.20.1', 'ascending'],
#  ['b.2SA.20.1', 'negative'],
#  ['b.2SA.20.1', 'neutral'],
#  ['b.2SA.20.2', 'ascending'],
#  ['b.2SA.20.2', 'negative'],
#  ['b.2SA.20.2', 'neutral'],
#  ['b.2SA.20.3', 'concubin'],
#  ['b.2SA.20.3', 'negative'],
#  ['b.2SA.20.3', 'neutral'],
#  ['b.2SA.20.3', 'no-sex'],
#  ['b.2SA.20.6', 'ascending'],
#  ['b.2SA.20.6', 'negative'],
#  ['b.2SA.20.6', 'neutral'],
#  ['b.2SA.20.7', 'ascending'],
#  ['b.2SA.20.7', 'negative'],
#  ['b.2SA.20.7', 'neutral'],
#  ['b.2SA.20.9', 'negative'],
#  ['b.2SA.20.9', 'neutral'],
#  ['b.2SA.20.19', 'motherhood'],
#  ['b.2SA.20.19', 'methaporical'],
#  ['b.2SA.20.19', 'negative'],
#  ['b.2SA.20.19', 'positive'],
#  ['b.2SA.20.21', 'ascending'],
#  ['b.2SA.20.21', 'negative'],
#  ['b.2SA.20.21', 'neutral'],
#  ['b.2SA.20.22', 'ascending'],
#  ['b.2SA.20.22', 'negative'],
#  ['b.2SA.20.22', 'neutral'],
#  ['b.2SA.20.23', 'ascending'],
#  ['b.2SA.20.23', 'neutral'],
#  ['b.2SA.20.24', 'ascending'],
#  ['b.2SA.20.24', 'neutral'],
#  ['b.2SA.21.2', 'ascending'],
#  ['b.2SA.21.2', 'neutral'],
#  ['b.2SA.21.2', 'negative'],
#  ['b.2SA.21.7', 'ascending'],
#  ['b.2SA.21.7', 'positive'],
#  ['b.2SA.21.7', 'negative'],
#  ['b.2SA.21.8', 'ascending'],
#  ['b.2SA.21.8', 'neutral'],
#  ['b.2SA.21.8', 'negative'],
#  ['b.2SA.21.9', 'ascending'],
#  ['b.2SA.21.9', 'negative'],
#  ['b.2SA.21.11', 'ascending'],
#  ['b.2SA.21.11', 'neutral'],
#  ['b.2SA.21.11', 'negative'],
#  ['b.2SA.21.11', 'concubina'],
#  ['b.2SA.21.12', 'ascending'],
#  ['b.2SA.21.12', 'positive'],
#  ['b.2SA.21.12', 'negative'],
#  ['b.2SA.21.13', 'ascending'],
#  ['b.2SA.21.13', 'neutral'],
#  ['b.2SA.21.13', 'negative'],
#  ['b.2SA.21.14', 'ascending'],
#  ['b.2SA.21.14', 'neutral'],
#  ['b.2SA.21.14', 'negative'],
#  ['b.2SA.21.16', 'ascending'],
#  ['b.2SA.21.16', 'neurtal'],
#  ['b.2SA.21.16', 'negative'],
#  ['b.2SA.21.17', 'ascending'],
#  ['b.2SA.21.17', 'positive'],
#  ['b.2SA.21.17', 'negative'],
#  ['b.2SA.21.18', 'ascending'],
#  ['b.2SA.21.18', 'positive'],
#  ['b.2SA.21.18', 'negative'],
#  ['b.2SA.21.19', 'ascending'],
#  ['b.2SA.21.19', 'positive'],
#  ['b.2SA.21.19', 'negative'],
#  ['b.2SA.21.20', 'ascending'],
#  ['b.2SA.21.20', 'neutral'],
#  ['b.2SA.21.20', 'negative'],
#  ['b.2SA.21.21', 'ascending'],
#  ['b.2SA.21.21', 'positive'],
#  ['b.2SA.21.21', 'negative'],
#  ['b.2SA.21.22', 'ascending'],
#  ['b.2SA.21.22', 'positive'],
#  ['b.2SA.21.22', 'negative']]

# %%
standOff_str[0:10000]
# Out:
# '<standOff xml:id="b.GAL.sexualThemes"  scheme="taxonomy.xml">\n<spanGrp type="theme" inst="#b.GAL.001.001">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.001">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.001">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.003">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.003">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.003">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.004">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.004">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.004">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.014">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.014">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.014">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.015">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.015">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.015">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.016">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.016">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.001.016">\n\t<span ana="flesh">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.002.003">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.002.003">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.002.003">\n\t<span ana="circumcision">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.002.007">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.GAL.002.007">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spa ...

# %%
valorations_lt = taxonomy_el.xpath("//tei:category[@xml:id='valorations']//tei:category//@xml:id", namespaces = namespaces_dict)

# %%
len(valorations_lt)
# Out:
# 5

# %%
valorations_lt
# Out:
# ['blessed-aspect',
#  'positive-aspect',
#  'neutral-aspect',
#  'negative-aspect',
#  'condemned-aspect']

# %%
for verse in sorted(list(set(etree.fromstring(standOff_str).xpath('//spanGrp//@inst')))):
    #print(verse)
    annotations = etree.fromstring(standOff_str).xpath('//spanGrp[@inst ="' + verse + '"]/span/@ana')

    if valorations_lt[0] not in annotations and valorations_lt[1]  not in annotations and valorations_lt[2]  not in annotations  and valorations_lt[3] not in annotations  and valorations_lt[4] not in annotations:
        print(verse, annotations)

# %%
verse
# Out:
# '#b.GAL.006.015'

# %%
annotations
# Out:
# ['circumcision', 'uncircumcised', 'blessed-aspect', 'positive-aspect']

# %%
import pandas as pd
pd.DataFrame([["a", 1],["b", 5],["c", 0],["d", 2],], columns=["label", "value"]).sort_values(by="value", ascending=False).iloc[0]
# Out:
# label    b
# value    5
# Name: 1, dtype: object

# %%
from collections import Counter
Counter([error_id[1] for  error_id in error_lt]).most_common()
# Out:
# [('positive', 32),
#  ('negative', 24),
#  ('ascending', 23),
#  ('blessed', 16),
#  ('neutral', 13),
#  ('condemned', 5),
#  ('incircumcision', 2),
#  ('sacending', 1),
#  ('estirility', 1),
#  ('adultery', 1),
#  ('fornication', 1),
#  ('lust', 1),
#  ('sex-in-group', 1),
#  ('condemened', 1),
#  ('uncircumcision', 1)]

# %%
parse_sexual_anotation.save_book_with_standOff_element(book_str, standOff_str, book_name,     wdir_str = "./../../../sexual-annotation/",)

# %%
book_str[0:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<?xml-model href="https://raw.githubusercontent.com/morethanbooks/XML-TEI-Bible/master/scheme/tei_lite.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-quotes.css" rel="stylesheet" title="Word2Pix Quotations"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-reference.css" rel="stylesheet" title="Word2Pix References"?>\n<?xml-stylesheet type="text/css" href="styles/styles.css" rel="stylesheet" title="Classic"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-level-q.css" rel="stylesheet" title="Word2Pix Level Quotation"?>\n\n<TEI xmlns="http://www.tei-c.org/ns/1.0">\n\t<teiHeader>\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title>Gálatas</title>\n\t\t\t\t<title type="idno">\n\t\t\t\t\t<idno type="string">GAL</idno>\n\t\t\t\t\t<idno type="viaf">183875648</idno>\n\t\t\t\t</title>\n\t\t\t\t<author>\n\t\t\t\t\t<name type="short"></name>\n\t\t\t\t\t<name type="full"></name>\n\t\t\t\t\t<idno type="viaf"></idno>\n\t\t'

# %%
book_str[-1000:]
# Out:
# 'itive-->\n\t\t\t\t\t\t\tporque, en <rs key="#per1">Cristo</rs> <rs key="#per1">Jesús</rs>, ni la circuncisión vale nada ni la incircuncisión, sino la <rs key="#org18">nueva criatura</rs>.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t\t<ab xml:id="b.GAL.006.016" type="verse" n="16">\n\t\t\t\t\t\t\tA todos los que anden conforme a esta regla, paz y misericordia sea a ellos, y al <rs key="#pla4">Israel de <rs key="#per14">Dios</rs></rs>.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t\t<ab xml:id="b.GAL.006.017" type="verse" n="17">\n\t\t\t\t\t\t\tDe aquí en adelante nadie me cause molestias, porque yo llevo en mi cuerpo las marcas del <rs key="#per1">Señor</rs> <rs key="#per1">Jesús</rs>.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div type="pericope">\n\t\t\t\t\t\t<head type="pericope">Bendición final</head>\n\t\t\t\t\t\t<ab xml:id="b.GAL.006.018" type="verse" n="18">\n\t\t\t\t\t\t\t<rs key="#org282">Hermanos</rs>, la gracia de nuestro <rs key="#per1">Señor</rs> <rs key="#per1">Jesucristo</rs> sea con vuestro espíritu. Amén.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n\t\t\t\t\t</div>\n</body>\n<back />\n</text>\n</TEI>\n'
