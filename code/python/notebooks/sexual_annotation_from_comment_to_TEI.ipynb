# %%
import parse_sexual_anotation

# %%
book_name = "JOH"

# %%
wdir_str = "../../sexual-annotation/"
file_str = book_name + ".xml"

book_name_str = file_str[0:3]

# %%
book_str = parse_sexual_anotation.open_book(wdir_str, file_str)
book_str[0:1000]
# Out:
# ['../../sexual-annotation/JOH.xml']
# JOH
# <class 'str'>
# '<?xml version="1.0" encoding="UTF-8"?>\n\n\n\n<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml"\n\tschematypens="http://purl.oclc.org/dsdl/schematron"?>\n<?xml-model href="https://raw.githubusercontent.com/morethanbooks/XML-TEI-Bible/master/scheme/tei_lite.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>\n\n\n\n<?xml-stylesheet type="text/css" href="styles/word2pix-reference.css" rel="stylesheet" title="Word2Pix References"?>\n<?xml-stylesheet type="text/css" href="styles/styles.css" rel="stylesheet" title="Classic"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-quotes.css" rel="stylesheet" title="Word2Pix Quotations"?>\n<?xml-stylesheet type="text/css" href="styles/word2pix-level-q.css" rel="stylesheet" title="Word2Pix Level Quotation"?>\n\n\n\n<TEI xmlns="http://www.tei-c.org/ns/1.0">\n\t<teiHeader>\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title>Evangelio de Juan</title>\n\t\t\t\t<title type="idno">\n\t\t\t\t\t<idno t'

# %%
taxonomy_file_str = "taxonomy.xml"

# %%
taxonomy_el = parse_sexual_anotation.open_taxonomy(wdir_str, taxonomy_file_str)
# Out:
# <class 'lxml.etree._Element'>

# %%
namespaces_dict = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
categories_id_lt = parse_sexual_anotation.get_list_categories(taxonomy_el, namespaces = namespaces_dict)

print(categories_id_lt)
# Out:
# ['relations', 'monogamy', 'poligamy', 'marriage', 'second-marriage', 'second-marriage-divorce', 'second-marriage-widow', 'interfaith-marriage', 'interfaith-relation', 'non-marital-relation', 'marital-relation-political-family', 'lord-servant-relation', 'marital-relation-direct-family', 'arranged-marriage', 'divorce', 'engaged', 'love', 'jealousy', 'ascendant-descendant', 'indirect-ascendant-descendant', 'acts', 'social-related-act', 'wedding', 'body-related-act', 'massage', 'kiss', 'hug', 'dance', 'abortion', 'circumcision', 'breast-feeding', 'sexual-act', 'sexual-act-stage', 'seduction', 'erotic-time', 'initation-sexual-act', 'orgasm', 'ejaculation', 'time-after-sex', 'sexual-act-type', 'coitus', 'first-sexual-act', 'coitus-interruptus', 'self-masturbation', 'masturbation', 'oral-sex', 'anal-sex', 'non-penetrative-sex', 'female-rape', 'male-rape', 'sexual-assault', 'female-sexual-assault', 'male-sexual-assault', 'sexual-deception', 'sexual-drive', 'sexual-desire', 'sex-for-goods', 'other-sexual-act', 'sexual-act-situation', 'sex-in-marriage', 'sex-before-marriage', 'sex-outside-marriage', 'sex-outside', 'sexual-act-participants', 'heterosexual-sex', 'homosexual-sex', 'gay-sex', 'lesbian-sex', 'prostitution-sex', 'religous-sex', 'parents-children-sex', 'sibling-sex', 'greater-family-sex', '
b.JOH.004.018', 'non-marital-relation; negative; marriage'), ('b.JOH.006.051', 'body; flesh; positive'), ('b.JOH.006.052', 'body; flesh; positive'), ('b.JOH.006.053', 'body; flesh; positive'), ('b.JOH.006.054', 'body; flesh; positive'), ('b.JOH.006.055', 'body; flesh; positive'), ('b.JOH.006.056', 'body; flesh; positive'), ('b.JOH.006.057', 'body; flesh; positive'), ('b.JOH.006.058', 'body; flesh; positive'), ('b.JOH.006.063', 'body; flesh; neutral'), ('b.JOH.007.022', 'circumcision; neutral'), ('b.JOH.007.023', 'circumcision; positive'), ('b.JOH.008.003', 'condemned; adultery; women'), ('b.JOH.008.004', 'condemned; adultery; coitus; women'), ('b.JOH.008.005', 'condemned; adultery; coitus;'), ('b.JOH.008.007', 'condemned; adultery'), ('b.JOH.008.010', 'condemned; adultery'), ('b.JOH.008.011', 'condemned; adultery'), ('b.JOH.008.015', 'flesh; neutral; negative'), ('b.JOH.008.041', 'fornication; negative'), ('b.JOH.008.042', 'birth; positive'), ('b.JOH.009.001', 'birth; negative'), ('b.JOH.009.002', 'birth; negative'), ('b.JOH.009.019', 'birth'), ('b.JOH.009.032', 'birth; neutral'), ('b.JOH.011.002', 'massage; feet; hair; perfume'), ('b.JOH.012.003', 'massage; feet; perfume; hair; positive'), ('b.JOH.013.001', 'love; blessed'), ('b.JOH.013.005', 'feet; massage; cleaning; blessed'), ('b.JOH.013.006', 'feet; massage; cleaning; blessed'), ('b.JOH.013.008', 'feet; massage; cleaning; blessed'), ('b.JOH.013.009', 'feet; massage; cleaning; blessed; hands; head; water'), ('b.JOH.013.010', 'feet; massage; cleaning; blessed; negative'), ('b.JOH.013.012', 'feet; water; blessed'), ('b.JOH.013.014', 'feet; water; blessed'), ('b.JOH.013.023', 'love'), ('b.JOH.013.025', 'hug; breast; positive'), ('b.JOH.013.034', 'love; blessed'), ('b.JOH.014.015', 'love'), ('b.JOH.014.021', 'love'), ('b.JOH.014.023', 'love'), ('b.JOH.014.024', 'love'), ('b.JOH.014.031', 'love'), ('b.JOH.015.009', 'love; blessed'), ('b.JOH.015.010', 'love; blessed'), ('b.JOH.015.012', 'love; blessed'), ('b.JOH.015.013', 'love; blessed'), ('b.JOH.015.017', 'love; blessed'), ('b.JOH.016.021', 'birth; women; descendant; negative; positive'), ('b.JOH.017.002', 'flesh'), ('b.JOH.017.023', 'love; blessed'), ('b.JOH.017.024', 'love; blessed'), ('b.JOH.017.026', 'love; blessed'), ('b.JOH.020.002', 'love; blessed'), ('b.JOH.021.007', 'love; positive'), ('b.JOH.021.015', 'love; positive'), ('b.JOH.021.016', 'love; positive'), ('b.JOH.021.017', 'love; positive'), ('b.JOH.021.020', 'love; positive')]

# %%
error_lt, standOff_str = parse_sexual_anotation.parse_each_sexual_annotation_as_comment(sexual_annotations_from_comments_lt, categories_id_lt, book_name)
# Out:
# b.JOH.001.014
# body
# <class 'str'>
# body
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.002.001
# wedding
# <class 'str'>
# wedding
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.002.002
# wedding
# <class 'str'>
# wedding
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.003.003
# birth
# <class 'str'>
# birth
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.015.012
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.015.013
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.015.017
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.016.021
# birth
# <class 'str'>
# birth
#  women
# <class 'str'>
# women
#  descendant
# <class 'str'>
# descendant
# ERROR!! descendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.017.002
# flesh
# <class 'str'>
# flesh
# ERROR!! flesh
# b.JOH.017.023
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.017.024
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.017.026
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.020.002
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.JOH.021.007
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.021.015
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.021.016
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.021.017
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.JOH.021.020
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# errors [['b.JOH.001.014', 'blessed'], ['b.JOH.002.001', 'positive'], ['b.JOH.002.002', 'positive'], ['b.JOH.003.003', 'blessed'], ['b.JOH.003.004', 'uterus'], ['b.JOH.003.004', 'neutral'], ['b.JOH.003.005', 'blessed'], ['b.JOH.003.006', 'flesh'], ['b.JOH.003.006', 'blessed'], ['b.JOH.003.006', 'condemned'], ['b.JOH.003.007', 'blessed'], ['b.JOH.003.008', 'blessed'], ['b.JOH.003.035', 'blessed'], ['b.JOH.004.007', 'watter'], ['b.JOH.004.017', 'neutral'], ['b.JOH.004.018', 'negative'], ['b.JOH.006.051', 'flesh'], ['b.JOH.006.051', 'positive'], ['b.JOH.006.052', 'flesh'], ['b.JOH.006.052', 'positive'], ['b.JOH.006.053', 'flesh'], ['b.JOH.006.053', 'positive'], ['b.JOH.006.054', 'flesh'], ['b.JOH.006.054', 'positive'], ['b.JOH.006.055', 'flesh'], ['b.JOH.006.055', 'positive'], ['b.JOH.006.056', 'flesh'], ['b.JOH.006.056', 'positive'], ['b.JOH.006.057', 'flesh'], ['b.JOH.006.057', 'positive'], ['b.JOH.006.058', 'flesh'], ['b.JOH.006.058', 'positive'], ['b.JOH.006.063', 'flesh'], ['b.JOH.006.063', 'neutral'], ['b.JOH.007.022', 'neutral'], ['b.JOH.007.023', 'positive'], ['b.JOH.008.003', 'condemned'], ['b.JOH.008.003', 'adultery'], ['b.JOH.008.004', 'condemned'], ['b.JOH.008.004', 'adultery'], ['b.JOH.008.005', 'condemned'], ['b.JOH.008.005', 'adultery'], ['b.JOH.008.007', 'condemned'], ['b.JOH.008.007', 'adultery'], ['b.JOH.008.010', 'condemned'], ['b.JOH.008.010', 'adultery'], ['b.JOH.008.011', 'condemned'], ['b.JOH.008.011', 'adultery'], ['b.JOH.008.015', 'flesh'], ['b.JOH.008.015', 'neutral'], ['b.JOH.008.015', 'negative'], ['b.JOH.008.041', 'fornication'], ['b.JOH.008.041', 'negative'], ['b.JOH.008.042', 'positive'], ['b.JOH.009.001', 'negative'], ['b.JOH.009.002', 'negative'], ['b.JOH.009.032', 'neutral'], ['b.JOH.011.002', 'feet'], ['b.JOH.012.003', 'feet'], ['b.JOH.012.003', 'positive'], ['b.JOH.013.001', 'blessed'], ['b.JOH.013.005', 'feet'], ['b.JOH.013.005', 'cleaning'], ['b.JOH.013.005', 'blessed'], ['b.JOH.013.006', 'feet'], ['b.JOH.013.006', 'cleaning'], ['b.JOH.013.006', 'blessed'], ['b.JOH.013.008', 'feet'], ['b.JOH.013.008', 'cleaning'], ['b.JOH.013.008', 'blessed'], ['b.JOH.013.009', 'feet'], ['b.JOH.013.009', 'cleaning'], ['b.JOH.013.009', 'blessed'], ['b.JOH.013.009', 'hands'], ['b.JOH.013.010', 'feet'], ['b.JOH.013.010', 'cleaning'], ['b.JOH.013.010', 'blessed'], ['b.JOH.013.010', 'negative'], ['b.JOH.013.012', 'feet'], ['b.JOH.013.012', 'blessed'], ['b.JOH.013.014', 'feet'], ['b.JOH.013.014', 'blessed'], ['b.JOH.013.025', 'breast'], ['b.JOH.013.025', 'positive'], ['b.JOH.013.034', 'blessed'], ['b.JOH.015.009', 'blessed'], ['b.JOH.015.010', 'blessed'], ['b.JOH.015.012', 'blessed'], ['b.JOH.015.013', 'blessed'], ['b.JOH.015.017', 'blessed'], ['b.JOH.016.021', 'descendant'], ['b.JOH.016.021', 'negative'], ['b.JOH.016.021', 'positive'], ['b.JOH.017.002', 'flesh'], ['b.JOH.017.023', 'blessed'], ['b.JOH.017.024', 'blessed'], ['b.JOH.017.026', 'blessed'], ['b.JOH.020.002', 'blessed'], ['b.JOH.021.007', 'positive'], ['b.JOH.021.015', 'positive'], ['b.JOH.021.016', 'positive'], ['b.JOH.021.017', 'positive'], ['b.JOH.021.020', 'positive']]
# [('blessed', 25), ('positive', 20), ('flesh', 12), ('feet', 9), ('condemned', 7), ('negative', 7), ('neutral', 6), ('adultery', 6), ('cleaning', 5), ('uterus', 1), ('watter', 1), ('fornication', 1), ('hands', 1), ('breast', 1), ('descendant', 1)]
#
#
# Consider substitue hands with hand . Levenshtein ratio:0.89
# Replacement accepted
#
#
# Consider substitue blessed with blessed-aspect . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue neutral with neutral-aspect . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue cleaning with earrings . Levenshtein ratio:0.62
# Replacement rejected. No change.
#
#
# Consider substitue feet with desert . Levenshtein ratio:0.6
# Replacement modified with foot
#
#
# Consider substitue flesh with flowers . Levenshtein ratio:0.67
# Replacement rejected. No change.
#
#
# Consider substitue negative with negative-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue condemned with condemned-aspect . Levenshtein ratio:0.72
# Replacement accepted
#
#
# Consider substitue adultery with water . Levenshtein ratio:0.62
# Replacement modified with sex-before-marriage
#
#
# Consider substitue positive with positive-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue fornication with lubrication . Levenshtein ratio:0.73
# Replacement modified with sex-outside-marriage
#
#
# Consider substitue descendant with ascendant-descendant . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue breast with beauty . Levenshtein ratio:0.67
# Replacement modified with female-breast
#
#
# Consider substitue watter with water . Levenshtein ratio:0.91
# Replacement accepted
#
#
# Consider substitue uterus with gluteus-anus . Levenshtein ratio:0.56
# Replacement rejected. No change.

# %%
standOff_str[0:100000]
# Out:
# '<standOff xml:id="b.JOH.sexualThemes"  scheme="taxonomy.xml">\n<spanGrp type="theme" inst="#b.JOH.001.014">\n\t<span ana="body">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.001.014">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.002.001">\n\t<span ana="wedding">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.002.001">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.002.002">\n\t<span ana="wedding">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.002.002">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.003">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.003">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.004">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.004">\n\t<span ana="pregnancy">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.004">\n\t<span ana="uterus">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.004">\n\t<span ana="neutral-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.005">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.005">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.006">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.006">\n\t<span ana="flesh">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.006">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.006">\n\t<span ana="condemned-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.007">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.007">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.008">\n\t<span ana="birth">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.008">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.035">\n\t<span ana="love">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.JOH.003.035">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" g ...

# %%
import pandas as pd
pd.DataFrame([["a", 1],["b", 5],["c", 0],["d", 2],], columns=["label", "value"]).sort_values(by="value", ascending=False).iloc[0]
# Out:
# label    b
# value    5
# Name: 1, dtype: object

# %%
error_lt
# Out:
# [['b.JOH.001.014', 'blessed'],
#  ['b.JOH.002.001', 'positive'],
#  ['b.JOH.002.002', 'positive'],
#  ['b.JOH.003.003', 'blessed'],
#  ['b.JOH.003.004', 'uterus'],
#  ['b.JOH.003.004', 'neutral'],
#  ['b.JOH.003.005', 'blessed'],
#  ['b.JOH.003.006', 'flesh'],
#  ['b.JOH.003.006', 'blessed'],
#  ['b.JOH.003.006', 'condemned'],
#  ['b.JOH.003.007', 'blessed'],
#  ['b.JOH.003.008', 'blessed'],
#  ['b.JOH.003.035', 'blessed'],
#  ['b.JOH.004.007', 'watter'],
#  ['b.JOH.004.017', 'neutral'],
#  ['b.JOH.004.018', 'negative'],
#  ['b.JOH.006.051', 'flesh'],
#  ['b.JOH.006.051', 'positive'],
#  ['b.JOH.006.052', 'flesh'],
#  ['b.JOH.006.052', 'positive'],
#  ['b.JOH.006.053', 'flesh'],
#  ['b.JOH.006.053', 'positive'],
#  ['b.JOH.006.054', 'flesh'],
#  ['b.JOH.006.054', 'positive'],
#  ['b.JOH.006.055', 'flesh'],
#  ['b.JOH.006.055', 'positive'],
#  ['b.JOH.006.056', 'flesh'],
#  ['b.JOH.006.056', 'positive'],
#  ['b.JOH.006.057', 'flesh'],
#  ['b.JOH.006.057', 'positive'],
#  ['b.JOH.006.058', 'flesh'],
#  ['b.JOH.006.058', 'positive'],
#  ['b.JOH.006.063', 'flesh'],
#  ['b.JOH.006.063', 'neutral'],
#  ['b.JOH.007.022', 'neutral'],
#  ['b.JOH.007.023', 'positive'],
#  ['b.JOH.008.003', 'condemned'],
#  ['b.JOH.008.003', 'adultery'],
#  ['b.JOH.008.004', 'condemned'],
#  ['b.JOH.008.004', 'adultery'],
#  ['b.JOH.008.005', 'condemned'],
#  ['b.JOH.008.005', 'adultery'],
#  ['b.JOH.008.007', 'condemned'],
#  ['b.JOH.008.007', 'adultery'],
#  ['b.JOH.008.010', 'condemned'],
#  ['b.JOH.008.010', 'adultery'],
#  ['b.JOH.008.011', 'condemned'],
#  ['b.JOH.008.011', 'adultery'],
#  ['b.JOH.008.015', 'flesh'],
#  ['b.JOH.008.015', 'neutral'],
#  ['b.JOH.008.015', 'negative'],
#  ['b.JOH.008.041', 'fornication'],
#  ['b.JOH.008.041', 'negative'],
#  ['b.JOH.008.042', 'positive'],
#  ['b.JOH.009.001', 'negative'],
#  ['b.JOH.009.002', 'negative'],
#  ['b.JOH.009.032', 'neutral'],
#  ['b.JOH.011.002', 'feet'],
#  ['b.JOH.012.003', 'feet'],
#  ['b.JOH.012.003', 'positive'],
#  ['b.JOH.013.001', 'blessed'],
#  ['b.JOH.013.005', 'feet'],
#  ['b.JOH.013.005', 'cleaning'],
#  ['b.JOH.013.005', 'blessed'],
#  ['b.JOH.013.006', 'feet'],
#  ['b.JOH.013.006', 'cleaning'],
#  ['b.JOH.013.006', 'blessed'],
#  ['b.JOH.013.008', 'feet'],
#  ['b.JOH.013.008', 'cleaning'],
#  ['b.JOH.013.008', 'blessed'],
#  ['b.JOH.013.009', 'feet'],
#  ['b.JOH.013.009', 'cleaning'],
#  ['b.JOH.013.009', 'blessed'],
#  ['b.JOH.013.009', 'hands'],
#  ['b.JOH.013.010', 'feet'],
#  ['b.JOH.013.010', 'cleaning'],
#  ['b.JOH.013.010', 'blessed'],
#  ['b.JOH.013.010', 'negative'],
#  ['b.JOH.013.012', 'feet'],
#  ['b.JOH.013.012', 'blessed'],
#  ['b.JOH.013.014', 'feet'],
#  ['b.JOH.013.014', 'blessed'],
#  ['b.JOH.013.025', 'breast'],
#  ['b.JOH.013.025', 'positive'],
#  ['b.JOH.013.034', 'blessed'],
#  ['b.JOH.015.009', 'blessed'],
#  ['b.JOH.015.010', 'blessed'],
#  ['b.JOH.015.012', 'blessed'],
#  ['b.JOH.015.013', 'blessed'],
#  ['b.JOH.015.017', 'blessed'],
#  ['b.JOH.016.021', 'descendant'],
#  ['b.JOH.016.021', 'negative'],
#  ['b.JOH.016.021', 'positive'],
#  ['b.JOH.017.002', 'flesh'],
#  ['b.JOH.017.023', 'blessed'],
#  ['b.JOH.017.024', 'blessed'],
#  ['b.JOH.017.026', 'blessed'],
#  ['b.JOH.020.002', 'blessed'],
#  ['b.JOH.021.007', 'positive'],
#  ['b.JOH.021.015', 'positive'],
#  ['b.JOH.021.016', 'positive'],
#  ['b.JOH.021.017', 'positive'],
#  ['b.JOH.021.020', 'positive']]

# %%
from collections import Counter
Counter([error_id[1] for  error_id in error_lt]).most_common()
# Out:
# [('blessed', 25),
#  ('positive', 20),
#  ('flesh', 12),
#  ('feet', 9),
#  ('condemned', 7),
#  ('negative', 7),
#  ('neutral', 6),
#  ('adultery', 6),
#  ('cleaning', 5),
#  ('uterus', 1),
#  ('watter', 1),
#  ('fornication', 1),
#  ('hands', 1),
#  ('breast', 1),
#  ('descendant', 1)]

# %%
parse_sexual_anotation.save_book_with_standOff_element(book_str, standOff_str, book_name)
