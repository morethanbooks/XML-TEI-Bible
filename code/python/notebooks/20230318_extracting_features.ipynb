# %%
from lxml import etree
import pandas as pd
from collections import Counter
import os
import glob
import re
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
from numpy import array
import numpy as np
import matplotlib.pyplot as plt
#import pyarrow
# %matplotlib inline


wdir = "../../../sexual-annotation/"
file_bible = "TEIBible" # "*.xml"
file_taxonomy = "taxonomy"
outdir = "../../../resulting data/"

# %%
wdir + file_bible + ".xml"
# Out:
# '../../../sexual-annotation/TEIBible.xml'

# %%
parser = etree.XMLParser(encoding = 'utf-8')
documento_xml_bible = etree.parse(wdir + file_bible + ".xml", parser)
documento_root_bible = documento_xml_bible.getroot()
specific_namespaces = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
parser = etree.XMLParser(encoding = 'utf-8')
documento_xml_taxonomy = etree.parse(wdir + file_taxonomy + ".xml", parser)
documento_root_taxonomy = documento_xml_taxonomy.getroot()

# %%
documento_root_taxonomy
# Out:
# <Element {http://www.tei-c.org/ns/1.0}TEI at 0x19ee6d7d8c8>

# %%
verses_identifiers = documento_root_bible.xpath('.//tei:ab[@type="verse"]/@xml:id', namespaces = specific_namespaces, with_tail = True)

# %%
[verse for verse in verses_identifiers if "ROM" in verse]
# Out:
# ['b.ROM.001.001',
#  'b.ROM.001.002',
#  'b.ROM.001.003',
#  'b.ROM.001.004',
#  'b.ROM.001.005',
#  'b.ROM.001.006',
#  'b.ROM.001.007',
#  'b.ROM.001.008',
#  'b.ROM.001.009',
#  'b.ROM.001.010',
#  'b.ROM.001.011',
#  'b.ROM.001.012',
#  'b.ROM.001.013',
#  'b.ROM.001.014',
#  'b.ROM.001.015',
#  'b.ROM.001.016',
#  'b.ROM.001.017',
#  'b.ROM.001.018',
#  'b.ROM.001.019',
#  'b.ROM.001.020',
#  'b.ROM.001.021',
#  'b.ROM.001.022',
#  'b.ROM.001.023',
#  'b.ROM.001.024',
#  'b.ROM.001.025',
#  'b.ROM.001.026',
#  'b.ROM.001.027',
#  'b.ROM.001.028',
#  'b.ROM.001.029',
#  'b.ROM.001.030',
#  'b.ROM.001.031',
#  'b.ROM.001.032',
#  'b.ROM.002.001',
#  'b.ROM.002.002',
#  'b.ROM.002.003',
#  'b.ROM.002.004',
#  'b.ROM.002.005',
#  'b.ROM.002.006',
#  'b.ROM.002.007',
#  'b.ROM.002.008',
#  'b.ROM.002.009',
#  'b.ROM.002.010',
#  'b.ROM.002.011',
#  'b.ROM.002.012',
#  'b.ROM.002.013',
#  'b.ROM.002.014',
#  'b.ROM.002.015',
#  'b.ROM.002.016',
#  'b.ROM.002.017',
#  'b.ROM.002.018',
#  'b.ROM.002.019',
#  'b.ROM.002.020',
#  'b.ROM.002.021',
#  'b.ROM.002.022',
#  'b.ROM.002.023',
#  'b.ROM.002.024',
#  'b.ROM.002.025',
#  'b.ROM.002.026',
#  'b.ROM.002.027',
#  'b.ROM.002.028',
#  'b.ROM.002.029',
#  'b.ROM.003.001',
#  'b.ROM.003.002',
#  'b.ROM.003.003',
#  'b.ROM.003.004',
#  'b.ROM.003.005',
#  'b.ROM.003.006',
#  'b.ROM.003.007',
#  'b.ROM.003.008',
#  'b.ROM.003.009',
#  'b.ROM.003.010',
#  'b.ROM.003.011',
#  'b.ROM.003.012',
#  'b.ROM.003.013',
#  'b.ROM.003.014',
#  'b.ROM.003.015',
#  'b.ROM.003.016',
#  'b.ROM.003.017',
#  'b.ROM.003.018',
#  'b.ROM.003.019',
#  'b.ROM.003.020',
#  'b.ROM.003.021',
#  'b.ROM.003.022',
#  'b.ROM.003.023',
#  'b.ROM.003.024',
#  'b.ROM.003.025',
#  'b.ROM.003.026',
#  'b.ROM.003.027',
#  'b.ROM.003.028',
#  'b.ROM.003.029',
#  'b.ROM.003.030',
#  'b.ROM.003.031',
#  'b.ROM.004.001',
#  'b.ROM.004.002',
#  'b.ROM.004.003',
#  'b.ROM.004.004',
#  'b.ROM.004.005',
#  'b.ROM.004.006',
#  'b.ROM.004.007',
#  'b.ROM.004.008',
#  'b.ROM.004.009',
#  'b.ROM.004.010',
#  'b.ROM.004.011',
#  'b.ROM.004.012',
#  'b.ROM.004.013',
#  'b.ROM.004.014',
#  'b.ROM.004.015',
#  'b.ROM.004.016',
#  'b.ROM.004.017',
#  'b.ROM.004.018',
#  'b.ROM.004.019',
#  'b.ROM.004.020',
#  'b.ROM.004.021',
#  'b.ROM.004.022',
#  'b.ROM.004.023',
#  'b.ROM.004.024',
#  'b.ROM.004.025',
#  'b.ROM.005.001',
#  'b.ROM.005.002',
#  'b.ROM.005.003',
#  'b.ROM.005.004',
#  'b.ROM.005.005',
#  'b.ROM.005.006',
#  'b.ROM.005.007',
#  'b.ROM.005.008',
#  'b.ROM.005.009',
#  'b.ROM.005.010',
#  'b.ROM.005.011',
#  'b.ROM.005.012',
#  'b.ROM.005.013',
#  'b.ROM.005.014',
#  'b.ROM.005.015',
#  'b.ROM.005.016',
#  'b.ROM.005.017',
#  'b.ROM.005.018',
#  'b.ROM.005.019',
#  'b.ROM.005.020',
#  'b.ROM.005.021',
#  'b.ROM.006.001',
#  'b.ROM.006.002',
#  'b.ROM.006.003',
#  'b.ROM.006.004',
#  'b.ROM.006.005',
#  'b.ROM.006.006',
#  'b.ROM.006.007',
#  'b.ROM.006.008',
#  'b.ROM.006.009',
#  'b.ROM.006.010',
#  'b.ROM.006.011',
#  'b.ROM.006.012',
#  'b.ROM.006.013',
#  'b.ROM.006.014',
#  'b.ROM.006.015',
#  'b.ROM.006.016',
#  'b.ROM.006.017',
#  'b.ROM.006.018',
#  'b.ROM.006.019',
#  'b.ROM.006.020',
#  'b.ROM.006.021',
#  'b.ROM.006.022',
#  'b.ROM.006.023',
#  'b.ROM.007.001',
#  'b.ROM.007.002',
#  'b.ROM.007.003',
#  'b.ROM.007.004',
#  'b.ROM.007.005',
#  'b.ROM.007.006',
#  'b.ROM.007.007',
#  'b.ROM.007.008',
#  'b.ROM.007.009',
#  'b.ROM.007.010',
#  'b.ROM.007.011',
#  'b.ROM.007.012',
#  'b.ROM.007.013',
#  'b.ROM.007.014',
#  'b.ROM.007.015',
#  'b.ROM.007.016',
#  'b.ROM.007.017',
#  'b.ROM.007.018',
#  'b.ROM.007.019',
#  'b.ROM.007.020',
#  'b.ROM.007.021',
#  'b.ROM.007.022',
#  'b.ROM.007.023',
#  'b.ROM.007.024',
#  'b.ROM.007.025',
#  'b.ROM.008.001',
#  'b.ROM.008.002',
#  'b.ROM.008.003',
#  'b.ROM.008.004',
#  'b.ROM.008.005',
#  'b.ROM.008.006',
#  'b.ROM.008.007',
#  'b.ROM.008.008',
#  'b.ROM.008.009',
#  'b.ROM.008.010',
#  'b.ROM.008.011',
#  'b.ROM.008.012',
#  'b.ROM.008.013',
#  'b.ROM.008.014',
#  'b.ROM.008.015',
#  'b.ROM.008.016',
#  'b.ROM.008.017',
#  'b.ROM.008.018',
#  'b.ROM.008.019',
#  'b.ROM.008.020',
#  'b.ROM.008.021',
#  'b.ROM.008.022',
#  'b.ROM.008.023',
#  'b.ROM.008.024',
#  'b.ROM.008.025',
#  'b.ROM.008.026',
#  'b.ROM.008.027',
#  'b.ROM.008.028',
#  'b.ROM.008.029',
#  'b.ROM.008.030',
#  'b.ROM.008.031',
#  'b.ROM.008.032',
#  'b.ROM.008.033',
#  'b.ROM.008.034',
#  'b.ROM.008.035',
#  'b.ROM.008.036',
#  'b.ROM.008.037',
#  'b.ROM.008.038',
#  'b.ROM.008.039',
#  'b.ROM.009.001',
#  'b.ROM.009.002',
#  'b.ROM.009.003',
#  'b.ROM.009.004',
#  'b.ROM.009.005',
#  'b.ROM.009.006',
#  'b.ROM.009.007',
#  'b.ROM.009.008',
#  'b.ROM.009.009',
#  'b.ROM.009.010',
#  'b.ROM.009.011',
#  'b.ROM.009.012',
#  'b.ROM.009.013',
#  'b.ROM.009.014',
#  'b.ROM.009.015',
#  'b.ROM.009.016',
#  'b.ROM.009.017',
#  'b.ROM.009.018',
#  'b.ROM.009.019',
#  'b.ROM.009.020',
#  'b.ROM.009.021',
#  'b.ROM.009.022',
#  'b.ROM.009.023',
#  'b.ROM.009.024',
#  'b.ROM.009.025',
#  'b.ROM.009.026',
#  'b.ROM.009.027',
#  'b.ROM.009.028',
#  'b.ROM.009.029',
#  'b.ROM.009.030',
#  'b.ROM.009.031',
#  'b.ROM.009.032',
#  'b.ROM.009.033',
#  'b.ROM.010.001',
#  'b.ROM.010.002',
#  'b.ROM.010.003',
#  'b.ROM.010.004',
#  'b.ROM.010.005',
#  'b.ROM.010.006',
#  'b.ROM.010.007',
#  'b.ROM.010.008',
#  'b.ROM.010.009',
#  'b.ROM.010.010',
#  'b.ROM.010.011',
#  'b.ROM.010.012',
#  'b.ROM.010.013',
#  'b.ROM.010.014',
#  'b.ROM.010.015',
#  'b.ROM.010.016',
#  'b.ROM.010.017',
#  'b.ROM.010.018',
#  'b.ROM.010.019',
#  'b.ROM.010.020',
#  'b.ROM.010.021',
#  'b.ROM.011.001',
#  'b.ROM.011.002',
#  'b.ROM.011.003',
#  'b.ROM.011.004',
#  'b.ROM.011.005',
#  'b.ROM.011.006',
#  'b.ROM.011.007',
#  'b.ROM.011.008',
#  'b.ROM.011.009',
#  'b.ROM.011.010',
#  'b.ROM.011.011',
#  'b.ROM.011.012',
#  'b.ROM.011.013',
#  'b.ROM.011.014',
#  'b.ROM.011.015',
#  'b.ROM.011.016',
#  'b.ROM.011.017',
#  'b.ROM.011.018',
#  'b.ROM.011.019',
#  'b.ROM.011.020',
#  'b.ROM.011.021',
#  'b.ROM.011.022',
#  'b.ROM.011.023',
#  'b.ROM.011.024',
#  'b.ROM.011.025',
#  'b.ROM.011.026',
#  'b.ROM.011.027',
#  'b.ROM.011.028',
#  'b.ROM.011.029',
#  'b.ROM.011.030',
#  'b.ROM.011.031',
#  'b.ROM.011.032',
#  'b.ROM.011.033',
#  'b.ROM.011.034',
#  'b.ROM.011.035',
#  'b.ROM.011.036',
#  'b.ROM.012.001',
#  'b.ROM.012.002',
#  'b.ROM.012.003',
#  'b.ROM.012.004',
#  'b.ROM.012.005',
#  'b.ROM.012.006',
#  'b.ROM.012.007',
#  'b.ROM.012.008',
#  'b.ROM.012.009',
#  'b.ROM.012.010',
#  'b.ROM.012.011',
#  'b.ROM.012.012',
#  'b.ROM.012.013',
#  'b.ROM.012.014',
#  'b.ROM.012.015',
#  'b.ROM.012.016',
#  'b.ROM.012.017',
#  'b.ROM.012.018',
#  'b.ROM.012.019',
#  'b.ROM.012.020',
#  'b.ROM.012.021',
#  'b.ROM.013.001',
#  'b.ROM.013.002',
#  'b.ROM.013.003',
#  'b.ROM.013.004',
#  'b.ROM.013.005',
#  'b.ROM.013.006',
#  'b.ROM.013.007',
#  'b.ROM.013.008',
#  'b.ROM.013.009',
#  'b.ROM.013.010',
#  'b.ROM.013.011',
#  'b.ROM.013.012',
#  'b.ROM.013.013',
#  'b.ROM.013.014',
#  'b.ROM.014.001',
#  'b.ROM.014.002',
#  'b.ROM.014.003',
#  'b.ROM.014.004',
#  'b.ROM.014.005',
#  'b.ROM.014.006',
#  'b.ROM.014.007',
#  'b.ROM.014.008',
#  'b.ROM.014.009',
#  'b.ROM.014.010',
#  'b.ROM.014.011',
#  'b.ROM.014.012',
#  'b.ROM.014.013',
#  'b.ROM.014.014',
#  'b.ROM.014.015',
#  'b.ROM.014.016',
#  'b.ROM.014.017',
#  'b.ROM.014.018',
#  'b.ROM.014.019',
#  'b.ROM.014.020',
#  'b.ROM.014.021',
#  'b.ROM.014.022',
#  'b.ROM.014.023',
#  'b.ROM.015.001',
#  'b.ROM.015.002',
#  'b.ROM.015.003',
#  'b.ROM.015.004',
#  'b.ROM.015.005',
#  'b.ROM.015.006',
#  'b.ROM.015.007',
#  'b.ROM.015.008',
#  'b.ROM.015.009',
#  'b.ROM.015.010',
#  'b.ROM.015.011',
#  'b.ROM.015.012',
#  'b.ROM.015.013',
#  'b.ROM.015.014',
#  'b.ROM.015.015',
#  'b.ROM.015.016',
#  'b.ROM.015.017',
#  'b.ROM.015.018',
#  'b.ROM.015.019',
#  'b.ROM.015.020',
#  'b.ROM.015.021',
#  'b.ROM.015.022',
#  'b.ROM.015.023',
#  'b.ROM.015.024',
#  'b.ROM.015.025',
#  'b.ROM.015.026',
#  'b.ROM.015.027',
#  'b.ROM.015.028',
#  'b.ROM.015.029',
#  'b.ROM.015.030',
#  'b.ROM.015.031',
#  'b.ROM.015.032',
#  'b.ROM.015.033',
#  'b.ROM.016.001',
#  'b.ROM.016.002',
#  'b.ROM.016.003',
#  'b.ROM.016.004',
#  'b.ROM.016.005',
#  'b.ROM.016.006',
#  'b.ROM.016.007',
#  'b.ROM.016.008',
#  'b.ROM.016.009',
#  'b.ROM.016.010',
#  'b.ROM.016.011',
#  'b.ROM.016.012',
#  'b.ROM.016.013',
#  'b.ROM.016.014',
#  'b.ROM.016.015',
#  'b.ROM.016.016',
#  'b.ROM.016.017',
#  'b.ROM.016.018',
#  'b.ROM.016.019',
#  'b.ROM.016.020',
#  'b.ROM.016.021',
#  'b.ROM.016.022',
#  'b.ROM.016.023',
#  'b.ROM.016.024',
#  'b.ROM.016.025',
#  'b.ROM.016.026',
#  'b.ROM.016.027']

# %%
categories_names = documento_root_taxonomy.xpath('.//tei:category/@xml:id', namespaces = specific_namespaces, with_tail = True)

# %%
categories_names
# Out:
# ['relations',
#  'monogamy',
#  'poligamy',
#  'marriage',
#  'second-marriage',
#  'second-marriage-divorce',
#  'second-marriage-widow',
#  'interfaith-marriage',
#  'interfaith-relation',
#  'non-marital-relation',
#  'pre-marital-relation',
#  'relation-greater-family',
#  'marital-relation-political-family',
#  'lord-servant-relation',
#  'marital-relation-direct-family',
#  'arranged-marriage',
#  'divorce',
#  'engaged',
#  'love',
#  'jealousy',
#  'ascendant-descendant',
#  'primogeniture',
#  'intercultural-ascendant-descendant',
#  'outside-marriage-ascendant-descendant',
#  'indirect-ascendant-descendant',
#  'homosexual-relation',
#  'acts',
#  'social-related-act',
#  'wedding',
#  'deception',
#  'prostitute',
#  'body-related-act',
#  'massage',
#  'kiss',
#  'hug',
#  'dance',
#  'abortion',
#  'circumcision',
#  'breast-feeding',
#  'bath',
#  'wash',
#  'sexual-act',
#  'sexual-act-stage',
#  'consent',
#  'seduction',
#  'rejection',
#  'erotic-time',
#  'initation-sexual-act',
#  'orgasm',
#  'ejaculation',
#  'time-after-sex',
#  'sexual-act-type',
#  'coitus',
#  'first-sexual-act',
#  'coitus-interruptus',
#  'self-masturbation',
#  'masturbation',
#  'sleep-orgasm',
#  'oral-sex',
#  'anal-sex',
#  'non-penetrative-sex',
#  'rape',
#  'female-rape',
#  'male-rape',
#  'sexual-assault',
#  'female-sexual-assault',
#  'male-sexual-assault',
#  'sexual-deception',
#  'sexual-drive',
#  'sexual-desire',
#  'sex-for-goods',
#  'voyerism',
#  'other-sexual-act',
#  'sexual-act-situation',
#  'sex-in-marriage',
#  'sex-before-marriage',
#  'sex-outside-marriage',
#  'sex-outside',
#  'sex-menstruation',
#  'sexual-act-participants',
#  'heterosexual-sex',
#  'homosexual-sex',
#  'gay-sex',
#  'lesbian-sex',
#  'prostitution-sex',
#  'religous-sex',
#  'parents-children-sex',
#  'sibling-sex',
#  'greater-family-sex',
#  'adults-children-sex',
#  'interfaith-sex',
#  'interracial-sex',
#  'angel-human-sex',
#  'god-human-sex',
#  'animal-human-sex',
#  'animal-sex',
#  'groupal-sex',
#  'lord-servant-sex',
#  'states',
#  'single-life',
#  'virginity',
#  'celibacy',
#  'infertility',
#  'nudity',
#  'semi-nudity',
#  'pregnancy',
#  'beauty',
#  'dishonor',
#  'sickness',
#  'body',
#  'body-by-gender',
#  'female-body',
#  'male-body',
#  'body-part',
#  'genitalia',
#  'female-genitalia',
#  'uterus',
#  'male-genitalia',
#  'prepuce',
#  'testicle',
#  'gluteus-anus',
#  'female-breast',
#  'male-chest',
#  'ovaries',
#  'semen',
#  'head',
#  'eye',
#  'nose',
#  'beard',
#  'cheek',
#  'mouth',
#  'lips',
#  'tongue',
#  'tooth',
#  'hair',
#  'thigh',
#  'neck',
#  'hand',
#  'skin',
#  'foot',
#  'waist',
#  'heart',
#  'navel',
#  'belly',
#  'leg',
#  'knie',
#  'arm',
#  'rib',
#  'lubrication',
#  'face',
#  'flesh',
#  'blood',
#  'umbilical-cord',
#  'body-function',
#  'birth',
#  'fertilization',
#  'misscarriage',
#  'erection',
#  'menstruation',
#  'sleep',
#  'diseases',
#  'menstrual-disorder',
#  'senses',
#  'smell',
#  'things',
#  'clothes',
#  'belt',
#  'veil',
#  'skirt',
#  'underwear',
#  'male-underwear',
#  'female-underwear',
#  'perfume',
#  'juwels',
#  'earrings',
#  'piercing',
#  'collar',
#  'bracelet',
#  'food-and-related',
#  'drink',
#  'water',
#  'milk',
#  'wine',
#  'alcohol',
#  'glass',
#  'oil',
#  'spices',
#  'wheat',
#  'honey',
#  'fruits',
#  'pomegranate',
#  'grapes',
#  'raisin',
#  'apples',
#  'figs',
#  'carriage',
#  'weapons',
#  'sword',
#  'shield',
#  'money',
#  'metal',
#  'silver',
#  'gold',
#  'fountain',
#  'well',
#  'pitcher',
#  'sexual-object',
#  'make-up',
#  'song',
#  'environment',
#  'moon',
#  'sun',
#  'rain',
#  'wind',
#  'places',
#  'interior-spaces',
#  'room',
#  'bedroom',
#  'bed',
#  'door',
#  'wall',
#  'house',
#  'tower',
#  'exterior-spaces',
#  'garden',
#  'vineyard',
#  'spring',
#  'desert',
#  'river',
#  'field',
#  'lake',
#  'groups',
#  'based-on-gender',
#  'women',
#  'men',
#  'third-sexual-group',
#  'eunuchs',
#  'based-on-orientation',
#  'heterosexuals',
#  'homosexuals',
#  'male-homosexuals',
#  'female-homosexuals',
#  'by-state',
#  'single',
#  'married',
#  'widow-widower',
#  'widow',
#  'widower',
#  'virgin',
#  'by-profession',
#  'prostitutes',
#  'female-prostitutes',
#  'male-prostitutes',
#  'sexual-priests',
#  'concubine',
#  'midwife',
#  'by-corporal-traits',
#  'circumcised',
#  'uncircumcised',
#  'animals',
#  'gazelle',
#  'deer',
#  'dove',
#  'fox',
#  'goat',
#  'sheep',
#  'leopard',
#  'lion',
#  'crow',
#  'turtledove',
#  'horse',
#  'donkey',
#  'cow',
#  'camel',
#  'plants',
#  'flowers',
#  'trees',
#  'palms',
#  'time',
#  'part-of-the-day',
#  'night',
#  'sunrise',
#  'seasons',
#  'winter',
#  'valorations',
#  'blessed-aspect',
#  'positive-aspect',
#  'neutral-aspect',
#  'negative-aspect',
#  'condemned-aspect']

# %%
import pandas as pd

verses_sexual_categories_df = pd.DataFrame(index= verses_identifiers, columns = ["bible_identifier", "verse_text", "bible_book", "bible_chapter", "bible_book_chapter"] + categories_names, dtype=object).fillna(0)

# %%
verses = documento_root_bible.xpath('.//tei:ab[@type="verse"]/@xml:id', namespaces = specific_namespaces, with_tail = True)

# %%
[verse for verse in verses if "ROM" in verse]
# Out:
# ['b.ROM.001.001',
#  'b.ROM.001.002',
#  'b.ROM.001.003',
#  'b.ROM.001.004',
#  'b.ROM.001.005',
#  'b.ROM.001.006',
#  'b.ROM.001.007',
#  'b.ROM.001.008',
#  'b.ROM.001.009',
#  'b.ROM.001.010',
#  'b.ROM.001.011',
#  'b.ROM.001.012',
#  'b.ROM.001.013',
#  'b.ROM.001.014',
#  'b.ROM.001.015',
#  'b.ROM.001.016',
#  'b.ROM.001.017',
#  'b.ROM.001.018',
#  'b.ROM.001.019',
#  'b.ROM.001.020',
#  'b.ROM.001.021',
#  'b.ROM.001.022',
#  'b.ROM.001.023',
#  'b.ROM.001.024',
#  'b.ROM.001.025',
#  'b.ROM.001.026',
#  'b.ROM.001.027',
#  'b.ROM.001.028',
#  'b.ROM.001.029',
#  'b.ROM.001.030',
#  'b.ROM.001.031',
#  'b.ROM.001.032',
#  'b.ROM.002.001',
#  'b.ROM.002.002',
#  'b.ROM.002.003',
#  'b.ROM.002.004',
#  'b.ROM.002.005',
#  'b.ROM.002.006',
#  'b.ROM.002.007',
#  'b.ROM.002.008',
#  'b.ROM.002.009',
#  'b.ROM.002.010',
#  'b.ROM.002.011',
#  'b.ROM.002.012',
#  'b.ROM.002.013',
#  'b.ROM.002.014',
#  'b.ROM.002.015',
#  'b.ROM.002.016',
#  'b.ROM.002.017',
#  'b.ROM.002.018',
#  'b.ROM.002.019',
#  'b.ROM.002.020',
#  'b.ROM.002.021',
#  'b.ROM.002.022',
#  'b.ROM.002.023',
#  'b.ROM.002.024',
#  'b.ROM.002.025',
#  'b.ROM.002.026',
#  'b.ROM.002.027',
#  'b.ROM.002.028',
#  'b.ROM.002.029',
#  'b.ROM.003.001',
#  'b.ROM.003.002',
#  'b.ROM.003.003',
#  'b.ROM.003.004',
#  'b.ROM.003.005',
#  'b.ROM.003.006',
#  'b.ROM.003.007',
#  'b.ROM.003.008',
#  'b.ROM.003.009',
#  'b.ROM.003.010',
#  'b.ROM.003.011',
#  'b.ROM.003.012',
#  'b.ROM.003.013',
#  'b.ROM.003.014',
#  'b.ROM.003.015',
#  'b.ROM.003.016',
#  'b.ROM.003.017',
#  'b.ROM.003.018',
#  'b.ROM.003.019',
#  'b.ROM.003.020',
#  'b.ROM.003.021',
#  'b.ROM.003.022',
#  'b.ROM.003.023',
#  'b.ROM.003.024',
#  'b.ROM.003.025',
#  'b.ROM.003.026',
#  'b.ROM.003.027',
#  'b.ROM.003.028',
#  'b.ROM.003.029',
#  'b.ROM.003.030',
#  'b.ROM.003.031',
#  'b.ROM.004.001',
#  'b.ROM.004.002',
#  'b.ROM.004.003',
#  'b.ROM.004.004',
#  'b.ROM.004.005',
#  'b.ROM.004.006',
#  'b.ROM.004.007',
#  'b.ROM.004.008',
#  'b.ROM.004.009',
#  'b.ROM.004.010',
#  'b.ROM.004.011',
#  'b.ROM.004.012',
#  'b.ROM.004.013',
#  'b.ROM.004.014',
#  'b.ROM.004.015',
#  'b.ROM.004.016',
#  'b.ROM.004.017',
#  'b.ROM.004.018',
#  'b.ROM.004.019',
#  'b.ROM.004.020',
#  'b.ROM.004.021',
#  'b.ROM.004.022',
#  'b.ROM.004.023',
#  'b.ROM.004.024',
#  'b.ROM.004.025',
#  'b.ROM.005.001',
#  'b.ROM.005.002',
#  'b.ROM.005.003',
#  'b.ROM.005.004',
#  'b.ROM.005.005',
#  'b.ROM.005.006',
#  'b.ROM.005.007',
#  'b.ROM.005.008',
#  'b.ROM.005.009',
#  'b.ROM.005.010',
#  'b.ROM.005.011',
#  'b.ROM.005.012',
#  'b.ROM.005.013',
#  'b.ROM.005.014',
#  'b.ROM.005.015',
#  'b.ROM.005.016',
#  'b.ROM.005.017',
#  'b.ROM.005.018',
#  'b.ROM.005.019',
#  'b.ROM.005.020',
#  'b.ROM.005.021',
#  'b.ROM.006.001',
#  'b.ROM.006.002',
#  'b.ROM.006.003',
#  'b.ROM.006.004',
#  'b.ROM.006.005',
#  'b.ROM.006.006',
#  'b.ROM.006.007',
#  'b.ROM.006.008',
#  'b.ROM.006.009',
#  'b.ROM.006.010',
#  'b.ROM.006.011',
#  'b.ROM.006.012',
#  'b.ROM.006.013',
#  'b.ROM.006.014',
#  'b.ROM.006.015',
#  'b.ROM.006.016',
#  'b.ROM.006.017',
#  'b.ROM.006.018',
#  'b.ROM.006.019',
#  'b.ROM.006.020',
#  'b.ROM.006.021',
#  'b.ROM.006.022',
#  'b.ROM.006.023',
#  'b.ROM.007.001',
#  'b.ROM.007.002',
#  'b.ROM.007.003',
#  'b.ROM.007.004',
#  'b.ROM.007.005',
#  'b.ROM.007.006',
#  'b.ROM.007.007',
#  'b.ROM.007.008',
#  'b.ROM.007.009',
#  'b.ROM.007.010',
#  'b.ROM.007.011',
#  'b.ROM.007.012',
#  'b.ROM.007.013',
#  'b.ROM.007.014',
#  'b.ROM.007.015',
#  'b.ROM.007.016',
#  'b.ROM.007.017',
#  'b.ROM.007.018',
#  'b.ROM.007.019',
#  'b.ROM.007.020',
#  'b.ROM.007.021',
#  'b.ROM.007.022',
#  'b.ROM.007.023',
#  'b.ROM.007.024',
#  'b.ROM.007.025',
#  'b.ROM.008.001',
#  'b.ROM.008.002',
#  'b.ROM.008.003',
#  'b.ROM.008.004',
#  'b.ROM.008.005',
#  'b.ROM.008.006',
#  'b.ROM.008.007',
#  'b.ROM.008.008',
#  'b.ROM.008.009',
#  'b.ROM.008.010',
#  'b.ROM.008.011',
#  'b.ROM.008.012',
#  'b.ROM.008.013',
#  'b.ROM.008.014',
#  'b.ROM.008.015',
#  'b.ROM.008.016',
#  'b.ROM.008.017',
#  'b.ROM.008.018',
#  'b.ROM.008.019',
#  'b.ROM.008.020',
#  'b.ROM.008.021',
#  'b.ROM.008.022',
#  'b.ROM.008.023',
#  'b.ROM.008.024',
#  'b.ROM.008.025',
#  'b.ROM.008.026',
#  'b.ROM.008.027',
#  'b.ROM.008.028',
#  'b.ROM.008.029',
#  'b.ROM.008.030',
#  'b.ROM.008.031',
#  'b.ROM.008.032',
#  'b.ROM.008.033',
#  'b.ROM.008.034',
#  'b.ROM.008.035',
#  'b.ROM.008.036',
#  'b.ROM.008.037',
#  'b.ROM.008.038',
#  'b.ROM.008.039',
#  'b.ROM.009.001',
#  'b.ROM.009.002',
#  'b.ROM.009.003',
#  'b.ROM.009.004',
#  'b.ROM.009.005',
#  'b.ROM.009.006',
#  'b.ROM.009.007',
#  'b.ROM.009.008',
#  'b.ROM.009.009',
#  'b.ROM.009.010',
#  'b.ROM.009.011',
#  'b.ROM.009.012',
#  'b.ROM.009.013',
#  'b.ROM.009.014',
#  'b.ROM.009.015',
#  'b.ROM.009.016',
#  'b.ROM.009.017',
#  'b.ROM.009.018',
#  'b.ROM.009.019',
#  'b.ROM.009.020',
#  'b.ROM.009.021',
#  'b.ROM.009.022',
#  'b.ROM.009.023',
#  'b.ROM.009.024',
#  'b.ROM.009.025',
#  'b.ROM.009.026',
#  'b.ROM.009.027',
#  'b.ROM.009.028',
#  'b.ROM.009.029',
#  'b.ROM.009.030',
#  'b.ROM.009.031',
#  'b.ROM.009.032',
#  'b.ROM.009.033',
#  'b.ROM.010.001',
#  'b.ROM.010.002',
#  'b.ROM.010.003',
#  'b.ROM.010.004',
#  'b.ROM.010.005',
#  'b.ROM.010.006',
#  'b.ROM.010.007',
#  'b.ROM.010.008',
#  'b.ROM.010.009',
#  'b.ROM.010.010',
#  'b.ROM.010.011',
#  'b.ROM.010.012',
#  'b.ROM.010.013',
#  'b.ROM.010.014',
#  'b.ROM.010.015',
#  'b.ROM.010.016',
#  'b.ROM.010.017',
#  'b.ROM.010.018',
#  'b.ROM.010.019',
#  'b.ROM.010.020',
#  'b.ROM.010.021',
#  'b.ROM.011.001',
#  'b.ROM.011.002',
#  'b.ROM.011.003',
#  'b.ROM.011.004',
#  'b.ROM.011.005',
#  'b.ROM.011.006',
#  'b.ROM.011.007',
#  'b.ROM.011.008',
#  'b.ROM.011.009',
#  'b.ROM.011.010',
#  'b.ROM.011.011',
#  'b.ROM.011.012',
#  'b.ROM.011.013',
#  'b.ROM.011.014',
#  'b.ROM.011.015',
#  'b.ROM.011.016',
#  'b.ROM.011.017',
#  'b.ROM.011.018',
#  'b.ROM.011.019',
#  'b.ROM.011.020',
#  'b.ROM.011.021',
#  'b.ROM.011.022',
#  'b.ROM.011.023',
#  'b.ROM.011.024',
#  'b.ROM.011.025',
#  'b.ROM.011.026',
#  'b.ROM.011.027',
#  'b.ROM.011.028',
#  'b.ROM.011.029',
#  'b.ROM.011.030',
#  'b.ROM.011.031',
#  'b.ROM.011.032',
#  'b.ROM.011.033',
#  'b.ROM.011.034',
#  'b.ROM.011.035',
#  'b.ROM.011.036',
#  'b.ROM.012.001',
#  'b.ROM.012.002',
#  'b.ROM.012.003',
#  'b.ROM.012.004',
#  'b.ROM.012.005',
#  'b.ROM.012.006',
#  'b.ROM.012.007',
#  'b.ROM.012.008',
#  'b.ROM.012.009',
#  'b.ROM.012.010',
#  'b.ROM.012.011',
#  'b.ROM.012.012',
#  'b.ROM.012.013',
#  'b.ROM.012.014',
#  'b.ROM.012.015',
#  'b.ROM.012.016',
#  'b.ROM.012.017',
#  'b.ROM.012.018',
#  'b.ROM.012.019',
#  'b.ROM.012.020',
#  'b.ROM.012.021',
#  'b.ROM.013.001',
#  'b.ROM.013.002',
#  'b.ROM.013.003',
#  'b.ROM.013.004',
#  'b.ROM.013.005',
#  'b.ROM.013.006',
#  'b.ROM.013.007',
#  'b.ROM.013.008',
#  'b.ROM.013.009',
#  'b.ROM.013.010',
#  'b.ROM.013.011',
#  'b.ROM.013.012',
#  'b.ROM.013.013',
#  'b.ROM.013.014',
#  'b.ROM.014.001',
#  'b.ROM.014.002',
#  'b.ROM.014.003',
#  'b.ROM.014.004',
#  'b.ROM.014.005',
#  'b.ROM.014.006',
#  'b.ROM.014.007',
#  'b.ROM.014.008',
#  'b.ROM.014.009',
#  'b.ROM.014.010',
#  'b.ROM.014.011',
#  'b.ROM.014.012',
#  'b.ROM.014.013',
#  'b.ROM.014.014',
#  'b.ROM.014.015',
#  'b.ROM.014.016',
#  'b.ROM.014.017',
#  'b.ROM.014.018',
#  'b.ROM.014.019',
#  'b.ROM.014.020',
#  'b.ROM.014.021',
#  'b.ROM.014.022',
#  'b.ROM.014.023',
#  'b.ROM.015.001',
#  'b.ROM.015.002',
#  'b.ROM.015.003',
#  'b.ROM.015.004',
#  'b.ROM.015.005',
#  'b.ROM.015.006',
#  'b.ROM.015.007',
#  'b.ROM.015.008',
#  'b.ROM.015.009',
#  'b.ROM.015.010',
#  'b.ROM.015.011',
#  'b.ROM.015.012',
#  'b.ROM.015.013',
#  'b.ROM.015.014',
#  'b.ROM.015.015',
#  'b.ROM.015.016',
#  'b.ROM.015.017',
#  'b.ROM.015.018',
#  'b.ROM.015.019',
#  'b.ROM.015.020',
#  'b.ROM.015.021',
#  'b.ROM.015.022',
#  'b.ROM.015.023',
#  'b.ROM.015.024',
#  'b.ROM.015.025',
#  'b.ROM.015.026',
#  'b.ROM.015.027',
#  'b.ROM.015.028',
#  'b.ROM.015.029',
#  'b.ROM.015.030',
#  'b.ROM.015.031',
#  'b.ROM.015.032',
#  'b.ROM.015.033',
#  'b.ROM.016.001',
#  'b.ROM.016.002',
#  'b.ROM.016.003',
#  'b.ROM.016.004',
#  'b.ROM.016.005',
#  'b.ROM.016.006',
#  'b.ROM.016.007',
#  'b.ROM.016.008',
#  'b.ROM.016.009',
#  'b.ROM.016.010',
#  'b.ROM.016.011',
#  'b.ROM.016.012',
#  'b.ROM.016.013',
#  'b.ROM.016.014',
#  'b.ROM.016.015',
#  'b.ROM.016.016',
#  'b.ROM.016.017',
#  'b.ROM.016.018',
#  'b.ROM.016.019',
#  'b.ROM.016.020',
#  'b.ROM.016.021',
#  'b.ROM.016.022',
#  'b.ROM.016.023',
#  'b.ROM.016.024',
#  'b.ROM.016.025',
#  'b.ROM.016.026',
#  'b.ROM.016.027']

# %%
verses = documento_root_bible.xpath('.//tei:ab[@type="verse"]', namespaces = specific_namespaces, with_tail = True)

print(len(verses))

for verse in verses:
    

    verse_reference = verse.xpath('./@xml:id', namespaces=specific_namespaces, with_tail=True)

    verse_text = verse.xpath('.//text()', namespaces=specific_namespaces, with_tail=True)
    verse_text = "".join(verse_text).strip()

    verses_sexual_categories_df.loc[verse_reference, "verse_text"] = verse_text

    #print(verse_reference)
    if "2SA" in verse_reference: print(verse_reference)

    grouped_referenced_entities = verse.xpath('.//tei:rs/@key | .//tei:q/@who | .//tei:q/@toWhom', namespaces=specific_namespaces, with_tail=True)
    entities_referenced = [entity for group_entities in grouped_referenced_entities for entity in group_entities.split(" ") ]

    for key, value in dict(Counter(entities_referenced)).items():
        verses_sexual_categories_df.loc[verse_reference, key] = value
    verses_sexual_categories_df.loc[verse_reference, "number of entities referred"] = len(entities_referenced)


    verses_sexual_categories_df.loc[verse_reference,"number of different entities referred"] =  len(set(entities_referenced))

    """
    try:
        verses_sexual_categories_df.loc[verse_reference, "most common entity id"] =  Counter(entities_referenced).most_common(1)[0][0]
    except:
        verses_sexual_categories_df.loc[verse_reference, "most common entity id"] = ""
    try:
        verses_sexual_categories_df.loc[verse_reference, "most common entity frecuency"] =  Counter(entities_referenced).most_common(1)[0][1]
    except:
        verses_sexual_categories_df.loc[verse_reference, "most common entity frecuency"] = 0
    try:
        verses_sexual_categories_df.loc[verse_reference, "second most common entity id"] =  Counter(entities_referenced).most_common(2)[1][0]
    except:
        verses_sexual_categories_df.loc[verse_reference, "second most common entity id"] = ""
    try:
        verses_sexual_categories_df.loc[verse_reference, "second most common entitity frequency"] =  Counter(entities_referenced).most_common(2)[1][1]
    except:
        verses_sexual_categories_df.loc[verse_reference, "second most common entitity frequency"] = 0 

    """

    people_referenced = [entity for entity in entities_referenced if "per" in entity]
    groups_referenced = [entity for entity in entities_referenced if "org" in entity]
    places_referenced = [entity for entity in entities_referenced if "pla" in entity]
    times_referenced = [entity for entity in entities_referenced if "tim" in entity]
    works_referenced = [entity for entity in entities_referenced if "wor" in entity]
    for key, list_ in {"number of people" : people_referenced, "number of groups" : groups_referenced, "number of places" : places_referenced,"number of times" : times_referenced ,"number of works" : works_referenced }.items():
        verses_sexual_categories_df.loc[verse_reference,key] = len(list_)
        verses_sexual_categories_df.loc[verse_reference,"number of different " + key] = len(set(list_))

    """
        if list_ == []:
            verses_sexual_categories_df.loc[verse_reference,"most frequent entitiy id "+key] = "-"
            verses_sexual_categories_df.loc[verse_reference,"most frequenct entity frequency "+key] = 0
        else:
            verses_sexual_categories_df.loc[verse_reference,"most frequent entity id "+key] = Counter(list_).most_common(1)[0][0]
            verses_sexual_categories_df.loc[verse_reference,"most frequenct entity frequency "+key] = Counter(list_).most_common(1)[0][1]
    """            
    verses_sexual_categories_df.loc[verse_reference,"number of 1st level quotations"] = len(verse.xpath('./tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 2nd level quotations"] = len(verse.xpath('./tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 3rd level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 4th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 5th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 6th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 7th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of quotations"] = len(verse.xpath('.//tei:q', namespaces=specific_namespaces, with_tail=True))
        

    grouped_who = verse.xpath('.//tei:q/@who', namespaces=specific_namespaces, with_tail=True)
    who_entities = [entity for group_who in grouped_who for entity in group_who.split(" ") ]
    verses_sexual_categories_df.loc[verse_reference,"number of entities communicating"] = len(who_entities)
    verses_sexual_categories_df.loc[verse_reference,"number of different entities communicating"] = len(set(who_entities))
    
    grouped_toWohm = verse.xpath('.//tei:q/@toWhom', namespaces=specific_namespaces, with_tail=True)
    toWhom_entities = [entity for group_toWohm in grouped_toWohm for entity in group_toWohm.split(" ") ]
    verses_sexual_categories_df.loc[verse_reference,"number of entities receiving communication"] = len(toWhom_entities)
    verses_sexual_categories_df.loc[verse_reference,"number of different entities receiving communication"] = len(set(toWhom_entities))


    verses_sexual_categories_df.loc[verse_reference,"number of oral quotations"] = len(verse.xpath('.//tei:q[@type="oral"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of dream quotations"] = len(verse.xpath('.//tei:q[@type="dream"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of praying quotations"] = len(verse.xpath('.//tei:q[@type="prayer"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of oath quotations"] = len(verse.xpath('.//tei:q[@type="oath"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of written quotations"] = len(verse.xpath('.//tei:q[@type="written"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of song quotations"] = len(verse.xpath('.//tei:q[@type="song"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of soCalled quotations"] = len(verse.xpath('.//tei:q[@type="soCalled"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of idea quotations"] = len(verse.xpath('.//tei:q[@type="idea"]', namespaces=specific_namespaces, with_tail=True))
# Out:
# 31065

# %%
verses_sexual_categories_df.columns.tolist()
# Out:
# ['bible_identifier',
#  'verse_text',
#  'bible_book',
#  'bible_chapter',
#  'bible_book_chapter',
#  'relations',
#  'monogamy',
#  'poligamy',
#  'marriage',
#  'second-marriage',
#  'second-marriage-divorce',
#  'second-marriage-widow',
#  'interfaith-marriage',
#  'interfaith-relation',
#  'non-marital-relation',
#  'pre-marital-relation',
#  'relation-greater-family',
#  'marital-relation-political-family',
#  'lord-servant-relation',
#  'marital-relation-direct-family',
#  'arranged-marriage',
#  'divorce',
#  'engaged',
#  'love',
#  'jealousy',
#  'ascendant-descendant',
#  'primogeniture',
#  'intercultural-ascendant-descendant',
#  'outside-marriage-ascendant-descendant',
#  'indirect-ascendant-descendant',
#  'homosexual-relation',
#  'acts',
#  'social-related-act',
#  'wedding',
#  'deception',
#  'prostitute',
#  'body-related-act',
#  'massage',
#  'kiss',
#  'hug',
#  'dance',
#  'abortion',
#  'circumcision',
#  'breast-feeding',
#  'bath',
#  'wash',
#  'sexual-act',
#  'sexual-act-stage',
#  'consent',
#  'seduction',
#  'rejection',
#  'erotic-time',
#  'initation-sexual-act',
#  'orgasm',
#  'ejaculation',
#  'time-after-sex',
#  'sexual-act-type',
#  'coitus',
#  'first-sexual-act',
#  'coitus-interruptus',
#  'self-masturbation',
#  'masturbation',
#  'sleep-orgasm',
#  'oral-sex',
#  'anal-sex',
#  'non-penetrative-sex',
#  'rape',
#  'female-rape',
#  'male-rape',
#  'sexual-assault',
#  'female-sexual-assault',
#  'male-sexual-assault',
#  'sexual-deception',
#  'sexual-drive',
#  'sexual-desire',
#  'sex-for-goods',
#  'voyerism',
#  'other-sexual-act',
#  'sexual-act-situation',
#  'sex-in-marriage',
#  'sex-before-marriage',
#  'sex-outside-marriage',
#  'sex-outside',
#  'sex-menstruation',
#  'sexual-act-participants',
#  'heterosexual-sex',
#  'homosexual-sex',
#  'gay-sex',
#  'lesbian-sex',
#  'prostitution-sex',
#  'religous-sex',
#  'parents-children-sex',
#  'sibling-sex',
#  'greater-family-sex',
#  'adults-children-sex',
#  'interfaith-sex',
#  'interracial-sex',
#  'angel-human-sex',
#  'god-human-sex',
#  'animal-human-sex',
#  'animal-sex',
#  'groupal-sex',
#  'lord-servant-sex',
#  'states',
#  'single-life',
#  'virginity',
#  'celibacy',
#  'infertility',
#  'nudity',
#  'semi-nudity',
#  'pregnancy',
#  'beauty',
#  'dishonor',
#  'sickness',
#  'body',
#  'body-by-gender',
#  'female-body',
#  'male-body',
#  'body-part',
#  'genitalia',
#  'female-genitalia',
#  'uterus',
#  'male-genitalia',
#  'prepuce',
#  'testicle',
#  'gluteus-anus',
#  'female-breast',
#  'male-chest',
#  'ovaries',
#  'semen',
#  'head',
#  'eye',
#  'nose',
#  'beard',
#  'cheek',
#  'mouth',
#  'lips',
#  'tongue',
#  'tooth',
#  'hair',
#  'thigh',
#  'neck',
#  'hand',
#  'skin',
#  'foot',
#  'waist',
#  'heart',
#  'navel',
#  'belly',
#  'leg',
#  'knie',
#  'arm',
#  'rib',
#  'lubrication',
#  'face',
#  'flesh',
#  'blood',
#  'umbilical-cord',
#  'body-function',
#  'birth',
#  'fertilization',
#  'misscarriage',
#  'erection',
#  'menstruation',
#  'sleep',
#  'diseases',
#  'menstrual-disorder',
#  'senses',
#  'smell',
#  'things',
#  'clothes',
#  'belt',
#  'veil',
#  'skirt',
#  'underwear',
#  'male-underwear',
#  'female-underwear',
#  'perfume',
#  'juwels',
#  'earrings',
#  'piercing',
#  'collar',
#  'bracelet',
#  'food-and-related',
#  'drink',
#  'water',
#  'milk',
#  'wine',
#  'alcohol',
#  'glass',
#  'oil',
#  'spices',
#  'wheat',
#  'honey',
#  'fruits',
#  'pomegranate',
#  'grapes',
#  'raisin',
#  'apples',
#  'figs',
#  'carriage',
#  'weapons',
#  'sword',
#  'shield',
#  'money',
#  'metal',
#  'silver',
#  'gold',
#  'fountain',
#  'well',
#  'pitcher',
#  'sexual-object',
#  'make-up',
#  'song',
#  'environment',
#  'moon',
#  'sun',
#  'rain',
#  'wind',
#  'places',
#  'interior-spaces',
#  'room',
#  'bedroom',
#  'bed',
#  'door',
#  'wall',
#  'house',
#  'tower',
#  'exterior-spaces',
#  'garden',
#  'vineyard',
#  'spring',
#  'desert',
#  'river',
#  'field',
#  'lake',
#  'groups',
#  'based-on-gender',
#  'women',
#  'men',
#  'third-sexual-group',
#  'eunuchs',
#  'based-on-orientation',
#  'heterosexuals',
#  'homosexuals',
#  'male-homosexuals',
#  'female-homosexuals',
#  'by-state',
#  'single',
#  'married',
#  'widow-widower',
#  'widow',
#  'widower',
#  'virgin',
#  'by-profession',
#  'prostitutes',
#  'female-prostitutes',
#  'male-prostitutes',
#  'sexual-priests',
#  'concubine',
#  'midwife',
#  'by-corporal-traits',
#  'circumcised',
#  'uncircumcised',
#  'animals',
#  'gazelle',
#  'deer',
#  'dove',
#  'fox',
#  'goat',
#  'sheep',
#  'leopard',
#  'lion',
#  'crow',
#  'turtledove',
#  'horse',
#  'donkey',
#  'cow',
#  'camel',
#  'plants',
#  'flowers',
#  'trees',
#  'palms',
#  'time',
#  'part-of-the-day',
#  'night',
#  'sunrise',
#  'seasons',
#  'winter',
#  'valorations',
#  'blessed-aspect',
#  'positive-aspect',
#  'neutral-aspect',
#  'negative-aspect',
#  'condemned-aspect',
#  '#tim3',
#  '#per14',
#  '#pla41',
#  'number of entities referred',
#  'number of different entities referred',
#  'number of people',
#  'number of different number of people',
#  'number of groups',
#  'number of different number of groups',
#  'number of places',
#  'number of different number of places',
#  'number of times',
#  'number of different number of times',
#  'number of works',
#  'number of different number of works',
#  'number of 1st level quotations',
#  'number of 2nd level quotations',
#  'number of 3rd level quotations',
#  'number of 4th level quotations',
#  'number of 5th level quotations',
#  'number of 6th level quotations',
#  'number of 7th level quotations',
#  'number of quotations',
#  'number of entities communicating',
#  'number of different entities communicating',
#  'number of entities receiving communication',
#  'number of different entities receiving communication',
#  'number of oral quotations',
#  'number of dream quotations',
#  'number of praying quotations',
#  'number of oath quotations',
#  'number of written quotations',
#  'number of song quotations',
#  'number of soCalled quotations',
#  'number of idea quotations',
#  '#per17',
#  '#org0',
#  '#per145',
#  '#per241',
#  '#pla77',
#  '#pla39',
#  '#pla85',
#  '#pla86',
#  '#pla87',
#  '#pla88',
#  '#pla89',
#  '#pla90',
#  '#pla64',
#  '#per20',
#  '#org4',
#  '#per142',
#  '#per43',
#  '#pla91',
#  '#per164',
#  '#pla92',
#  '#per256',
#  '#per283',
#  '#per243',
#  '#per154',
#  '#per166',
#  '#per209',
#  '#per299',
#  '#per362',
#  '#per428',
#  '#per392',
#  '#per169',
#  '#per179',
#  '#per198',
#  '#per183',
#  '#per194',
#  '#per206',
#  '#per190',
#  '#per440',
#  '#per47',
#  '#per144',
#  '#per158',
#  '#per162',
#  '#org122',
#  '#tim4',
#  '#per207',
#  '#pla18',
#  '#pla93',
#  '#pla84',
#  '#per242',
#  '#per212',
#  '#per351',
#  '#per264',
#  '#per457',
#  '#per333',
#  '#per320',
#  '#per324',
#  '#per253',
#  '#per315',
#  '#per420',
#  '#per233',
#  '#per314',
#  '#per177',
#  '#per330',
#  '#per454',
#  '#per289',
#  '#per294',
#  '#per291',
#  '#per307',
#  '#per302',
#  '#per284',
#  '#per301',
#  '#per435',
#  '#per436',
#  '#per292',
#  '#per269',
#  '#per393',
#  '#per458',
#  '#per444',
#  '#per257',
#  '#pla79',
#  '#pla94',
#  '#pla95',
#  '#pla96',
#  '#pla97',
#  '#pla20',
#  '#pla98',
#  '#pla99',
#  '#pla100',
#  '#per374',
#  '#per352',
#  '#per413',
#  '#per391',
#  '#per401',
#  '#per363',
#  '#org53',
#  '#per403',
#  '#per236',
#  '#per146',
#  '#org54',
#  '#org55',
#  '#org56',
#  '#org57',
#  '#org58',
#  '#org59',
#  '#org60',
#  '#org61',
#  '#org62',
#  '#org63',
#  '#pla23',
#  '#pla101',
#  '#pla81',
#  '#pla16',
#  '#pla17',
#  '#pla102',
#  '#pla103',
#  '#pla104',
#  '#per168',
#  '#per165',
#  '#per369',
#  '#per416',
#  '#per167',
#  '#per176',
#  '#per184',
#  '#per210',
#  '#per290',
#  '#per319',
#  '#per261',
#  '#per367',
#  '#per247',
#  '#per386',
#  '#per347',
#  '#per240',
#  '#per318',
#  '#per442',
#  '#per399',
#  '#per388',
#  '#per220',
#  '#pla105',
#  '#pla106',
#  '#tim15',
#  '#per199',
#  '#per200',
#  '#per451',
#  '#per156',
#  '#per2',
#  '#per141',
#  '#per148',
#  '#per137',
#  '#pla78',
#  '#org64',
#  '#per134',
#  '#per171',
#  '#per353',
#  '#pla107',
#  '#org78',
#  '#pla116',
#  '#per139',
#  '#pla109',
#  '#pla110',
#  '#pla111',
#  '#pla112',
#  '#pla5',
#  '#org65',
#  '#per251',
#  '#org94',
#  '#org83',
#  '#org150',
#  '#org66',
#  '#pla9',
#  '#pla113',
#  '#org79',
#  '#per153',
#  '#pla115',
#  '#per260',
#  '#per262',
#  '#pla117',
#  '#per191',
#  '#pla118',
#  '#per285',
#  '#pla119',
#  '#per395',
#  '#per360',
#  '#per366',
#  '#per329',
#  '#per461',
#  '#pla120',
#  '#pla121',
#  '#org67',
#  '#pla122',
#  '#org68',
#  '#pla123',
#  '#pla124',
#  '#org71',
#  '#pla125',
#  '#pla126',
#  '#pla127',
#  '#org69',
#  '#pla128',
#  '#per113',
#  '#org70',
#  '#per263',
#  '#per250',
#  '#pla311',
#  '#pla129',
#  '#pla80',
#  '#per431',
#  '#pla130',
#  '#org101',
#  '#per345',
#  '#per3',
#  '#org75',
#  '#pla131',
#  '#org72',
#  '#org73',
#  '#org74',
#  '#org76',
#  '#org77',
#  '#per143',
#  '#pla132',
#  '#per140',
#  '#pla114',
#  '#org16',
#  '#org134',
#  '#org85',
#  '#org18',
#  '#org19',
#  '#org80',
#  '#per170',
#  '#per272',
#  '#org81',
#  '#per268',
#  '#org82',
#  '#per138',
#  '#pla133',
#  '#per227',
#  '#pla83',
#  '#per404',
#  '#per304',
#  '#per151',
#  '#per365',
#  '#per336',
#  '#per323',
#  '#per159',
#  '#per453',
#  '#per136',
#  '#per306',
#  '#per310',
#  '#per338',
#  '#per421',
#  '#per357',
#  '#org84',
#  '#per149',
#  '#per213',
#  '#pla134',
#  '#pla135',
#  '#pla82',
#  '#org440',
#  '#per132',
#  '#per41',
#  '#org86',
#  '#per270',
#  '#per383',
#  '#per280',
#  '#per337',
#  '#per238',
#  '#per382',
#  '#per228',
#  '#per443',
#  '#per234',
#  '#per408',
#  '#per425',
#  '#per356',
#  '#per188',
#  '#per297',
#  '#per249',
#  '#per405',
#  '#per309',
#  '#per218',
#  '#per293',
#  '#per424',
#  '#per175',
#  '#per429',
#  '#per389',
#  '#per277',
#  '#per387',
#  '#per321',
#  '#per380',
#  '#per334',
#  '#per358',
#  '#pla136',
#  '#per131',
#  '#per4',
#  '#org131',
#  '#org87',
#  '#per385',
#  '#org24',
#  '#per354',
#  '#per410',
#  '#per182',
#  '#per216',
#  '#org88',
#  '#per373',
#  '#per16',
#  '#per135',
#  '#per173',
#  '#per157',
#  '#per109',
#  '#per125',
#  '#per124',
#  '#per5',
#  '#per181',
#  '#per13',
#  '#per122',
#  '#per120',
#  '#per121',
#  '#per35',
#  '#per126',
#  '#per127',
#  '#per161',
#  '#per104',
#  '#org89',
#  '#pla137',
#  '#per32',
#  '#pla138',
#  '#per344',
#  '#pla139',
#  '#org13',
#  '#pla4',
#  '#pla140',
#  '#pla108',
#  '#per150',
#  '#org103',
#  '#pla142',
#  '#per397',
#  '#per204',
#  '#per128',
#  '#pla1',
#  '#per282',
#  '#per180',
#  '#per197',
#  '#per214',
#  '#per211',
#  '#per205',
#  '#per433',
#  '#per172',
#  '#per460',
#  '#per160',
#  '#per174',
#  '#per202',
#  '#per252',
#  '#per254',
#  '#per259',
#  '#per232',
#  '#per450',
#  '#per279',
#  '#per244',
#  '#per226',
#  '#per248',
#  '#per258',
#  '#per163',
#  '#per203',
#  '#per229',
#  '#per208',
#  '#per222',
#  '#per219',
#  '#per346',
#  '#per331',
#  '#per308',
#  '#per379',
#  '#per422',
#  '#per375',
#  '#per372',
#  '#per407',
#  '#per78',
#  '#per364',
#  '#per303',
#  '#per328',
#  '#per456',
#  '#per384',
#  '#per327',
#  '#per437',
#  '#per359',
#  '#per187',
#  '#per390',
#  '#pla143',
#  '#per445',
#  '#per368',
#  '#per274',
#  '#pla202',
#  '#per276',
#  '#per378',
#  '#per446',
#  '#pla144',
#  '#per271',
#  '#per340',
#  '#per231',
#  '#per273',
#  '#per275',
#  '#per452',
#  '#pla145',
#  '#per371',
#  '#per296',
#  '#per350',
#  '#per370',
#  '#per418',
#  '#per427',
#  '#per295',
#  '#per398',
#  '#per147',
#  '#per414',
#  '#org90',
#  '#pla15',
#  '#per267',
#  '#per133',
#  '#per245',
#  '#per449',
#  '#per186',
#  '#per193',
#  '#per185',
#  '#per6',
#  '#pla146',
#  '#per7',
#  '#per286',
#  '#per0',
#  '#per178',
#  '#per201',
#  '#per195',
#  '#per196',
#  '#org92',
#  '#org100',
#  '#per230',
#  '#per217',
#  '#per235',
#  '#per72',
#  '#per152',
#  '#org40',
#  '#per189',
#  '#pla155',
#  '#pla147',
#  '#per448',
#  '#per423',
#  '#per266',
#  '#per305',
#  '#org45',
#  '#per155',
#  '#per341',
#  '#per317',
#  '#per342',
#  '#per447',
#  '#per441',
#  '#per432',
#  '#org46',
#  '#per215',
#  '#per426',
#  '#per349',
#  '#org39',
#  '#per419',
#  '#org47',
#  '#per221',
#  '#per376',
#  '#per396',
#  '#per402',
#  '#org48',
#  '#per223',
#  '#per439',
#  '#per394',
#  '#org41',
#  '#per237',
#  '#per406',
#  '#per343',
#  '#per287',
#  '#per332',
#  '#per326',
#  '#per355',
#  '#org42',
#  '#per239',
#  '#per361',
#  '#per316',
#  '#per246',
#  '#per409',
#  '#per455',
#  '#per288',
#  '#org50',
#  '#per438',
#  '#per325',
#  '#per312',
#  '#per417',
#  '#per313',
#  '#per322',
#  '#per300',
#  '#per377',
#  '#per335',
#  '#per412',
#  '#org49',
#  '#org91',
#  '#per224',
#  '#org43',
#  '#per225',
#  '#per415',
#  '#per400',
#  '#per411',
#  '#per339',
#  '#org93',
#  '#per1',
#  '#org22',
#  '#pla148',
#  '#per281',
#  '#org44',
#  '#per381',
#  '#per578',
#  '#pla247',
#  '#pla248',
#  '#per579',
#  '#per580',
#  '#per495',
#  '#per496',
#  '#per582',
#  '#per26',
#  '#per581',
#  '#per497',
#  '#pla249',
#  '#per583',
#  '#org127',
#  '#per584',
#  '#per499',
#  '#pla176',
#  '#pla159',
#  '#per585',
#  '#org25',
#  '#org15',
#  '#per500',
#  '#per614',
#  '#per586',
#  '#per588',
#  '#per589',
#  '#per590',
#  '#per591',
#  '#per592',
#  '#per593',
#  '#per594',
#  '#per595',
#  '#per596',
#  '#per597',
#  '#per598',
#  '#per599',
#  '#per600',
#  '#per601',
#  '#per602',
#  '#per603',
#  '#per604',
#  '#per605',
#  '#org129',
#  '#per606',
#  '#per607',
#  '#per608',
#  '#per611',
#  '#per609',
#  '#per610',
#  '#org14',
#  '#pla250',
#  '#pla175',
#  '#tim5',
#  '#org102',
#  '#pla251',
#  '#tim19',
#  '#org130',
#  '#tim20',
#  '#pla252',
#  '#pla253',
#  '#pla254',
#  '#pla255',
#  '#pla72',
#  '#pla246',
#  '#per612',
#  '#pla256',
#  '#pla257',
#  '#pla258',
#  '#tim9',
#  '#pla259',
#  '#pla260',
#  '#per503',
#  '#per613',
#  '#pla261',
#  'per14',
#  '#org95',
#  'org12',
#  'org70',
#  '#org12',
#  'org0',
#  '#pla262',
#  '#org188',
#  '#tim6',
#  '#tim17',
#  '#tim21',
#  '#pla30',
#  '#pla153',
#  '#wor1',
#  '#wor7',
#  '#pla263',
#  '#org132',
#  '#per615',
#  '#per616',
#  '#per617',
#  '#per618',
#  '#wor4',
#  '#per619',
#  '#per620',
#  '#tim22',
#  '#pla73',
#  '#pla613',
#  '#org183',
#  '#org6',
#  '#per501',
#  '#org281',
#  '#org21',
#  '#org214',
#  '#org144',
#  '#tim11',
#  '#per1504',
#  '#per1505',
#  '#pla676',
#  '#per1818',
#  '#per1774',
#  '#per1848',
#  '#per1775',
#  '#per1849',
#  '#per1776',
#  '#per1784',
#  '#per1777',
#  '#per1451',
#  '#per1770',
#  '#per1850',
#  '#per1778',
#  '#per1851',
#  '#per1779',
#  '#per1854',
#  '#per1780',
#  '#per1852',
#  '#per1781',
#  '#per1847',
#  '#per1783',
#  '#per1853',
#  '#per1782',
#  '#org216',
#  '#per587',
#  '#per731',
#  '#org215',
#  '#per1800',
#  '#org217',
#  '#org312',
#  '#pla42',
#  '#per1801',
#  '#org313',
#  '#org314',
#  '#org315',
#  '#org316',
#  '#per1855',
#  '#org319',
#  '#org317',
#  '#org318',
#  '#per1856',
#  '#per1802',
#  '#per1857',
#  '#per1804',
#  '#pla738',
#  '#pla943',
#  '#per1806',
#  '#per1787',
#  '#pla920',
#  '#pla919',
#  ...]

# %%
verses_sexual_categories_df.head(5)
# Out:
#                bible_identifier  \
# b.GEN.001.001                 0
# b.GEN.001.002                 0
# b.GEN.001.003                 0
# b.GEN.001.004                 0
# b.GEN.001.005                 0
#
#                                                       verse_text  bible_book  \
# b.GEN.001.001  En el principio creó Dios los cielos y la tierra.           0
# b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...           0
# b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.           0
# b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...           0
# b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...           0
#
#                bible_chapter  bible_book_chapter  relations  monogamy  \
# b.GEN.001.001              0                   0          0         0
# b.GEN.001.002              0                   0          0         0
# b.GEN.001.003              0                   0          0         0
# b.GEN.001.004              0                   0          0         0
# b.GEN.001.005              0                   0          0         0
#
#                poligamy  marriage  second-marriage  ...  #org439  #pla65  \
# b.GEN.001.001         0         0                0  ...      NaN     NaN
# b.GEN.001.002         0         0                0  ...      NaN     NaN
# b.GEN.001.003         0         0                0  ...      NaN     NaN
# b.GEN.001.004         0         0                0  ...      NaN     NaN
# b.GEN.001.005         0         0                0  ...      NaN     NaN
#
#                #pla68  #per116  #per119  #pla67  #org52  #per129  #pla74  \
# b.GEN.001.001     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.002     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.003     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.004     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.005     NaN      NaN      NaN     NaN     NaN      NaN     NaN
#
#                #pla75
# b.GEN.001.001     NaN
# b.GEN.001.002     NaN
# b.GEN.001.003     NaN
# b.GEN.001.004     NaN
# b.GEN.001.005     NaN
#
# [5 rows x 4232 columns]

# %%
verses_sexual_categories_df.iloc[:,2:].sum(axis=0).sort_values(ascending=False).head(50)
# Out:
# number of entities referred                             148212.0
# number of different entities referred                   101606.0
# number of people                                         82257.0
# number of different number of people                     54470.0
# number of groups                                         46454.0
# number of different number of groups                     31750.0
# number of entities receiving communication               30289.0
# number of entities communicating                         27141.0
# number of quotations                                     26705.0
# number of different entities receiving communication     26600.0
# number of different entities communicating               24254.0
# #per14                                                   23695.0
# number of oral quotations                                20079.0
# number of 1st level quotations                           18815.0
# number of places                                         18286.0
# number of different number of places                     14388.0
# #org70                                                   10583.0
# #org0                                                     7411.0
# number of 2nd level quotations                            5419.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2408.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1412.0
# #org24                                                    1331.0
# #org3                                                     1302.0
# #org19                                                    1288.0
# #pla3                                                     1253.0
# #org18                                                    1242.0
# #org12                                                    1241.0
# number of written quotations                              1211.0
# #per845                                                   1142.0
# #org25                                                    1043.0
# #pla5                                                     1025.0
# #pla41                                                     982.0
# #per500                                                    948.0
# #per4                                                      906.0
# #pla30                                                     902.0
# #org4                                                      888.0
# #pla2                                                      802.0
# #org100                                                    799.0
# #per522                                                    759.0
# #per851                                                    728.0
# #per473                                                    707.0
# dtype: float64

# %%
verses_sexual_categories_df.sum()
# Out:
# bible_identifier                                                      0
# verse_text            En el principio creó Dios los cielos y la tier...
# bible_book                                                            0
# bible_chapter                                                         0
# bible_book_chapter                                                    0
#                                             ...
# #pla67                                                                1
# #org52                                                               27
# #per129                                                               4
# #pla74                                                                1
# #pla75                                                                1
# Length: 4232, dtype: object

# %%
#verses_sexual_categories_df.to_csv("../../../resulting data/verses_structural_features.tsv", sep="\t")

# %%
verses_sexual_categories_df.to_parquet("../../../resulting data/verses_structural_features.parquet")#, engine =  'pyarrow')

# %%
span_grps = documento_root_bible.xpath('.//tei:spanGrp', namespaces = specific_namespaces, with_tail = True)
verses_sexual_themes = []
for span_grp in span_grps:

    verse = span_grp.xpath('./@inst', namespaces = specific_namespaces, with_tail = True)[0]
    try:
        sexual_theme = span_grp.xpath('./tei:span/@ana', namespaces = specific_namespaces, with_tail = True)
        
        verse = verse[1:]

        verses_sexual_categories_df.loc[verse, sexual_theme] = 1
    except:
        print(verse)
# Out:
# b.EXO.020.017

# %%
verses_sexual_categories_df.iloc[:,5:25].sum()
# Out:
# relations                              8.0
# monogamy                               6.0
# poligamy                              35.0
# marriage                             115.0
# second-marriage                        4.0
# second-marriage-divorce                0.0
# second-marriage-widow                  1.0
# interfaith-marriage                   14.0
# interfaith-relation                    5.0
# non-marital-relation                  95.0
# pre-marital-relation                   1.0
# relation-greater-family                4.0
# marital-relation-political-family     12.0
# lord-servant-relation                 16.0
# marital-relation-direct-family        10.0
# arranged-marriage                     28.0
# divorce                               25.0
# engaged                               27.0
# love                                 236.0
# jealousy                               4.0
# dtype: float64

# %%
verses_sexual_categories_df["bible_book"] = verses_sexual_categories_df.index.str.extract("b\.(...).+$")

# %%
verses_sexual_categories_df["bible_identifier"] = verses_sexual_categories_df.index.tolist()

# %%
verses_sexual_categories_df["number of people"].sum()
# Out:
# 82257.0

# %%
verses_sexual_categories_df.dtypes
# Out:
# bible_identifier       object
# verse_text             object
# bible_book             object
# bible_chapter         float64
# bible_book_chapter    float64
#                        ...
# #pla67                float64
# #org52                float64
# #per129               float64
# #pla74                float64
# #pla75                float64
# Length: 4232, dtype: object

# %%
#verses_sexual_categories_df.to_csv("../../../resulting data/verses_features.tsv", sep="\t")

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet")#, engine =  'pyarrow')

# %%
#verses_sexual_categories_df = pd.read_parquet("../../../resulting data/verses_features.parquet")

# %%
verses_sexual_categories_df.shape
# Out:
# (31377, 4232)

# %%
verses_sexual_categories_df
# Out:
#               bible_identifier  \
# b.GEN.001.001    b.GEN.001.001
# b.GEN.001.002    b.GEN.001.002
# b.GEN.001.003    b.GEN.001.003
# b.GEN.001.004    b.GEN.001.004
# b.GEN.001.005    b.GEN.001.005
# ...                        ...
# b.ROM.16.5          b.ROM.16.5
# b.ROM.16.8          b.ROM.16.8
# b.ROM.16.9          b.ROM.16.9
# b.ROM.16.12        b.ROM.16.12
# b.ROM.16.16        b.ROM.16.16
#
#                                                       verse_text bible_book  \
# b.GEN.001.001  En el principio creó Dios los cielos y la tierra.        NaN
# b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...        NaN
# b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.        NaN
# b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...        NaN
# b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...        NaN
# ...                                                          ...        ...
# b.ROM.16.5                                                   NaN        NaN
# b.ROM.16.8                                                   NaN        NaN
# b.ROM.16.9                                                   NaN        NaN
# b.ROM.16.12                                                  NaN        NaN
# b.ROM.16.16                                                  NaN        NaN
#
#                bible_chapter  bible_book_chapter  relations  monogamy  \
# b.GEN.001.001            0.0                 0.0        0.0       0.0
# b.GEN.001.002            0.0                 0.0        0.0       0.0
# b.GEN.001.003            0.0                 0.0        0.0       0.0
# b.GEN.001.004            0.0                 0.0        0.0       0.0
# b.GEN.001.005            0.0                 0.0        0.0       0.0
# ...                      ...                 ...        ...       ...
# b.ROM.16.5               NaN                 NaN        NaN       NaN
# b.ROM.16.8               NaN                 NaN        NaN       NaN
# b.ROM.16.9               NaN                 NaN        NaN       NaN
# b.ROM.16.12              NaN                 NaN        NaN       NaN
# b.ROM.16.16              NaN                 NaN        NaN       NaN
#
#                poligamy  marriage  second-marriage  ...  #org439  #pla65  \
# b.GEN.001.001       0.0       0.0              0.0  ...      NaN     NaN
# b.GEN.001.002       0.0       0.0              0.0  ...      NaN     NaN
# b.GEN.001.003       0.0       0.0              0.0  ...      NaN     NaN
# b.GEN.001.004       0.0       0.0              0.0  ...      NaN     NaN
# b.GEN.001.005       0.0       0.0              0.0  ...      NaN     NaN
# ...                 ...       ...              ...  ...      ...     ...
# b.ROM.16.5          NaN       NaN              NaN  ...      NaN     NaN
# b.ROM.16.8          NaN       NaN              NaN  ...      NaN     NaN
# b.ROM.16.9          NaN       NaN              NaN  ...      NaN     NaN
# b.ROM.16.12         NaN       NaN              NaN  ...      NaN     NaN
# b.ROM.16.16         NaN       NaN              NaN  ...      NaN     NaN
#
#                #pla68  #per116  #per119  #pla67  #org52  #per129  #pla74  \
# b.GEN.001.001     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.002     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.003     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.004     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.005     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# ...               ...      ...      ...     ...     ...      ...     ...
# b.ROM.16.5        NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.ROM.16.8        NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.ROM.16.9        NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.ROM.16.12       NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.ROM.16.16       NaN      NaN      NaN     NaN     NaN      NaN     NaN
#
#                #pla75
# b.GEN.001.001     NaN
# b.GEN.001.002     NaN
# b.GEN.001.003     NaN
# b.GEN.001.004     NaN
# b.GEN.001.005     NaN
# ...               ...
# b.ROM.16.5        NaN
# b.ROM.16.8        NaN
# b.ROM.16.9        NaN
# b.ROM.16.12       NaN
# b.ROM.16.16       NaN
#
# [31377 rows x 4232 columns]

# %%
verses_sexual_categories_df.select_dtypes(include="number").sum(axis=0).sort_values(ascending=False).head(50)
# Out:
# number of entities referred                             148212.0
# number of different entities referred                   101606.0
# number of people                                         82257.0
# number of different number of people                     54470.0
# number of groups                                         46454.0
# number of different number of groups                     31750.0
# number of entities receiving communication               30289.0
# number of entities communicating                         27141.0
# number of quotations                                     26705.0
# number of different entities receiving communication     26600.0
# number of different entities communicating               24254.0
# #per14                                                   23695.0
# number of oral quotations                                20079.0
# number of 1st level quotations                           18815.0
# number of places                                         18286.0
# number of different number of places                     14388.0
# #org70                                                   10583.0
# #org0                                                     7411.0
# number of 2nd level quotations                            5419.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2408.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1412.0
# #org24                                                    1331.0
# #org3                                                     1302.0
# #org19                                                    1288.0
# #pla3                                                     1253.0
# #org18                                                    1242.0
# #org12                                                    1241.0
# number of written quotations                              1211.0
# #per845                                                   1142.0
# ascendant-descendant                                      1128.0
# #org25                                                    1043.0
# #pla5                                                     1025.0
# positive-aspect                                           1005.0
# #pla41                                                     982.0
# #per500                                                    948.0
# #per4                                                      906.0
# #pla30                                                     902.0
# #org4                                                      888.0
# neutral-aspect                                             841.0
# #pla2                                                      802.0
# #org100                                                    799.0
# dtype: float64

# %%
verses_sexual_categories_df["bible_book"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\.(...).+$")

# %%
verses_sexual_categories_df["bible_book_chapter"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\.(...\.\d+).+$")

# %%
verses_sexual_categories_df["bible_chapter"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\....\.(\d+).+$")

# %%
verses_sexual_categories_df
# Out:
#               bible_identifier  \
# b.GEN.001.001    b.GEN.001.001
# b.GEN.001.002    b.GEN.001.002
# b.GEN.001.003    b.GEN.001.003
# b.GEN.001.004    b.GEN.001.004
# b.GEN.001.005    b.GEN.001.005
# ...                        ...
# b.ROM.16.5          b.ROM.16.5
# b.ROM.16.8          b.ROM.16.8
# b.ROM.16.9          b.ROM.16.9
# b.ROM.16.12        b.ROM.16.12
# b.ROM.16.16        b.ROM.16.16
#
#                                                       verse_text bible_book  \
# b.GEN.001.001  En el principio creó Dios los cielos y la tierra.        GEN
# b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...        GEN
# b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.        GEN
# b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...        GEN
# b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...        GEN
# ...                                                          ...        ...
# b.ROM.16.5                                                   NaN        ROM
# b.ROM.16.8                                                   NaN        ROM
# b.ROM.16.9                                                   NaN        ROM
# b.ROM.16.12                                                  NaN        ROM
# b.ROM.16.16                                                  NaN        ROM
#
#               bible_chapter bible_book_chapter  relations  monogamy  poligamy  \
# b.GEN.001.001           001            GEN.001        0.0       0.0       0.0
# b.GEN.001.002           001            GEN.001        0.0       0.0       0.0
# b.GEN.001.003           001            GEN.001        0.0       0.0       0.0
# b.GEN.001.004           001            GEN.001        0.0       0.0       0.0
# b.GEN.001.005           001            GEN.001        0.0       0.0       0.0
# ...                     ...                ...        ...       ...       ...
# b.ROM.16.5               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.8               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.9               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.12              16             ROM.16        NaN       NaN       NaN
# b.ROM.16.16              16             ROM.16        NaN       NaN       NaN
#
#                marriage  second-marriage  ...  #org439  #pla65  #pla68  \
# b.GEN.001.001       0.0              0.0  ...      NaN     NaN     NaN
# b.GEN.001.002       0.0              0.0  ...      NaN     NaN     NaN
# b.GEN.001.003       0.0              0.0  ...      NaN     NaN     NaN
# b.GEN.001.004       0.0              0.0  ...      NaN     NaN     NaN
# b.GEN.001.005       0.0              0.0  ...      NaN     NaN     NaN
# ...                 ...              ...  ...      ...     ...     ...
# b.ROM.16.5          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.8          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.9          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.12         NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.16         NaN              NaN  ...      NaN     NaN     NaN
#
#                #per116  #per119  #pla67  #org52  #per129  #pla74  #pla75
# b.GEN.001.001      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.002      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.003      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.004      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.005      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# ...                ...      ...     ...     ...      ...     ...     ...
# b.ROM.16.5         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.8         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.9         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.12        NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.16        NaN      NaN     NaN     NaN      NaN     NaN     NaN
#
# [31377 rows x 4232 columns]

# %%
verses_sexual_categories_df.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).sum(axis = 0).sort_values(ascending=False).head(30)
# Out:
# number of entities referred                             148212.0
# number of different entities referred                   101606.0
# number of people                                         82257.0
# number of different number of people                     54470.0
# number of groups                                         46454.0
# number of different number of groups                     31750.0
# number of entities receiving communication               30289.0
# number of entities communicating                         27141.0
# number of quotations                                     26705.0
# number of different entities receiving communication     26600.0
# number of different entities communicating               24254.0
# #per14                                                   23695.0
# number of oral quotations                                20079.0
# number of 1st level quotations                           18815.0
# number of places                                         18286.0
# number of different number of places                     14388.0
# #org70                                                   10583.0
# #org0                                                     7411.0
# number of 2nd level quotations                            5419.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2408.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1412.0
# dtype: float64

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet")#, engine =  'pyarrow')

# %%
verses_sexual_categories_df = pd.read_parquet("../../../resulting data/verses_features.parquet")

# %%
verses_sexual_categories_df.loc[verses_sexual_categories_df.bible_identifier.str.contains("ROM")]
# Out:
#               bible_identifier  \
# index
# b.ROM.001.001    b.ROM.001.001
# b.ROM.001.002    b.ROM.001.002
# b.ROM.001.003    b.ROM.001.003
# b.ROM.001.004    b.ROM.001.004
# b.ROM.001.005    b.ROM.001.005
# ...                        ...
# b.ROM.16.5          b.ROM.16.5
# b.ROM.16.8          b.ROM.16.8
# b.ROM.16.9          b.ROM.16.9
# b.ROM.16.12        b.ROM.16.12
# b.ROM.16.16        b.ROM.16.16
#
#                                                       verse_text bible_book  \
# index
# b.ROM.001.001  Pablo, siervo de Jesucristo, llamado a ser apó...        ROM
# b.ROM.001.002  que él había prometido antes por sus profetas ...        ROM
# b.ROM.001.003  evangelio que se refiere a su Hijo, nuestro Se...        ROM
# b.ROM.001.004  que fue declarado Hijo de Dios con poder, segú...        ROM
# b.ROM.001.005  Por medio de él recibimos la gracia y el apost...        ROM
# ...                                                          ...        ...
# b.ROM.16.5                                                  None        ROM
# b.ROM.16.8                                                  None        ROM
# b.ROM.16.9                                                  None        ROM
# b.ROM.16.12                                                 None        ROM
# b.ROM.16.16                                                 None        ROM
#
#               bible_chapter bible_book_chapter  relations  monogamy  poligamy  \
# index
# b.ROM.001.001           001            ROM.001        0.0       0.0       0.0
# b.ROM.001.002           001            ROM.001        0.0       0.0       0.0
# b.ROM.001.003           001            ROM.001        0.0       0.0       0.0
# b.ROM.001.004           001            ROM.001        0.0       0.0       0.0
# b.ROM.001.005           001            ROM.001        0.0       0.0       0.0
# ...                     ...                ...        ...       ...       ...
# b.ROM.16.5               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.8               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.9               16             ROM.16        NaN       NaN       NaN
# b.ROM.16.12              16             ROM.16        NaN       NaN       NaN
# b.ROM.16.16              16             ROM.16        NaN       NaN       NaN
#
#                marriage  second-marriage  ...  #org439  #pla65  #pla68  \
# index                                     ...
# b.ROM.001.001       0.0              0.0  ...      NaN     NaN     NaN
# b.ROM.001.002       0.0              0.0  ...      NaN     NaN     NaN
# b.ROM.001.003       0.0              0.0  ...      NaN     NaN     NaN
# b.ROM.001.004       0.0              0.0  ...      NaN     NaN     NaN
# b.ROM.001.005       0.0              0.0  ...      NaN     NaN     NaN
# ...                 ...              ...  ...      ...     ...     ...
# b.ROM.16.5          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.8          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.9          NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.12         NaN              NaN  ...      NaN     NaN     NaN
# b.ROM.16.16         NaN              NaN  ...      NaN     NaN     NaN
#
#                #per116  #per119  #pla67  #org52  #per129  #pla74  #pla75
# index
# b.ROM.001.001      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.001.002      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.001.003      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.001.004      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.001.005      NaN      NaN     NaN     NaN      NaN     NaN     NaN
# ...                ...      ...     ...     ...      ...     ...     ...
# b.ROM.16.5         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.8         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.9         NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.12        NaN      NaN     NaN     NaN      NaN     NaN     NaN
# b.ROM.16.16        NaN      NaN     NaN     NaN      NaN     NaN     NaN
#
# [522 rows x 4232 columns]

# %%
verses_sexual_categories_df.bible_book.unique()
# Out:
# array(['GEN', 'EXO', 'LEV', 'NUM', 'DEU', 'JOS', 'JDG', 'RUT', '1SA',
#        '2SA', '1KI', '2KI', '1CH', '2CH', 'EZR', 'NEH', 'EST', 'JOB',
#        'PSA', 'PRO', 'ECC', 'SON', 'ISA', 'LAM', 'JER', 'EZE', 'DAN',
#        'HOS', 'JOE', 'AMO', 'OBA', 'JON', 'MIC', 'NAH', 'HAB', 'ZEP',
#        'HAG', 'ZEC', 'MAL', 'MAT', 'MAR', 'LUK', 'JOH', 'ACT', 'ROM',
#        '1CO', '2CO', 'GAL', 'EPH', 'PHI', 'COL', '1TH', '2TH', '1TI',
#        '2TI', 'TIT', 'PHM', 'HEB', 'JAM', '1PE', '2PE', '1JO', '2JO',
#        '3JO', 'JUD', 'REV'], dtype=object)

# %%
books = pd.ExcelFile("../../../books.xls").parse('Sheet1')

# %%
books
# Out:
#     Unnamed: 0  bible  id title_Spanish testament  encoded title_English  \
# 0            0  bible   1       Génesis       old        1       Genesis
# 1            1  bible   2         Éxodo       old        1        Exodus
# 2            2  bible   3      Levítico       old        1     Leviticus
# 3            3  bible   4       Números       old        1       Numbers
# 4            4  bible   5  Deuteronomio       old        1   Deuteronomy
# ..         ...    ...  ..           ...       ...      ...           ...
# 61          61  bible  62        1 Juan       new        1        1 John
# 62          62  bible  63        2 Juan       new        1        2 John
# 63          63  bible  64        3 Juan       new        1        3 John
# 64          64  bible  65         Judas       new        1          Jude
# 65          65  bible  66   Apocalipsis       new        1    Revelation
#
#    codebook  Unnamed: 8  chaptersc  ...   latitude  longitude  alternative_id  \
# 0       GEN         NaN         50  ...  32.615687  36.793083             Gen
# 1       EXO         NaN         40  ...  30.469969  33.843280            Exod
# 2       LEV         NaN         27  ...  30.521765  34.112561             Lev
# 3       NUM         NaN         36  ...  31.221618  34.841433             Num
# 4       DEU         NaN         34  ...  31.506106  35.735247            Deut
# ..      ...         ...        ...  ...        ...        ...             ...
# 61      1JO         NaN          5  ...        NaN        NaN           1John
# 62      2JO         NaN          1  ...        NaN        NaN           2John
# 63      3JO         NaN          1  ...        NaN        NaN           3John
# 64      JUD         NaN          1  ...  26.820553  30.802498            Jude
# 65      REV         NaN         22  ...  34.707841  33.514733             Rev
#
#       wikid sexual_annotation    division  author language  period_produced  \
# 0     Q9184               1.0  Pentateuch     NaN   hebrew              NaN
# 1     Q9190               1.0  Pentateuch     NaN   hebrew              NaN
# 2    Q41490               1.0  Pentateuch     NaN   hebrew              NaN
# 3    Q43099               NaN  Pentateuch     NaN   hebrew              NaN
# 4    Q42614               NaN  Pentateuch     NaN   hebrew              NaN
# ..      ...               ...         ...     ...      ...              ...
# 61  Q131101               NaN     Letters     NaN    greek              NaN
# 62  Q131453               NaN     Letters     NaN    greek              NaN
# 63  Q131462               NaN     Letters     NaN    greek              NaN
# 64  Q131466               NaN     Letters     NaN    greek              NaN
# 65   Q42040               1.0  Revelation     NaN    greek              NaN
#
#    period_setting
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 61            NaN
# 62            NaN
# 63            NaN
# 64            NaN
# 65            NaN
#
# [66 rows x 22 columns]

# %%
verses_sexual_categories_df = pd.merge(verses_sexual_categories_df, books[["genre", "codebook"]], left_on="bible_book", right_on="codebook")

# %%
verses_sexual_categories_df.drop(["codebook"], axis="columns", inplace=True)

# %%
verses_sexual_categories_df.columns.tolist()[4:-2][0:10]
# Out:
# ['bible_book_chapter',
#  'relations',
#  'monogamy',
#  'poligamy',
#  'marriage',
#  'second-marriage',
#  'second-marriage-divorce',
#  'second-marriage-widow',
#  'interfaith-marriage',
#  'interfaith-relation']

# %%
verses_sexual_categories_df = verses_sexual_categories_df[
    verses_sexual_categories_df.columns.tolist()[0:4] +
    [verses_sexual_categories_df.columns.tolist()[-1]] + 
    verses_sexual_categories_df.columns.tolist()[4:-2]
    ]

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier                                         verse_text  \
# 0        b.GEN.001.001  En el principio creó Dios los cielos y la tierra.
# 1        b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...
# 2        b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.
# 3        b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...
# 4        b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...
# ...                ...                                                ...
# 31372    b.REV.022.017  El Espíritu y la Esposa dicen ¡Ven!. El que oy...
# 31373    b.REV.022.018  Yo advierto a todo aquel que oye las palabras ...
# 31374    b.REV.022.019  Y si alguno quita de las palabras del libro de...
# 31375    b.REV.022.020  El que da testimonio de estas cosas dice Ciert...
# 31376    b.REV.022.021  La gracia de nuestro Señor Jesucristo sea con ...
#
#       bible_book bible_chapter        genre bible_book_chapter  relations  \
# 0            GEN           001   historical            GEN.001        0.0
# 1            GEN           001   historical            GEN.001        0.0
# 2            GEN           001   historical            GEN.001        0.0
# 3            GEN           001   historical            GEN.001        0.0
# 4            GEN           001   historical            GEN.001        0.0
# ...          ...           ...          ...                ...        ...
# 31372        REV           022  apocalyptic            REV.022        0.0
# 31373        REV           022  apocalyptic            REV.022        0.0
# 31374        REV           022  apocalyptic            REV.022        0.0
# 31375        REV           022  apocalyptic            REV.022        0.0
# 31376        REV           022  apocalyptic            REV.022        0.0
#
#        monogamy  poligamy  marriage  ...  #org35  #org439  #pla65  #pla68  \
# 0           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 1           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 2           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 3           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 4           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# ...         ...       ...       ...  ...     ...      ...     ...     ...
# 31372       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31373       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31374       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31375       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31376       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
#
#        #per116  #per119  #pla67  #org52  #per129  #pla74
# 0          NaN      NaN     NaN     NaN      NaN     NaN
# 1          NaN      NaN     NaN     NaN      NaN     NaN
# 2          NaN      NaN     NaN     NaN      NaN     NaN
# 3          NaN      NaN     NaN     NaN      NaN     NaN
# 4          NaN      NaN     NaN     NaN      NaN     NaN
# ...        ...      ...     ...     ...      ...     ...
# 31372      NaN      NaN     NaN     NaN      NaN     NaN
# 31373      NaN      NaN     NaN     NaN      NaN     NaN
# 31374      NaN      NaN     NaN     NaN      NaN     NaN
# 31375      NaN      NaN     NaN     NaN      NaN     NaN
# 31376      NaN      NaN     NaN     NaN      NaN     NaN
#
# [31377 rows x 4232 columns]

# %%
standard_frequencies_twitter = pd.read_csv("../../../other data sets/standard-frequencies-twitter-2014-2015.tsv", sep="\t")

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
#standard_frequencies_twitter["old_reference_standard"] =  standard_frequencies_twitter["reference_standard"]

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\.)(\d)(\..*)",r"\1__\2\3")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\.)(\d\d)(\..*)",r"\1_\2\3")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\....\.)(.)$",r"\1__\2")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\....\.)(..)$",r"\1_\2")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"_",r"0")

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
standard_frequencies_twitter.rename(columns={'2014': 'twitter_freq_2014', '2015': 'twitter_freq_2015', "sum-2014-2015": "twitter_freq_sum_2014_2015",}, inplace=True)

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
#standard_frequencies_twitter.to_csv("../../../../datos/stephen-smit/standard-frequencies-twitter-2014-2015.tsv", sep="\t")

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier                                         verse_text  \
# 0        b.GEN.001.001  En el principio creó Dios los cielos y la tierra.
# 1        b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...
# 2        b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.
# 3        b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...
# 4        b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...
# ...                ...                                                ...
# 31372    b.REV.022.017  El Espíritu y la Esposa dicen ¡Ven!. El que oy...
# 31373    b.REV.022.018  Yo advierto a todo aquel que oye las palabras ...
# 31374    b.REV.022.019  Y si alguno quita de las palabras del libro de...
# 31375    b.REV.022.020  El que da testimonio de estas cosas dice Ciert...
# 31376    b.REV.022.021  La gracia de nuestro Señor Jesucristo sea con ...
#
#       bible_book bible_chapter        genre bible_book_chapter  relations  \
# 0            GEN           001   historical            GEN.001        0.0
# 1            GEN           001   historical            GEN.001        0.0
# 2            GEN           001   historical            GEN.001        0.0
# 3            GEN           001   historical            GEN.001        0.0
# 4            GEN           001   historical            GEN.001        0.0
# ...          ...           ...          ...                ...        ...
# 31372        REV           022  apocalyptic            REV.022        0.0
# 31373        REV           022  apocalyptic            REV.022        0.0
# 31374        REV           022  apocalyptic            REV.022        0.0
# 31375        REV           022  apocalyptic            REV.022        0.0
# 31376        REV           022  apocalyptic            REV.022        0.0
#
#        monogamy  poligamy  marriage  ...  #org35  #org439  #pla65  #pla68  \
# 0           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 1           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 2           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 3           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 4           0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# ...         ...       ...       ...  ...     ...      ...     ...     ...
# 31372       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31373       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31374       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31375       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
# 31376       0.0       0.0       0.0  ...     NaN      NaN     NaN     NaN
#
#        #per116  #per119  #pla67  #org52  #per129  #pla74
# 0          NaN      NaN     NaN     NaN      NaN     NaN
# 1          NaN      NaN     NaN     NaN      NaN     NaN
# 2          NaN      NaN     NaN     NaN      NaN     NaN
# 3          NaN      NaN     NaN     NaN      NaN     NaN
# 4          NaN      NaN     NaN     NaN      NaN     NaN
# ...        ...      ...     ...     ...      ...     ...
# 31372      NaN      NaN     NaN     NaN      NaN     NaN
# 31373      NaN      NaN     NaN     NaN      NaN     NaN
# 31374      NaN      NaN     NaN     NaN      NaN     NaN
# 31375      NaN      NaN     NaN     NaN      NaN     NaN
# 31376      NaN      NaN     NaN     NaN      NaN     NaN
#
# [31377 rows x 4232 columns]

# %%
verses_sexual_categories_df = pd.merge(verses_sexual_categories_df, standard_frequencies_twitter[["reference_standard","twitter_freq_sum_2014_2015","twitter_freq_2014","twitter_freq_2015"]], left_on= "bible_identifier", right_on="reference_standard")

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier                                         verse_text  \
# 0        b.GEN.001.001  En el principio creó Dios los cielos y la tierra.
# 1        b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...
# 2        b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.
# 3        b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...
# 4        b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...
# ...                ...                                                ...
# 31060    b.REV.022.017  El Espíritu y la Esposa dicen ¡Ven!. El que oy...
# 31061    b.REV.022.018  Yo advierto a todo aquel que oye las palabras ...
# 31062    b.REV.022.019  Y si alguno quita de las palabras del libro de...
# 31063    b.REV.022.020  El que da testimonio de estas cosas dice Ciert...
# 31064    b.REV.022.021  La gracia de nuestro Señor Jesucristo sea con ...
#
#       bible_book bible_chapter        genre bible_book_chapter  relations  \
# 0            GEN           001   historical            GEN.001        0.0
# 1            GEN           001   historical            GEN.001        0.0
# 2            GEN           001   historical            GEN.001        0.0
# 3            GEN           001   historical            GEN.001        0.0
# 4            GEN           001   historical            GEN.001        0.0
# ...          ...           ...          ...                ...        ...
# 31060        REV           022  apocalyptic            REV.022        0.0
# 31061        REV           022  apocalyptic            REV.022        0.0
# 31062        REV           022  apocalyptic            REV.022        0.0
# 31063        REV           022  apocalyptic            REV.022        0.0
# 31064        REV           022  apocalyptic            REV.022        0.0
#
#        monogamy  poligamy  marriage  ...  #per116  #per119  #pla67  #org52  \
# 0           0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 1           0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 2           0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 3           0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 4           0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# ...         ...       ...       ...  ...      ...      ...     ...     ...
# 31060       0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 31061       0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 31062       0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 31063       0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
# 31064       0.0       0.0       0.0  ...      NaN      NaN     NaN     NaN
#
#        #per129  #pla74  reference_standard  twitter_freq_sum_2014_2015  \
# 0          NaN     NaN       b.GEN.001.001                       49268
# 1          NaN     NaN       b.GEN.001.002                        8601
# 2          NaN     NaN       b.GEN.001.003                       20970
# 3          NaN     NaN       b.GEN.001.004                        4222
# 4          NaN     NaN       b.GEN.001.005                        3208
# ...        ...     ...                 ...                         ...
# 31060      NaN     NaN       b.REV.022.017                        8693
# 31061      NaN     NaN       b.REV.022.018                        4396
# 31062      NaN     NaN       b.REV.022.019                        3947
# 31063      NaN     NaN       b.REV.022.020                       11981
# 31064      NaN     NaN       b.REV.022.021                       10466
#
#        twitter_freq_2014  twitter_freq_2015
# 0                  26376              22892
# 1                   3693               4908
# 2                   8816              12154
# 3                   2286               1936
# 4                   1666               1542
# ...                  ...                ...
# 31060               4633               4060
# 31061               1939               2457
# 31062               1952               1995
# 31063               6014               5967
# 31064               3780               6686
#
# [31065 rows x 4236 columns]

# %%
verses_sexual_categories_df = verses_sexual_categories_df[
    verses_sexual_categories_df.columns.tolist()[0:5] +
    verses_sexual_categories_df.columns.tolist()[-3:] + 
    verses_sexual_categories_df.columns.tolist()[5:-4]
    ]

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier                                         verse_text  \
# 0        b.GEN.001.001  En el principio creó Dios los cielos y la tierra.
# 1        b.GEN.001.002  La tierra estaba desordenada y vacía, las tini...
# 2        b.GEN.001.003                Dijo Dios Sea la luz. Y fue la luz.
# 3        b.GEN.001.004  Vio Dios que la luz era buena, y separó la luz...
# 4        b.GEN.001.005  Llamó a la luz Día, y a las tinieblas llamó No...
# ...                ...                                                ...
# 31060    b.REV.022.017  El Espíritu y la Esposa dicen ¡Ven!. El que oy...
# 31061    b.REV.022.018  Yo advierto a todo aquel que oye las palabras ...
# 31062    b.REV.022.019  Y si alguno quita de las palabras del libro de...
# 31063    b.REV.022.020  El que da testimonio de estas cosas dice Ciert...
# 31064    b.REV.022.021  La gracia de nuestro Señor Jesucristo sea con ...
#
#       bible_book bible_chapter        genre  twitter_freq_sum_2014_2015  \
# 0            GEN           001   historical                       49268
# 1            GEN           001   historical                        8601
# 2            GEN           001   historical                       20970
# 3            GEN           001   historical                        4222
# 4            GEN           001   historical                        3208
# ...          ...           ...          ...                         ...
# 31060        REV           022  apocalyptic                        8693
# 31061        REV           022  apocalyptic                        4396
# 31062        REV           022  apocalyptic                        3947
# 31063        REV           022  apocalyptic                       11981
# 31064        REV           022  apocalyptic                       10466
#
#        twitter_freq_2014  twitter_freq_2015 bible_book_chapter  relations  \
# 0                  26376              22892            GEN.001        0.0
# 1                   3693               4908            GEN.001        0.0
# 2                   8816              12154            GEN.001        0.0
# 3                   2286               1936            GEN.001        0.0
# 4                   1666               1542            GEN.001        0.0
# ...                  ...                ...                ...        ...
# 31060               4633               4060            REV.022        0.0
# 31061               1939               2457            REV.022        0.0
# 31062               1952               1995            REV.022        0.0
# 31063               6014               5967            REV.022        0.0
# 31064               3780               6686            REV.022        0.0
#
#        ...  #org35  #org439  #pla65  #pla68  #per116  #per119  #pla67  #org52  \
# 0      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 1      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 2      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 3      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 4      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# ...    ...     ...      ...     ...     ...      ...      ...     ...     ...
# 31060  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31061  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31062  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31063  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31064  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
#
#        #per129  #pla74
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 31060      NaN     NaN
# 31061      NaN     NaN
# 31062      NaN     NaN
# 31063      NaN     NaN
# 31064      NaN     NaN
#
# [31065 rows x 4235 columns]

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet")#, engine="pyarrow")
