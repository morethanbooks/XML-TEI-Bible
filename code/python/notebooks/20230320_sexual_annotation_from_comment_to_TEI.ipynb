# %%
import pandas as pd
from lxml import etree
import requests
import os
import sys
import time

# %%
sys.path.append(os.path.abspath("./../scripts/"))

# %%
import parse_sexual_anotation

# %%
book_name = "MAR"

# %%
wdir_str = "./../../../sexual-annotation/"
file_str = book_name + ".xml"

book_name_str = file_str[0:3]

# %%
book_str = parse_sexual_anotation.open_book(wdir_str, file_str)
book_str[0:1000]
# Out:
# ['./../../../sexual-annotation/MAR.xml']
# MAR
# <class 'str'>
# '<?xml version="1.0" encoding="UTF-8"?>\n<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>\n<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml"\n\tschematypens="http://purl.oclc.org/dsdl/schematron"?>\n<TEI xmlns="http://www.tei-c.org/ns/1.0">\n\t<teiHeader>\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title>Evangelio de Marcos</title>\n\t\t\t\t<title type="idno">\n\t\t\t\t\t<idno type="string">MAR</idno>\n\t\t\t\t\t<idno type="viaf">179823714</idno>\n\t\t\t\t</title>\n\t\t\t\t<author>\n\t\t\t\t\t<name type="short">Marcos</name>\n\t\t\t\t\t<name type="full">Marcos</name>\n\t\t\t\t\t<idno type="viaf">264405984</idno>\n\t\t\t\t</author>\n\t\t\t\t<principal key="#jct">José Calvo Tello</principal>\n\t\t\t</titleStmt>\n\t\t\t<publicationStmt>\n\t\t\t\t<publisher>José Calvo Tello</publisher>\n\t\t\t\t<availability status="free">\n\t\t\t\t\t<p>The text is freely available.</p>\n\t\t\t\t</availability>\n\t\t\t\t<date when="201'

# %%
taxonomy_file_str = "taxonomy.xml"

# %%
taxonomy_el = parse_sexual_anotation.open_taxonomy(wdir_str, taxonomy_file_str)
# Out:
# <class 'lxml.etree._Element'>

# %%
namespaces_dict = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
categories_id_lt = parse_sexual_anotation.get_list_categories(taxonomy_el, namespaces = namespaces_dict)

print(categories_id_lt)
# Out:
# ['relations', 'monogamy', 'poligamy', 'marriage', 'second-marriage', 'second-marriage-divorce', 'second-marriage-widow', 'interfaith-marriage', 'interfaith-relation', 'non-marital-relation', 'pre-marital-relation', 'relation-greater-family', 'marital-relation-political-family', 'lord-servant-relation', 'marital-relation-direct-family', 'arranged-marriage', 'divorce', 'engaged', 'love', 'jealousy', 'ascendant-descendant', 'primogeniture', 'intercultural-ascendant-descendant', 'outside-marriage-ascendant-descendant', 'indirect-ascendant-descendant', 'homosexual-relation', 'acts', 'social-related-act', 'wedding', 'deception', 'prostitute', 'body-related-act', 'massage', 'kiss', 'hug', 'dance', 'abortion', 'circumcision', 'breast-feeding', 'bath', 'wash', 'sexual-act', 'sexual-act-stage', 'consent', 'seduction', 'rejection', 'erotic-time', 'initation-sexual-act', 'orgasm', 'ejaculation', 'time-after-sex', 'sexual-act-type', 'coitus', 'first-sexual-act', 'coitus-interruptus', 'self-masturbation', 'masturbation', 'sleep-orgasm', 'oral-sex', 'anal-sex', 'non-penetrative-sex', 'rape', 'female-rape', 'male-rape', 'sexual-assault', 'female-sexual-assault', 'male-sexual-assault', 'sexual-deception', 'sexual-drive', 'sexual-desire', 'sex-for-goods', 'voyerism', 'other-sexual-act', 'sexual-act-situation', 'sex-in-marriage', 'sex-before-marriage', 'sex-outside-marriage', 'sex-outside', 'sex-menstruation', 'sexual-act-participants', 'heterosexual-sex', 'homosexual-sex', 'gay-sex', 'lesbian-sex', 'prostitution-sex', 'religous-sex', 'parents-children-sex', 'sibling-sex', 'greater-family-sex', 'adults-children-sex', 'interfaith-sex', 'interracial-sex', 'angel-human-sex', 'god-human-sex', 'animal-human-sex', 'animal-sex', 'groupal-sex', 'lord-servant-sex', 'states', 'single-life', 'virginity', 'celibacy', 'infertility', 'nudity', 'semi-nudity', 'pregnancy', 'beauty', 'dishonor', 'sickness', 'body', 'body-by-gender', 'female-body', 'male-body', 'body-part', 'genitalia', 'female-genitalia', 'uterus', 'male-genitalia', 'prepuce', 'testicle', 'gluteus-anus', 'female-breast', 'male-chest', 'ovaries', 'semen', 'head', 'eye', 'nose', 'beard', 'cheek', 'mouth', 'lips', 'tongue', 'tooth', 'hair', 'thigh', 'neck', 'hand', 'skin', 'foot', 'waist', 'heart', 'navel', 'belly', 'leg', 'knie', 'arm', 'rib', 'lubrication', 'face', 'flesh', 'blood', 'umbilical-cord', 'body-function', 'birth', 'fertilization', 'misscarriage', 'erection', 'menstruation', 'sleep', 'diseases', 'menstrual-disorder', 'senses', 'smell', 'things', 'clothes', 'belt', 'veil', 'skirt', 'underwear', 'male-underwear', 'female-underwear', 'perfume', 'juwels', 'earrings', 'piercing', 'collar', 'bracelet', 'food-and-related', 'drink', 'water', 'milk', 'wine', 'alcohol', 'glass', 'oil', 'spices', 'wheat', 'honey', 'fruits', 'pomegranate', 'grapes', 'raisin', 'apples', 'figs', 'carriage', 'weapons', 'sword', 'shield', 'money', 'metal', 'silver', 'gold', 'fountain', 'well', 'pitcher', 'sexual-object', 'make-up', 'song', 'environment', 'moon', 'sun', 'rain', 'wind', 'places', 'interior-spaces', 'room', 'bedroom', 'bed', 'door', 'wall', 'house', 'tower', 'exterior-spaces', 'garden', 'vineyard', 'spring', 'desert', 'river', 'field', 'lake', 'groups', 'based-on-gender', 'women', 'men', 'third-sexual-group', 'eunuchs', 'based-on-orientation', 'heterosexuals', 'homosexuals', 'male-homosexuals', 'female-homosexuals', 'by-state', 'single', 'married', 'widow-widower', 'widow', 'widower', 'virgin', 'female-virgin', 'male-virgin', 'by-profession', 'prostitutes', 'female-prostitutes', 'male-prostitutes', 'sexual-priests', 'concubine', 'midwife', 'by-corporal-traits', 'circumcised', 'uncircumcised', 'animals', 'gazelle', 'deer', 'dove', 'fox', 'goat', 'sheep', 'leopard', 'lion', 'crow', 'turtledove', 'horse', 'donkey', 'cow', 'camel', 'plants', 'flowers', 'trees', 'palms', 'time', 'part-of-the-day', 'night', 'sunrise', 'seasons', 'winter', 'valorations', 'blessed-aspect', 'positive-aspect', 'neutral-aspect', 'n ...

# %%
sexual_annotations_from_comments_lt = parse_sexual_anotation.parse_sexual_annotations_from_comments(book_str)
# Out:
# [('b.MAR.001.001', 'ascendant; positive; neutral'), ('b.MAR.001.011', 'ascendant; positive; blessed'), ('b.MAR.001.019', 'ascendant; neutral'), ('b.MAR.001.020', 'ascendant; positive; negative'), ('b.MAR.001.030', 'ascendant; marriage-relation; negative; neutral'), ('b.MAR.002.005', 'ascendant; blessed; negative'), ('b.MAR.002.010', 'ascendant; positive; negative'), ('b.MAR.002.014', 'ascendant; positive; neutral'), ('b.MAR.002.019', 'wedding; esposo; positive; negative'), ('b.MAR.002.020', 'esposo; positive; negative'), ('b.MAR.002.028', 'ascendant; positive; neutral'), ('b.MAR.003.011', 'ascendant; negative; positive'), ('b.MAR.003.017', 'ascendant; neutral; positive'), ('b.MAR.003.018', 'ascendant; neutral; positive'), ('b.MAR.003.028', 'condemned; blessed; ascendant'), ('b.MAR.003.031', 'ascendant; negative; positive'), ('b.MAR.003.032', 'ascendant; neutral; positive'), ('b.MAR.003.033', 'ascendant; negative; positive'), ('b.MAR.003.034', 'ascendant; negative; positive'), ('b.MAR.003.035', 'ascendant; negative; positive'), ('b.MAR.005.007', 'ascendant; positive; negative'), ('b.MAR.005.023', 'ascendant; positive; blessed'), ('b.MAR.005.025', 'menstrual-disorder; women; negative; neutral'), ('b.MAR.005.029', 'menstrual-disorder; negative; positive'), ('b.MAR.005.034', 'ascendant; menstrual-disorder; blessed; negative'), ('b.MAR.005.035', 'ascendant; negative; positive'), ('b.MAR.005.040', 'ascendant; negative; positive'), ('b.MAR.006.003', 'ascendant; negative; neutral'), ('b.MAR.006.017', 'second-marriage-widow; marital-relation-political-family; negative; neutral-'), ('b.MAR.006.018', 'second-marriage-widow; marital-relation-political-family; condemned; neutral-'), ('b.MAR.006.022', 'dance; ascendant; erotic-time cert="medium"; positive; neutral'), ('b.MAR.006.024', 'ascendant; negative; positive'), ('b.MAR.006.028', 'ascendant; negative; neutral'), ('b.MAR.007.010', 'ascendant; positive; condemned'), ('b.MAR.007.011', 'ascendant; positive; neutral'), ('b.MAR.007.012', 'ascendant; positive; neutral'), ('b.MAR.007.021', 'adultery; fornication; condemned; neutral'), ('b.MAR.007.022', 'lust; condemned'), ('b.MAR.007.025', 'ascendant; negative; neutral'), ('b.MAR.007.026', 'ascendant; negative; neutral'), ('b.MAR.007.027', 'ascendant; condemned; neutral'), ('b.MAR.007.029', 'ascendant; blessed; negative'), ('b.MAR.007.030', 'ascendant; blessed; negative'), ('b.MAR.008.031', 'ascendant; negative; blessed'), ('b.MAR.008.038', 'adultery; condemned; positive'), ('b.MAR.009.007', 'ascendant; blessed; positive'), ('b.MAR.009.009', 'ascendant; positive; negative'), ('b.MAR.009.012', 'negative; positive; ascendant'), ('b.MAR.009.017', 'ascendant; positive; neutral'), ('b.MAR.009.021', 'ascendant; negative; neutral'), ('b.MAR.009.022', 'ascendant; negative; neutral'), ('b.MAR.009.024', 'ascendant; negative; positive'), ('b.MAR.009.031', 'ascendant; negative; positive'), ('b.MAR.009.047', 'lust cert="low"; eye; condemned; positive'), ('b.MAR.010.002', 'divorce; neutral; negative'), ('b.MAR.010.004', 'divorce; positive; negative'), ('b.MAR.010.006', 'woman; man; positive; neutral'), ('b.MAR.010.007', 'marriage cert="medium"; woman; man; positive; neutral'), ('b.MAR.010.008', 'sex; positive; neutral'), ('b.MAR.010.011', 'divorce; adultery; negative; neutral'), ('b.MAR.010.012', 'divorce; adultery; negative; neutral'), ('b.MAR.010.019', 'ascendant; blessed; adultery; condmened'), ('b.MAR.010.024', 'ascendant; positive; negative'), ('b.MAR.010.029', 'ascendant; negative; positive'), ('b.MAR.010.030', 'ascendant; negative; positive'), ('b.MAR.010.033', 'ascendant; positive; negative'), ('b.MAR.010.035', 'ascendant; neutral; positive'), ('b.MAR.010.045', 'ascendant; blessed; negative'), ('b.MAR.010.046', 'ascendant; negative; positive'), ('b.MAR.010.047', 'ascendant; positive; negative'), ('b.MAR.010.048', 'ascendant; positive; negative'), ('b.MAR.011.010', 'ascendant; blessed; positive'), ('b.MAR.011.014', 'condemned; neutral; fertilization ...

# %%
error_lt, standOff_str = parse_sexual_anotation.parse_each_sexual_annotation_as_comment(sexual_annotations_from_comments_lt, categories_id_lt, book_name)
# Out:
# b.MAR.001.001
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.001.011
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.MAR.001.019
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.001.020
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.001.030
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  marriage-relation
# <class 'str'>
# marriage-relation
# ERROR!! marriage-relation
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.002.005
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.002.010
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.002.014
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.002.019
# wedding
# <class 'str'>
# wedding
#  esposo
# <class 'str'>
# esposo
# ERROR!! esposo
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.002.020
# esposo
# <class 'str'>
# esposo
# ERROR!! esposo
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.002.028
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.003.011
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.017
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.018
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.028
# condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.003.031
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.032
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.033
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.034
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.003.035
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.005.007
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.005.023
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.MAR.005.025
# menstrual-disorder
# <class 'str'>
# menstrual-disorder
#  women
# <class 'str'>
# women
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.005.029
# menstrual-disorder
# <class 'str'>
# menstrual-disorder
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.005.034
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  menstrual-disorder
# <class 'str'>
# menstrual-disorder
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.005.035
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.005.040
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.006.003
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.006.017
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral-
# <class 'str'>
# neutral-
# ERROR!! neutral-
# b.MAR.006.018
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  neutral-
# <class 'str'>
# neutral-
# ERROR!! neutral-
# b.MAR.006.022
# dance
# <class 'str'>
# dance
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  erotic-time cert="medium"
# <class 'str'>
# erotic-time
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.006.024
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.006.028
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.010
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
# b.MAR.007.011
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.012
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.021
# adultery
# <class 'str'>
# adultery
# ERROR!! adultery
#  fornication
# <class 'str'>
# fornication
# ERROR!! fornication
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.022
# lust
# <class 'str'>
# lust
# ERROR!! lust
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
# b.MAR.007.025
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.026
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.027
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.007.029
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.007.030
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.008.031
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.MAR.008.038
# adultery
# <class 'str'>
# adultery
# ERROR!! adultery
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.009.007
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.009.009
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.009.012
# negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.009.017
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.009.021
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.009.022
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.009.024
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.009.031
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.009.047
# lust cert="low"
# <class 'str'>
# lust
# ERROR!! lust
#  eye
# <class 'str'>
# eye
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.010.002
# divorce
# <class 'str'>
# divorce
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.004
# divorce
# <class 'str'>
# divorce
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.006
# woman
# <class 'str'>
# woman
# ERROR!! woman
#  man
# <class 'str'>
# man
# ERROR!! man
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.010.007
# marriage cert="medium"
# <class 'str'>
# marriage
#  woman
# <class 'str'>
# woman
# ERROR!! woman
#  man
# <class 'str'>
# man
# ERROR!! man
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.010.008
# sex
# <class 'str'>
# sex
# ERROR!! sex
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.010.011
# divorce
# <class 'str'>
# divorce
#  adultery
# <class 'str'>
# adultery
# ERROR!! adultery
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.010.012
# divorce
# <class 'str'>
# divorce
#  adultery
# <class 'str'>
# adultery
# ERROR!! adultery
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.010.019
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  adultery
# <class 'str'>
# adultery
# ERROR!! adultery
#  condmened
# <class 'str'>
# condmened
# ERROR!! condmened
# b.MAR.010.024
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.029
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.010.030
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.010.033
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.035
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.010.045
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.046
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.010.047
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.010.048
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.011.010
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.011.014
# condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  fertilization
# <class 'str'>
# fertilization
# b.MAR.011.025
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.011.026
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.012.006
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.012.007
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.012.019
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  arranged-marriage
# <class 'str'>
# arranged-marriage
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.012.020
# marriage
# <class 'str'>
# marriage
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.012.021
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  arranged-marriage
# <class 'str'>
# arranged-marriage
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.012.022
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  arranged-marriage
# <class 'str'>
# arranged-marriage
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
# b.MAR.012.023
# second-marriage-widow
# <class 'str'>
# second-marriage-widow
#  arranged-marriage
# <class 'str'>
# arranged-marriage
#  marital-relation-political-family
# <class 'str'>
# marital-relation-political-family
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.012.025
# marriage
# <class 'str'>
# marriage
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.012.030
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.012.031
# love
# <class 'str'>
# love
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.012.033
# love
# <class 'str'>
# love
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.012.035
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.012.037
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.012.042
# widow
# <class 'str'>
# widow
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.012.043
# widow
# <class 'str'>
# widow
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.MAR.013.012
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.013.017
# pregnangcy
# <class 'str'>
# pregnangcy
# ERROR!! pregnangcy
#  ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.013.026
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.013.030
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.013.032
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.014.003
# perfume
# <class 'str'>
# perfume
#  hair
# <class 'str'>
# hair
#  head
# <class 'str'>
# head
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  massage cert="medium"
# <class 'str'>
# massage
# b.MAR.014.004
# perfume
# <class 'str'>
# perfume
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.014.006
# perfume
# <class 'str'>
# perfume
#  massage
# <class 'str'>
# massage
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.014.008
# perfume
# <class 'str'>
# perfume
#  body
# <class 'str'>
# body
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.014.009
# perfume
# <class 'str'>
# perfume
#  massage
# <class 'str'>
# massage
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.014.021
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  condemned
# <class 'str'>
# condemned
# ERROR!! condemned
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.014.022
# body
# <class 'str'>
# body
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  nuetral
# <class 'str'>
# nuetral
# ERROR!! nuetral
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.014.023
# wine
# <class 'str'>
# wine
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
#  nuetral
# <class 'str'>
# nuetral
# ERROR!! nuetral
# b.MAR.014.024
# wine
# <class 'str'>
# wine
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  blood
# <class 'str'>
# blood
# b.MAR.014.025
# wine
# <class 'str'>
# wine
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.014.036
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  negative
# <class 'str'>
# negative
# ERROR!! negative
# b.MAR.014.038
# body cert="medium"
# <class 'str'>
# body
#  flesh
# <class 'str'>
# flesh
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.014.041
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.014.044
# kiss
# <class 'str'>
# kiss
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  postive
# <class 'str'>
# postive
# ERROR!! postive
# b.MAR.014.045
# kiss
# <class 'str'>
# kiss
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  postive
# <class 'str'>
# postive
# ERROR!! postive
# b.MAR.014.051
# clothes
# <class 'str'>
# clothes
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.014.052
# nudity
# <class 'str'>
# nudity
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  clothes
# <class 'str'>
# clothes
# b.MAR.014.061
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.014.062
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  blessed
# <class 'str'>
# blessed
# ERROR!! blessed
# b.MAR.015.021
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# b.MAR.015.039
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.015.040
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  woman
# <class 'str'>
# woman
# ERROR!! woman
# b.MAR.015.043
# body
# <class 'str'>
# body
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.015.045
# body
# <class 'str'>
# body
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  positive
# <class 'str'>
# positive
# ERROR!! positive
# b.MAR.015.047
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  negative
# <class 'str'>
# negative
# ERROR!! negative
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
#  woman
# <class 'str'>
# woman
# ERROR!! woman
# b.MAR.016.001
# ascendant
# <class 'str'>
# ascendant
# ERROR!! ascendant
#  positive
# <class 'str'>
# positive
# ERROR!! positive
#  neutral
# <class 'str'>
# neutral
# ERROR!! neutral
# errors [['b.MAR.001.001', 'ascendant'], ['b.MAR.001.001', 'positive'], ['b.MAR.001.001', 'neutral'], ['b.MAR.001.011', 'ascendant'], ['b.MAR.001.011', 'positive'], ['b.MAR.001.011', 'blessed'], ['b.MAR.001.019', 'ascendant'], ['b.MAR.001.019', 'neutral'], ['b.MAR.001.020', 'ascendant'], ['b.MAR.001.020', 'positive'], ['b.MAR.001.020', 'negative'], ['b.MAR.001.030', 'ascendant'], ['b.MAR.001.030', 'marriage-relation'], ['b.MAR.001.030', 'negative'], ['b.MAR.001.030', 'neutral'], ['b.MAR.002.005', 'ascendant'], ['b.MAR.002.005', 'blessed'], ['b.MAR.002.005', 'negative'], ['b.MAR.002.010', 'ascendant'], ['b.MAR.002.010', 'positive'], ['b.MAR.002.010', 'negative'], ['b.MAR.002.014', 'ascendant'], ['b.MAR.002.014', 'positive'], ['b.MAR.002.014', 'neutral'], ['b.MAR.002.019', 'esposo'], ['b.MAR.002.019', 'positive'], ['b.MAR.002.019', 'negative'], ['b.MAR.002.020', 'esposo'], ['b.MAR.002.020', 'positive'], ['b.MAR.002.020', 'negative'], ['b.MAR.002.028', 'ascendant'], ['b.MAR.002.028', 'positive'], ['b.MAR.002.028', 'neutral'], ['b.MAR.003.011', 'ascendant'], ['b.MAR.003.011', 'negative'], ['b.MAR.003.011', 'positive'], ['b.MAR.003.017', 'ascendant'], ['b.MAR.003.017', 'neutral'], ['b.MAR.003.017', 'positive'], ['b.MAR.003.018', 'ascendant'], ['b.MAR.003.018', 'neutral'], ['b.MAR.003.018', 'positive'], ['b.MAR.003.028', 'condemned'], ['b.MAR.003.028', 'blessed'], ['b.MAR.003.028', 'ascendant'], ['b.MAR.003.031', 'ascendant'], ['b.MAR.003.031', 'negative'], ['b.MAR.003.031', 'positive'], ['b.MAR.003.032', 'ascendant'], ['b.MAR.003.032', 'neutral'], ['b.MAR.003.032', 'positive'], ['b.MAR.003.033', 'ascendant'], ['b.MAR.003.033', 'negative'], ['b.MAR.003.033', 'positive'], ['b.MAR.003.034', 'ascendant'], ['b.MAR.003.034', 'negative'], ['b.MAR.003.034', 'positive'], ['b.MAR.003.035', 'ascendant'], ['b.MAR.003.035', 'negative'], ['b.MAR.003.035', 'positive'], ['b.MAR.005.007', 'ascendant'], ['b.MAR.005.007', 'positive'], ['b.MAR.005.007', 'negative'], ['b.MAR.005.023', 'ascendant'], ['b.MAR.005.023', 'positive'], ['b.MAR.005.023', 'blessed'], ['b.MAR.005.025', 'negative'], ['b.MAR.005.025', 'neutral'], ['b.MAR.005.029', 'negative'], ['b.MAR.005.029', 'positive'], ['b.MAR.005.034', 'ascendant'], ['b.MAR.005.034', 'blessed'], ['b.MAR.005.034', 'negative'], ['b.MAR.005.035', 'ascendant'], ['b.MAR.005.035', 'negative'], ['b.MAR.005.035', 'positive'], ['b.MAR.005.040', 'ascendant'], ['b.MAR.005.040', 'negative'], ['b.MAR.005.040', 'positive'], ['b.MAR.006.003', 'ascendant'], ['b.MAR.006.003', 'negative'], ['b.MAR.006.003', 'neutral'], ['b.MAR.006.017', 'negative'], ['b.MAR.006.017', 'neutral-'], ['b.MAR.006.018', 'condemned'], ['b.MAR.006.018', 'neutral-'], ['b.MAR.006.022', 'ascendant'], ['b.MAR.006.022', 'positive'], ['b.MAR.006.022', 'neutral'], ['b.MAR.006.024', 'ascendant'], ['b.MAR.006.024', 'negative'], ['b.MAR.006.024', 'positive'], ['b.MAR.006.028', 'ascendant'], ['b.MAR.006.028', 'negative'], ['b.MAR.006.028', 'neutral'], ['b.MAR.007.010', 'ascendant'], ['b.MAR.007.010', 'positive'], ['b.MAR.007.010', 'condemned'], ['b.MAR.007.011', 'ascendant'], ['b.MAR.007.011', 'positive'], ['b.MAR.007.011', 'neutral'], ['b.MAR.007.012', 'ascendant'], ['b.MAR.007.012', 'positive'], ['b.MAR.007.012', 'neutral'], ['b.MAR.007.021', 'adultery'], ['b.MAR.007.021', 'fornication'], ['b.MAR.007.021', 'condemned'], ['b.MAR.007.021', 'neutral'], ['b.MAR.007.022', 'lust'], ['b.MAR.007.022', 'condemned'], ['b.MAR.007.025', 'ascendant'], ['b.MAR.007.025', 'negative'], ['b.MAR.007.025', 'neutral'], ['b.MAR.007.026', 'ascendant'], ['b.MAR.007.026', 'negative'], ['b.MAR.007.026', 'neutral'], ['b.MAR.007.027', 'ascendant'], ['b.MAR.007.027', 'condemned'], ['b.MAR.007.027', 'neutral'], ['b.MAR.007.029', 'ascendant'], ['b.MAR.007.029', 'blessed'], ['b.MAR.007.029', 'negative'], ['b.MAR.007.030', 'ascendant'], ['b.MAR.007.030', 'blessed'], ['b.MAR.007.030', 'negative'], ['b.MAR.008.031', 'ascendant'], ['b.MAR.008.031', 'negative'], ['b.MAR.008.031', 'blessed'], ['b. ...
# [('ascendant', 80), ('positive', 80), ('negative', 74), ('neutral', 47), ('blessed', 21), ('condemned', 11), ('adultery', 5), ('woman', 4), ('esposo', 2), ('neutral-', 2), ('lust', 2), ('man', 2), ('nuetral', 2), ('postive', 2), ('marriage-relation', 1), ('fornication', 1), ('sex', 1), ('condmened', 1), ('pregnangcy', 1)]
#
#
# Consider substitue sex with gay-sex . Levenshtein ratio:0.6
# Replacement modified with sexual-act
#
#
# Consider substitue nuetral with metal . Levenshtein ratio:0.67
# Replacement modified with neutral-aspect
#
#
# Consider substitue blessed with blessed-aspect . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue man with men . Levenshtein ratio:0.67
# Replacement accepted
#
#
# Consider substitue adultery with water . Levenshtein ratio:0.62
# Replacement modified with sex-outside-marriage
#
#
# Consider substitue condmened with condemned-aspect . Levenshtein ratio:0.64
# Replacement accepted
#
#
# Consider substitue neutral- with neutral-aspect . Levenshtein ratio:0.73
# Replacement accepted
#
#
# Consider substitue postive with prostitute . Levenshtein ratio:0.71
# Replacement modified with positive-aspect
#
#
# Consider substitue marriage-relation with pre-marital-relation . Levenshtein ratio:0.76
# Replacement modified with marriage
#
#
# Consider substitue pregnangcy with pregnancy . Levenshtein ratio:0.95
# Replacement accepted
#
#
# Consider substitue lust with belt . Levenshtein ratio:0.5
# Replacement modified with sexual-desire
#
#
# Consider substitue woman with women . Levenshtein ratio:0.8
# Replacement accepted
#
#
# Consider substitue negative with negative-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue ascendant with ascendant-descendant . Levenshtein ratio:0.62
# Replacement accepted
#
#
# Consider substitue fornication with lubrication . Levenshtein ratio:0.73
# Replacement modified with sex-before-marriage
#
#
# Consider substitue esposo with seasons . Levenshtein ratio:0.62
# Replacement modified with groom
#
#
# Consider substitue neutral with metal . Levenshtein ratio:0.67
# Replacement modified with neutral-aspect
#
#
# Consider substitue positive with positive-aspect . Levenshtein ratio:0.7
# Replacement accepted
#
#
# Consider substitue condemned with condemned-aspect . Levenshtein ratio:0.72
# Replacement accepted

# %%
error_lt
# Out:
# [['b.LEV.001.002', 'ascendant'],
#  ['b.LEV.001.002', 'neutral'],
#  ['b.LEV.001.002', 'positive'],
#  ['b.LEV.001.005', 'ascedant'],
#  ['b.LEV.001.005', 'neutral'],
#  ['b.LEV.001.005', 'positive'],
#  ['b.LEV.001.007', 'ascendant'],
#  ['b.LEV.001.007', 'positive'],
#  ['b.LEV.001.007', 'neutral'],
#  ['b.LEV.001.008', 'ascendant'],
#  ['b.LEV.001.008', 'neutral'],
#  ['b.LEV.001.011', 'ascendant'],
#  ['b.LEV.001.011', 'neutral'],
#  ['b.LEV.001.011', 'positive'],
#  ['b.LEV.002.002', 'ascendant'],
#  ['b.LEV.002.002', 'neutral'],
#  ['b.LEV.002.002', 'blessed'],
#  ['b.LEV.002.003', 'ascendant'],
#  ['b.LEV.002.003', 'neutral'],
#  ['b.LEV.002.003', 'positive'],
#  ['b.LEV.002.010', 'ascendant'],
#  ['b.LEV.002.010', 'neutral'],
#  ['b.LEV.002.010', 'blessed'],
#  ['b.LEV.003.002', 'ascendant'],
#  ['b.LEV.003.002', 'neutral'],
#  ['b.LEV.003.002', 'positive'],
#  ['b.LEV.003.005', 'ascendant'],
#  ['b.LEV.003.005', 'neutral'],
#  ['b.LEV.003.005', 'blessed'],
#  ['b.LEV.003.008', 'ascendant'],
#  ['b.LEV.003.008', 'neutral'],
#  ['b.LEV.003.008', 'positive'],
#  ['b.LEV.003.013', 'ascendant'],
#  ['b.LEV.003.013', 'neutral'],
#  ['b.LEV.003.013', 'positive'],
#  ['b.LEV.003.017', 'ascendant'],
#  ['b.LEV.003.017', 'neutral'],
#  ['b.LEV.003.017', 'negative'],
#  ['b.LEV.004.002', 'ascendant'],
#  ['b.LEV.004.002', 'condemned'],
#  ['b.LEV.004.002', 'neutral'],
#  ['b.LEV.006.009', 'ascendant'],
#  ['b.LEV.006.009', 'neutral'],
#  ['b.LEV.006.009', 'positive'],
#  ['b.LEV.006.010', 'positive'],
#  ['b.LEV.006.010', 'neutral'],
#  ['b.LEV.006.014', 'ascendant'],
#  ['b.LEV.006.014', 'positive'],
#  ['b.LEV.006.014', 'neutral'],
#  ['b.LEV.006.018', 'ascendant'],
#  ['b.LEV.006.018', 'blessed'],
#  ['b.LEV.006.018', 'neutral'],
#  ['b.LEV.006.020', 'ascendant'],
#  ['b.LEV.006.020', 'neutral'],
#  ['b.LEV.006.020', 'positive'],
#  ['b.LEV.006.022', 'ascendant'],
#  ['b.LEV.006.022', 'neutral'],
#  ['b.LEV.006.022', 'positive'],
#  ['b.LEV.006.025', 'ascendant'],
#  ['b.LEV.006.025', 'neutral'],
#  ['b.LEV.006.025', 'blessed'],
#  ['b.LEV.007.010', 'ascendant'],
#  ['b.LEV.007.010', 'neutral'],
#  ['b.LEV.007.023', 'ascendant'],
#  ['b.LEV.007.023', 'neutral'],
#  ['b.LEV.007.023', 'negative'],
#  ['b.LEV.007.029', 'ascendant'],
#  ['b.LEV.007.029', 'neutral'],
#  ['b.LEV.007.029', 'positive'],
#  ['b.LEV.007.031', 'ascendant'],
#  ['b.LEV.007.031', 'neutral'],
#  ['b.LEV.007.031', 'positive'],
#  ['b.LEV.007.033', 'ascendant'],
#  ['b.LEV.007.033', 'neutral'],
#  ['b.LEV.007.033', 'positive'],
#  ['b.LEV.007.034', 'ascendant'],
#  ['b.LEV.007.034', 'positive'],
#  ['b.LEV.007.034', 'neutral'],
#  ['b.LEV.007.035', 'ascendant'],
#  ['b.LEV.007.035', 'neutral'],
#  ['b.LEV.007.035', 'positive'],
#  ['b.LEV.007.036', 'ascendant'],
#  ['b.LEV.007.036', 'neutral'],
#  ['b.LEV.007.036', 'positive'],
#  ['b.LEV.007.038', 'ascendant'],
#  ['b.LEV.007.038', 'neutral'],
#  ['b.LEV.007.038', 'positive'],
#  ['b.LEV.008.002', 'ascendant'],
#  ['b.LEV.008.002', 'neutral'],
#  ['b.LEV.008.002', 'positive'],
#  ['b.LEV.008.006', 'ascendant'],
#  ['b.LEV.008.006', 'neutral'],
#  ['b.LEV.008.006', 'positive'],
#  ['b.LEV.008.013', 'ascendant'],
#  ['b.LEV.008.013', 'neutral'],
#  ['b.LEV.008.013', 'positive'],
#  ['b.LEV.008.014', 'ascendant'],
#  ['b.LEV.008.014', 'positive'],
#  ['b.LEV.008.014', 'neurtal'],
#  ['b.LEV.008.018', 'ascendant'],
#  ['b.LEV.008.018', 'neutral'],
#  ['b.LEV.008.018', 'positive'],
#  ['b.LEV.008.022', 'ascendant'],
#  ['b.LEV.008.022', 'positive'],
#  ['b.LEV.008.022', 'neutral'],
#  ['b.LEV.008.024', 'ascendant'],
#  ['b.LEV.008.024', 'neutral'],
#  ['b.LEV.008.024', 'positive'],
#  ['b.LEV.008.027', 'ascendant'],
#  ['b.LEV.008.027', 'neutral'],
#  ['b.LEV.008.027', 'positive'],
#  ['b.LEV.008.030', 'ascendant'],
#  ['b.LEV.008.030', 'neutral'],
#  ['b.LEV.008.030', 'blessed'],
#  ['b.LEV.008.031', 'ascendant'],
#  ['b.LEV.008.031', 'neutral'],
#  ['b.LEV.008.031', 'positive'],
#  ['b.LEV.009.001', 'ascendant'],
#  ['b.LEV.009.001', 'neutral'],
#  ['b.LEV.009.003', 'ascendant'],
#  ['b.LEV.009.003', 'positive'],
#  ['b.LEV.009.003', 'neutral'],
#  ['b.LEV.009.009', 'ascendant'],
#  ['b.LEV.009.009', 'negative'],
#  ['b.LEV.009.009', 'positive'],
#  ['b.LEV.009.012', 'ascendant'],
#  ['b.LEV.009.012', 'negative'],
#  ['b.LEV.009.012', 'positive'],
#  ['b.LEV.009.018', 'ascendant'],
#  ['b.LEV.009.018', 'neutral'],
#  ['b.LEV.009.018', 'positive'],
#  ['b.LEV.010.001', 'ascendant'],
#  ['b.LEV.010.001', 'negative'],
#  ['b.LEV.010.001', 'neutral'],
#  ['b.LEV.010.004', 'ascendant'],
#  ['b.LEV.010.004', 'neutral'],
#  ['b.LEV.010.006', 'ascendant'],
#  ['b.LEV.010.006', 'neutral'],
#  ['b.LEV.010.006', 'positive'],
#  ['b.LEV.010.009', 'ascendant'],
#  ['b.LEV.010.009', 'neutral'],
#  ['b.LEV.010.009', 'negative'],
#  ['b.LEV.010.011', 'ascendant'],
#  ['b.LEV.010.011', 'neutral'],
#  ['b.LEV.010.011', 'positive'],
#  ['b.LEV.010.012', 'ascendant'],
#  ['b.LEV.010.012', 'neutral'],
#  ['b.LEV.010.012', 'blessed'],
#  ['b.LEV.010.013', 'ascendant'],
#  ['b.LEV.010.013', 'neutral'],
#  ['b.LEV.010.013', 'positive'],
#  ['b.LEV.010.014', 'ascendant'],
#  ['b.LEV.010.014', 'positive'],
#  ['b.LEV.010.014', 'neutral'],
#  ['b.LEV.010.015', 'ascendant'],
#  ['b.LEV.010.015', 'neutral'],
#  ['b.LEV.010.015', 'positive'],
#  ['b.LEV.010.016', 'ascendant'],
#  ['b.LEV.010.016', 'neutral'],
#  ['b.LEV.011.002', 'ascendant'],
#  ['b.LEV.011.002', 'neutral'],
#  ['b.LEV.011.002', 'positive'],
#  ['b.LEV.012.002', 'ascendant'],
#  ['b.LEV.012.002', 'woman'],
#  ['b.LEV.012.002', 'negative'],
#  ['b.LEV.012.002', 'neutral'],
#  ['b.LEV.012.003', 'ascendant'],
#  ['b.LEV.012.003', 'neutral'],
#  ['b.LEV.012.003', 'positive'],
#  ['b.LEV.012.004', 'ascendant'],
#  ['b.LEV.012.004', 'negative'],
#  ['b.LEV.012.004', 'positive'],
#  ['b.LEV.012.005', 'ascendant'],
#  ['b.LEV.012.005', 'woman'],
#  ['b.LEV.012.005', 'positive'],
#  ['b.LEV.012.005', 'negative'],
#  ['b.LEV.012.006', 'ascendant'],
#  ['b.LEV.012.006', 'neutral'],
#  ['b.LEV.012.007', 'positive'],
#  ['b.LEV.012.007', 'negative'],
#  ['b.LEV.012.007', 'ascendant'],
#  ['b.LEV.012.007', 'woman'],
#  ['b.LEV.012.007', 'man'],
#  ['b.LEV.013.002', 'negative'],
#  ['b.LEV.013.002', 'ascendant'],
#  ['b.LEV.013.002', 'neutral'],
#  ['b.LEV.013.003', 'negative'],
#  ['b.LEV.013.003', 'neutral'],
#  ['b.LEV.013.004', 'negative'],
#  ['b.LEV.013.004', 'neutral'],
#  ['b.LEV.013.005', 'negative'],
#  ['b.LEV.013.005', 'neutral'],
#  ['b.LEV.013.006', 'negative'],
#  ['b.LEV.013.006', 'positive'],
#  ['b.LEV.013.007', 'negative'],
#  ['b.LEV.013.007', 'positive'],
#  ['b.LEV.013.008', 'negative'],
#  ['b.LEV.013.008', 'neutral'],
#  ['b.LEV.013.009', 'negative'],
#  ['b.LEV.013.009', 'neutral'],
#  ['b.LEV.013.010', 'negative'],
#  ['b.LEV.013.010', 'neutral'],
#  ['b.LEV.013.011', 'negative'],
#  ['b.LEV.013.011', 'neutral'],
#  ['b.LEV.013.012', 'negative'],
#  ['b.LEV.013.012', 'neutral'],
#  ['b.LEV.013.013', 'negative'],
#  ['b.LEV.013.013', 'neutral'],
#  ['b.LEV.013.014', 'negative'],
#  ['b.LEV.013.014', 'neutral'],
#  ['b.LEV.013.015', 'negative'],
#  ['b.LEV.013.015', 'neutral'],
#  ['b.LEV.013.016', 'negative'],
#  ['b.LEV.013.016', 'neutral'],
#  ['b.LEV.013.017', 'negative'],
#  ['b.LEV.013.017', 'positive'],
#  ['b.LEV.013.018', 'negative'],
#  ['b.LEV.013.018', 'neutral'],
#  ['b.LEV.013.019', 'negative'],
#  ['b.LEV.013.019', 'neutral'],
#  ['b.LEV.013.020', 'negative'],
#  ['b.LEV.013.020', 'neutral'],
#  ['b.LEV.013.021', 'negative'],
#  ['b.LEV.013.021', 'neutral'],
#  ['b.LEV.013.022', 'negative'],
#  ['b.LEV.013.022', 'neutral'],
#  ['b.LEV.013.023', 'positive'],
#  ['b.LEV.013.023', 'neutral'],
#  ['b.LEV.013.024', 'neutral'],
#  ['b.LEV.013.024', 'negative'],
#  ['b.LEV.013.025', 'neutral'],
#  ['b.LEV.013.025', 'negative'],
#  ['b.LEV.013.026', 'neutral'],
#  ['b.LEV.013.026', 'negative'],
#  ['b.LEV.013.027', 'neutral'],
#  ['b.LEV.013.027', 'negative'],
#  ['b.LEV.013.028', 'positive'],
#  ['b.LEV.013.028', 'negative'],
#  ['b.LEV.013.029', 'negative'],
#  ['b.LEV.013.029', 'neutral'],
#  ['b.LEV.013.030', 'negative'],
#  ['b.LEV.013.030', 'neutral'],
#  ['b.LEV.013.031', 'negative'],
#  ['b.LEV.013.031', 'neutral'],
#  ['b.LEV.013.032', 'negative'],
#  ['b.LEV.013.032', 'neutral'],
#  ['b.LEV.013.033', 'negative'],
#  ['b.LEV.013.033', 'neutral'],
#  ['b.LEV.013.034', 'negative'],
#  ['b.LEV.013.034', 'positive'],
#  ['b.LEV.013.035', 'negative'],
#  ['b.LEV.013.035', 'positive'],
#  ['b.LEV.013.036', 'negative'],
#  ['b.LEV.013.036', 'neutral'],
#  ['b.LEV.013.037', 'negative'],
#  ['b.LEV.013.037', 'positive'],
#  ['b.LEV.013.038', 'negative'],
#  ['b.LEV.013.038', 'neutral'],
#  ['b.LEV.013.039', 'negative'],
#  ['b.LEV.013.039', 'neutral'],
#  ['b.LEV.013.040', 'neutral'],
#  ['b.LEV.013.040', 'positive'],
#  ['b.LEV.013.041', 'neutral'],
#  ['b.LEV.013.041', 'positive'],
#  ['b.LEV.013.042', 'neutral'],
#  ['b.LEV.013.042', 'negative'],
#  ['b.LEV.013.043', 'neutral'],
#  ['b.LEV.013.043', 'negative'],
#  ['b.LEV.013.044', 'neutral'],
#  ['b.LEV.013.044', 'negative'],
#  ['b.LEV.013.045', 'neutral'],
#  ['b.LEV.013.045', 'negative'],
#  ['b.LEV.013.046', 'neutral'],
#  ['b.LEV.013.046', 'negative'],
#  ['b.LEV.013.047', 'neutral'],
#  ['b.LEV.013.047', 'negative'],
#  ['b.LEV.013.047', 'cloths'],
#  ['b.LEV.013.048', 'neutral'],
#  ['b.LEV.013.048', 'negative'],
#  ['b.LEV.013.048', 'cloths'],
#  ['b.LEV.013.049', 'neutral'],
#  ['b.LEV.013.049', 'negative'],
#  ['b.LEV.013.049', 'cloths'],
#  ['b.LEV.013.050', 'neutral'],
#  ['b.LEV.013.050', 'negative'],
#  ['b.LEV.013.050', 'cloths'],
#  ['b.LEV.013.051', 'neutral'],
#  ['b.LEV.013.051', 'negative'],
#  ['b.LEV.013.051', 'cloths'],
#  ['b.LEV.013.052', 'neutral'],
#  ['b.LEV.013.052', 'negative'],
#  ['b.LEV.013.052', 'cloths'],
#  ['b.LEV.013.053', 'neutral'],
#  ['b.LEV.013.053', 'negative'],
#  ['b.LEV.013.053', 'cloths'],
#  ['b.LEV.013.054', 'neutral'],
#  ['b.LEV.013.054', 'negative'],
#  ['b.LEV.013.054', 'cloths'],
#  ['b.LEV.013.055', 'neutral'],
#  ['b.LEV.013.055', 'negative'],
#  ['b.LEV.013.055', 'cloths'],
#  ['b.LEV.013.056', 'neutral'],
#  ['b.LEV.013.056', 'negative'],
#  ['b.LEV.013.056', 'cloths'],
#  ['b.LEV.013.057', 'neutral'],
#  ['b.LEV.013.057', 'negative'],
#  ['b.LEV.013.057', 'cloths'],
#  ['b.LEV.013.058', 'neutral'],
#  ['b.LEV.013.058', 'positive'],
#  ['b.LEV.013.058', 'cloths'],
#  ['b.LEV.013.059', 'positive'],
#  ['b.LEV.013.059', 'negative'],
#  ['b.LEV.013.059', 'cloths'],
#  ['b.LEV.014.002', 'neutral'],
#  ['b.LEV.014.002', 'negative'],
#  ['b.LEV.014.003', 'neutral'],
#  ['b.LEV.014.003', 'negative'],
#  ['b.LEV.014.007', 'positive'],
#  ['b.LEV.014.007', 'negative'],
#  ['b.LEV.014.008', 'positive'],
#  ['b.LEV.014.008', 'negative'],
#  ['b.LEV.014.008', 'cloths'],
#  ['b.LEV.014.009', 'positive'],
#  ['b.LEV.014.009', 'neutral'],
#  ['b.LEV.014.009', 'cloths'],
#  ['b.LEV.014.029', 'positive'],
#  ['b.LEV.014.029', 'negative'],
#  ['b.LEV.014.032', 'negative'],
#  ['b.LEV.014.032', 'positive'],
#  ['b.LEV.015.002', 'ascendant'],
#  ['b.LEV.015.002', 'orgasm-in-the-night'],
#  ['b.LEV.015.002', 'neutral'],
#  ['b.LEV.015.002', 'negative'],
#  ['b.LEV.015.003', 'neutral'],
#  ['b.LEV.015.003', 'negative'],
#  ['b.LEV.015.004', 'neutral'],
#  ['b.LEV.015.004', 'negative'],
#  ['b.LEV.015.005', 'neutral'],
#  ['b.LEV.015.005', 'negative'],
#  ['b.LEV.015.006', 'neutral'],
#  ['b.LEV.015.006', 'negative'],
#  ['b.LEV.015.007', 'neutral'],
#  ['b.LEV.015.007', 'negative'],
#  ['b.LEV.015.008', 'neutral'],
#  ['b.LEV.015.008', 'negative'],
#  ['b.LEV.015.008', 'cloths'],
#  ['b.LEV.015.009', 'neutral'],
#  ['b.LEV.015.009', 'negative'],
#  ['b.LEV.015.010', 'neutral'],
#  ['b.LEV.015.010', 'negative'],
#  ['b.LEV.015.011', 'neutral'],
#  ['b.LEV.015.011', 'negative'],
#  ['b.LEV.015.012', 'neutral'],
#  ['b.LEV.015.012', 'negative'],
#  ['b.LEV.015.013', 'positive'],
#  ['b.LEV.015.013', 'negative'],
#  ['b.LEV.015.016', 'neutral'],
#  ['b.LEV.015.016', 'negative'],
#  ['b.LEV.015.017', 'neutral'],
#  ['b.LEV.015.017', 'negative'],
#  ['b.LEV.015.018', 'neutral'],
#  ['b.LEV.015.018', 'vaginal-penetration'],
#  ['b.LEV.015.018', 'negative'],
#  ['b.LEV.015.019', 'neutral'],
#  ['b.LEV.015.019', 'negative'],
#  ['b.LEV.015.020', 'neutral'],
#  ['b.LEV.015.020', 'negative'],
#  ['b.LEV.015.024', 'negative'],
#  ['b.LEV.015.024', 'neutral'],
#  ['b.LEV.015.025', 'negative'],
#  ['b.LEV.015.025', 'neutral'],
#  ['b.LEV.015.026', 'negative'],
#  ['b.LEV.015.026', 'neutral'],
#  ['b.LEV.015.028', 'negative'],
#  ['b.LEV.015.028', 'positive'],
#  ['b.LEV.015.030', 'negative'],
#  ['b.LEV.015.030', 'positive'],
#  ['b.LEV.015.031', 'negative'],
#  ['b.LEV.015.031', 'positive'],
#  ['b.LEV.015.031', 'ascendant'],
#  ['b.LEV.015.032', 'negative'],
#  ['b.LEV.015.032', 'neutral'],
#  ['b.LEV.015.033', 'negative'],
#  ['b.LEV.015.033', 'neutral'],
#  ['b.LEV.016.001', 'ascendant'],
#  ['b.LEV.016.001', 'negative'],
#  ['b.LEV.016.001', 'neutral'],
#  ['b.LEV.016.004', 'cloths'],
#  ['b.LEV.016.004', 'positive'],
#  ['b.LEV.016.004', 'neutral'],
#  ['b.LEV.016.005', 'ascendant'],
#  ['b.LEV.016.005', 'neutral'],
#  ['b.LEV.016.005', 'positive'],
#  ['b.LEV.016.016', 'ascendant'],
#  ['b.LEV.016.019', 'ascendant'],
#  ['b.LEV.016.019', 'negative'],
#  ['b.LEV.016.019', 'neutral'],
#  ['b.LEV.016.021', 'ascendant'],
#  ['b.LEV.016.021', 'negative'],
#  ['b.LEV.016.023', 'cloths'],
#  ['b.LEV.016.023', 'neutral'],
#  ['b.LEV.016.023', 'positive'],
#  ['b.LEV.016.024', 'cloths'],
#  ['b.LEV.016.024', 'positive'],
#  ['b.LEV.016.024', 'neutral'],
#  ['b.LEV.016.026', 'cloths'],
#  ['b.LEV.016.026', 'positive'],
#  ['b.LEV.016.026', 'neutral'],
#  ['b.LEV.016.028', 'cloths'],
#  ['b.LEV.016.028', 'neutral'],
#  ['b.LEV.016.028', 'positive'],
#  ['b.LEV.016.032', 'ascendant'],
#  ['b.LEV.016.032', 'neutral'],
#  ['b.LEV.016.032', 'positive'],
#  ['b.LEV.017.002', 'ascendant'],
#  ['b.LEV.017.002', 'neutral'],
#  ['b.LEV.017.002', 'positive'],
#  ['b.LEV.017.007', 'ascendant'],
#  ['b.LEV.017.007', 'negative'],
#  ['b.LEV.017.007', 'neutral'],
#  ['b.LEV.017.012', 'ascendant'],
#  ['b.LEV.017.012', 'condemned'],
#  ['b.LEV.017.012', 'neutral'],
#  ['b.LEV.017.013', 'ascendant'],
#  ['b.LEV.017.013', 'neutral'],
#  ['b.LEV.017.014', 'ascendant'],
#  ['b.LEV.017.014', 'condemned'],
#  ['b.LEV.017.015', 'cloths'],
#  ['b.LEV.017.015', 'condemned'],
#  ['b.LEV.017.015', 'positive'],
#  ['b.LEV.017.016', 'cloths'],
#  ['b.LEV.017.016', 'condemned'],
#  ['b.LEV.017.016', 'neutral'],
#  ['b.LEV.018.002', 'ascendant'],
#  ['b.LEV.018.002', 'positive'],
#  ['b.LEV.018.002', 'neutral'],
#  ['b.LEV.018.006', 'condemned'],
#  ['b.LEV.018.006', 'neutral'],
#  ['b.LEV.018.007', 'sex-in-great-family'],
#  ['b.LEV.018.007', 'condemned'],
#  ['b.LEV.018.007', 'neutral'],
#  ['b.LEV.018.008', 'sex-in-great-family'],
#  ['b.LEV.018.008', 'condemned'],
#  ['b.LEV.018.008', 'neutral'],
#  ['b.LEV.018.009', 'sex-in-great-family'],
#  ['b.LEV.018.009', 'condemned'],
#  ['b.LEV.018.009', 'neutral'],
#  ['b.LEV.018.010', 'sex-in-great-family'],
#  ['b.LEV.018.010', 'condemned'],
#  ['b.LEV.018.010', 'neutral'],
#  ['b.LEV.018.011', 'sex-in-great-family'],
#  ['b.LEV.018.011', 'condemned'],
#  ['b.LEV.018.011', 'neutral'],
#  ['b.LEV.018.012', 'sex-in-great-family'],
#  ['b.LEV.018.012', 'condemned'],
#  ['b.LEV.018.012', 'neutral'],
#  ['b.LEV.018.013', 'sex-in-great-family'],
#  ['b.LEV.018.013', 'condemned'],
#  ['b.LEV.018.013', 'neutral'],
#  ['b.LEV.018.014', 'sex-in-great-family'],
#  ['b.LEV.018.014', 'condemned'],
#  ['b.LEV.018.014', 'neutral'],
#  ['b.LEV.018.015', 'sex-in-great-family'],
#  ['b.LEV.018.015', 'condemned'],
#  ['b.LEV.018.015', 'neutral'],
#  ['b.LEV.018.016', 'sex-in-great-family'],
#  ['b.LEV.018.016', 'condemned'],
#  ['b.LEV.018.016', 'neutral'],
#  ['b.LEV.018.017', 'sex-in-great-family'],
#  ['b.LEV.018.017', 'condemned'],
#  ['b.LEV.018.017', 'neutral'],
#  ['b.LEV.018.018', 'sex-in-great-family'],
#  ['b.LEV.018.018', 'condemned'],
#  ['b.LEV.018.018', 'neutral'],
#  ['b.LEV.018.019', 'condemned'],
#  ['b.LEV.018.019', 'neutral'],
#  ['b.LEV.018.020', 'condemned'],
#  ['b.LEV.018.020', 'neutral'],
#  ['b.LEV.018.021', 'religious-sexual-act'],
#  ['b.LEV.018.021', 'condemned'],
#  ['b.LEV.018.021', 'neutral'],
#  ['b.LEV.018.022', 'male-homosexual-sex'],
#  ['b.LEV.018.022', 'condemned'],
#  ['b.LEV.018.022', 'neutral'],
#  ['b.LEV.018.023', 'sex-with-animals'],
#  ['b.LEV.018.023', 'condemned'],
#  ['b.LEV.018.023', 'neutral'],
#  ['b.LEV.018.024', 'negative'],
#  ['b.LEV.018.024', 'neutral'],
#  ['b.LEV.018.025', 'condemned'],
#  ['b.LEV.018.025', 'neutral'],
#  ['b.LEV.018.026', 'condmened'],
#  ['b.LEV.018.026', 'neutral'],
#  ['b.LEV.018.027', 'condmened'],
#  ['b.LEV.018.027', 'neutral'],
#  ['b.LEV.018.028', 'condmened'],
#  ['b.LEV.018.028', 'neutral'],
#  ['b.LEV.018.029', 'condmened'],
#  ['b.LEV.018.029', 'neutral'],
#  ['b.LEV.018.030', 'condmened'],
#  ['b.LEV.018.030', 'neutral'],
#  ['b.LEV.019.002', 'ascendant'],
#  ['b.LEV.019.002', 'blessed'],
#  ['b.LEV.019.002', 'neutral'],
#  ['b.LEV.019.003', 'ascendant'],
#  ['b.LEV.019.003', 'blessed'],
#  ['b.LEV.019.003', 'neutral'],
#  ['b.LEV.019.018', 'ascendant'],
#  ['b.LEV.019.018', 'condemned'],
#  ['b.LEV.019.018', 'positive'],
#  ['b.LEV.019.020', 'sex-with-servant'],
#  ['b.LEV.019.020', 'condemned'],
#  ['b.LEV.019.020', 'neutral'],
#  ['b.LEV.019.021', 'sex-with-servant'],
#  ['b.LEV.019.021', 'condemned'],
#  ['b.LEV.019.021', 'neutral'],
#  ['b.LEV.019.022', 'sex-with-servant'],
#  ['b.LEV.019.022', 'condemned'],
#  ['b.LEV.019.022', 'neutral'],
#  ['b.LEV.019.023', 'negative'],
#  ['b.LEV.019.023', 'neutral'],
#  ['b.LEV.019.029', 'condemned'],
#  ['b.LEV.019.029', 'neutral'],
#  ['b.LEV.020.002', 'ascendant'],
#  ['b.LEV.020.002', 'condemned'],
#  ['b.LEV.020.002', 'neutral'],
#  ['b.LEV.020.003', 'ascendant'],
#  ['b.LEV.020.003', 'condemned'],
#  ['b.LEV.020.003', 'neutral'],
#  ['b.LEV.020.004', 'ascendant'],
#  ['b.LEV.020.004', 'condemned'],
#  ['b.LEV.020.004', 'neutral'],
#  ['b.LEV.020.005', 'ascendant'],
#  ['b.LEV.020.005', 'condemned'],
#  ['b.LEV.020.005', 'neutral'],
#  ['b.LEV.020.006', 'religious-sex'],
#  ['b.LEV.020.006', 'condemned'],
#  ['b.LEV.020.006', 'neutral'],
#  ['b.LEV.020.009', 'ascendant'],
#  ['b.LEV.020.009', 'condemned'],
#  ['b.LEV.020.009', 'neutral'],
#  ['b.LEV.020.010', 'adultery'],
#  ['b.LEV.020.010', 'condemned'],
#  ['b.LEV.020.010', 'neutral'],
#  ['b.LEV.020.011', 'family-sex'],
#  ['b.LEV.020.011', 'condemned'],
#  ['b.LEV.020.011', 'neutral'],
#  ['b.LEV.020.012', 'family-sex'],
#  ['b.LEV.020.012', 'condemned'],
#  ['b.LEV.020.012', 'neutral'],
#  ['b.LEV.020.013', 'condemned'],
#  ['b.LEV.020.013', 'neutral'],
#  ['b.LEV.020.014', 'condemned'],
#  ['b.LEV.020.014', 'neutral'],
#  ['b.LEV.020.015', 'sex-with-animals'],
#  ['b.LEV.020.015', 'condmened'],
#  ['b.LEV.020.015', 'neutral'],
#  ['b.LEV.020.016', 'sex-with-animals'],
#  ['b.LEV.020.016', 'condmened'],
#  ['b.LEV.020.016', 'neutral'],
#  ['b.LEV.020.017', 'condmened'],
#  ['b.LEV.020.017', 'neutral'],
#  ['b.LEV.020.018', 'condmened'],
#  ['b.LEV.020.018', 'neutral'],
#  ['b.LEV.020.019', 'condmened'],
#  ['b.LEV.020.019', 'neutral'],
#  ['b.LEV.020.020', 'ascendant'],
#  ['b.LEV.020.020', 'condmened'],
#  ['b.LEV.020.020', 'positive'],
#  ['b.LEV.020.021', 'ascendant'],
#  ['b.LEV.020.021', 'condmened'],
#  ['b.LEV.020.021', 'positive'],
#  ['b.LEV.021.001', 'ascendant'],
#  ['b.LEV.021.001', 'negative'],
#  ['b.LEV.021.001', 'neutral'],
#  ['b.LEV.021.002', 'ascendant'],
#  ['b.LEV.021.002', 'positive'],
#  ['b.LEV.021.002', 'neutral'],
#  ['b.LEV.021.003', 'positive'],
#  ['b.LEV.021.003', 'neutral'],
#  ['b.LEV.021.005', 'beard'],
#  ['b.LEV.021.005', 'positive'],
#  ['b.LEV.021.005', 'negative'],
#  ['b.LEV.021.007', 'female-prostitute'],
#  ['b.LEV.021.007', 'negative'],
#  ['b.LEV.021.007', 'positive'],
#  ['b.LEV.021.009', 'female-prostitution'],
#  ['b.LEV.021.009', 'condemned'],
#  ['b.LEV.021.009', 'ascendant'],
#  ['b.LEV.021.009', 'positive'],
#  ['b.LEV.021.011', 'ascendant'],
#  ['b.LEV.021.011', 'neutral'],
#  ['b.LEV.021.011', 'negative'],
#  ['b.LEV.021.013', 'positive'],
#  ['b.LEV.021.013', 'neutral'],
#  ['b.LEV.021.014', 'female-widow'],
#  ['b.LEV.021.014', 'female-prostitution'],
#  ['b.LEV.021.014', 'woman'],
#  ['b.LEV.021.014', 'positive'],
#  ['b.LEV.021.014', 'negative'],
#  ['b.LEV.021.015', 'ascendant'],
#  ['b.LEV.021.015', 'blessed'],
#  ['b.LEV.021.015', 'neutral'],
#  ['b.LEV.021.017', 'ascednant'],
#  ['b.LEV.021.017', 'negative'],
#  ['b.LEV.021.017', 'positive'],
#  ['b.LEV.021.020', 'negative'],
#  ['b.LEV.021.020', 'positive'],
#  ['b.LEV.021.021', 'ascendant'],
#  ['b.LEV.021.021', 'positive'],
#  ['b.LEV.021.021', 'negative'],
#  ['b.LEV.021.024', 'ascendant'],
#  ['b.LEV.021.024', 'positive'],
#  ['b.LEV.021.024', 'neutral'],
#  ['b.LEV.022.002', 'ascendant'],
#  ['b.LEV.022.002', 'blessed'],
#  ['b.LEV.022.002', 'neutral'],
#  ['b.LEV.022.003', 'ascendant'],
#  ['b.LEV.022.003', 'blessed'],
#  ['b.LEV.022.003', 'negative'],
#  ['b.LEV.022.004', 'ascendant'],
#  ['b.LEV.022.004', 'negative'],
#  ['b.LEV.022.004', 'neutral'],
#  ['b.LEV.022.006', 'blessed'],
#  ['b.LEV.022.006', 'negative'],
#  ['b.LEV.022.006', 'watter'],
#  ['b.LEV.022.012', 'ascendant'],
#  ['b.LEV.022.012', 'neutral'],
#  ['b.LEV.022.012', 'blessed'],
#  ['b.LEV.022.013', 'ascendant'],
#  ['b.LEV.022.013', 'female-widow'],
#  ['b.LEV.022.013', 'divorced'],
#  ['b.LEV.022.013', 'negative'],
#  ['b.LEV.022.013', 'positive'],
#  ['b.LEV.022.015', 'ascendant'],
#  ['b.LEV.022.015', 'blessed'],
#  ['b.LEV.022.015', 'negative'],
#  ['b.LEV.022.018', 'ascendant'],
#  ['b.LEV.022.018', 'neutral'],
#  ['b.LEV.022.024', 'animal'],
#  ['b.LEV.022.024', 'testicles'],
#  ['b.LEV.022.032', 'ascendant'],
#  ['b.LEV.022.032', 'blessed'],
#  ['b.LEV.022.032', 'negative'],
#  ['b.LEV.023.002', 'ascendant'],
#  ['b.LEV.023.002', 'neutral'],
#  ['b.LEV.023.002', 'positive'],
#  ['b.LEV.023.010', 'ascendant'],
#  ['b.LEV.023.010', 'neutral'],
#  ['b.LEV.023.010', 'positive'],
#  ['b.LEV.023.021', 'ascendant'],
#  ['b.LEV.023.021', 'positive'],
#  ['b.LEV.023.021', 'negative'],
#  ['b.LEV.023.024', 'ascendant'],
#  ['b.LEV.023.024', 'neutral'],
#  ['b.LEV.023.024', 'blessed'],
#  ['b.LEV.023.031', 'ascendant'],
#  ['b.LEV.023.031', 'negative'],
#  ['b.LEV.023.031', 'positive'],
#  ['b.LEV.023.034', 'ascendant'],
#  ['b.LEV.023.034', 'positive'],
#  ['b.LEV.023.034', 'neutral'],
#  ['b.LEV.023.043', 'ascendant'],
#  ['b.LEV.023.043', 'positive'],
#  ['b.LEV.023.043', 'neutral'],
#  ['b.LEV.023.044', 'ascendant'],
#  ['b.LEV.023.044', 'positive'],
#  ['b.LEV.023.044', 'neutral'],
#  ['b.LEV.024.002', 'ascendant'],
#  ['b.LEV.024.002', 'neutral'],
#  ['b.LEV.024.002', 'positive'],
#  ['b.LEV.024.003', 'ascendant'],
#  ['b.LEV.024.003', 'neutral'],
#  ['b.LEV.024.003', 'positive'],
#  ['b.LEV.024.008', 'ascendant'],
#  ['b.LEV.024.008', 'nuetral'],
#  ['b.LEV.024.008', 'positive'],
#  ['b.LEV.024.009', 'ascendant'],
#  ['b.LEV.024.009', 'nuetral'],
#  ['b.LEV.024.009', 'blessed'],
#  ['b.LEV.024.010', 'negative'],
#  ['b.LEV.024.010', 'neutral'],
#  ['b.LEV.024.011', 'ascendant'],
#  ['b.LEV.024.011', 'condemned'],
#  ['b.LEV.024.011', 'neutral'],
#  ['b.LEV.024.014', 'condemned'],
#  ['b.LEV.024.014', 'neutral'],
#  ['b.LEV.024.015', 'ascendant'],
#  ['b.LEV.024.015', 'condemned'],
#  ['b.LEV.024.015', 'neutral'],
#  ['b.LEV.024.023', 'ascendant'],
#  ['b.LEV.024.023', 'condemned'],
#  ['b.LEV.025.002', 'ascendant'],
#  ['b.LEV.025.002', 'neutral'],
#  ['b.LEV.025.002', 'positive'],
#  ['b.LEV.025.041', 'ascendant'],
#  ['b.LEV.025.041', 'positive'],
#  ['b.LEV.025.041', 'neutral'],
#  ['b.LEV.025.045', 'ascendant'],
#  ['b.LEV.025.045', 'neutral'],
#  ['b.LEV.025.045', 'negative'],
#  ['b.LEV.025.046', 'ascendant'],
#  ['b.LEV.025.046', 'negative'],
#  ['b.LEV.025.046', 'neutral'],
#  ['b.LEV.025.049', 'ascendant'],
#  ['b.LEV.025.049', 'negative'],
#  ['b.LEV.025.049', 'positive'],
#  ['b.LEV.025.054', 'positive'],
#  ['b.LEV.025.054', 'neutral'],
#  ['b.LEV.025.054', 'ascendant'],
#  ['b.LEV.025.055', 'ascendant'],
#  ['b.LEV.025.055', 'blessed'],
#  ['b.LEV.025.055', 'neutral'],
#  ['b.LEV.026.022', 'ascendant'],
#  ['b.LEV.026.022', 'condemned'],
#  ['b.LEV.026.022', 'neutral'],
#  ['b.LEV.026.029', 'condemned'],
#  ['b.LEV.026.029', 'neutral'],
#  ['b.LEV.026.029', 'ascendant'],
#  ['b.LEV.026.039', 'ascendant'],
#  ['b.LEV.026.039', 'condemned'],
#  ['b.LEV.026.039', 'neutral'],
#  ['b.LEV.026.040', 'ascendant'],
#  ['b.LEV.026.040', 'negative'],
#  ['b.LEV.026.040', 'neutral'],
#  ['b.LEV.026.041', 'negative'],
#  ['b.LEV.026.041', 'neutral'],
#  ['b.LEV.026.046', 'ascendant'],
#  ['b.LEV.026.046', 'positive'],
#  ['b.LEV.026.046', 'neutral'],
#  ['b.LEV.027.002', 'ascendant'],
#  ['b.LEV.027.002', 'positive'],
#  ['b.LEV.027.002', 'neutral'],
#  ['b.LEV.027.034', 'ascendant'],
#  ['b.LEV.027.034', 'positive'],
#  ['b.LEV.027.034', 'neutral']]

# %%
standOff_str[0:10000]
# Out:
# '<standOff xml:id="b.MAR.sexualThemes"  scheme="taxonomy.xml">\n<spanGrp type="theme" inst="#b.MAR.001.001">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.001">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.001">\n\t<span ana="neutral-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.011">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.011">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.011">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.019">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.019">\n\t<span ana="neutral-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.020">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.020">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.020">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.030">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.030">\n\t<span ana="marriage">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.030">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.001.030">\n\t<span ana="neutral-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.005">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.005">\n\t<span ana="blessed-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.005">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.010">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.010">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.010">\n\t<span ana="negative-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.014">\n\t<span ana="ascendant-descendant">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/>\n\t</span>\n</spanGrp>\n<spanGrp type="theme" inst="#b.MAR.002.014">\n\t<span ana="positive-aspect">\n\t\t<certainty match="@ana" locus="value" cert="high" given="text"/> ...

# %%
valorations_lt = taxonomy_el.xpath("//tei:category[@xml:id='valorations']//tei:category//@xml:id", namespaces = namespaces_dict)

# %%
len(valorations_lt)
# Out:
# 5

# %%
valorations_lt
# Out:
# ['blessed-aspect',
#  'positive-aspect',
#  'neutral-aspect',
#  'negative-aspect',
#  'condemned-aspect']

# %%
for verse in sorted(list(set(etree.fromstring(standOff_str).xpath('//spanGrp//@inst')))):
    #print(verse)
    annotations = etree.fromstring(standOff_str).xpath('//spanGrp[@inst ="' + verse + '"]/span/@ana')

    if valorations_lt[0] not in annotations and valorations_lt[1]  not in annotations and valorations_lt[2]  not in annotations  and valorations_lt[3] not in annotations  and valorations_lt[4] not in annotations:
        print(verse, annotations)

# %%
verse
# Out:
# '#b.MAR.016.001'

# %%
annotations
# Out:
# ['ascendant-descendant', 'positive-aspect', 'neutral-aspect']

# %%
import pandas as pd
pd.DataFrame([["a", 1],["b", 5],["c", 0],["d", 2],], columns=["label", "value"]).sort_values(by="value", ascending=False).iloc[0]
# Out:
# label    b
# value    5
# Name: 1, dtype: object

# %%
from collections import Counter
Counter([error_id[1] for  error_id in error_lt]).most_common()
# Out:
# [('ascendant', 80),
#  ('positive', 80),
#  ('negative', 74),
#  ('neutral', 47),
#  ('blessed', 21),
#  ('condemned', 11),
#  ('adultery', 5),
#  ('woman', 4),
#  ('esposo', 2),
#  ('neutral-', 2),
#  ('lust', 2),
#  ('man', 2),
#  ('nuetral', 2),
#  ('postive', 2),
#  ('marriage-relation', 1),
#  ('fornication', 1),
#  ('sex', 1),
#  ('condmened', 1),
#  ('pregnangcy', 1)]

# %%
parse_sexual_anotation.save_book_with_standOff_element(book_str, standOff_str, book_name,     wdir_str = "./../../../sexual-annotation/",)

# %%
book_str[0:1000]
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml" schematypens="http://relaxng.org/ns/structure/1.0"?>\n<?xml-model href="http://www.tei-c.org/release/xml/tei/custom/schema/relaxng/tei_all.rng" type="application/xml"\n\tschematypens="http://purl.oclc.org/dsdl/schematron"?>\n<TEI xmlns="http://www.tei-c.org/ns/1.0">\n\t<teiHeader>\n\t\t<fileDesc>\n\t\t\t<titleStmt>\n\t\t\t\t<title>Evangelio de Marcos</title>\n\t\t\t\t<title type="idno">\n\t\t\t\t\t<idno type="string">MAR</idno>\n\t\t\t\t\t<idno type="viaf">179823714</idno>\n\t\t\t\t</title>\n\t\t\t\t<author>\n\t\t\t\t\t<name type="short">Marcos</name>\n\t\t\t\t\t<name type="full">Marcos</name>\n\t\t\t\t\t<idno type="viaf">264405984</idno>\n\t\t\t\t</author>\n\t\t\t\t<principal key="#jct">José Calvo Tello</principal>\n\t\t\t</titleStmt>\n\t\t\t<publicationStmt>\n\t\t\t\t<publisher>José Calvo Tello</publisher>\n\t\t\t\t<availability status="free">\n\t\t\t\t\t<p>The text is freely available.</p>\n\t\t\t\t</availability>\n\t\t\t\t<date when="201'

# %%
book_str[-1000:]
# Out:
# '#org6">demonios</rs>, hablarán nuevas lenguas,</q>\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t\t<ab xml:id="b.MAR.016.018" type="verse" n="18">\n\t\t\t\t\t\t\t<q who="#per1" toWhom="#org3" type="oral">tomarán serpientes en las manos y, aunque beban cosa mortífera, no les hará daño; sobre los <rs key="#org15">enfermos</rs> pondrán sus manos, y sanarán.</q>\n\t\t\t\t\t\t\t<!--jct: interesantes versículos-->\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t</div>\n\t\t\t\t\t<div type="pericope">\n\t\t\t\t\t\t<head type="pericope">La ascensión</head>\n\t\t\t\t\t\t<ab xml:id="b.MAR.016.019" type="verse" n="19">\n\t\t\t\t\t\t\tY el <rs key="#per1">Señor</rs>, después que les habló, fue recibido arriba en el <rs key="#pla18">cielo</rs> y se sentó a la diestra de <rs key="#per14">Dios</rs>.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t\t<ab xml:id="b.MAR.016.020" type="verse" n="20">\n\t\t\t\t\t\t\tEllos, saliendo, predicaron en todas partes, ayudándolos el <rs key="#per1">Señor</rs> y confirmando la palabra con las señales que la acompañaban. Amén.\n\t\t\t\t\t\t</ab>\n\t\t\t\t\t</div>\n\t\t\t\t</div>\n\t\t\t</div>\n\t\t</body>\n\t\t<back />\n\t</text>\n</TEI>\n'
