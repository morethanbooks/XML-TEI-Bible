# %%
import sys
import os
import glob
import re 
import pandas as pd
import numpy as np
from lxml import etree
import matplotlib.pyplot as plt
import requests
import time
from collections import Counter
import json

# %%
#sys.path.append(os.path.abspath("./../../../../Dropbox/MTB/Göttingen/research/"))
#sys.path.append(os.path.abspath("./../../"))

# %%
import json

# %%
from urllib.request import urlopen

# %%
url = "https://www.wikidata.org/w/api.php?action=wbgetclaims&entity=Q9184&format=json"
jsonurl = urlopen(url)
text = json.loads(jsonurl.read())

# %%
text["claims"]
# Out:
# {'P373': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P373',
#     'hash': '034ae74f5f375593b69a8e968886a4c11a7a6199',
#     'datavalue': {'value': 'Book of Numbers', 'type': 'string'},
#     'datatype': 'string'},
#    'type': 'statement',
#    'id': 'q43099$8CA58FC3-4D55-4F55-9906-71E260A1BF4E',
#    'rank': 'normal',
#    'references': [{'hash': '9a24f7c0208b05d6be97077d855671d1dfdbc0dd',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'd38375ffe6fe142663ff55cd783aa4df4301d83d',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 48183,
#           'id': 'Q48183'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P361': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': '4dc7eb91db2251ac1dfbe799c1fd7c5fe8de4afe',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 34990,
#       'id': 'Q34990'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'q43099$9ae75591-4429-0071-0b3b-e3b4ee0f5c98',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': '020dc1715d9fe530bef053bb0df59b6e7ea40576',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 83367,
#       'id': 'Q83367'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$2da5b251-4da8-5991-7f7e-b6baa1524647',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': 'a7f957d833bc3b47b4a4988844473b5b7215d916',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 19786,
#       'id': 'Q19786'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$504b761f-40cc-0886-0b8e-53a4b8d29fb7',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': 'd36229de30e49537851e797597da55f86cd928d7',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 14405870,
#       'id': 'Q14405870'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$3ea7f301-4972-cc38-7ab7-ede73da14b22',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': 'e188cedcf8fb655a5e533d3bca6e7c95662a33b3',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 245719,
#       'id': 'Q245719'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$793235e2-4740-6797-e442-fb883d2eb416',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P361',
#     'hash': 'e7a5ece75df0c277a368f5faad40089bcf64f971',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 162062,
#       'id': 'Q162062'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$98CF4807-632D-41F4-A26A-6452C7B8D3E8',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P910': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P910',
#     'hash': 'b14d69affea48c64a6db5b2173f4ab9113800a1c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 8305703,
#       'id': 'Q8305703'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$1FF928A0-A66C-4A41-A755-8C97E2425FA0',
#    'rank': 'normal'}],
#  'P136': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P136',
#     'hash': '28ee857db844a766e2d38164772a07539a98fda0',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 3086228,
#       'id': 'Q3086228'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$11F4FC67-2671-46C0-B4B0-C9008022BC60',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']},
#     {'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '6a164248fc96bfa583bbb495cb63ae6401ec203c',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 206855,
#           'id': 'Q206855'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P646': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P646',
#     'hash': 'd01a906617698828954854e460be221f80290c53',
#     'datavalue': {'value': '/m/01dlg', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$4C4E939B-F664-4103-8C97-A37B5252FDFD',
#    'rank': 'normal',
#    'references': [{'hash': '2b00cb481cddcac7623114367489b5c194901c4a',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': 'a94b740202b097dd33355e0e6c00e54b9395e5e0',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 15241312,
#           'id': 'Q15241312'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P577': [{'snaktype': 'value',
#         'property': 'P577',
#         'hash': 'fde79ecb015112d2f29229ccc1ec514ed3e71fa2',
#         'datavalue': {'value': {'time': '+2013-10-28T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P577']}]}],
#  'P31': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P31',
#     'hash': '99ac5408d003b0c915c504963bd942d59f3fbc56',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 179461,
#       'id': 'Q179461'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$b056dc78-43e4-c05f-f6e2-4271dcc72056',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P31',
#     'hash': '358f77891f2e7082039f7efa73d8b1c1d2b8a7da',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 29154430,
#       'id': 'Q29154430'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$30bb2261-42c7-10fa-daf8-74c6f39c970d',
#    'rank': 'normal'}],
#  'P18': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P18',
#     'hash': '55b57e3cafca0db150b91ebf84bc5dfca96c5305',
#     'datavalue': {'value': 'The Two Reports of the Spies (crop).jpg',
#      'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'id': 'Q43099$E625320D-44EC-467E-8E2D-55ABE5EB5B34',
#    'rank': 'normal',
#    'references': [{'hash': '732ec1c90a6f0694c7db9a71bf09fe7f2b674172',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '9123b0de1cc9c3954366ba797d598e4e1ea4146f',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 10000,
#           'id': 'Q10000'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P18',
#     'hash': '2039590bc2d9736c59a9ac5c872ddf5fcd40cf4e',
#     'datavalue': {'value': 'Figures.jpg', 'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'id': 'Q43099$AF4F158B-5353-4971-8A63-B7010CBD030C',
#    'rank': 'normal'}],
#  'P1296': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1296',
#     'hash': '88dd22b5897115960fd2706587a90bb86ab25b76',
#     'datavalue': {'value': '0046299', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$50DBB77F-C21E-4148-991F-4D382C67AA0E',
#    'rank': 'normal',
#    'references': [{'hash': 'b3fd5e254143d8b52cd96cff43af9af5e3a82358',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'f13c99a16441677ec69fcea23f221d866f1fc98f',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 199693,
#           'id': 'Q199693'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P1438': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1438',
#     'hash': '9c53538c0028d192fd30f0012aad9df976c11424',
#     'datavalue': {'value': '14688', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$223477FF-2C6B-4A61-B5C2-B1AE50F9E234',
#    'rank': 'normal',
#    'references': [{'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '6a164248fc96bfa583bbb495cb63ae6401ec203c',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 206855,
#           'id': 'Q206855'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P935': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P935',
#     'hash': '52625a3641079f9a7d37b037131e5c2d34d798e4',
#     'datavalue': {'value': 'Book of Numbers', 'type': 'string'},
#     'datatype': 'string'},
#    'type': 'statement',
#    'id': 'Q43099$13F75C18-002C-40B2-9D7D-3BE8C3BDF4C6',
#    'rank': 'normal'}],
#  'P2959': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P2959',
#     'hash': '879a384359cfa3029a0031e045cf12472fe4c08c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 25689997,
#       'id': 'Q25689997'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$36A5875E-8A44-4D92-91B9-3755323D3F68',
#    'rank': 'normal'}],
#  'P3417': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P3417',
#     'hash': '9f5086c061aa0f543a8805513f5223c8ef7aa1f0',
#     'datavalue': {'value': 'Book-of-Numbers', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$7B8EEE84-F6D7-454F-866E-BBE7150FEDAB',
#    'rank': 'normal'}],
#  'P3710': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P3710',
#     'hash': '3a769cb092da1401146d046a3117b0933a604360',
#     'datavalue': {'value': '2635', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$B3914A16-033E-4A59-BC75-C54BCF45F6AA',
#    'rank': 'normal',
#    'references': [{'hash': 'ed8bd3f9343e9a35e58b67284f26a67859f1808d',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '07596fc82d3ed4d248b85e5543852cc31e37dc8c',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 199913,
#           'id': 'Q199913'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P1813': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1813',
#     'hash': '3586082bf2824d261f6efd9e380e50fadaea851e',
#     'datavalue': {'value': {'text': 'Num', 'language': 'de'},
#      'type': 'monolingualtext'},
#     'datatype': 'monolingualtext'},
#    'type': 'statement',
#    'id': 'Q43099$fae84782-4b11-0a0f-d89b-7f67d09211a1',
#    'rank': 'normal'}],
#  'P4230': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P4230',
#     'hash': 'de46ca86a137ccfafc3b3746dbdd723853e5d230',
#     'datavalue': {'value': 'Numbers', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$E16CC001-CC0C-4D2F-B539-726BCA101051',
#    'rank': 'normal'}],
#  'P1343': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1343',
#     'hash': '7d6f86cef085693a10b0e0663a0960f58d0e15e2',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 4173137,
#       'id': 'Q4173137'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P805': [{'snaktype': 'value',
#       'property': 'P805',
#       'hash': 'd95ba2c7893e82d4ee5d4ac52e203d0ce5f19806',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 24923254,
#         'id': 'Q24923254'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P805'],
#    'id': 'Q43099$3e90536d-4040-c89c-e124-c0e45f2d361f',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P1343',
#     'hash': '88389772f86dcd7d415ddd029f601412e5cc894a',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 602358,
#       'id': 'Q602358'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P805': [{'snaktype': 'value',
#       'property': 'P805',
#       'hash': '0e93d036218d4ed31ddbf554c5057bdbc183b8fc',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 24514155,
#         'id': 'Q24514155'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P805'],
#    'id': 'Q43099$bcb277bd-415f-951a-b453-a5bb2028aa89',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P1343',
#     'hash': '42346dfe9209b7359c1f5db829a368b38d407797',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 19180675,
#       'id': 'Q19180675'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P805': [{'snaktype': 'value',
#       'property': 'P805',
#       'hash': '1dc3e24ebb7611ced5709e73875cb6839e65be02',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 24738271,
#         'id': 'Q24738271'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P805'],
#    'id': 'Q43099$77e5c260-4e5d-17c9-e778-8a1d52479fad',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P1343',
#     'hash': '4cfd4eb1fe49d401455df557a7d9b1154f22a725',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 3181656,
#       'id': 'Q3181656'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'qualifiers': {'P1932': [{'snaktype': 'value',
#       'property': 'P1932',
#       'hash': 'e35313e83608599b1ab388dad5062a89d9f73404',
#       'datavalue': {'value': 'Numbers, Book of', 'type': 'string'},
#       'datatype': 'string'}]},
#    'qualifiers-order': ['P1932'],
#    'id': 'Q43099$bff7f12b-4e2c-9dea-3af9-32d29851e565',
#    'rank': 'normal'}],
#  'P407': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P407',
#     'hash': '6d71717341dc5a8e98ca5a631dca15f905671c82',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 1982248,
#       'id': 'Q1982248'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$953F38DA-4D1D-4BD2-80E5-5CCE1B4DF336',
#    'rank': 'normal',
#    'references': [{'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': 'e4f6d9441d0600513c4533c672b5ab472dc73694',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 328,
#           'id': 'Q328'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']},
#     {'hash': '288ab581e7d2d02995a26dfa8b091d96e78457fc',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '6a164248fc96bfa583bbb495cb63ae6401ec203c',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 206855,
#           'id': 'Q206855'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P143']}]}],
#  'P527': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '938739b36523e355fa209662dffae41041dc376e',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476206,
#       'id': 'Q12476206'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$1B720C44-BB39-4E2D-9871-70B7873AB0B7',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '707fd1f4cd83ba840ecc785bce6ab260afef7f46',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476207,
#       'id': 'Q12476207'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$84E05A86-EADA-49E4-ABA7-0C372B3697DC',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '0cdb68d04d4116e1e8682634f337ab4bfaf7ba76',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476205,
#       'id': 'Q12476205'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$B851CF10-7BD4-4EBB-9696-C096A8D4E3B4',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'e87b4c3588c4067dae95cd7d43f9b5180aa10dd9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476210,
#       'id': 'Q12476210'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$E471DF52-E365-4344-858E-D6379D84A560',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'e076a4c703080c8fbdd16d2abb0139dcc64e0cde',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476211,
#       'id': 'Q12476211'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$EACFFB4B-D880-4B26-81F5-ACC1FCC74CE8',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '4736b3b7a03ecff67d8aea426693ff2db6a4416c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476208,
#       'id': 'Q12476208'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$DE69A11E-4CA0-4C48-87AA-5D4E73AE3E69',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '21b51ff2e0d672c259b72704e57addba5fc8c4f9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476209,
#       'id': 'Q12476209'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$AAF6F56D-3690-455F-B896-40D4136D22AE',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '92aa97e7da776e66df957c99237cd9e5ac49652b',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476214,
#       'id': 'Q12476214'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$305FFEF8-64D2-4883-82F5-0FEA1B51E1FC',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '16fad79ca0e886c8a13cc0b64fcb984de949b576',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476215,
#       'id': 'Q12476215'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$CFFCC10C-5DAC-41BF-AD9B-ED3051AABBC5',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '640fee07b380efbccc6e483939a7b51ff5ea0a2a',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476212,
#       'id': 'Q12476212'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$2FCB77F8-266F-497E-8FF5-136C625A8990',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '49483f53bd290a0cfa19de9d6930203ebb890db8',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476213,
#       'id': 'Q12476213'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$69382F59-B48A-452D-9CCC-E9D79CBFEED1',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'f84581e7964daec8e8c0e7da9d1212d9e1f1dc5a',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476218,
#       'id': 'Q12476218'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$7881AE74-8A4C-49AF-801A-34297BA71C68',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '39311642de932c54098ab2aa4d621d52a829e079',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476219,
#       'id': 'Q12476219'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$13A8819E-F584-40D6-802E-952F2E54C1FE',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '42b82c0fbd52c3ce794d30c056c5ea8621d8c703',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476216,
#       'id': 'Q12476216'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$6F127A85-F976-483B-A23F-07D65A57232B',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '543a88db2a201fa6b44e1c299253732469065eb9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476217,
#       'id': 'Q12476217'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$B898D66F-FD8D-4359-87BC-31A1EE21D08D',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '36e0c2dce567ea1b2090e431f95b222c0529d99c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476222,
#       'id': 'Q12476222'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$293EE8AC-47ED-47E1-A6FE-FE6ECC13DCE1',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '93e913707128545a86ae7f5b8680a29d9409bd11',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 6842271,
#       'id': 'Q6842271'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$4E8EDF43-85B9-47AB-AB31-2796A74E2A27',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'a13e6629df4d7953bab23bf7a9eb8448e98138c7',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476220,
#       'id': 'Q12476220'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$C593EB1D-932F-4ED3-8FA0-ECFC079A6267',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'b54df2fd0ebcbc5e3c7b16458494fbeb31fd9da3',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476221,
#       'id': 'Q12476221'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$4BE087C7-9F4F-4C7C-8A4D-B467D4358AFB',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'cf4cf06c6c731783a014bcde9a2adf2f13654574',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476227,
#       'id': 'Q12476227'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$BDD3F6D3-2AF8-40C2-98D0-51013945C214',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'e3cd6e9838e81b6f5733c36b1043d7beb1d76e5c',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476224,
#       'id': 'Q12476224'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$50923911-1374-4A6D-8065-063ABEFAF13D',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '0649b9d486829c96bcdf6cbd722c3121c5313ea3',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476225,
#       'id': 'Q12476225'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$EE8C7688-BEE4-478E-B6C3-68A8FEF5DD7D',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'b92ae88012be4d863f47efd62638e2fb12ee487b',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476230,
#       'id': 'Q12476230'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$807E11DA-B317-4FD7-929A-00134345C021',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '7a4e4b046f3af9ed6932d680481f7f6da90d9233',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476231,
#       'id': 'Q12476231'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$868955AD-50C0-499E-9D03-284659888A32',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'd1e6b5a361597313229d4b722ff5a210cc565820',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476228,
#       'id': 'Q12476228'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$9192C1C3-BCB8-412A-8E3F-EFDAB9C3889A',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'e93024afb8f172d49c036e908afae89453901663',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 12476229,
#       'id': 'Q12476229'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$E3153308-3F0F-4389-9582-671102E6E7F3',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'a83bc8eb7b2ac9c0ebd17fa6c067bee2e59021d9',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16158757,
#       'id': 'Q16158757'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$B8659A4E-B86C-4870-B3C1-86BF9846352F',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'f3900900913bc7bf951fd1430c7cba0e922c675e',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16159411,
#       'id': 'Q16159411'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$1E43A6AC-413D-4A9A-A962-427FFB674B80',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '03469de119d19f4623b7bae9e92ec27d4524f99f',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16159979,
#       'id': 'Q16159979'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$EF6C9212-50DE-4493-8AB4-A8E41B004133',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'feb5975a084f64e0a759257e9eb1d0270a27d3e8',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16160263,
#       'id': 'Q16160263'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$09C05C70-F953-40CC-8469-A2538FA4F256',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'dc894d2a7dde8589c4243676ae2e9fed32bb9821',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16160582,
#       'id': 'Q16160582'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$76F3FBEA-A7D9-4D9F-8329-C475EBA355E7',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': 'e257850d3f02316a6bd90f91a8c701983a00764b',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16160889,
#       'id': 'Q16160889'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$12F2C8CA-BFE0-4261-8F32-03F628441A83',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '4f8d519399c75592371b7d973263a8971fea667e',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16161086,
#       'id': 'Q16161086'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$E9D24ADA-4DA0-4C33-82D4-870521FD34A5',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '69683a604a3158650bb2b9cd51e70da1e2a3b6f6',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16161289,
#       'id': 'Q16161289'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$019C35B0-33A7-413F-BD4F-FDC35C002AFB',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '4702659cc58c1db18c06415012d77e2c1e138c64',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 16161410,
#       'id': 'Q16161410'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$B651F614-E025-4C29-A1CB-57888792369B',
#    'rank': 'normal'},
#   {'mainsnak': {'snaktype': 'value',
#     'property': 'P527',
#     'hash': '53474f91ec2bb93f03b4acaea7219d8173f1651f',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 17997451,
#       'id': 'Q17997451'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$012BA56C-CF99-4BFE-92D7-A18A0AB8E664',
#    'rank': 'normal'}],
#  'P2581': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P2581',
#     'hash': '544e312b69c506daa3cda4d3c6ac8d33eed96f09',
#     'datavalue': {'value': '00012104n', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$341A4A62-3085-4E9E-AA2C-BC8E4BA7D694',
#    'rank': 'normal',
#    'references': [{'hash': '248ac337a217a5f5eed7139a82a4e60931611af0',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '25b816aab41db18565946259c950aed6de05dd1e',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 4837690,
#           'id': 'Q4837690'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}]},
#      'snaks-order': ['P248']}]}],
#  'P3219': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P3219',
#     'hash': '9b8f89cf324904afe6a223385935404f085611e7',
#     'datavalue': {'value': 'livre-des-nombres', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$7A77CF7F-EEB4-48DF-A4FE-8DCF41B7A177',
#    'rank': 'normal'}],
#  'P155': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P155',
#     'hash': '35f9d7988494bee4588f0223ee1d20e7edf30df6',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 41490,
#       'id': 'Q41490'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$dec49b43-4e3d-49bb-7c1c-e0259056da12',
#    'rank': 'normal'}],
#  'P156': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P156',
#     'hash': '460cbb28c13437dedc7c1cdd9d7d24a6c19513ed',
#     'datavalue': {'value': {'entity-type': 'item',
#       'numeric-id': 42614,
#       'id': 'Q42614'},
#      'type': 'wikibase-entityid'},
#     'datatype': 'wikibase-item'},
#    'type': 'statement',
#    'id': 'Q43099$33e37a8e-41bc-5f0c-767a-6c6b1d6a6988',
#    'rank': 'normal'}],
#  'P1417': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1417',
#     'hash': '579e1f82cbafce955913d628d5460d13104e074b',
#     'datavalue': {'value': 'topic/Numbers-Old-Testament', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$4A86A6AA-48A0-4468-853F-45964BBB4D57',
#    'rank': 'normal'}],
#  'P989': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P989',
#     'hash': '00f34ab980f323c0e39846cb16c41ca589a7ef77',
#     'datavalue': {'value': 'Nl-Numeri-article.ogg', 'type': 'string'},
#     'datatype': 'commonsMedia'},
#    'type': 'statement',
#    'qualifiers': {'P407': [{'snaktype': 'value',
#       'property': 'P407',
#       'hash': '700aeaff381db1a1b58c6d58777ab5ec7daefe17',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 7411,
#         'id': 'Q7411'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P407'],
#    'id': 'Q43099$A1B06A27-E908-4F0C-80EC-BA5C0B2BE3EC',
#    'rank': 'normal',
#    'references': [{'hash': '319be303164456645d57bca05978269cdfc332aa',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '9123b0de1cc9c3954366ba797d598e4e1ea4146f',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 10000,
#           'id': 'Q10000'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P4656': [{'snaktype': 'value',
#         'property': 'P4656',
#         'hash': '04ca81cdeddff3f83b7683c44a7ea3dfe529a458',
#         'datavalue': {'value': 'https://nl.wikipedia.org/w/index.php?title=Numeri&oldid=54366762',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P143', 'P4656']}]}],
#  'P1705': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P1705',
#     'hash': 'e0663b851bfa5cc3653e25f2ef9721917632c294',
#     'datavalue': {'value': {'text': 'בְּמִדְבַּר', 'language': 'he'},
#      'type': 'monolingualtext'},
#     'datatype': 'monolingualtext'},
#    'type': 'statement',
#    'id': 'Q43099$5f4502e9-4575-7e6e-9592-8c1d9e456a2d',
#    'rank': 'normal',
#    'references': [{'hash': '5145ab7e7c38a060a680f0cef4a10e08a6edb78b',
#      'snaks': {'P143': [{'snaktype': 'value',
#         'property': 'P143',
#         'hash': '6a164248fc96bfa583bbb495cb63ae6401ec203c',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 206855,
#           'id': 'Q206855'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P4656': [{'snaktype': 'value',
#         'property': 'P4656',
#         'hash': '5513878a618992bf1b1867db2b65d33315c2aa5a',
#         'datavalue': {'value': 'https://ru.wikipedia.org/?oldid=104361335',
#          'type': 'string'},
#         'datatype': 'url'}]},
#      'snaks-order': ['P143', 'P4656']}]}],
#  'P7818': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P7818',
#     'hash': '8a3ef131642dfee30ee42a53ba77715b70a8197b',
#     'datavalue': {'value': 'Nombres_(livre_biblique)', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$2BBEED49-FBDF-41A6-85CA-848BB2B43F30',
#    'rank': 'normal'}],
#  'P8408': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8408',
#     'hash': '10ab0fe5ffc5bbd12a8cc69eb54b4574a84019ba',
#     'datavalue': {'value': 'Numbers-BookOfBible', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$BDFD6E29-D850-4A0E-9B47-93C3ADC35554',
#    'rank': 'normal',
#    'references': [{'hash': '9a681f9dd95c90224547c404e11295f4f7dcf54e',
#      'snaks': {'P248': [{'snaktype': 'value',
#         'property': 'P248',
#         'hash': '9d5780dddffa8746637a9929a936ab6b0f601e24',
#         'datavalue': {'value': {'entity-type': 'item',
#           'numeric-id': 64139102,
#           'id': 'Q64139102'},
#          'type': 'wikibase-entityid'},
#         'datatype': 'wikibase-item'}],
#       'P813': [{'snaktype': 'value',
#         'property': 'P813',
#         'hash': '622a5a27fa5b25e7e7984974e9db494cf8460990',
#         'datavalue': {'value': {'time': '+2020-07-09T00:00:00Z',
#           'timezone': 0,
#           'before': 0,
#           'after': 0,
#           'precision': 11,
#           'calendarmodel': 'http://www.wikidata.org/entity/Q1985727'},
#          'type': 'time'},
#         'datatype': 'time'}]},
#      'snaks-order': ['P248', 'P813']}]}],
#  'P5063': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P5063',
#     'hash': '577add43976847886edd2788692565978b4b916e',
#     'datavalue': {'value': 'i70297', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$DA146CBA-E121-4A3D-9B7B-6ED1CC1996C2',
#    'rank': 'normal'}],
#  'P8759': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8759',
#     'hash': 'b2733c995f74c745718fdc4eb6db15cbbb0c022d',
#     'datavalue': {'value': 'Liczb_Ksiega', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$4AF90C49-6A90-44B0-B95A-CF6E6FFA0E2B',
#    'rank': 'normal'}],
#  'P4212': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P4212',
#     'hash': '97a870df2c2d459b2857fb06dcc7b07da25b2824',
#     'datavalue': {'value': 'pcrtRwGiIY5OP6', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$A37B3B0A-D497-43BF-8974-522BFBAB1B99',
#    'rank': 'normal'}],
#  'P8814': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8814',
#     'hash': 'a7c4b80eb5615e889a6da3942bd6f04b39850fa1',
#     'datavalue': {'value': '06444919-n', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'id': 'Q43099$E6168EA1-BCE3-4BBF-9796-F860038FE5B3',
#    'rank': 'normal'}],
#  'P8248': [{'mainsnak': {'snaktype': 'value',
#     'property': 'P8248',
#     'hash': '499d4274df4f7a7e35cb29ae549d63084a0dfcc7',
#     'datavalue': {'value': 'Q6:2214', 'type': 'string'},
#     'datatype': 'external-id'},
#    'type': 'statement',
#    'qualifiers': {'P747': [{'snaktype': 'value',
#       'property': 'P747',
#       'hash': '050115e00610f532de12a73d97ee504d8443bfb7',
#       'datavalue': {'value': {'entity-type': 'item',
#         'numeric-id': 95449814,
#         'id': 'Q95449814'},
#        'type': 'wikibase-entityid'},
#       'datatype': 'wikibase-item'}]},
#    'qualifiers-order': ['P747'],
#    'id': 'Q43099$001C9FC0-7E06-4A2C-BEF7-E66A65FEB691',
#    'rank': 'normal'}]}
