# %%
from lxml import etree
import pandas as pd
from collections import Counter
import os
import glob
import re
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
from numpy import array
import numpy as np
import matplotlib.pyplot as plt
import pyarrow
# %matplotlib inline


wdir = "../../../sexual-annotation/"
file_bible = "TEIBible" # "*.xml"
file_taxonomy = "taxonomy"
outdir = "../../../resulting data/"

# %%
wdir + file_bible + ".xml"
# Out:
# '../../../sexual-annotation/TEIBible.xml'

# %%
parser = etree.XMLParser(encoding = 'utf-8')
documento_xml_bible = etree.parse(wdir + file_bible + ".xml", parser)
documento_root_bible = documento_xml_bible.getroot()
specific_namespaces = {'tei':'http://www.tei-c.org/ns/1.0','xi':'http://www.w3.org/2001/XInclude'}

# %%
parser = etree.XMLParser(encoding = 'utf-8')
documento_xml_taxonomy = etree.parse(wdir + file_taxonomy + ".xml", parser)
documento_root_taxonomy = documento_xml_taxonomy.getroot()

# %%
documento_root_taxonomy
# Out:
# <Element {http://www.tei-c.org/ns/1.0}TEI at 0x2164e7c0448>

# %%
verses_identifiers = documento_root_bible.xpath('.//tei:ab[@type="verse"]/@xml:id', namespaces = specific_namespaces, with_tail = True)

# %%
categories_names = documento_root_taxonomy.xpath('.//tei:category/@xml:id', namespaces = specific_namespaces, with_tail = True)

# %%
categories_names
# Out:
# ['relations',
#  'monogamy',
#  'poligamy',
#  'marriage',
#  'second-marriage',
#  'second-marriage-divorce',
#  'second-marriage-widow',
#  'interfaith-marriage',
#  'interfaith-relation',
#  'non-marital-relation',
#  'relation-greater-family',
#  'marital-relation-political-family',
#  'lord-servant-relation',
#  'marital-relation-direct-family',
#  'arranged-marriage',
#  'divorce',
#  'engaged',
#  'love',
#  'jealousy',
#  'ascendant-descendant',
#  'primogeniture',
#  'indirect-ascendant-descendant',
#  'homosexual-relation',
#  'acts',
#  'social-related-act',
#  'wedding',
#  'deception',
#  'body-related-act',
#  'massage',
#  'kiss',
#  'hug',
#  'dance',
#  'abortion',
#  'circumcision',
#  'breast-feeding',
#  'bath',
#  'sexual-act',
#  'sexual-act-stage',
#  'seduction',
#  'rejection',
#  'erotic-time',
#  'initation-sexual-act',
#  'orgasm',
#  'ejaculation',
#  'time-after-sex',
#  'sexual-act-type',
#  'coitus',
#  'first-sexual-act',
#  'coitus-interruptus',
#  'self-masturbation',
#  'masturbation',
#  'oral-sex',
#  'anal-sex',
#  'non-penetrative-sex',
#  'rape',
#  'female-rape',
#  'male-rape',
#  'sexual-assault',
#  'female-sexual-assault',
#  'male-sexual-assault',
#  'sexual-deception',
#  'sexual-drive',
#  'sexual-desire',
#  'sex-for-goods',
#  'voyerism',
#  'other-sexual-act',
#  'sexual-act-situation',
#  'sex-in-marriage',
#  'sex-before-marriage',
#  'sex-outside-marriage',
#  'sex-outside',
#  'sex-menstruation',
#  'sexual-act-participants',
#  'heterosexual-sex',
#  'homosexual-sex',
#  'gay-sex',
#  'lesbian-sex',
#  'prostitution-sex',
#  'religous-sex',
#  'parents-children-sex',
#  'sibling-sex',
#  'greater-family-sex',
#  'interfaith-sex',
#  'interracial-sex',
#  'angel-human-sex',
#  'animal-human-sex',
#  'animal-sex',
#  'groupal-sex',
#  'lord-servant-sex',
#  'states',
#  'single-life',
#  'virginity',
#  'celibacy',
#  'infertility',
#  'nudity',
#  'semi-nudity',
#  'pregnancy',
#  'beauty',
#  'dishonor',
#  'sickness',
#  'body',
#  'body-by-gender',
#  'female-body',
#  'male-body',
#  'body-part',
#  'genitalia',
#  'female-genitalia',
#  'uterus',
#  'male-genitalia',
#  'prepuce',
#  'testicle',
#  'gluteus-anus',
#  'female-breast',
#  'male-chest',
#  'ovaries',
#  'semen',
#  'head',
#  'eye',
#  'nose',
#  'cheek',
#  'mouth',
#  'lips',
#  'tongue',
#  'tooth',
#  'hair',
#  'thigh',
#  'neck',
#  'hand',
#  'skin',
#  'foot',
#  'waist',
#  'heart',
#  'navel',
#  'belly',
#  'leg',
#  'knie',
#  'arm',
#  'rib',
#  'lubrication',
#  'face',
#  'flesh',
#  'blood',
#  'umbilical-cord',
#  'body-function',
#  'birth',
#  'fertilization',
#  'misscarriage',
#  'erection',
#  'menstruation',
#  'sleep',
#  'diseases',
#  'menstrual-disorder',
#  'senses',
#  'smell',
#  'things',
#  'clothes',
#  'belt',
#  'veil',
#  'skirt',
#  'underwear',
#  'male-underwear',
#  'female-underwear',
#  'perfume',
#  'juwels',
#  'earrings',
#  'piercing',
#  'collar',
#  'bracelet',
#  'food-and-related',
#  'drink',
#  'water',
#  'milk',
#  'wine',
#  'alcohol',
#  'glass',
#  'oil',
#  'spices',
#  'wheat',
#  'honey',
#  'fruits',
#  'pomegranate',
#  'grapes',
#  'raisin',
#  'apples',
#  'figs',
#  'carriage',
#  'weapons',
#  'sword',
#  'shield',
#  'money',
#  'metal',
#  'silver',
#  'gold',
#  'fountain',
#  'well',
#  'pitcher',
#  'sexual-object',
#  'make-up',
#  'song',
#  'environment',
#  'moon',
#  'sun',
#  'rain',
#  'wind',
#  'places',
#  'interior-spaces',
#  'room',
#  'bedroom',
#  'bed',
#  'door',
#  'wall',
#  'house',
#  'tower',
#  'exterior-spaces',
#  'garden',
#  'vineyard',
#  'spring',
#  'desert',
#  'river',
#  'field',
#  'lake',
#  'groups',
#  'based-on-gender',
#  'women',
#  'men',
#  'third-sexual-group',
#  'eunuchs',
#  'based-on-orientation',
#  'heterosexuals',
#  'homosexuals',
#  'male-homosexuals',
#  'female-homosexuals',
#  'by-state',
#  'single',
#  'married',
#  'widow-widower',
#  'widow',
#  'widower',
#  'virgin',
#  'by-profession',
#  'prostitutes',
#  'female-prostitutes',
#  'male-prostitutes',
#  'sexual-priests',
#  'concubine',
#  'by-corporal-traits',
#  'circumcised',
#  'uncircumcised',
#  'animals',
#  'gazelle',
#  'deer',
#  'dove',
#  'fox',
#  'goat',
#  'sheep',
#  'leopard',
#  'lion',
#  'crow',
#  'turtledove',
#  'horse',
#  'donkey',
#  'cow',
#  'camel',
#  'plants',
#  'flowers',
#  'trees',
#  'palms',
#  'time',
#  'part-of-the-day',
#  'night',
#  'sunrise',
#  'seasons',
#  'winter',
#  'valorations',
#  'blessed-aspect',
#  'positive-aspect',
#  'neutral-aspect',
#  'negative-aspect',
#  'condemned-aspect']

# %%
import pandas as pd

verses_sexual_categories_df = pd.DataFrame(index= verses_identifiers, columns = ["bible_identifier", "bible_book", "bible_chapter", "bible_book_chapter"] + categories_names).fillna(0)

# %%
verses = documento_root_bible.xpath('.//tei:ab[@type="verse"]', namespaces = specific_namespaces, with_tail = True)

print(len(verses))

for verse in verses:

    verse_reference = verse.xpath('./@xml:id', namespaces=specific_namespaces, with_tail=True)

    print(verse_reference)

    grouped_referenced_entities = verse.xpath('.//tei:rs/@key | .//tei:q/@who | .//tei:q/@toWhom', namespaces=specific_namespaces, with_tail=True)
    entities_referenced = [entity for group_entities in grouped_referenced_entities for entity in group_entities.split(" ") ]

    for key, value in dict(Counter(entities_referenced)).items():
        verses_sexual_categories_df.loc[verse_reference, key] = value
    verses_sexual_categories_df.loc[verse_reference, "number of entities referred"] = len(entities_referenced)


    verses_sexual_categories_df.loc[verse_reference,"number of different entities referred"] =  len(set(entities_referenced))

    """
    try:
        verses_sexual_categories_df.loc[verse_reference, "most common entity id"] =  Counter(entities_referenced).most_common(1)[0][0]
    except:
        verses_sexual_categories_df.loc[verse_reference, "most common entity id"] = ""
    try:
        verses_sexual_categories_df.loc[verse_reference, "most common entity frecuency"] =  Counter(entities_referenced).most_common(1)[0][1]
    except:
        verses_sexual_categories_df.loc[verse_reference, "most common entity frecuency"] = 0
    try:
        verses_sexual_categories_df.loc[verse_reference, "second most common entity id"] =  Counter(entities_referenced).most_common(2)[1][0]
    except:
        verses_sexual_categories_df.loc[verse_reference, "second most common entity id"] = ""
    try:
        verses_sexual_categories_df.loc[verse_reference, "second most common entitity frequency"] =  Counter(entities_referenced).most_common(2)[1][1]
    except:
        verses_sexual_categories_df.loc[verse_reference, "second most common entitity frequency"] = 0 

    """

    people_referenced = [entity for entity in entities_referenced if "per" in entity]
    groups_referenced = [entity for entity in entities_referenced if "org" in entity]
    places_referenced = [entity for entity in entities_referenced if "pla" in entity]
    times_referenced = [entity for entity in entities_referenced if "tim" in entity]
    works_referenced = [entity for entity in entities_referenced if "wor" in entity]
    for key, list_ in {"number of people" : people_referenced, "number of groups" : groups_referenced, "number of places" : places_referenced,"number of times" : times_referenced ,"number of works" : works_referenced }.items():
        verses_sexual_categories_df.loc[verse_reference,key] = len(list_)
        verses_sexual_categories_df.loc[verse_reference,"number of different " + key] = len(set(list_))

    """
        if list_ == []:
            verses_sexual_categories_df.loc[verse_reference,"most frequent entitiy id "+key] = "-"
            verses_sexual_categories_df.loc[verse_reference,"most frequenct entity frequency "+key] = 0
        else:
            verses_sexual_categories_df.loc[verse_reference,"most frequent entity id "+key] = Counter(list_).most_common(1)[0][0]
            verses_sexual_categories_df.loc[verse_reference,"most frequenct entity frequency "+key] = Counter(list_).most_common(1)[0][1]
    """            
    verses_sexual_categories_df.loc[verse_reference,"number of 1st level quotations"] = len(verse.xpath('./tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 2nd level quotations"] = len(verse.xpath('./tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 3rd level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 4th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 5th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 6th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of 7th level quotations"] = len(verse.xpath('./tei:q/tei:q/tei:q/tei:q/tei:q/tei:q/tei:q', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of quotations"] = len(verse.xpath('.//tei:q', namespaces=specific_namespaces, with_tail=True))
        

    grouped_who = verse.xpath('.//tei:q/@who', namespaces=specific_namespaces, with_tail=True)
    who_entities = [entity for group_who in grouped_who for entity in group_who.split(" ") ]
    verses_sexual_categories_df.loc[verse_reference,"number of entities communicating"] = len(who_entities)
    verses_sexual_categories_df.loc[verse_reference,"number of different entities communicating"] = len(set(who_entities))
    
    grouped_toWohm = verse.xpath('.//tei:q/@toWhom', namespaces=specific_namespaces, with_tail=True)
    toWhom_entities = [entity for group_toWohm in grouped_toWohm for entity in group_toWohm.split(" ") ]
    verses_sexual_categories_df.loc[verse_reference,"number of entities receiving communication"] = len(toWhom_entities)
    verses_sexual_categories_df.loc[verse_reference,"number of different entities receiving communication"] = len(set(toWhom_entities))


    verses_sexual_categories_df.loc[verse_reference,"number of oral quotations"] = len(verse.xpath('.//tei:q[@type="oral"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of dream quotations"] = len(verse.xpath('.//tei:q[@type="dream"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of praying quotations"] = len(verse.xpath('.//tei:q[@type="prayer"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of oath quotations"] = len(verse.xpath('.//tei:q[@type="oath"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of written quotations"] = len(verse.xpath('.//tei:q[@type="written"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of song quotations"] = len(verse.xpath('.//tei:q[@type="song"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of soCalled quotations"] = len(verse.xpath('.//tei:q[@type="soCalled"]', namespaces=specific_namespaces, with_tail=True))
    verses_sexual_categories_df.loc[verse_reference,"number of idea quotations"] = len(verse.xpath('.//tei:q[@type="idea"]', namespaces=specific_namespaces, with_tail=True))
# Out:
# 31065
# ['b.GEN.001.001']
# ['b.GEN.001.002']
# ['b.GEN.001.003']
# ['b.GEN.001.004']
# ['b.GEN.001.005']
# ['b.GEN.001.006']
# ['b.GEN.001.007']
# ['b.GEN.001.008']
# ['b.GEN.001.009']
# ['b.GEN.001.010']
# ['b.GEN.001.011']
# ['b.GEN.001.012']
# ['b.GEN.001.013']
# ['b.GEN.001.014']
# ['b.GEN.001.015']
# ['b.GEN.001.016']
# ['b.GEN.001.017']
# ['b.GEN.001.018']
# ['b.GEN.001.019']
# ['b.GEN.001.020']
# ['b.GEN.001.021']
# ['b.GEN.001.022']
# ['b.GEN.001.023']
# ['b.GEN.001.024']
# ['b.GEN.001.025']
# ['b.GEN.001.026']
# ['b.GEN.001.027']
# ['b.GEN.001.028']
# ['b.GEN.001.029']
# ['b.GEN.001.030']
# ['b.GEN.001.031']
# ['b.GEN.002.001']
# ['b.GEN.002.002']
# ['b.GEN.002.003']
# ['b.GEN.002.004']
# ['b.GEN.002.005']
# ['b.GEN.002.006']
# ['b.GEN.002.007']
# ['b.GEN.002.008']
# ['b.GEN.002.009']
# ['b.GEN.002.010']
# ['b.GEN.002.011']
# ['b.GEN.002.012']
# ['b.GEN.002.013']
# ['b.GEN.002.014']
# ['b.GEN.002.015']
# ['b.GEN.002.016']
# ['b.GEN.002.017']
# ['b.GEN.002.018']
# ['b.GEN.002.019']
# ['b.GEN.002.020']
# ['b.GEN.002.021']
# ['b.GEN.002.022']
# ['b.GEN.002.023']
# ['b.GEN.002.024']
# ['b.GEN.002.025']
# ['b.GEN.003.001']
# ['b.GEN.003.002']
# ['b.GEN.003.003']
# ['b.GEN.003.004']
# ['b.GEN.003.005']
# ['b.GEN.003.006']
# ['b.GEN.003.007']
# ['b.GEN.003.008']
# ['b.GEN.003.009']
# ['b.GEN.003.010']
# ['b.GEN.003.011']
# ['b.GEN.003.012']
# ['b.GEN.003.013']
# ['b.GEN.003.014']
# ['b.GEN.003.015']
# ['b.GEN.003.016']
# ['b.GEN.003.017']
# ['b.GEN.003.018']
# ['b.GEN.003.019']
# ['b.GEN.003.020']
# ['b.GEN.003.021']
# ['b.GEN.003.022']
# ['b.GEN.003.023']
# ['b.GEN.003.024']
# ['b.GEN.004.001']
# ['b.GEN.004.002']
# ['b.GEN.004.003']
# ['b.GEN.004.004']
# ['b.GEN.004.005']
# ['b.GEN.004.006']
# ['b.GEN.004.007']
# ['b.GEN.004.008']
# ['b.GEN.004.009']
# ['b.GEN.004.010']
# ['b.GEN.004.011']
# ['b.GEN.004.012']
# ['b.GEN.004.013']
# ['b.GEN.004.014']
# ['b.GEN.004.015']
# ['b.GEN.004.016']
# ['b.GEN.004.017']
# ['b.GEN.004.018']
# ['b.GEN.004.019']
# ['b.GEN.004.020']
# ['b.GEN.004.021']
# ['b.GEN.004.022']
# ['b.GEN.004.023']
# ['b.GEN.004.024']
# ['b.GEN.004.025']
# ['b.GEN.004.026']
# ['b.GEN.005.001']
# ['b.GEN.005.002']
# ['b.GEN.005.003']
# ['b.GEN.005.004']
# ['b.GEN.005.005']
# ['b.GEN.005.006']
# ['b.GEN.005.007']
# ['b.GEN.005.008']
# ['b.GEN.005.009']
# ['b.GEN.005.010']
# ['b.GEN.005.011']
# ['b.GEN.005.012']
# ['b.GEN.005.013']
# ['b.GEN.005.014']
# ['b.GEN.005.015']
# ['b.GEN.005.016']
# ['b.GEN.005.017']
# ['b.GEN.005.018']
# ['b.GEN.005.019']
# ['b.GEN.005.020']
# ['b.GEN.005.021']
# ['b.GEN.005.022']
# ['b.GEN.005.023']
# ['b.GEN.005.024']
# ['b.GEN.005.025']
# ['b.GEN.005.026']
# ['b.GEN.005.027']
# ['b.GEN.005.028']
# ['b.GEN.005.029']
# ['b.GEN.005.030']
# ['b.GEN.005.031']
# ['b.GEN.005.032']
# ['b.GEN.006.001']
# ['b.GEN.006.002']
# ['b.GEN.006.003']
# ['b.GEN.006.004']
# ['b.GEN.006.005']
# ['b.GEN.006.006']
# ['b.GEN.006.007']
# ['b.GEN.006.008']
# ['b.GEN.006.009']
# ['b.GEN.006.010']
# ['b.GEN.006.011']
# ['b.GEN.006.012']
# ['b.GEN.006.013']
# ['b.GEN.006.014']
# ['b.GEN.006.015']
# ['b.GEN.006.016']
# ['b.GEN.006.017']
# ['b.GEN.006.018']
# ['b.GEN.006.019']
# ['b.GEN.006.020']
# ['b.GEN.006.021']
# ['b.GEN.006.022']
# ['b.GEN.007.001']
# ['b.GEN.007.002']
# ['b.GEN.007.003']
# ['b.GEN.007.004']
# ['b.GEN.007.005']
# ['b.GEN.007.006']
# ['b.GEN.007.007']
# ['b.GEN.007.008']
# ['b.GEN.007.009']
# ['b.GEN.007.010']
# ['b.GEN.007.011']
# ['b.GEN.007.012']
# ['b.GEN.007.013']
# ['b.GEN.007.014']
# ['b.GEN.007.015']
# ['b.GEN.007.016']
# ['b.GEN.007.017']
# ['b.GEN.007.018']
# ['b.GEN.007.019']
# ['b.GEN.007.020']
# ['b.GEN.007.021']
# ['b.GEN.007.022']
# ['b.GEN.007.023']
# ['b.GEN.007.024']
# ['b.GEN.008.001']
# ['b.GEN.008.002']
# ['b.GEN.008.003']
# ['b.GEN.008.004']
# ['b.GEN.008.005']
# ['b.GEN.008.006']
# ['b.GEN.008.007']
# ['b.GEN.008.008']
# ['b.GEN.008.009']
# ['b.GEN.008.010']
# ['b.GEN.008.011']
# ['b.GEN.008.012']
# ['b.GEN.008.013']
# ['b.GEN.008.014']
# ['b.GEN.008.015']
# ['b.GEN.008.016']
# ['b.GEN.008.017']
# ['b.GEN.008.018']
# ['b.GEN.008.019']
# ['b.GEN.008.020']
# ['b.GEN.008.021']
# ['b.GEN.008.022']
# ['b.GEN.009.001']
# ['b.GEN.009.002']
# ['b.GEN.009.003']
# ['b.GEN.009.004']
# ['b.GEN.009.005']
# ['b.GEN.009.006']
# ['b.GEN.009.007']
# ['b.GEN.009.008']
# ['b.GEN.009.009']
# ['b.GEN.009.010']
# ['b.GEN.009.011']
# ['b.GEN.009.012']
# ['b.GEN.009.013']
# ['b.GEN.009.014']
# ['b.GEN.009.015']
# ['b.GEN.009.016']
# ['b.GEN.009.017']
# ['b.GEN.009.018']
# ['b.GEN.009.019']
# ['b.GEN.009.020']
# ['b.GEN.009.021']
# ['b.GEN.009.022']
# ['b.GEN.009.023']
# ['b.GEN.009.024']
# ['b.GEN.009.025']
# ['b.GEN.009.026']
# ['b.GEN.009.027']
# ['b.GEN.009.028']
# ['b.GEN.009.029']
# ['b.GEN.010.001']
# ['b.GEN.010.002']
# ['b.GEN.010.003']
# ['b.GEN.010.004']
# ['b.GEN.010.005']
# ['b.GEN.010.006']
# ['b.GEN.010.007']
# ['b.GEN.010.008']
# ['b.GEN.010.009']
# ['b.GEN.010.010']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-10869d6b2791> in <module>
#      45     works_referenced = [entity for entity in entities_referenced if "wor" in entity]
#      46     for key, list_ in {"number of people" : people_referenced, "number of groups" : groups_referenced, "number of places" : places_referenced,"number of times" : times_referenced ,"number of works" : works_referenced }.items():
# ---> 47         verses_sexual_categories_df.loc[verse_reference,key] = len(list_)
#      48         verses_sexual_categories_df.loc[verse_reference,"number of different " + key] = len(set(list_))
#      49
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     668             key = com.apply_if_callable(key, self.obj)
#     669         indexer = self._get_setitem_indexer(key)
# --> 670         self._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value)
#    1026                 # scalar
#    1027                 for item in labels:
# -> 1028                     setter(item, value)
#    1029
#    1030         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in setter(item, v)
#     963
#     964                 # reset the sliced object if unique
# --> 965                 self.obj[item] = s
#     966
#     967             # we need an iterable, with a ndim of at least 1
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2999         self._ensure_valid_index(value)
#    3000         value = self._sanitize_column(key, value)
# -> 3001         NDFrame._set_item(self, key, value)
#    3002
#    3003         # check if we are modifying a copy
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_item(self, key, value)
#    3622
#    3623     def _set_item(self, key, value) -> None:
# -> 3624         self._data.set(key, value)
#    3625         self._clear_item_cache()
#    3626
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in set(self, item, value)
#    1088             blk_locs = blklocs[val_locs.indexer]
#    1089             if blk.should_store(value):
# -> 1090                 blk.set(blk_locs, value_getitem(val_locs))
#    1091             else:
#    1092                 unfit_mgr_locs.append(blk.mgr_locs.as_array[blk_locs])
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in set(self, locs, values)
#     374         None
#     375         """
# --> 376         self.values[locs] = values
#     377
#     378     def delete(self, loc):
#
# KeyboardInterrupt:

# %%
verses_sexual_categories_df.sum(axis=0).sort_values(ascending=False).head(50)
# Out:
# number of entities referred                             147898.0
# number of different entities referred                   101388.0
# number of people                                         82249.0
# number of different number of people                     54472.0
# number of groups                                         46160.0
# number of different number of groups                     31529.0
# number of entities receiving communication               30284.0
# number of entities communicating                         27135.0
# number of quotations                                     26702.0
# number of different entities receiving communication     26595.0
# number of different entities communicating               24251.0
# #per14                                                   23692.0
# number of oral quotations                                20077.0
# number of 1st level quotations                           18815.0
# number of places                                         18276.0
# number of different number of places                     14389.0
# #org70                                                   10576.0
# #org0                                                     7390.0
# number of 2nd level quotations                            5417.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2407.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1413.0
# #org3                                                     1302.0
# #org19                                                    1281.0
# #org24                                                    1267.0
# #pla3                                                     1251.0
# #org12                                                    1243.0
# #org18                                                    1238.0
# number of written quotations                              1211.0
# #per845                                                   1141.0
# #org25                                                    1043.0
# #pla5                                                     1025.0
# #pla41                                                     983.0
# #per500                                                    948.0
# #per4                                                      906.0
# #pla30                                                     901.0
# #org4                                                      887.0
# #pla2                                                      798.0
# #org100                                                    793.0
# #per522                                                    759.0
# #per851                                                    728.0
# #per473                                                    706.0
# dtype: float64

# %%
verses_sexual_categories_df
# Out:
#                bible_identifier  bible_book  bible_chapter  \
# b.GEN.001.001                 0           0              0
# b.GEN.001.002                 0           0              0
# b.GEN.001.003                 0           0              0
# b.GEN.001.004                 0           0              0
# b.GEN.001.005                 0           0              0
# ...                         ...         ...            ...
# b.REV.022.017                 0           0              0
# b.REV.022.018                 0           0              0
# b.REV.022.019                 0           0              0
# b.REV.022.020                 0           0              0
# b.REV.022.021                 0           0              0
#
#                bible_book_chapter  relations  monogamy  poligamy  marriage  \
# b.GEN.001.001                   0          0         0         0         0
# b.GEN.001.002                   0          0         0         0         0
# b.GEN.001.003                   0          0         0         0         0
# b.GEN.001.004                   0          0         0         0         0
# b.GEN.001.005                   0          0         0         0         0
# ...                           ...        ...       ...       ...       ...
# b.REV.022.017                   0          0         0         0         0
# b.REV.022.018                   0          0         0         0         0
# b.REV.022.019                   0          0         0         0         0
# b.REV.022.020                   0          0         0         0         0
# b.REV.022.021                   0          0         0         0         0
#
#                second-marriage  second-marriage-divorce  ...  #org439  #pla65  \
# b.GEN.001.001                0                        0  ...      NaN     NaN
# b.GEN.001.002                0                        0  ...      NaN     NaN
# b.GEN.001.003                0                        0  ...      NaN     NaN
# b.GEN.001.004                0                        0  ...      NaN     NaN
# b.GEN.001.005                0                        0  ...      NaN     NaN
# ...                        ...                      ...  ...      ...     ...
# b.REV.022.017                0                        0  ...      NaN     NaN
# b.REV.022.018                0                        0  ...      NaN     NaN
# b.REV.022.019                0                        0  ...      NaN     NaN
# b.REV.022.020                0                        0  ...      NaN     NaN
# b.REV.022.021                0                        0  ...      NaN     NaN
#
#                #pla68  #per116  #per119  #pla67  #org52  #per129  #pla74  \
# b.GEN.001.001     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.002     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.003     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.004     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.GEN.001.005     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# ...               ...      ...      ...     ...     ...      ...     ...
# b.REV.022.017     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.REV.022.018     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.REV.022.019     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.REV.022.020     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# b.REV.022.021     NaN      NaN      NaN     NaN     NaN      NaN     NaN
#
#                #pla75
# b.GEN.001.001     NaN
# b.GEN.001.002     NaN
# b.GEN.001.003     NaN
# b.GEN.001.004     NaN
# b.GEN.001.005     NaN
# ...               ...
# b.REV.022.017     NaN
# b.REV.022.018     NaN
# b.REV.022.019     NaN
# b.REV.022.020     NaN
# b.REV.022.021     NaN
#
# [31065 rows x 4164 columns]

# %%
verses_sexual_categories_df.sum()
# Out:
# bible_identifier       0.0
# bible_book             0.0
# bible_chapter          0.0
# bible_book_chapter     0.0
# relations              0.0
#                       ...
# #pla67                 1.0
# #org52                27.0
# #per129                4.0
# #pla74                 1.0
# #pla75                 1.0
# Length: 4164, dtype: float64

# %%
#verses_sexual_categories_df.to_csv("../../../resulting data/verses_structural_features.tsv", sep="\t")

# %%
verses_sexual_categories_df.to_parquet("../../../resulting data/verses_structural_features.parquet", engine =  'pyarrow')

# %%
span_grps = documento_root_bible.xpath('.//tei:spanGrp', namespaces = specific_namespaces, with_tail = True)
verses_sexual_themes = []
for span_grp in span_grps:
    sexual_theme = span_grp.xpath('./tei:span/@ana', namespaces = specific_namespaces, with_tail = True)[0]
    verse = span_grp.xpath('./@inst', namespaces = specific_namespaces, with_tail = True)[0]
    
    verse = verse[1:]

    verses_sexual_categories_df.loc[verse, sexual_theme] = 1

# %%
verses_sexual_categories_df["bible_book"] = verses_sexual_categories_df.index.str.extract("b\.(...).+$")

# %%
verses_sexual_categories_df["bible_identifier"] = verses_sexual_categories_df.index.tolist()

# %%
verses_sexual_categories_df["number of people"].sum()
# Out:
# 82249.0

# %%
verses_sexual_categories_df.dtypes
# Out:
# bible_identifier       object
# bible_book             object
# bible_chapter           int64
# bible_book_chapter      int64
# relations               int64
#                        ...
# #pla67                float64
# #org52                float64
# #per129               float64
# #pla74                float64
# #pla75                float64
# Length: 4164, dtype: object

# %%
#verses_sexual_categories_df.to_csv("../../../resulting data/verses_features.tsv", sep="\t")

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet", engine =  'pyarrow')

# %%
#verses_sexual_categories_df = pd.read_parquet("../../../resulting data/verses_features.parquet")

# %%
verses_sexual_categories_df.shape
# Out:
# (31065, 4164)

# %%
verses_sexual_categories_df
# Out:
#               bible_identifier bible_book  bible_chapter  bible_book_chapter  \
# b.GEN.001.001    b.GEN.001.001        NaN              0                   0
# b.GEN.001.002    b.GEN.001.002        NaN              0                   0
# b.GEN.001.003    b.GEN.001.003        NaN              0                   0
# b.GEN.001.004    b.GEN.001.004        NaN              0                   0
# b.GEN.001.005    b.GEN.001.005        NaN              0                   0
# ...                        ...        ...            ...                 ...
# b.REV.022.017    b.REV.022.017        NaN              0                   0
# b.REV.022.018    b.REV.022.018        NaN              0                   0
# b.REV.022.019    b.REV.022.019        NaN              0                   0
# b.REV.022.020    b.REV.022.020        NaN              0                   0
# b.REV.022.021    b.REV.022.021        NaN              0                   0
#
#                relations  monogamy  poligamy  marriage  second-marriage  \
# b.GEN.001.001          0         0         0         0                0
# b.GEN.001.002          0         0         0         0                0
# b.GEN.001.003          0         0         0         0                0
# b.GEN.001.004          0         0         0         0                0
# b.GEN.001.005          0         0         0         0                0
# ...                  ...       ...       ...       ...              ...
# b.REV.022.017          0         0         0         0                0
# b.REV.022.018          0         0         0         0                0
# b.REV.022.019          0         0         0         0                0
# b.REV.022.020          0         0         0         0                0
# b.REV.022.021          0         0         0         0                0
#
#                second-marriage-divorce  ...  #org439  #pla65  #pla68  #per116  \
# b.GEN.001.001                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.002                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.003                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.004                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.005                        0  ...      NaN     NaN     NaN      NaN
# ...                                ...  ...      ...     ...     ...      ...
# b.REV.022.017                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.018                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.019                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.020                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.021                        0  ...      NaN     NaN     NaN      NaN
#
#                #per119  #pla67  #org52  #per129  #pla74  #pla75
# b.GEN.001.001      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.002      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.003      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.004      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.005      NaN     NaN     NaN      NaN     NaN     NaN
# ...                ...     ...     ...      ...     ...     ...
# b.REV.022.017      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.018      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.019      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.020      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.021      NaN     NaN     NaN      NaN     NaN     NaN
#
# [31065 rows x 4164 columns]

# %%
verses_sexual_categories_df.select_dtypes(include="number").sum(axis=0).sort_values(ascending=False).head(50)
# Out:
# number of entities referred                             147898.0
# number of different entities referred                   101388.0
# number of people                                         82249.0
# number of different number of people                     54472.0
# number of groups                                         46160.0
# number of different number of groups                     31529.0
# number of entities receiving communication               30284.0
# number of entities communicating                         27135.0
# number of quotations                                     26702.0
# number of different entities receiving communication     26595.0
# number of different entities communicating               24251.0
# #per14                                                   23692.0
# number of oral quotations                                20077.0
# number of 1st level quotations                           18815.0
# number of places                                         18276.0
# number of different number of places                     14389.0
# #org70                                                   10576.0
# #org0                                                     7390.0
# number of 2nd level quotations                            5417.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2407.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1413.0
# #org3                                                     1302.0
# #org19                                                    1281.0
# #org24                                                    1267.0
# #pla3                                                     1251.0
# #org12                                                    1243.0
# #org18                                                    1238.0
# number of written quotations                              1211.0
# #per845                                                   1141.0
# #org25                                                    1043.0
# #pla5                                                     1025.0
# #pla41                                                     983.0
# #per500                                                    948.0
# #per4                                                      906.0
# #pla30                                                     901.0
# #org4                                                      887.0
# #pla2                                                      798.0
# #org100                                                    793.0
# #per522                                                    759.0
# #per851                                                    728.0
# #per473                                                    706.0
# dtype: float64

# %%
verses_sexual_categories_df["bible_book"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\.(...).+$")

# %%
verses_sexual_categories_df["bible_book_chapter"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\.(...\.\d+).+$")

# %%
verses_sexual_categories_df["bible_chapter"] = verses_sexual_categories_df["bible_identifier"].str.extract("b\....\.(\d+).+$")

# %%
verses_sexual_categories_df
# Out:
#               bible_identifier bible_book bible_chapter bible_book_chapter  \
# b.GEN.001.001    b.GEN.001.001        GEN           001            GEN.001
# b.GEN.001.002    b.GEN.001.002        GEN           001            GEN.001
# b.GEN.001.003    b.GEN.001.003        GEN           001            GEN.001
# b.GEN.001.004    b.GEN.001.004        GEN           001            GEN.001
# b.GEN.001.005    b.GEN.001.005        GEN           001            GEN.001
# ...                        ...        ...           ...                ...
# b.REV.022.017    b.REV.022.017        REV           022            REV.022
# b.REV.022.018    b.REV.022.018        REV           022            REV.022
# b.REV.022.019    b.REV.022.019        REV           022            REV.022
# b.REV.022.020    b.REV.022.020        REV           022            REV.022
# b.REV.022.021    b.REV.022.021        REV           022            REV.022
#
#                relations  monogamy  poligamy  marriage  second-marriage  \
# b.GEN.001.001          0         0         0         0                0
# b.GEN.001.002          0         0         0         0                0
# b.GEN.001.003          0         0         0         0                0
# b.GEN.001.004          0         0         0         0                0
# b.GEN.001.005          0         0         0         0                0
# ...                  ...       ...       ...       ...              ...
# b.REV.022.017          0         0         0         0                0
# b.REV.022.018          0         0         0         0                0
# b.REV.022.019          0         0         0         0                0
# b.REV.022.020          0         0         0         0                0
# b.REV.022.021          0         0         0         0                0
#
#                second-marriage-divorce  ...  #org439  #pla65  #pla68  #per116  \
# b.GEN.001.001                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.002                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.003                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.004                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.005                        0  ...      NaN     NaN     NaN      NaN
# ...                                ...  ...      ...     ...     ...      ...
# b.REV.022.017                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.018                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.019                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.020                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.021                        0  ...      NaN     NaN     NaN      NaN
#
#                #per119  #pla67  #org52  #per129  #pla74  #pla75
# b.GEN.001.001      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.002      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.003      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.004      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.005      NaN     NaN     NaN      NaN     NaN     NaN
# ...                ...     ...     ...      ...     ...     ...
# b.REV.022.017      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.018      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.019      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.020      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.021      NaN     NaN     NaN      NaN     NaN     NaN
#
# [31065 rows x 4164 columns]

# %%
verses_sexual_categories_df.select_dtypes(include=['int16', 'int32', 'int64', 'float16', 'float32', 'float64']).sum(axis = 0).sort_values(ascending=False).head(30)
# Out:
# number of entities referred                             147898.0
# number of different entities referred                   101388.0
# number of people                                         82249.0
# number of different number of people                     54472.0
# number of groups                                         46160.0
# number of different number of groups                     31529.0
# number of entities receiving communication               30284.0
# number of entities communicating                         27135.0
# number of quotations                                     26702.0
# number of different entities receiving communication     26595.0
# number of different entities communicating               24251.0
# #per14                                                   23692.0
# number of oral quotations                                20077.0
# number of 1st level quotations                           18815.0
# number of places                                         18276.0
# number of different number of places                     14389.0
# #org70                                                   10576.0
# #org0                                                     7390.0
# number of 2nd level quotations                            5417.0
# #per1                                                     5347.0
# #per26                                                    4933.0
# #per35                                                    3434.0
# number of idea quotations                                 2463.0
# #pla4                                                     2407.0
# number of 3rd level quotations                            2268.0
# number of praying quotations                              2041.0
# #per859                                                   1909.0
# #per15                                                    1704.0
# #org39                                                    1653.0
# #per39                                                    1413.0
# dtype: float64

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet", engine =  'pyarrow')

# %%
#verses_sexual_categories_df = pd.read_parquet("../../../resulting data/verses_features.parquet")

# %%
verses_sexual_categories_df
# Out:
#               bible_identifier bible_book bible_chapter bible_book_chapter  \
# b.GEN.001.001    b.GEN.001.001        GEN           001            GEN.001
# b.GEN.001.002    b.GEN.001.002        GEN           001            GEN.001
# b.GEN.001.003    b.GEN.001.003        GEN           001            GEN.001
# b.GEN.001.004    b.GEN.001.004        GEN           001            GEN.001
# b.GEN.001.005    b.GEN.001.005        GEN           001            GEN.001
# ...                        ...        ...           ...                ...
# b.REV.022.017    b.REV.022.017        REV           022            REV.022
# b.REV.022.018    b.REV.022.018        REV           022            REV.022
# b.REV.022.019    b.REV.022.019        REV           022            REV.022
# b.REV.022.020    b.REV.022.020        REV           022            REV.022
# b.REV.022.021    b.REV.022.021        REV           022            REV.022
#
#                relations  monogamy  poligamy  marriage  second-marriage  \
# b.GEN.001.001          0         0         0         0                0
# b.GEN.001.002          0         0         0         0                0
# b.GEN.001.003          0         0         0         0                0
# b.GEN.001.004          0         0         0         0                0
# b.GEN.001.005          0         0         0         0                0
# ...                  ...       ...       ...       ...              ...
# b.REV.022.017          0         0         0         0                0
# b.REV.022.018          0         0         0         0                0
# b.REV.022.019          0         0         0         0                0
# b.REV.022.020          0         0         0         0                0
# b.REV.022.021          0         0         0         0                0
#
#                second-marriage-divorce  ...  #org439  #pla65  #pla68  #per116  \
# b.GEN.001.001                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.002                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.003                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.004                        0  ...      NaN     NaN     NaN      NaN
# b.GEN.001.005                        0  ...      NaN     NaN     NaN      NaN
# ...                                ...  ...      ...     ...     ...      ...
# b.REV.022.017                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.018                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.019                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.020                        0  ...      NaN     NaN     NaN      NaN
# b.REV.022.021                        0  ...      NaN     NaN     NaN      NaN
#
#                #per119  #pla67  #org52  #per129  #pla74  #pla75
# b.GEN.001.001      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.002      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.003      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.004      NaN     NaN     NaN      NaN     NaN     NaN
# b.GEN.001.005      NaN     NaN     NaN      NaN     NaN     NaN
# ...                ...     ...     ...      ...     ...     ...
# b.REV.022.017      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.018      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.019      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.020      NaN     NaN     NaN      NaN     NaN     NaN
# b.REV.022.021      NaN     NaN     NaN      NaN     NaN     NaN
#
# [31065 rows x 4164 columns]

# %%
books = pd.ExcelFile("../../../documentation/books.xlsx").parse('Sheet1')

# %%
books
# Out:
#     Unnamed: 0  bible  id title_Spanish testament  encoded title_English  \
# 0            0  bible   1       Génesis       old        1       Genesis
# 1            1  bible   2         Éxodo       old        1        Exodus
# 2            2  bible   3      Levítico       old        1     Leviticus
# 3            3  bible   4       Números       old        1       Numbers
# 4            4  bible   5  Deuteronomio       old        1   Deuteronomy
# ..         ...    ...  ..           ...       ...      ...           ...
# 61          61  bible  62        1 Juan       new        1        1 John
# 62          62  bible  63        2 Juan       new        1        2 John
# 63          63  bible  64        3 Juan       new        1        3 John
# 64          64  bible  65         Judas       new        1          Jude
# 65          65  bible  66   Apocalipsis       new        1    Revelation
#
#    codebook  chaptersc        genre   latitude  longitude topical bible  \
# 0       GEN         50   historical  32.615687  36.793083           Gen
# 1       EXO         40   historical  30.469969  33.843280          Exod
# 2       LEV         27          law  30.521765  34.112561           Lev
# 3       NUM         36          law  31.221618  34.841433           Num
# 4       DEU         34          law  31.506106  35.735247          Deut
# ..      ...        ...          ...        ...        ...           ...
# 61      1JO          5       letter        NaN        NaN         1John
# 62      2JO          1       letter        NaN        NaN         2John
# 63      3JO          1       letter        NaN        NaN         3John
# 64      JUD          1       letter  26.820553  30.802498          Jude
# 65      REV         22  apocalyptic  34.707841  33.514733           Rev
#
#       wikid sexual_annotation
# 0     Q9184                 1
# 1     Q9190               NaN
# 2    Q41490               NaN
# 3    Q43099               NaN
# 4    Q42614               NaN
# ..      ...               ...
# 61  Q131101               NaN
# 62  Q131453               NaN
# 63  Q131462               NaN
# 64  Q131466               NaN
# 65   Q42040                 1
#
# [66 rows x 15 columns]

# %%
verses_sexual_categories_df = pd.merge(verses_sexual_categories_df, books[["genre", "codebook"]], left_on="bible_book", right_on="codebook")

# %%
verses_sexual_categories_df.drop(["codebook"], axis="columns", inplace=True)

# %%
verses_sexual_categories_df.columns.tolist()[4:-2][0:10]
# Out:
# ['relations',
#  'monogamy',
#  'poligamy',
#  'marriage',
#  'second-marriage',
#  'second-marriage-divorce',
#  'second-marriage-widow',
#  'interfaith-marriage',
#  'interfaith-relation',
#  'non-marital-relation']

# %%
verses_sexual_categories_df = verses_sexual_categories_df[
    verses_sexual_categories_df.columns.tolist()[0:4] +
    [verses_sexual_categories_df.columns.tolist()[-1]] + 
    verses_sexual_categories_df.columns.tolist()[4:-2]
    ]

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier bible_book bible_chapter bible_book_chapter  \
# 0        b.GEN.001.001        GEN           001            GEN.001
# 1        b.GEN.001.002        GEN           001            GEN.001
# 2        b.GEN.001.003        GEN           001            GEN.001
# 3        b.GEN.001.004        GEN           001            GEN.001
# 4        b.GEN.001.005        GEN           001            GEN.001
# ...                ...        ...           ...                ...
# 31060    b.REV.022.017        REV           022            REV.022
# 31061    b.REV.022.018        REV           022            REV.022
# 31062    b.REV.022.019        REV           022            REV.022
# 31063    b.REV.022.020        REV           022            REV.022
# 31064    b.REV.022.021        REV           022            REV.022
#
#              genre  relations  monogamy  poligamy  marriage  second-marriage  \
# 0       historical          0         0         0         0                0
# 1       historical          0         0         0         0                0
# 2       historical          0         0         0         0                0
# 3       historical          0         0         0         0                0
# 4       historical          0         0         0         0                0
# ...            ...        ...       ...       ...       ...              ...
# 31060  apocalyptic          0         0         0         0                0
# 31061  apocalyptic          0         0         0         0                0
# 31062  apocalyptic          0         0         0         0                0
# 31063  apocalyptic          0         0         0         0                0
# 31064  apocalyptic          0         0         0         0                0
#
#        ...  #org35  #org439  #pla65  #pla68  #per116  #per119  #pla67  #org52  \
# 0      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 1      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 2      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 3      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 4      ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# ...    ...     ...      ...     ...     ...      ...      ...     ...     ...
# 31060  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31061  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31062  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31063  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
# 31064  ...     NaN      NaN     NaN     NaN      NaN      NaN     NaN     NaN
#
#        #per129  #pla74
# 0          NaN     NaN
# 1          NaN     NaN
# 2          NaN     NaN
# 3          NaN     NaN
# 4          NaN     NaN
# ...        ...     ...
# 31060      NaN     NaN
# 31061      NaN     NaN
# 31062      NaN     NaN
# 31063      NaN     NaN
# 31064      NaN     NaN
#
# [31065 rows x 4164 columns]

# %%
standard_frequencies_twitter = pd.read_csv("../../../other data sets/standard-frequencies-twitter-2014-2015.tsv", sep="\t")

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
#standard_frequencies_twitter["old_reference_standard"] =  standard_frequencies_twitter["reference_standard"]

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\.)(\d)(\..*)",r"\1__\2\3")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\.)(\d\d)(\..*)",r"\1_\2\3")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\....\.)(.)$",r"\1__\2")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"(b\....\....\.)(..)$",r"\1_\2")

# %%
standard_frequencies_twitter["reference_standard"] = standard_frequencies_twitter["reference_standard"].str.replace(r"_",r"0")

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
standard_frequencies_twitter.rename(columns={'2014': 'twitter_freq_2014', '2015': 'twitter_freq_2015', "sum-2014-2015": "twitter_freq_sum_2014_2015",}, inplace=True)

# %%
standard_frequencies_twitter
# Out:
#        Unnamed: 0 Unnamed: 0.1  chapter  verse book_standard  \
# 0               0    b.1CH.1.1        1      1           1CH
# 1               1   b.1CH.1.10        1     10           1CH
# 2               2   b.1CH.1.11        1     11           1CH
# 3               3   b.1CH.1.12        1     12           1CH
# 4               4   b.1CH.1.13        1     13           1CH
# ...           ...          ...      ...    ...           ...
# 31099       31099    b.ZEP.3.5        3      5           ZEP
# 31100       31100    b.ZEP.3.6        3      6           ZEP
# 31101       31101    b.ZEP.3.7        3      7           ZEP
# 31102       31102    b.ZEP.3.8        3      8           ZEP
# 31103       31103    b.ZEP.3.9        3      9           ZEP
#
#       reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0          b.1CH.001.001                         575                200
# 1          b.1CH.001.010                         323                 93
# 2          b.1CH.001.011                         278                 72
# 3          b.1CH.001.012                         297                 79
# 4          b.1CH.001.013                         278                 70
# ...                  ...                         ...                ...
# 31099      b.ZEP.003.005                         515                256
# 31100      b.ZEP.003.006                         104                 50
# 31101      b.ZEP.003.007                         159                 87
# 31102      b.ZEP.003.008                         454                242
# 31103      b.ZEP.003.009                         767                421
#
#        twitter_freq_2015  mean-2014-2015  std-2014-2015  numerical-id  \
# 0                    375           287.5     123.743687      13001001
# 1                    230           161.5      96.873629      13001010
# 2                    206           139.0      94.752309      13001011
# 3                    218           148.5      98.287843      13001012
# 4                    208           139.0      97.580736      13001013
# ...                  ...             ...            ...           ...
# 31099                259           257.5       2.121320      36003005
# 31100                 54            52.0       2.828427      36003006
# 31101                 72            79.5      10.606602      36003007
# 31102                212           227.0      21.213203      36003008
# 31103                346           383.5      53.033009      36003009
#
#             OSIS book_OSIS old_reference_standard
# 0       1Chr.1.1      1Chr              b.1CH.1.1
# 1      1Chr.1.10      1Chr             b.1CH.1.10
# 2      1Chr.1.11      1Chr             b.1CH.1.11
# 3      1Chr.1.12      1Chr             b.1CH.1.12
# 4      1Chr.1.13      1Chr             b.1CH.1.13
# ...          ...       ...                    ...
# 31099   Zeph.3.5      Zeph              b.ZEP.3.5
# 31100   Zeph.3.6      Zeph              b.ZEP.3.6
# 31101   Zeph.3.7      Zeph              b.ZEP.3.7
# 31102   Zeph.3.8      Zeph              b.ZEP.3.8
# 31103   Zeph.3.9      Zeph              b.ZEP.3.9
#
# [31104 rows x 15 columns]

# %%
#standard_frequencies_twitter.to_csv("../../../../datos/stephen-smit/standard-frequencies-twitter-2014-2015.tsv", sep="\t")

# %%
verses_sexual_categories_df = pd.merge(verses_sexual_categories_df, standard_frequencies_twitter[["reference_standard","twitter_freq_sum_2014_2015","twitter_freq_2014","twitter_freq_2015"]], left_on="bible_identifier", right_on="reference_standard")

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier bible_book bible_chapter bible_book_chapter  \
# 0        b.GEN.001.001        GEN           001            GEN.001
# 1        b.GEN.001.002        GEN           001            GEN.001
# 2        b.GEN.001.003        GEN           001            GEN.001
# 3        b.GEN.001.004        GEN           001            GEN.001
# 4        b.GEN.001.005        GEN           001            GEN.001
# ...                ...        ...           ...                ...
# 31060    b.REV.022.017        REV           022            REV.022
# 31061    b.REV.022.018        REV           022            REV.022
# 31062    b.REV.022.019        REV           022            REV.022
# 31063    b.REV.022.020        REV           022            REV.022
# 31064    b.REV.022.021        REV           022            REV.022
#
#              genre  relations  monogamy  poligamy  marriage  second-marriage  \
# 0       historical          0         0         0         0                0
# 1       historical          0         0         0         0                0
# 2       historical          0         0         0         0                0
# 3       historical          0         0         0         0                0
# 4       historical          0         0         0         0                0
# ...            ...        ...       ...       ...       ...              ...
# 31060  apocalyptic          0         0         0         0                0
# 31061  apocalyptic          0         0         0         0                0
# 31062  apocalyptic          0         0         0         0                0
# 31063  apocalyptic          0         0         0         0                0
# 31064  apocalyptic          0         0         0         0                0
#
#        ...  #per116  #per119  #pla67  #org52  #per129  #pla74  \
# 0      ...      NaN      NaN     NaN     NaN      NaN     NaN
# 1      ...      NaN      NaN     NaN     NaN      NaN     NaN
# 2      ...      NaN      NaN     NaN     NaN      NaN     NaN
# 3      ...      NaN      NaN     NaN     NaN      NaN     NaN
# 4      ...      NaN      NaN     NaN     NaN      NaN     NaN
# ...    ...      ...      ...     ...     ...      ...     ...
# 31060  ...      NaN      NaN     NaN     NaN      NaN     NaN
# 31061  ...      NaN      NaN     NaN     NaN      NaN     NaN
# 31062  ...      NaN      NaN     NaN     NaN      NaN     NaN
# 31063  ...      NaN      NaN     NaN     NaN      NaN     NaN
# 31064  ...      NaN      NaN     NaN     NaN      NaN     NaN
#
#        reference_standard  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0           b.GEN.001.001                       49268              26376
# 1           b.GEN.001.002                        8601               3693
# 2           b.GEN.001.003                       20970               8816
# 3           b.GEN.001.004                        4222               2286
# 4           b.GEN.001.005                        3208               1666
# ...                   ...                         ...                ...
# 31060       b.REV.022.017                        8693               4633
# 31061       b.REV.022.018                        4396               1939
# 31062       b.REV.022.019                        3947               1952
# 31063       b.REV.022.020                       11981               6014
# 31064       b.REV.022.021                       10466               3780
#
#        twitter_freq_2015
# 0                  22892
# 1                   4908
# 2                  12154
# 3                   1936
# 4                   1542
# ...                  ...
# 31060               4060
# 31061               2457
# 31062               1995
# 31063               5967
# 31064               6686
#
# [31065 rows x 4168 columns]

# %%
verses_sexual_categories_df = verses_sexual_categories_df[
    verses_sexual_categories_df.columns.tolist()[0:5] +
    verses_sexual_categories_df.columns.tolist()[-3:] + 
    verses_sexual_categories_df.columns.tolist()[5:-4]
    ]

# %%
verses_sexual_categories_df
# Out:
#       bible_identifier bible_book bible_chapter bible_book_chapter  \
# 0        b.GEN.001.001        GEN           001            GEN.001
# 1        b.GEN.001.002        GEN           001            GEN.001
# 2        b.GEN.001.003        GEN           001            GEN.001
# 3        b.GEN.001.004        GEN           001            GEN.001
# 4        b.GEN.001.005        GEN           001            GEN.001
# ...                ...        ...           ...                ...
# 31060    b.REV.022.017        REV           022            REV.022
# 31061    b.REV.022.018        REV           022            REV.022
# 31062    b.REV.022.019        REV           022            REV.022
# 31063    b.REV.022.020        REV           022            REV.022
# 31064    b.REV.022.021        REV           022            REV.022
#
#              genre  twitter_freq_sum_2014_2015  twitter_freq_2014  \
# 0       historical                       49268              26376
# 1       historical                        8601               3693
# 2       historical                       20970               8816
# 3       historical                        4222               2286
# 4       historical                        3208               1666
# ...            ...                         ...                ...
# 31060  apocalyptic                        8693               4633
# 31061  apocalyptic                        4396               1939
# 31062  apocalyptic                        3947               1952
# 31063  apocalyptic                       11981               6014
# 31064  apocalyptic                       10466               3780
#
#        twitter_freq_2015  relations  monogamy  ...  #org35  #org439  #pla65  \
# 0                  22892          0         0  ...     NaN      NaN     NaN
# 1                   4908          0         0  ...     NaN      NaN     NaN
# 2                  12154          0         0  ...     NaN      NaN     NaN
# 3                   1936          0         0  ...     NaN      NaN     NaN
# 4                   1542          0         0  ...     NaN      NaN     NaN
# ...                  ...        ...       ...  ...     ...      ...     ...
# 31060               4060          0         0  ...     NaN      NaN     NaN
# 31061               2457          0         0  ...     NaN      NaN     NaN
# 31062               1995          0         0  ...     NaN      NaN     NaN
# 31063               5967          0         0  ...     NaN      NaN     NaN
# 31064               6686          0         0  ...     NaN      NaN     NaN
#
#        #pla68  #per116  #per119  #pla67  #org52  #per129  #pla74
# 0         NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 1         NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 2         NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 3         NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 4         NaN      NaN      NaN     NaN     NaN      NaN     NaN
# ...       ...      ...      ...     ...     ...      ...     ...
# 31060     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 31061     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 31062     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 31063     NaN      NaN      NaN     NaN     NaN      NaN     NaN
# 31064     NaN      NaN      NaN     NaN     NaN      NaN     NaN
#
# [31065 rows x 4167 columns]

# %%
verses_sexual_categories_df.to_parquet("./../../../resulting data/verses_features.parquet", engine="pyarrow")

# %% [markdown]
# # Tokenize

# %%
documento_root.xpath('.//tei:standOff//tei:span[./tei:certainty/@cert="high" or ./tei:certainty/@cert="medium"]/@ana', namespaces = specific_namespaces, with_tail = True)[0:10]
# Out:
# ['blessed-aspect',
#  'blessed-aspect',
#  'rib',
#  'sleep',
#  'blessed-aspect',
#  'rib',
#  'sleep',
#  'body',
#  'women',
#  'men']

# %%
for verse in documento_root.xpath('.//tei:ab[@type="verse"]', namespaces = specific_namespaces, with_tail = True)[0:100]:
    #print(verse.xpath("./@xml:id", namespaces = specific_namespaces))
    verse_str = str(etree.tostring(verse))
    #print(type(verse_str))
    verse_str = re.sub(r"(\\t|\\n)+", r"", verse_str, flags=re.DOTALL)
    verse_str = re.sub(r'<ab xmlns="http://www.tei-c.org/ns/1.0" .*?>', r"", verse_str)
    verse_str = re.sub(r'</.*?>', r"", verse_str)
    verse_str = re.sub(r'<(.*?)"(.*?)"(.*?)>', r"<\1\2\3>", verse_str)

    verse_str = re.sub(r'<', r"_", verse_str)
    verse_str = re.sub(r'(key|who|toWhom|type)=', r"@\1 ", verse_str)
    
    verse_str = re.sub(r'>', r" ", verse_str)
    #print(verse_str)
# Out:
# ['b.GEN.1.1']
# <class 'str'>
# b'En el _rs @key #tim3 principio cre&#243; _rs @key #per14 Dios los cielos y la _rs @key #pla41 tierra.'
# ['b.GEN.1.2']
# <class 'str'>
# b'La _rs @key #pla41 tierra estaba desordenada y vac&#237;a, las tinieblas estaban sobre la faz del abismo y el _rs @key #per17 cert="low" esp&#237;ritu de _rs @key #per14 Dios se mov&#237;a sobre la faz de las aguas.'
# ['b.GEN.1.3']
# <class 'str'>
# b'Dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Sea la luz. Y fue la luz.'
# ['b.GEN.1.4']
# <class 'str'>
# b'Vio _rs @key #per14 Dios que la luz era buena, y separ&#243; la luz de las tinieblas.'
# ['b.GEN.1.5']
# <class 'str'>
# b'Llam&#243; a la luz _q @who #per14 @toWhom "#org0" @type "oral" cert="low" D&#237;a, y a las tinieblas llam&#243; _q @who #per14 @toWhom "#org0" @type "oral" cert="low" Noche. Y fue la tarde y la ma&#241;ana del primer _rs @key #tim3 d&#237;a.'
# ['b.GEN.1.6']
# <class 'str'>
# b'Luego dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Haya un firmamento en medio de las aguas, para que separe las aguas de las aguas.'
# ['b.GEN.1.7']
# <class 'str'>
# b'E hizo _rs @key #per14 Dios un firmamento que separ&#243; las aguas que estaban debajo del firmamento, de las aguas que estaban sobre el firmamento. Y fue as&#237;.'
# ['b.GEN.1.8']
# <class 'str'>
# b'Al firmamento llam&#243; _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Cielos. Y fue la tarde y la ma&#241;ana del segundo d&#237;a.'
# ['b.GEN.1.9']
# <class 'str'>
# b'Dijo tambi&#233;n _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Re&#250;nanse las aguas que est&#225;n debajo de los cielos en un solo lugar, para que se descubra lo seco. Y fue as&#237;.'
# ['b.GEN.1.10']
# <class 'str'>
# b'A la parte seca llam&#243; _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Tierra, y al conjunto de las aguas lo llam&#243; _q @who #per14 @toWhom "#org0" @type "oral" Mares. Y vio _rs @key #per14 Dios que era bueno.'
# ['b.GEN.1.11']
# <class 'str'>
# b'Despu&#233;s dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Produzca la _rs @key #pla41 tierra hierba verde, hierba que d&#233; semilla; &#225;rbol que d&#233; fruto seg&#250;n su especie, cuya semilla est&#233; en &#233;l, sobre la _rs @key #pla41 tierra. Y fue as&#237;.'
# ['b.GEN.1.12']
# <class 'str'>
# b'Produjo, pues, la _rs @key #pla41 tierra hierba verde, hierba que da semilla seg&#250;n su naturaleza, y &#225;rbol que da fruto, cuya semilla est&#225; en &#233;l, seg&#250;n su especie. Y vio _rs @key #per14 Dios que era bueno.'
# ['b.GEN.1.13']
# <class 'str'>
# b'Y fue la tarde y la ma&#241;ana del tercer d&#237;a.'
# ['b.GEN.1.14']
# <class 'str'>
# b'Dijo luego _rs @key #per14 Dios: _q @who #per14 @toWhom "#org0" @type "oral" Haya lumbreras en el firmamento de los cielos para separar el d&#237;a de la noche, que sirvan de se&#241;ales para las estaciones, los d&#237;as y los a&#241;os,'
# ['b.GEN.1.15']
# <class 'str'>
# b'_q @who #per14 @toWhom "#org0" @type "oral" y sean por lumbreras en el firmamento celeste para alumbrar sobre la _rs @key #pla41 tierra. Y fue as&#237;.'
# ['b.GEN.1.16']
# <class 'str'>
# b'E hizo _rs @key #per14 Dios las dos grandes lumbreras: la lumbrera mayor para que se&#241;oreara en el d&#237;a, y la lumbrera menor para que se&#241;oreara en la noche; e hizo tambi&#233;n las estrellas.'
# ['b.GEN.1.17']
# <class 'str'>
# b'Las puso _rs @key #per14 Dios en el firmamento de los cielos para alumbrar sobre la _rs @key #pla41 tierra,'
# ['b.GEN.1.18']
# <class 'str'>
# b'se&#241;orear en el d&#237;a y en la noche y para separar la luz de las tinieblas. Y vio _rs @key #per14 Dios que era bueno.'
# ['b.GEN.1.19']
# <class 'str'>
# b'Y fue la tarde y la ma&#241;ana del cuarto d&#237;a.'
# ['b.GEN.1.20']
# <class 'str'>
# b'Dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Produzcan las aguas seres vivientes, y aves que vuelen sobre la _rs @key #pla41 tierra, en el firmamento de los cielos.'
# ['b.GEN.1.21']
# <class 'str'>
# b'Y cre&#243; _rs @key #per14 Dios los grandes monstruos marinos y todo ser viviente que se mueve, que las aguas produjeron seg&#250;n su especie, y toda ave alada seg&#250;n su especie. Y vio _rs @key #per14 Dios que era bueno.'
# ['b.GEN.1.22']
# <class 'str'>
# b'Y los bendijo _rs @key #per14 Dios, diciendo _q @who #per14 @toWhom "#org0" @type "oral" Fructificad y multiplicaos, llenad las aguas en los mares y multipl&#237;quense las aves en la _rs @key #pla41 tierra.'
# ['b.GEN.1.23']
# <class 'str'>
# b'Y fue la tarde y la ma&#241;ana del quinto d&#237;a.'
# ['b.GEN.1.24']
# <class 'str'>
# b'Luego dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Produzca la _rs @key #pla41 tierra seres vivientes seg&#250;n su especie: bestias, serpientes y animales de la _rs @key #pla41 tierra seg&#250;n su especie. Y fue as&#237;.'
# ['b.GEN.1.25']
# <class 'str'>
# b'E hizo _rs @key #per14 Dios los animales de la _rs @key #pla41 tierra seg&#250;n su especie, ganado seg&#250;n su especie y todo animal que se arrastra sobre la _rs @key #pla41 tierra seg&#250;n su especie. Y vio _rs @key #per14 Dios que era bueno.'
# ['b.GEN.1.26']
# <class 'str'>
# b'Entonces dijo _rs @key #per14 Dios _q @who #per14 @toWhom "#org0" @type "oral" Hagamos al hombre a nuestra imagen, conforme a nuestra semejanza; y tenga potestad sobre los peces del mar, las aves de los cielos y las bestias, sobre toda la _rs @key #pla41 tierra y sobre todo animal que se arrastra sobre la _rs @key #pla41 tierra.'
# ['b.GEN.1.27']
# <class 'str'>
# b'Y cre&#243; _rs @key #per14 Dios al hombre a su imagen, a imagen de _rs @key #per14 Dios lo cre&#243;; _rs @key #per145 var&#243;n y _rs @key #per241 hembra los cre&#243;.'
# ['b.GEN.1.28']
# <class 'str'>
# b'Los bendijo _rs @key #per14 Dios y les dijo _q @who #per14 @toWhom "#per145 #per241" @type "oral" Fructificad y multiplicaos; llenad la _rs @key #pla41 tierra y sometedla; ejerced potestad sobre los peces del mar, las aves de los cielos y todas las bestias que se mueven sobre la _rs @key #pla41 tierra.'
# ['b.GEN.1.29']
# <class 'str'>
# b'Despu&#233;s dijo _rs @key #per14 Dios: _q @who #per14 @toWhom "#per145 #per241" @type "oral" Mirad, os he dado toda planta que da semilla, que est&#225; sobre toda la _rs @key #pla41 tierra, as&#237; como todo &#225;rbol en que hay fruto y da semilla. De todo esto podr&#233;is comer.'
# ['b.GEN.1.30']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per145 #per241" @type "oral" Pero a toda bestia de la _rs @key #pla41 tierra, a todas las aves de los cielos y a todo lo que tiene vida y se arrastra sobre la _rs @key #pla41 tierra, les doy toda planta verde para comer. Y fue as&#237;.'
# ['b.GEN.1.31']
# <class 'str'>
# b'Y vio _rs @key #per14 Dios todo cuanto hab&#237;a hecho, y era bueno en gran manera. Y fue la tarde y la ma&#241;ana del sexto d&#237;a.'
# ['b.GEN.2.1']
# <class 'str'>
# b'Fueron, pues, acabados los cielos y la _rs @key #pla41 tierra, y todo lo que hay en ellos.'
# ['b.GEN.2.2']
# <class 'str'>
# b'El s&#233;ptimo d&#237;a concluy&#243; _rs @key #per14 Dios la obra que hizo, y repos&#243; el s&#233;ptimo d&#237;a de todo cuanto hab&#237;a hecho.'
# ['b.GEN.2.3']
# <class 'str'>
# b'Entonces bendijo _rs @key #per14 Dios el s&#233;ptimo d&#237;a y lo santific&#243;, porque en &#233;l repos&#243; de toda la obra que hab&#237;a hecho en la _rs @key #tim3 creaci&#243;n.'
# ['b.GEN.2.4']
# <class 'str'>
# b'Estos son los _rs @key #tim3 or&#237;genes de los cielos y de la _rs @key #pla41 tierra cuando fueron creados. Cuando _rs @key #per14 Jehov&#225; _rs @key #per14 Dios hizo la _rs @key #pla41 tierra y los cielos,'
# ['b.GEN.2.5']
# <class 'str'>
# b'a&#250;n no hab&#237;a ninguna planta del campo sobre la _rs @key #pla41 tierra ni hab&#237;a nacido ninguna hierba del campo, porque _rs @key #per14 Jehov&#225; _rs @key #per14 Dios todav&#237;a no hab&#237;a hecho llover sobre la _rs @key #pla41 tierra ni hab&#237;a hombre para que labrara la _rs @key #pla41 tierra,'
# ['b.GEN.2.6']
# <class 'str'>
# b'sino que sub&#237;a de la _rs @key #pla41 tierra un vapor que regaba toda la faz de la _rs @key #pla41 tierra.'
# ['b.GEN.2.7']
# <class 'str'>
# b'Entonces _rs @key #per14 Jehov&#225; _rs @key #per14 Dios form&#243; al _rs @key #per145 hombre del polvo de la _rs @key #pla41 tierra, sopl&#243; en su nariz aliento de vida y fue el _rs @key #per145 hombre un _rs @key #per145 ser viviente.'
# ['b.GEN.2.8']
# <class 'str'>
# b'_rs @key #per14 Jehov&#225; _rs @key #per14 Dios plant&#243; un _rs @key #pla77 huerto en _rs @key #pla77 Ed&#233;n, al _rs @key #pla39 oriente, y puso all&#237; al _rs @key #per145 hombre que hab&#237;a formado.'
# ['b.GEN.2.9']
# <class 'str'>
# b'E hizo _rs @key #per14 Jehov&#225; _rs @key #per14 Dios nacer de la _rs @key #pla41 tierra todo &#225;rbol delicioso a la vista y bueno para comer; tambi&#233;n el &#225;rbol de la vida en medio del _rs @key #pla77 huerto, y el &#225;rbol del conocimiento del bien y del mal.'
# ['b.GEN.2.10']
# <class 'str'>
# b'Sal&#237;a de _rs @key #pla77 Ed&#233;n un r&#237;o para regar el _rs @key #pla77 huerto, y de all&#237; se repart&#237;a en cuatro brazos.'
# ['b.GEN.2.11']
# <class 'str'>
# b'El primero se llama _rs @key #pla85 Pis&#243;n; es el que rodea toda la _rs @key #pla86 tierra de _rs @key #pla86 Havila, donde hay oro.'
# ['b.GEN.2.12']
# <class 'str'>
# b'El oro de aquella _rs @key #pla86 tierra es bueno; y hay all&#237; tambi&#233;n bedelio y &#243;nice.'
# ['b.GEN.2.13']
# <class 'str'>
# b'El segundo _rs @key #pla87 r&#237;o se llama _rs @key #pla87 Gih&#243;n; es el que rodea toda la _rs @key #pla88 tierra de _rs @key #pla88 Cus.'
# ['b.GEN.2.14']
# <class 'str'>
# b'El tercer _rs @key #pla89 r&#237;o se llama _rs @key #pla89 Hidekel; es el que va al _rs @key #pla39 oriente de _rs @key #pla90 Asiria. El cuarto _rs @key #pla64 r&#237;o es el _rs @key #pla64 &#201;ufrates.'
# ['b.GEN.2.15']
# <class 'str'>
# b'Tom&#243;, pues, _rs @key #per14 Jehov&#225; _rs @key #per14 Dios al _rs @key #per145 hombre y lo puso en el _rs @key #pla77 huerto de Ed&#233;n, para que lo labrara y lo cuidara.'
# ['b.GEN.2.16']
# <class 'str'>
# b'Y mand&#243; _rs @key #per14 Jehov&#225; _rs @key #per14 Dios al _rs @key #per145 hombre, diciendo: _q @who #per14 @toWhom "#per145" @type "oral" De todo &#225;rbol del huerto podr&#225;s comer;'
# ['b.GEN.2.17']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per145" @type "oral" pero del &#225;rbol del conocimiento del bien y del mal no comer&#225;s, porque el d&#237;a que de &#233;l comas, ciertamente morir&#225;s&#187;.'
# ['b.GEN.2.18']
# <class 'str'>
# b'Despu&#233;s dijo _rs @key #per14 Jehov&#225; _rs @key #per14 Dios _q @who #per14 @toWhom "#per14" @type "oral" No es bueno que el hombre est&#233; solo: le har&#233; ayuda id&#243;nea para &#233;l.'
# ['b.GEN.2.19']
# <class 'str'>
# b'_rs @key #per14 Jehov&#225; _rs @key #per14 Dios form&#243;, pues, de la _rs @key #pla41 tierra toda bestia del campo y toda ave de los cielos, y las trajo a _rs @key #per145 Ad&#225;n para que viera c&#243;mo las hab&#237;a de llamar; y el nombre que _rs @key #per145 Ad&#225;n dio a los seres vivientes, ese es su nombre.'
# ['b.GEN.2.20']
# <class 'str'>
# b'Y puso _rs @key #per145 Ad&#225;n nombre a toda bestia, a toda ave de los cielos y a todo ganado del campo; pero no se hall&#243; ayuda id&#243;nea para &#233;l.'
# ['b.GEN.2.21']
# <class 'str'>
# b'Entonces _rs @key #per14 Jehov&#225; _rs @key #per14 Dios hizo caer un sue&#241;o profundo sobre _rs @key #per145 Ad&#225;n y, mientras este dorm&#237;a, tom&#243; una de sus costillas y cerr&#243; la carne en su lugar.'
# ['b.GEN.2.22']
# <class 'str'>
# b'De la costilla que _rs @key #per14 Jehov&#225; _rs @key #per14 Dios tom&#243; del _rs @key #per145 hombre, hizo una _rs @key #per241 mujer, y la trajo al _rs @key #per145 hombre.'
# ['b.GEN.2.23']
# <class 'str'>
# b'Dijo entonces _rs @key #per145 Ad&#225;n _q @who #per145 @toWhom "#per241 #per14" @type "oral" &#161;Esta s&#237; que es hueso de mis huesos y carne de mi carne! Ser&#225; llamada _rs @key #per241 Mujer, porque del _rs @key #per145 hombre fue tomada.'
# ['b.GEN.2.24']
# <class 'str'>
# b'Por tanto dejar&#225; el hombre a su padre y a su madre, se unir&#225; a su mujer y ser&#225;n una sola carne.'
# ['b.GEN.2.25']
# <class 'str'>
# b'Estaban ambos desnudos, _rs @key #per145 Ad&#225;n y su _rs @key #per241 mujer, pero no se avergonzaban.'
# ['b.GEN.3.1']
# <class 'str'>
# b'La _rs @key #per20 serpiente era m&#225;s astuta que todos los animales del campo que _rs @key #per14 Jehov&#225; _rs @key #per14 Dios hab&#237;a hecho, y dijo a la _rs @key #per241 mujer: _q @who #per20 @toWhom "#per241" @type "oral" &#191;Conque _rs @key #per14 Dios os ha dicho: _q @who #per14 @toWhom "#per241 #per145" @type "oral" No com&#225;is de ning&#250;n &#225;rbol del huerto?'
# ['b.GEN.3.2']
# <class 'str'>
# b'La _rs @key #per241 mujer respondi&#243; a la _rs @key #per20 serpiente: _q @who #per241 @toWhom "#per20" @type "oral" Del fruto de los &#225;rboles del huerto podemos comer,'
# ['b.GEN.3.3']
# <class 'str'>
# b'_q @who #per241 @toWhom "#per20" @type "oral" pero del fruto del &#225;rbol que est&#225; en medio del huerto dijo _rs @key #per14 Dios: _q @who #per14 @toWhom "#per241 #per145" @type "oral" No comer&#233;is de &#233;l, ni lo tocar&#233;is, para que no mur&#225;is.'
# ['b.GEN.3.4']
# <class 'str'>
# b'Entonces la _rs @key #per20 serpiente dijo a la _rs @key #per241 mujer: _q @who #per20 @toWhom "#per241" @type "oral" No morir&#233;is.'
# ['b.GEN.3.5']
# <class 'str'>
# b'_q @who #per20 @toWhom "#per241" @type "oral" Pero _rs @key #per14 Dios sabe que el d&#237;a que com&#225;is de &#233;l ser&#225;n abiertos vuestros ojos y ser&#233;is como _rs @key #per14 Dios, conocedores del bien y el mal.'
# ['b.GEN.3.6']
# <class 'str'>
# b'Al ver la _rs @key #per241 mujer que el &#225;rbol era bueno para comer, agradable a los ojos y deseable para alcanzar la sabidur&#237;a, tom&#243; de su fruto y comi&#243;; y dio tambi&#233;n a su _rs @key #per145 marido, el cual comi&#243; al igual que ella.'
# ['b.GEN.3.7']
# <class 'str'>
# b'Entonces fueron abiertos los ojos de ambos y se dieron cuenta de que estaban desnudos. Cosieron, pues, hojas de higuera y se hicieron delantales.'
# ['b.GEN.3.8']
# <class 'str'>
# b'Luego oyeron la voz de _rs @key #per14 Jehov&#225; _rs @key #per14 Dios que se paseaba por el _rs @key #pla77 huerto, al aire del d&#237;a; y el _rs @key #per145 hombre y su _rs @key #per241 mujer se escondieron de la presencia de _rs @key #per14 Jehov&#225; _rs @key #per14 Dios entre los &#225;rboles del _rs @key #pla77 huerto.'
# ['b.GEN.3.9']
# <class 'str'>
# b'Pero _rs @key #per14 Jehov&#225; _rs @key #per14 Dios llam&#243; al _rs @key #per145 hombre, y le pregunt&#243;: _q @who #per14 @toWhom "#per145" @type "oral" &#191;D&#243;nde est&#225;s?'
# ['b.GEN.3.10']
# <class 'str'>
# b'&#201;l respondi&#243;: _q @who #per145 @toWhom "#per14" @type "oral" O&#237; tu voz en el _rs @key #pla77 huerto y tuve miedo, porque estaba desnudo; por eso me escond&#237;.'
# ['b.GEN.3.11']
# <class 'str'>
# b'Entonces _rs @key #per14 Dios le pregunt&#243;: _q @who #per14 @toWhom "#per145" @type "oral" &#191;Qui&#233;n te ense&#241;&#243; que estabas desnudo? &#191;Acaso has comido del &#225;rbol del cual yo te mand&#233; que no comieras?'
# ['b.GEN.3.12']
# <class 'str'>
# b'El _rs @key #per145 hombre le respondi&#243;: _q @who #per145 @toWhom "#per14" @type "oral" La _rs @key #per241 mujer que me diste por compa&#241;era me dio del &#225;rbol, y yo com&#237;.'
# ['b.GEN.3.13']
# <class 'str'>
# b'Entonces _rs @key #per14 Jehov&#225; _rs @key #per14 Dios dijo a la _rs @key #per241 mujer: _q @who #per14 @toWhom "#per241" @type "oral" &#191;Qu&#233; es lo que has hecho? Ella respondi&#243;: _q @who #per241 @toWhom "#per14" @type "oral" La _rs @key #per20 serpiente me enga&#241;&#243;, y com&#237;.'
# ['b.GEN.3.14']
# <class 'str'>
# b'Y _rs @key #per14 Jehov&#225; _rs @key #per14 Dios dijo a la _rs @key #per20 serpiente: _q @who #per14 @toWhom "#per20" @type "oral" Por cuanto esto hiciste, maldita ser&#225;s entre todas las bestias y entre todos los animales del campo. Sobre tu vientre te arrastrar&#225;s y polvo comer&#225;s todos los d&#237;as de tu vida.'
# ['b.GEN.3.15']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per20" @type "oral" Pondr&#233; enemistad entre ti y la mujer, y entre tu simiente y la simiente suya; esta te herir&#225; en la cabeza, y t&#250; la herir&#225;s en el tal&#243;n.'
# ['b.GEN.3.16']
# <class 'str'>
# b'A la _rs @key #per241 mujer dijo: _q @who #per14 @toWhom "#per241" @type "oral" Multiplicar&#233; en gran manera los dolores en tus embarazos, con dolor dar&#225;s a luz los hijos, tu deseo ser&#225; para tu _rs @key #per145 marido y &#233;l se ense&#241;orear&#225; de ti.'
# ['b.GEN.3.17']
# <class 'str'>
# b'Y al hombre dijo: _q @who #per14 @toWhom "#per145" @type "oral" Por cuanto obedeciste a la voz de tu _rs @key #per241 mujer y comiste del &#225;rbol de que te mand&#233; diciendo: _q @who #per14 @toWhom "#per145" @type "oral" No comer&#225;s de &#233;l, maldita ser&#225; la _rs @key #pla41 tierra por tu causa; con dolor comer&#225;s de ella todos los d&#237;as de tu vida,'
# ['b.GEN.3.18']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per145" @type "oral" espinos y cardos te producir&#225; y comer&#225;s plantas del campo.'
# ['b.GEN.3.19']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per145" @type "oral" Con el sudor de tu rostro comer&#225;s el pan, hasta que vuelvas a la tierra, porque de ella fuiste tomado; pues _rs @key #per145 polvo eres y al polvo volver&#225;s.'
# ['b.GEN.3.20']
# <class 'str'>
# b'A su _rs @key #per241 mujer _rs @key #per145 Ad&#225;n le puso por nombre _rs @key #per241 Eva, por cuanto ella fue la _rs @key #per241 madre de todos los vivientes.'
# ['b.GEN.3.21']
# <class 'str'>
# b'Y _rs @key #per14 Jehov&#225; _rs @key #per14 Dios hizo para el _rs @key #per145 hombre y su _rs @key #per241 mujer t&#250;nicas de pieles, y los visti&#243;.'
# ['b.GEN.3.22']
# <class 'str'>
# b'Luego dijo _rs @key #per14 Jehov&#225; _rs @key #per14 Dios _q @who #per14 @toWhom "#per14" @type "oral" El _rs @key #per145 cert="medium" hombre ha venido a ser como uno de nosotros, conocedor del bien y el mal; ahora, pues, que no alargue su mano, tome tambi&#233;n del &#225;rbol de la vida, coma y viva para siempre.'
# ['b.GEN.3.23']
# <class 'str'>
# b'Y lo sac&#243; _rs @key #per14 Jehov&#225; del _rs @key #pla77 huerto de Ed&#233;n, para que labrara la tierra de la que fue tomado.'
# ['b.GEN.3.24']
# <class 'str'>
# b'Ech&#243;, pues, fuera al _rs @key #per145 hombre, y puso _rs @key #org4 querubines al oriente del _rs @key #pla77 huerto de Ed&#233;n, y una _rs @key #org4 espada encendida que se revolv&#237;a por todos lados para guardar el camino del &#225;rbol de la vida.'
# ['b.GEN.4.1']
# <class 'str'>
# b'Conoci&#243; _rs @key #per145 Ad&#225;n a su _rs @key #per241 mujer _rs @key #per241 Eva, la cual concibi&#243; y dio a luz a _rs @key #per142 Ca&#237;n, y dijo _q @who #per241 @toWhom "#org0" @type "oral" Por voluntad de _rs @key #per14 Jehov&#225; he adquirido un _rs @key #per142 var&#243;n.'
# ['b.GEN.4.2']
# <class 'str'>
# b'Despu&#233;s dio a luz a su _rs @key #per43 hermano _rs @key #per43 Abel. Fue _rs @key #per43 Abel _rs @key #per43 pastor de ovejas y _rs @key #per142 Ca&#237;n, _rs @key #per142 labrador de la tierra.'
# ['b.GEN.4.3']
# <class 'str'>
# b'Pasado un tiempo, _rs @key #per142 Ca&#237;n trajo del fruto de la tierra una ofrenda a _rs @key #per14 Jehov&#225;.'
# ['b.GEN.4.4']
# <class 'str'>
# b'Y _rs @key #per43 Abel trajo tambi&#233;n de los primog&#233;nitos de sus ovejas, y de la grasa de ellas. Y mir&#243; _rs @key #per14 Jehov&#225; con agrado a _rs @key #per43 Abel y a su ofrenda;'
# ['b.GEN.4.5']
# <class 'str'>
# b'pero no mir&#243; con agrado a _rs @key #per142 Ca&#237;n ni a su ofrenda, por lo cual _rs @key #per142 Ca&#237;n se enoj&#243; en gran manera y decay&#243; su semblante.'
# ['b.GEN.4.6']
# <class 'str'>
# b'Entonces _rs @key #per14 Jehov&#225; dijo a _rs @key #per142 Ca&#237;n: _q @who #per14 @toWhom "#per142" @type "oral" &#191;Por qu&#233; te has enojado y por qu&#233; ha deca&#237;do tu semblante?'
# ['b.GEN.4.7']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per142" @type "oral" Si hicieras lo bueno, &#191;no ser&#237;as enaltecido?; pero si no lo haces, el pecado est&#225; a la puerta, acechando. Con todo, t&#250; lo dominar&#225;s.'
# ['b.GEN.4.8']
# <class 'str'>
# b'_rs @key #per142 Ca&#237;n dijo a su _rs @key #per43 hermano _rs @key #per43 Abel _q @who #per142 @toWhom "#per43" @type "oral" Salgamos al campo. Y aconteci&#243; que estando ellos en el campo, _rs @key #per142 Ca&#237;n se levant&#243; contra su _rs @key #per43 hermano _rs @key #per43 Abel y lo mat&#243;.'
# ['b.GEN.4.9']
# <class 'str'>
# b'Entonces _rs @key #per14 Jehov&#225; pregunt&#243; a _rs @key #per142 Ca&#237;n: _q @who #per14 @toWhom "#per142" @type "oral" &#191;D&#243;nde est&#225; _rs @key #per43 Abel, tu _rs @key #per43 hermano? Y &#233;l respondi&#243;: _q @who #per142 @toWhom "#per14" @type "oral" No s&#233;. &#191;Soy yo acaso guarda de mi _rs @key #per43 hermano?'
# ['b.GEN.4.10']
# <class 'str'>
# b'_rs @key #per14 Jehov&#225; le dijo: _q @who #per14 @toWhom "#per142" @type "oral" &#191;Qu&#233; has hecho? La voz de la sangre de tu _rs @key #per43 hermano clama a m&#237; desde la tierra.'
# ['b.GEN.4.11']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per142" @type "oral" Ahora, pues, maldito seas de la tierra, que abri&#243; su boca para recibir de tu mano la sangre de tu _rs @key #per43 hermano.'
# ['b.GEN.4.12']
# <class 'str'>
# b'_q @who #per14 @toWhom "#per142" @type "oral" Cuando labres la tierra, no te volver&#225; a dar sus frutos; errante y extranjero ser&#225;s en ella.'
# ['b.GEN.4.13']
# <class 'str'>
# b'Entonces _rs @key #per142 Ca&#237;n respondi&#243; a _rs @key #per14 Jehov&#225;: _q @who #per142 @toWhom "#per14" @type "oral" Grande es mi culpa para ser soportada.'
# ['b.GEN.4.14']
# <class 'str'>
# b'_q @who #per142 @toWhom "#per14" @type "oral" Hoy me echas de la tierra, y habr&#233; de esconderme de tu presencia, errante y extranjero en la tierra; y suceder&#225; que cualquiera que me encuentre, me matar&#225;.'
# ['b.GEN.4.15']
# <class 'str'>
# b'Le respondi&#243; _rs @key #per14 Jehov&#225;: _q @who #per14 @toWhom "#per142" @type "oral" Ciertamente cualquiera que mate a _rs @key #per142 Ca&#237;n, siete veces ser&#225; castigado. Entonces _rs @key #per14 Jehov&#225; puso se&#241;al en _rs @key #per142 Ca&#237;n, para que no lo matara cualquiera que lo encontrase.'
# ['b.GEN.4.16']
# <class 'str'>
# b'Sali&#243;, pues, _rs @key #per142 Ca&#237;n de delante de _rs @key #per14 Jehov&#225;, y habit&#243; en _rs @key #pla91 tierra de Nod, al oriente de _rs @key #pla77 Ed&#233;n.'
# ['b.GEN.4.17']
# <class 'str'>
# b'Conoci&#243; _rs @key #per142 Ca&#237;n a su mujer, la cual concibi&#243; y dio a luz a _rs @key #per164 Enoc; y edific&#243; una _rs @key #pla92 ciudad, a la cual dio el nombre de su hijo, _rs @key #pla92 Enoc.'
# ['b.GEN.4.18']
# <class 'str'>
# b'A _rs @key #per164 Enoc le naci&#243; _rs @key #per256 Irad, e _rs @key #per256 Irad engendr&#243; a _rs @key #per283 Mehujael; _rs @key #per283 Mehujael engendr&#243; a _rs @key #per243 Metusael, y _rs @key #per243 Metusael engendr&#243; a _rs @key #per154 Lamec.'
# ['b.GEN.4.19']
# <class 'str'>
# b'_rs @key #per154 Lamec tom&#243; para s&#237; _rs @key #per166 #per209 dos mujeres: el nombre de la una fue _rs @key #per166 Ada, y el nombre de la otra, _rs @key #per209 Zila.'
# ['b.GEN.4.20']
# <class 'str'>
# b'_rs @key #per166 Ada dio a luz a _rs @key #per299 Jabal, el cual fue _rs @key #per299 padre de los que habitan en tiendas y cr&#237;an ganados.'

# %%
verses
# Out:
# ['b.GEN.1.1',
#  'b.GEN.1.2',
#  'b.GEN.1.3',
#  'b.GEN.1.4',
#  'b.GEN.1.5',
#  'b.GEN.1.6',
#  'b.GEN.1.7',
#  'b.GEN.1.8',
#  'b.GEN.1.9',
#  'b.GEN.1.10',
#  'b.GEN.1.11',
#  'b.GEN.1.12',
#  'b.GEN.1.13',
#  'b.GEN.1.14',
#  'b.GEN.1.15',
#  'b.GEN.1.16',
#  'b.GEN.1.17',
#  'b.GEN.1.18',
#  'b.GEN.1.19',
#  'b.GEN.1.20',
#  'b.GEN.1.21',
#  'b.GEN.1.22',
#  'b.GEN.1.23',
#  'b.GEN.1.24',
#  'b.GEN.1.25',
#  'b.GEN.1.26',
#  'b.GEN.1.27',
#  'b.GEN.1.28',
#  'b.GEN.1.29',
#  'b.GEN.1.30',
#  'b.GEN.1.31',
#  'b.GEN.2.1',
#  'b.GEN.2.2',
#  'b.GEN.2.3',
#  'b.GEN.2.4',
#  'b.GEN.2.5',
#  'b.GEN.2.6',
#  'b.GEN.2.7',
#  'b.GEN.2.8',
#  'b.GEN.2.9',
#  'b.GEN.2.10',
#  'b.GEN.2.11',
#  'b.GEN.2.12',
#  'b.GEN.2.13',
#  'b.GEN.2.14',
#  'b.GEN.2.15',
#  'b.GEN.2.16',
#  'b.GEN.2.17',
#  'b.GEN.2.18',
#  'b.GEN.2.19',
#  'b.GEN.2.20',
#  'b.GEN.2.21',
#  'b.GEN.2.22',
#  'b.GEN.2.23',
#  'b.GEN.2.24',
#  'b.GEN.2.25',
#  'b.GEN.3.1',
#  'b.GEN.3.2',
#  'b.GEN.3.3',
#  'b.GEN.3.4',
#  'b.GEN.3.5',
#  'b.GEN.3.6',
#  'b.GEN.3.7',
#  'b.GEN.3.8',
#  'b.GEN.3.9',
#  'b.GEN.3.10',
#  'b.GEN.3.11',
#  'b.GEN.3.12',
#  'b.GEN.3.13',
#  'b.GEN.3.14',
#  'b.GEN.3.15',
#  'b.GEN.3.16',
#  'b.GEN.3.17',
#  'b.GEN.3.18',
#  'b.GEN.3.19',
#  'b.GEN.3.20',
#  'b.GEN.3.21',
#  'b.GEN.3.22',
#  'b.GEN.3.23',
#  'b.GEN.3.24',
#  'b.GEN.4.1',
#  'b.GEN.4.2',
#  'b.GEN.4.3',
#  'b.GEN.4.4',
#  'b.GEN.4.5',
#  'b.GEN.4.6',
#  'b.GEN.4.7',
#  'b.GEN.4.8',
#  'b.GEN.4.9',
#  'b.GEN.4.10',
#  'b.GEN.4.11',
#  'b.GEN.4.12',
#  'b.GEN.4.13',
#  'b.GEN.4.14',
#  'b.GEN.4.15',
#  'b.GEN.4.16',
#  'b.GEN.4.17',
#  'b.GEN.4.18',
#  'b.GEN.4.19',
#  'b.GEN.4.20',
#  'b.GEN.4.21',
#  'b.GEN.4.22',
#  'b.GEN.4.23',
#  'b.GEN.4.24',
#  'b.GEN.4.25',
#  'b.GEN.4.26',
#  'b.GEN.5.1',
#  'b.GEN.5.2',
#  'b.GEN.5.3',
#  'b.GEN.5.4',
#  'b.GEN.5.5',
#  'b.GEN.5.6',
#  'b.GEN.5.7',
#  'b.GEN.5.8',
#  'b.GEN.5.9',
#  'b.GEN.5.10',
#  'b.GEN.5.11',
#  'b.GEN.5.12',
#  'b.GEN.5.13',
#  'b.GEN.5.14',
#  'b.GEN.5.15',
#  'b.GEN.5.16',
#  'b.GEN.5.17',
#  'b.GEN.5.18',
#  'b.GEN.5.19',
#  'b.GEN.5.20',
#  'b.GEN.5.21',
#  'b.GEN.5.22',
#  'b.GEN.5.23',
#  'b.GEN.5.24',
#  'b.GEN.5.25',
#  'b.GEN.5.26',
#  'b.GEN.5.27',
#  'b.GEN.5.28',
#  'b.GEN.5.29',
#  'b.GEN.5.30',
#  'b.GEN.5.31',
#  'b.GEN.5.32',
#  'b.GEN.6.1',
#  'b.GEN.6.2',
#  'b.GEN.6.3',
#  'b.GEN.6.4',
#  'b.GEN.6.5',
#  'b.GEN.6.6',
#  'b.GEN.6.7',
#  'b.GEN.6.8',
#  'b.GEN.6.9',
#  'b.GEN.6.10',
#  'b.GEN.6.11',
#  'b.GEN.6.12',
#  'b.GEN.6.13',
#  'b.GEN.6.14',
#  'b.GEN.6.15',
#  'b.GEN.6.16',
#  'b.GEN.6.17',
#  'b.GEN.6.18',
#  'b.GEN.6.19',
#  'b.GEN.6.20',
#  'b.GEN.6.21',
#  'b.GEN.6.22',
#  'b.GEN.7.1',
#  'b.GEN.7.2',
#  'b.GEN.7.3',
#  'b.GEN.7.4',
#  'b.GEN.7.5',
#  'b.GEN.7.6',
#  'b.GEN.7.7',
#  'b.GEN.7.8',
#  'b.GEN.7.9',
#  'b.GEN.7.10',
#  'b.GEN.7.11',
#  'b.GEN.7.12',
#  'b.GEN.7.13',
#  'b.GEN.7.14',
#  'b.GEN.7.15',
#  'b.GEN.7.16',
#  'b.GEN.7.17',
#  'b.GEN.7.18',
#  'b.GEN.7.19',
#  'b.GEN.7.20',
#  'b.GEN.7.21',
#  'b.GEN.7.22',
#  'b.GEN.7.23',
#  'b.GEN.7.24',
#  'b.GEN.8.1',
#  'b.GEN.8.2',
#  'b.GEN.8.3',
#  'b.GEN.8.4',
#  'b.GEN.8.5',
#  'b.GEN.8.6',
#  'b.GEN.8.7',
#  'b.GEN.8.8',
#  'b.GEN.8.9',
#  'b.GEN.8.10',
#  'b.GEN.8.11',
#  'b.GEN.8.12',
#  'b.GEN.8.13',
#  'b.GEN.8.14',
#  'b.GEN.8.15',
#  'b.GEN.8.16',
#  'b.GEN.8.17',
#  'b.GEN.8.18',
#  'b.GEN.8.19',
#  'b.GEN.8.20',
#  'b.GEN.8.21',
#  'b.GEN.8.22',
#  'b.GEN.9.1',
#  'b.GEN.9.2',
#  'b.GEN.9.3',
#  'b.GEN.9.4',
#  'b.GEN.9.5',
#  'b.GEN.9.6',
#  'b.GEN.9.7',
#  'b.GEN.9.8',
#  'b.GEN.9.9',
#  'b.GEN.9.10',
#  'b.GEN.9.11',
#  'b.GEN.9.12',
#  'b.GEN.9.13',
#  'b.GEN.9.14',
#  'b.GEN.9.15',
#  'b.GEN.9.16',
#  'b.GEN.9.17',
#  'b.GEN.9.18',
#  'b.GEN.9.19',
#  'b.GEN.9.20',
#  'b.GEN.9.21',
#  'b.GEN.9.22',
#  'b.GEN.9.23',
#  'b.GEN.9.24',
#  'b.GEN.9.25',
#  'b.GEN.9.26',
#  'b.GEN.9.27',
#  'b.GEN.9.28',
#  'b.GEN.9.29',
#  'b.GEN.10.1',
#  'b.GEN.10.2',
#  'b.GEN.10.3',
#  'b.GEN.10.4',
#  'b.GEN.10.5',
#  'b.GEN.10.6',
#  'b.GEN.10.7',
#  'b.GEN.10.8',
#  'b.GEN.10.9',
#  'b.GEN.10.10',
#  'b.GEN.10.11',
#  'b.GEN.10.12',
#  'b.GEN.10.13',
#  'b.GEN.10.14',
#  'b.GEN.10.15',
#  'b.GEN.10.16',
#  'b.GEN.10.17',
#  'b.GEN.10.18',
#  'b.GEN.10.19',
#  'b.GEN.10.20',
#  'b.GEN.10.21',
#  'b.GEN.10.22',
#  'b.GEN.10.23',
#  'b.GEN.10.24',
#  'b.GEN.10.25',
#  'b.GEN.10.26',
#  'b.GEN.10.27',
#  'b.GEN.10.28',
#  'b.GEN.10.29',
#  'b.GEN.10.30',
#  'b.GEN.10.31',
#  'b.GEN.10.32',
#  'b.GEN.11.1',
#  'b.GEN.11.2',
#  'b.GEN.11.3',
#  'b.GEN.11.4',
#  'b.GEN.11.5',
#  'b.GEN.11.6',
#  'b.GEN.11.7',
#  'b.GEN.11.8',
#  'b.GEN.11.9',
#  'b.GEN.11.10',
#  'b.GEN.11.11',
#  'b.GEN.11.12',
#  'b.GEN.11.13',
#  'b.GEN.11.14',
#  'b.GEN.11.15',
#  'b.GEN.11.16',
#  'b.GEN.11.17',
#  'b.GEN.11.18',
#  'b.GEN.11.19',
#  'b.GEN.11.20',
#  'b.GEN.11.21',
#  'b.GEN.11.22',
#  'b.GEN.11.23',
#  'b.GEN.11.24',
#  'b.GEN.11.25',
#  'b.GEN.11.26',
#  'b.GEN.11.27',
#  'b.GEN.11.28',
#  'b.GEN.11.29',
#  'b.GEN.11.30',
#  'b.GEN.11.31',
#  'b.GEN.11.32',
#  'b.GEN.12.1',
#  'b.GEN.12.2',
#  'b.GEN.12.3',
#  'b.GEN.12.4',
#  'b.GEN.12.5',
#  'b.GEN.12.6',
#  'b.GEN.12.7',
#  'b.GEN.12.8',
#  'b.GEN.12.9',
#  'b.GEN.12.10',
#  'b.GEN.12.11',
#  'b.GEN.12.12',
#  'b.GEN.12.13',
#  'b.GEN.12.14',
#  'b.GEN.12.15',
#  'b.GEN.12.16',
#  'b.GEN.12.17',
#  'b.GEN.12.18',
#  'b.GEN.12.19',
#  'b.GEN.12.20',
#  'b.GEN.13.1',
#  'b.GEN.13.2',
#  'b.GEN.13.3',
#  'b.GEN.13.4',
#  'b.GEN.13.5',
#  'b.GEN.13.6',
#  'b.GEN.13.7',
#  'b.GEN.13.8',
#  'b.GEN.13.9',
#  'b.GEN.13.10',
#  'b.GEN.13.11',
#  'b.GEN.13.12',
#  'b.GEN.13.13',
#  'b.GEN.13.14',
#  'b.GEN.13.15',
#  'b.GEN.13.16',
#  'b.GEN.13.17',
#  'b.GEN.13.18',
#  'b.GEN.14.1',
#  'b.GEN.14.2',
#  'b.GEN.14.3',
#  'b.GEN.14.4',
#  'b.GEN.14.5',
#  'b.GEN.14.6',
#  'b.GEN.14.7',
#  'b.GEN.14.8',
#  'b.GEN.14.9',
#  'b.GEN.14.10',
#  'b.GEN.14.11',
#  'b.GEN.14.12',
#  'b.GEN.14.13',
#  'b.GEN.14.14',
#  'b.GEN.14.15',
#  'b.GEN.14.16',
#  'b.GEN.14.17',
#  'b.GEN.14.18',
#  'b.GEN.14.19',
#  'b.GEN.14.20',
#  'b.GEN.14.21',
#  'b.GEN.14.22',
#  'b.GEN.14.23',
#  'b.GEN.14.24',
#  'b.GEN.15.1',
#  'b.GEN.15.2',
#  'b.GEN.15.3',
#  'b.GEN.15.4',
#  'b.GEN.15.5',
#  'b.GEN.15.6',
#  'b.GEN.15.7',
#  'b.GEN.15.8',
#  'b.GEN.15.9',
#  'b.GEN.15.10',
#  'b.GEN.15.11',
#  'b.GEN.15.12',
#  'b.GEN.15.13',
#  'b.GEN.15.14',
#  'b.GEN.15.15',
#  'b.GEN.15.16',
#  'b.GEN.15.17',
#  'b.GEN.15.18',
#  'b.GEN.15.19',
#  'b.GEN.15.20',
#  'b.GEN.15.21',
#  'b.GEN.16.1',
#  'b.GEN.16.2',
#  'b.GEN.16.3',
#  'b.GEN.16.4',
#  'b.GEN.16.5',
#  'b.GEN.16.6',
#  'b.GEN.16.7',
#  'b.GEN.16.8',
#  'b.GEN.16.9',
#  'b.GEN.16.10',
#  'b.GEN.16.11',
#  'b.GEN.16.12',
#  'b.GEN.16.13',
#  'b.GEN.16.14',
#  'b.GEN.16.15',
#  'b.GEN.16.16',
#  'b.GEN.17.1',
#  'b.GEN.17.2',
#  'b.GEN.17.3',
#  'b.GEN.17.4',
#  'b.GEN.17.5',
#  'b.GEN.17.6',
#  'b.GEN.17.7',
#  'b.GEN.17.8',
#  'b.GEN.17.9',
#  'b.GEN.17.10',
#  'b.GEN.17.11',
#  'b.GEN.17.12',
#  'b.GEN.17.13',
#  'b.GEN.17.14',
#  'b.GEN.17.15',
#  'b.GEN.17.16',
#  'b.GEN.17.17',
#  'b.GEN.17.18',
#  'b.GEN.17.19',
#  'b.GEN.17.20',
#  'b.GEN.17.21',
#  'b.GEN.17.22',
#  'b.GEN.17.23',
#  'b.GEN.17.24',
#  'b.GEN.17.25',
#  'b.GEN.17.26',
#  'b.GEN.17.27',
#  'b.GEN.18.1',
#  'b.GEN.18.2',
#  'b.GEN.18.3',
#  'b.GEN.18.4',
#  'b.GEN.18.5',
#  'b.GEN.18.6',
#  'b.GEN.18.7',
#  'b.GEN.18.8',
#  'b.GEN.18.9',
#  'b.GEN.18.10',
#  'b.GEN.18.11',
#  'b.GEN.18.12',
#  'b.GEN.18.13',
#  'b.GEN.18.14',
#  'b.GEN.18.15',
#  'b.GEN.18.16',
#  'b.GEN.18.17',
#  'b.GEN.18.18',
#  'b.GEN.18.19',
#  'b.GEN.18.20',
#  'b.GEN.18.21',
#  'b.GEN.18.22',
#  'b.GEN.18.23',
#  'b.GEN.18.24',
#  'b.GEN.18.25',
#  'b.GEN.18.26',
#  'b.GEN.18.27',
#  'b.GEN.18.28',
#  'b.GEN.18.29',
#  'b.GEN.18.30',
#  'b.GEN.18.31',
#  'b.GEN.18.32',
#  'b.GEN.18.33',
#  'b.GEN.19.1',
#  'b.GEN.19.2',
#  'b.GEN.19.3',
#  'b.GEN.19.4',
#  'b.GEN.19.5',
#  'b.GEN.19.6',
#  'b.GEN.19.7',
#  'b.GEN.19.8',
#  'b.GEN.19.9',
#  'b.GEN.19.10',
#  'b.GEN.19.11',
#  'b.GEN.19.12',
#  'b.GEN.19.13',
#  'b.GEN.19.14',
#  'b.GEN.19.15',
#  'b.GEN.19.16',
#  'b.GEN.19.17',
#  'b.GEN.19.18',
#  'b.GEN.19.19',
#  'b.GEN.19.20',
#  'b.GEN.19.21',
#  'b.GEN.19.22',
#  'b.GEN.19.23',
#  'b.GEN.19.24',
#  'b.GEN.19.25',
#  'b.GEN.19.26',
#  'b.GEN.19.27',
#  'b.GEN.19.28',
#  'b.GEN.19.29',
#  'b.GEN.19.30',
#  'b.GEN.19.31',
#  'b.GEN.19.32',
#  'b.GEN.19.33',
#  'b.GEN.19.34',
#  'b.GEN.19.35',
#  'b.GEN.19.36',
#  'b.GEN.19.37',
#  'b.GEN.19.38',
#  'b.GEN.20.1',
#  'b.GEN.20.2',
#  'b.GEN.20.3',
#  'b.GEN.20.4',
#  'b.GEN.20.5',
#  'b.GEN.20.6',
#  'b.GEN.20.7',
#  'b.GEN.20.8',
#  'b.GEN.20.9',
#  'b.GEN.20.10',
#  'b.GEN.20.11',
#  'b.GEN.20.12',
#  'b.GEN.20.13',
#  'b.GEN.20.14',
#  'b.GEN.20.15',
#  'b.GEN.20.16',
#  'b.GEN.20.17',
#  'b.GEN.20.18',
#  'b.GEN.21.1',
#  'b.GEN.21.2',
#  'b.GEN.21.3',
#  'b.GEN.21.4',
#  'b.GEN.21.5',
#  'b.GEN.21.6',
#  'b.GEN.21.7',
#  'b.GEN.21.8',
#  'b.GEN.21.9',
#  'b.GEN.21.10',
#  'b.GEN.21.11',
#  'b.GEN.21.12',
#  'b.GEN.21.13',
#  'b.GEN.21.14',
#  'b.GEN.21.15',
#  'b.GEN.21.16',
#  'b.GEN.21.17',
#  'b.GEN.21.18',
#  'b.GEN.21.19',
#  'b.GEN.21.20',
#  'b.GEN.21.21',
#  'b.GEN.21.22',
#  'b.GEN.21.23',
#  'b.GEN.21.24',
#  'b.GEN.21.25',
#  'b.GEN.21.26',
#  'b.GEN.21.27',
#  'b.GEN.21.28',
#  'b.GEN.21.29',
#  'b.GEN.21.30',
#  'b.GEN.21.31',
#  'b.GEN.21.32',
#  'b.GEN.21.33',
#  'b.GEN.21.34',
#  'b.GEN.22.1',
#  'b.GEN.22.2',
#  'b.GEN.22.3',
#  'b.GEN.22.4',
#  'b.GEN.22.5',
#  'b.GEN.22.6',
#  'b.GEN.22.7',
#  'b.GEN.22.8',
#  'b.GEN.22.9',
#  'b.GEN.22.10',
#  'b.GEN.22.11',
#  'b.GEN.22.12',
#  'b.GEN.22.13',
#  'b.GEN.22.14',
#  'b.GEN.22.15',
#  'b.GEN.22.16',
#  'b.GEN.22.17',
#  'b.GEN.22.18',
#  'b.GEN.22.19',
#  'b.GEN.22.20',
#  'b.GEN.22.21',
#  'b.GEN.22.22',
#  'b.GEN.22.23',
#  'b.GEN.22.24',
#  'b.GEN.23.1',
#  'b.GEN.23.2',
#  'b.GEN.23.3',
#  'b.GEN.23.4',
#  'b.GEN.23.5',
#  'b.GEN.23.6',
#  'b.GEN.23.7',
#  'b.GEN.23.8',
#  'b.GEN.23.9',
#  'b.GEN.23.10',
#  'b.GEN.23.11',
#  'b.GEN.23.12',
#  'b.GEN.23.13',
#  'b.GEN.23.14',
#  'b.GEN.23.15',
#  'b.GEN.23.16',
#  'b.GEN.23.17',
#  'b.GEN.23.18',
#  'b.GEN.23.19',
#  'b.GEN.23.20',
#  'b.GEN.24.1',
#  'b.GEN.24.2',
#  'b.GEN.24.3',
#  'b.GEN.24.4',
#  'b.GEN.24.5',
#  'b.GEN.24.6',
#  'b.GEN.24.7',
#  'b.GEN.24.8',
#  'b.GEN.24.9',
#  'b.GEN.24.10',
#  'b.GEN.24.11',
#  'b.GEN.24.12',
#  'b.GEN.24.13',
#  'b.GEN.24.14',
#  'b.GEN.24.15',
#  'b.GEN.24.16',
#  'b.GEN.24.17',
#  'b.GEN.24.18',
#  'b.GEN.24.19',
#  'b.GEN.24.20',
#  'b.GEN.24.21',
#  'b.GEN.24.22',
#  'b.GEN.24.23',
#  'b.GEN.24.24',
#  'b.GEN.24.25',
#  'b.GEN.24.26',
#  'b.GEN.24.27',
#  'b.GEN.24.28',
#  'b.GEN.24.29',
#  'b.GEN.24.30',
#  'b.GEN.24.31',
#  'b.GEN.24.32',
#  'b.GEN.24.33',
#  'b.GEN.24.34',
#  'b.GEN.24.35',
#  'b.GEN.24.36',
#  'b.GEN.24.37',
#  'b.GEN.24.38',
#  'b.GEN.24.39',
#  'b.GEN.24.40',
#  'b.GEN.24.41',
#  'b.GEN.24.42',
#  'b.GEN.24.43',
#  'b.GEN.24.44',
#  'b.GEN.24.45',
#  'b.GEN.24.46',
#  'b.GEN.24.47',
#  'b.GEN.24.48',
#  'b.GEN.24.49',
#  'b.GEN.24.50',
#  'b.GEN.24.51',
#  'b.GEN.24.52',
#  'b.GEN.24.53',
#  'b.GEN.24.54',
#  'b.GEN.24.55',
#  'b.GEN.24.56',
#  'b.GEN.24.57',
#  'b.GEN.24.58',
#  'b.GEN.24.59',
#  'b.GEN.24.60',
#  'b.GEN.24.61',
#  'b.GEN.24.62',
#  'b.GEN.24.63',
#  'b.GEN.24.64',
#  'b.GEN.24.65',
#  'b.GEN.24.66',
#  'b.GEN.24.67',
#  'b.GEN.25.1',
#  'b.GEN.25.2',
#  'b.GEN.25.3',
#  'b.GEN.25.4',
#  'b.GEN.25.5',
#  'b.GEN.25.6',
#  'b.GEN.25.7',
#  'b.GEN.25.8',
#  'b.GEN.25.9',
#  'b.GEN.25.10',
#  'b.GEN.25.11',
#  'b.GEN.25.12',
#  'b.GEN.25.13',
#  'b.GEN.25.14',
#  'b.GEN.25.15',
#  'b.GEN.25.16',
#  'b.GEN.25.17',
#  'b.GEN.25.18',
#  'b.GEN.25.19',
#  'b.GEN.25.20',
#  'b.GEN.25.21',
#  'b.GEN.25.22',
#  'b.GEN.25.23',
#  'b.GEN.25.24',
#  'b.GEN.25.25',
#  'b.GEN.25.26',
#  'b.GEN.25.27',
#  'b.GEN.25.28',
#  'b.GEN.25.29',
#  'b.GEN.25.30',
#  'b.GEN.25.31',
#  'b.GEN.25.32',
#  'b.GEN.25.33',
#  'b.GEN.25.34',
#  'b.GEN.26.1',
#  'b.GEN.26.2',
#  'b.GEN.26.3',
#  'b.GEN.26.4',
#  'b.GEN.26.5',
#  'b.GEN.26.6',
#  'b.GEN.26.7',
#  'b.GEN.26.8',
#  'b.GEN.26.9',
#  'b.GEN.26.10',
#  'b.GEN.26.11',
#  'b.GEN.26.12',
#  'b.GEN.26.13',
#  'b.GEN.26.14',
#  'b.GEN.26.15',
#  'b.GEN.26.16',
#  'b.GEN.26.17',
#  'b.GEN.26.18',
#  'b.GEN.26.19',
#  'b.GEN.26.20',
#  'b.GEN.26.21',
#  'b.GEN.26.22',
#  'b.GEN.26.23',
#  'b.GEN.26.24',
#  'b.GEN.26.25',
#  'b.GEN.26.26',
#  'b.GEN.26.27',
#  'b.GEN.26.28',
#  'b.GEN.26.29',
#  'b.GEN.26.30',
#  'b.GEN.26.31',
#  'b.GEN.26.32',
#  'b.GEN.26.33',
#  'b.GEN.26.34',
#  'b.GEN.26.35',
#  'b.GEN.27.1',
#  'b.GEN.27.2',
#  'b.GEN.27.3',
#  'b.GEN.27.4',
#  'b.GEN.27.5',
#  'b.GEN.27.6',
#  'b.GEN.27.7',
#  'b.GEN.27.8',
#  'b.GEN.27.9',
#  'b.GEN.27.10',
#  'b.GEN.27.11',
#  'b.GEN.27.12',
#  'b.GEN.27.13',
#  'b.GEN.27.14',
#  'b.GEN.27.15',
#  'b.GEN.27.16',
#  'b.GEN.27.17',
#  'b.GEN.27.18',
#  'b.GEN.27.19',
#  'b.GEN.27.20',
#  'b.GEN.27.21',
#  'b.GEN.27.22',
#  'b.GEN.27.23',
#  'b.GEN.27.24',
#  'b.GEN.27.25',
#  'b.GEN.27.26',
#  'b.GEN.27.27',
#  'b.GEN.27.28',
#  'b.GEN.27.29',
#  'b.GEN.27.30',
#  'b.GEN.27.31',
#  'b.GEN.27.32',
#  'b.GEN.27.33',
#  'b.GEN.27.34',
#  'b.GEN.27.35',
#  'b.GEN.27.36',
#  'b.GEN.27.37',
#  'b.GEN.27.38',
#  'b.GEN.27.39',
#  'b.GEN.27.40',
#  'b.GEN.27.41',
#  'b.GEN.27.42',
#  'b.GEN.27.43',
#  'b.GEN.27.44',
#  'b.GEN.27.45',
#  'b.GEN.27.46',
#  'b.GEN.28.1',
#  'b.GEN.28.2',
#  'b.GEN.28.3',
#  'b.GEN.28.4',
#  'b.GEN.28.5',
#  'b.GEN.28.6',
#  'b.GEN.28.7',
#  'b.GEN.28.8',
#  'b.GEN.28.9',
#  'b.GEN.28.10',
#  'b.GEN.28.11',
#  'b.GEN.28.12',
#  'b.GEN.28.13',
#  'b.GEN.28.14',
#  'b.GEN.28.15',
#  'b.GEN.28.16',
#  'b.GEN.28.17',
#  'b.GEN.28.18',
#  'b.GEN.28.19',
#  'b.GEN.28.20',
#  'b.GEN.28.21',
#  'b.GEN.28.22',
#  'b.GEN.29.1',
#  'b.GEN.29.2',
#  'b.GEN.29.3',
#  'b.GEN.29.4',
#  'b.GEN.29.5',
#  'b.GEN.29.6',
#  'b.GEN.29.7',
#  'b.GEN.29.8',
#  'b.GEN.29.9',
#  'b.GEN.29.10',
#  'b.GEN.29.11',
#  'b.GEN.29.12',
#  'b.GEN.29.13',
#  'b.GEN.29.14',
#  'b.GEN.29.15',
#  'b.GEN.29.16',
#  'b.GEN.29.17',
#  'b.GEN.29.18',
#  'b.GEN.29.19',
#  'b.GEN.29.20',
#  'b.GEN.29.21',
#  'b.GEN.29.22',
#  'b.GEN.29.23',
#  'b.GEN.29.24',
#  'b.GEN.29.25',
#  'b.GEN.29.26',
#  'b.GEN.29.27',
#  'b.GEN.29.28',
#  'b.GEN.29.29',
#  'b.GEN.29.30',
#  'b.GEN.29.31',
#  'b.GEN.29.32',
#  'b.GEN.29.33',
#  'b.GEN.29.34',
#  'b.GEN.29.35',
#  'b.GEN.30.1',
#  'b.GEN.30.2',
#  'b.GEN.30.3',
#  'b.GEN.30.4',
#  'b.GEN.30.5',
#  'b.GEN.30.6',
#  'b.GEN.30.7',
#  'b.GEN.30.8',
#  'b.GEN.30.9',
#  'b.GEN.30.10',
#  'b.GEN.30.11',
#  'b.GEN.30.12',
#  'b.GEN.30.13',
#  'b.GEN.30.14',
#  'b.GEN.30.15',
#  'b.GEN.30.16',
#  'b.GEN.30.17',
#  'b.GEN.30.18',
#  'b.GEN.30.19',
#  'b.GEN.30.20',
#  'b.GEN.30.21',
#  'b.GEN.30.22',
#  'b.GEN.30.23',
#  'b.GEN.30.24',
#  'b.GEN.30.25',
#  'b.GEN.30.26',
#  'b.GEN.30.27',
#  'b.GEN.30.28',
#  'b.GEN.30.29',
#  'b.GEN.30.30',
#  'b.GEN.30.31',
#  'b.GEN.30.32',
#  'b.GEN.30.33',
#  'b.GEN.30.34',
#  'b.GEN.30.35',
#  'b.GEN.30.36',
#  'b.GEN.30.37',
#  'b.GEN.30.38',
#  'b.GEN.30.39',
#  'b.GEN.30.40',
#  'b.GEN.30.41',
#  'b.GEN.30.42',
#  'b.GEN.30.43',
#  'b.GEN.31.1',
#  'b.GEN.31.2',
#  'b.GEN.31.3',
#  'b.GEN.31.4',
#  'b.GEN.31.5',
#  'b.GEN.31.6',
#  'b.GEN.31.7',
#  'b.GEN.31.8',
#  'b.GEN.31.9',
#  'b.GEN.31.10',
#  'b.GEN.31.11',
#  'b.GEN.31.12',
#  'b.GEN.31.13',
#  'b.GEN.31.14',
#  'b.GEN.31.15',
#  'b.GEN.31.16',
#  'b.GEN.31.17',
#  'b.GEN.31.18',
#  'b.GEN.31.19',
#  'b.GEN.31.20',
#  'b.GEN.31.21',
#  'b.GEN.31.22',
#  'b.GEN.31.23',
#  'b.GEN.31.24',
#  'b.GEN.31.25',
#  'b.GEN.31.26',
#  'b.GEN.31.27',
#  'b.GEN.31.28',
#  'b.GEN.31.29',
#  'b.GEN.31.30',
#  'b.GEN.31.31',
#  'b.GEN.31.32',
#  'b.GEN.31.33',
#  'b.GEN.31.34',
#  'b.GEN.31.35',
#  'b.GEN.31.36',
#  'b.GEN.31.37',
#  'b.GEN.31.38',
#  'b.GEN.31.39',
#  'b.GEN.31.40',
#  'b.GEN.31.41',
#  'b.GEN.31.42',
#  'b.GEN.31.43',
#  'b.GEN.31.44',
#  'b.GEN.31.45',
#  'b.GEN.31.46',
#  'b.GEN.31.47',
#  'b.GEN.31.48',
#  'b.GEN.31.49',
#  'b.GEN.31.50',
#  'b.GEN.31.51',
#  'b.GEN.31.52',
#  'b.GEN.31.53',
#  'b.GEN.31.54',
#  'b.GEN.31.55',
#  'b.GEN.32.1',
#  'b.GEN.32.2',
#  'b.GEN.32.3',
#  'b.GEN.32.4',
#  'b.GEN.32.5',
#  'b.GEN.32.6',
#  'b.GEN.32.7',
#  'b.GEN.32.8',
#  'b.GEN.32.9',
#  'b.GEN.32.10',
#  'b.GEN.32.11',
#  'b.GEN.32.12',
#  'b.GEN.32.13',
#  'b.GEN.32.14',
#  'b.GEN.32.15',
#  'b.GEN.32.16',
#  'b.GEN.32.17',
#  'b.GEN.32.18',
#  'b.GEN.32.19',
#  'b.GEN.32.20',
#  'b.GEN.32.21',
#  'b.GEN.32.22',
#  'b.GEN.32.23',
#  'b.GEN.32.24',
#  'b.GEN.32.25',
#  'b.GEN.32.26',
#  'b.GEN.32.27',
#  'b.GEN.32.28',
#  'b.GEN.32.29',
#  'b.GEN.32.30',
#  'b.GEN.32.31',
#  'b.GEN.32.32',
#  'b.GEN.33.1',
#  'b.GEN.33.2',
#  'b.GEN.33.3',
#  'b.GEN.33.4',
#  'b.GEN.33.5',
#  'b.GEN.33.6',
#  'b.GEN.33.7',
#  'b.GEN.33.8',
#  'b.GEN.33.9',
#  'b.GEN.33.10',
#  'b.GEN.33.11',
#  'b.GEN.33.12',
#  'b.GEN.33.13',
#  'b.GEN.33.14',
#  'b.GEN.33.15',
#  'b.GEN.33.16',
#  'b.GEN.33.17',
#  'b.GEN.33.18',
#  'b.GEN.33.19',
#  'b.GEN.33.20',
#  'b.GEN.34.1',
#  'b.GEN.34.2',
#  'b.GEN.34.3',
#  'b.GEN.34.4',
#  'b.GEN.34.5',
#  'b.GEN.34.6',
#  'b.GEN.34.7',
#  'b.GEN.34.8',
#  'b.GEN.34.9',
#  'b.GEN.34.10',
#  'b.GEN.34.11',
#  'b.GEN.34.12',
#  'b.GEN.34.13',
#  'b.GEN.34.14',
#  'b.GEN.34.15',
#  'b.GEN.34.16',
#  'b.GEN.34.17',
#  'b.GEN.34.18',
#  'b.GEN.34.19',
#  ...]
